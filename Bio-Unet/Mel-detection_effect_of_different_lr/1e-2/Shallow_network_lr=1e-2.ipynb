# %%
import sys
sys.executable
# Out:
# '/home/rs37890/.conda/envs/UDA/bin/python'

# %%
import os
import re
import sys
import time
import copy
import h5py
import random
import logging
import argparse
import numpy as np
import pandas as pd
from PIL import Image

# %%
import torch
import torch.nn as nn

# %%
from torchvision import *
import torchvision.models

# %%
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # args

# %%
parser = argparse.ArgumentParser()

parser.add_argument('--report-freq', type=int, default=1, help='logging frequency')
parser.add_argument('--tune-mode', type=str, default='fine-tune', choices=['fine-tune', 'feature-extract'], help='tuning mode' )
parser.add_argument('--backbone', type=str, default='resnet50', choices=['resnet50', 'vgg19', 'inception_v3'], 
                    help='backbone architecture' )
parser.add_argument('--cls-type', type=str, default='single', choices=['single', 
                   'double', 'double-bn', 'double-dropout'], help='classifier architecture' )
parser.add_argument('--hidden-dim', type=int, default=512, help='hidden dimension of classifier' )
parser.add_argument('--record-root-dir', type=str, default='./record-data', help='record data root dir' )
parser.add_argument('--exp', type=str, default='default_exp', help='name of experiment' )
parser.add_argument('--batch-size', type=int, default=8, help='batch size' )
parser.add_argument('--num-workers', type=int, default=0, help='number of processes working on cpu.')
parser.add_argument('--num-classes', type=int, default=5, help='number of classes')
parser.add_argument('--num-epochs', type=int, default=20,  help='number of epochs.')
parser.add_argument( '--num-steps', type=int, default=-1, help='number of steps per epoch. '+ '-1 means use entire data' )
parser.add_argument('--learn-rate', type=float, default=1e-3, help='learning rate for gradient descent')
parser.add_argument('--weight-decay', type=float, default=1e-3, help='weight decay for optimization')
parser.add_argument('--resume', action='store_true', help='resume experiment <exp> from last checkpoint' )
parser.add_argument('--input-dir', type=str, default= r'../h5py/', help='data root dir' )
parser.add_argument('--save-name', type=str, default='model.pt', help='saved model name' )

args, unknown =  parser.parse_known_args()

# %%
# device
DEVICE = 'cuda:0' if torch.cuda.is_available() else 'cpu'
args.device = DEVICE
args.gpu_ids = [0]

# %%
args.num_epochs = 100
args.learn_rate = 1e-2
args.weight_decay = 1e-2 
args.batch_size = 120
args.num_classes = 1
args.seed = 1111

# %%
args.root = '/scratch/rs37890/CARC/Explainable-NN-model'
args.sub_root = '/Fold1_Bio-Unet-stage1'
args.shallow_network_folder = '/Mel-detection_effect_of_different_lr/1e-2'
args.checkpoint_root = '/F(CLR) + F(Res) + F(Seg)'

args.csv_h5_dir = args.root + '/Data'

args.record_dir = args.root  + args.sub_root + args.shallow_network_folder + '/record_dir'
args.save_name = 'Resnet50'

# %% [markdown]
# # dataset

# %%
def get_transform(split):
    
    img_size = ( 512, 512 )
    Normal_transform = transforms.Compose([ transforms.Resize( img_size ),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])],
                                         )

    return Normal_transform

# %%
class SkinDataset( torch.utils.data.Dataset ):

    def __init__( self, h5_file_path, transform, split, args):
        self.h5_file_path = h5_file_path
        self.h5_file = None
        self.transform = transform
        self.split = split
        self.img_id_to_h5idx = self.build_img_id_to_h5idx()
        self.num_imgs = self.get_num_imgs() 

        self.args = args

        self.ATTR_TO_INDEX = { 'globules': 0,
                               'milia_like_cyst': 1,
                               'negative_network': 2,
                               'pigment_network': 3,
                               'streaks': 4,
                             }

    def get_num_imgs( self ):
        with h5py.File( self.h5_file_path, 'r' ) as f:
            return len( f['image_ids'] )

    def build_img_id_to_h5idx( self ):
        with h5py.File( self.h5_file_path, 'r' ) as f:
            
            img_ids = f['image_ids']
            img_id_to_h5idx = { img_id : idx for idx, img_id in enumerate( img_ids ) }
            
            return img_id_to_h5idx

    def __len__( self ):
        return self.get_num_imgs()

    def __getitem__( self, idx ):
        # import pdb; pdb.set_trace()
        if not self.h5_file:
            self.h5_file = h5py.File( self.h5_file_path, 'r' )
            
        img_id = self.h5_file['image_ids'][idx]
        img = self.h5_file['images'][idx]
        img = img.transpose([1, 2, 0])

        assert img.shape == (512, 512, 3)

        img = Image.fromarray( np.uint8(img) )
        
        if self.split == 'unsup':
            img1 = self.transform( img )
            img2 = self.transform( img )
            return img_id, img1, img2
        
        else:
            masks = self.h5_file['masks'][idx]
            labels = self.h5_file['labels'][idx].astype(np.float64)
            img = self.transform( img )

            # labels[0] globus
            # labels[1] milia_like_cyst
            # labels[2] negative
            # labels[3] pigment
            # labels[4] streaks
            # labels[5] melanoma
            
            index = 5

            assert masks.shape == (5, 512, 512)
            assert np.expand_dims(labels[index], axis=0).shape == (1,)
            
            return img_id, img, np.expand_dims(labels[index], axis=0), masks

# %%
def get_dataloader( args ):
    
    dataloader = {}
    splits = [ 'train', 'val' ]
    
    for split in splits:
        
        h5_file_path = os.path.join( args.csv_h5_dir, f'{split}.h5' )
        transform = get_transform(split)

        bsz = args.batch_size
        
        dataset = SkinDataset( h5_file_path, transform, split, args)
        loader = torch.utils.data.DataLoader( dataset = dataset,
                                              batch_size = bsz,
                                              shuffle = True if split != 'val' else False,
                                              num_workers = args.num_workers,
                                              drop_last = False,
                                            )
        
        dataloader[ split ] = loader
        
    return dataloader

# %% [markdown]
# # Load model

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.base_model = torchvision.models.resnet50(pretrained=True)
        self.base_layers = list(self.base_model.children())
        
        self.layer0 = nn.Sequential(*self.base_layers[:3])
        self.layer1 = nn.Sequential(*self.base_layers[3:5]) # size=(N, 256, x.H/4, x.W/4)
        self.layer2 = self.base_layers[5]  # size=(N, 512, x.H/8, x.W/8)
        self.layer3 = self.base_layers[6]  # size=(N, 1024, x.H/16, x.W/16)
        self.layer4 = self.base_layers[7]  # size=(N, 2048, x.H/32, x.W/32)
        self.Avgpooling = nn.Sequential(self.base_layers[8])
        
        self.mlp = torch.nn.Sequential( torch.nn.Linear(2048,1), )# only one linear layer on top
        
    def forward(self, X):
        layer0 = self.layer0(X)  # layer0:  torch.Size([1, 64, 256, 256])
        layer1 = self.layer1(layer0) # layer1:  torch.Size([1, 256, 128, 128])
        layer2 = self.layer2(layer1) # layer2:  torch.Size([1, 512, 64, 64])
        layer3 = self.layer3(layer2) # layer3:  torch.Size([1, 1024, 32, 32])
        layer4 = self.layer4(layer3) # layer4:  torch.Size([1, 2048, 16, 16])
        out    = self.Avgpooling(layer4)
        
        out1 = torch.squeeze(out) 
        if X.size(0) == 1: # torch.Size([1, 2048, 1, 1]) => torch.Size([2048])
            out1 = torch.unsqueeze(out1, 0) # torch.Size([1, 2048])
        out = self.mlp(out1)
        return out1, out

# %% [markdown]
# # Streaks

# %%
net = Model()
streaks_net = torch.nn.DataParallel(net)
streaks_net = streaks_net.module.to( DEVICE )
# Out:
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/streaks"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
streaks_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
streaks_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/streaks/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(streaks_Model_path)
streaks_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Pigment

# %%
net = Model()
pigment_net = torch.nn.DataParallel(net)
pigment_net = pigment_net.to( DEVICE )
pigment_net = pigment_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/pigment"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
pigment_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
pigment_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/pigment/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(pigment_Model_path)
pigment_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Negative

# %%
net = Model()
negative_net = torch.nn.DataParallel(net)
negative_net = negative_net.to( DEVICE )
negative_net = negative_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/negative"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
negative_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
negative_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/negative/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(negative_Model_path)
negative_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Milia

# %%
net = Model()
milia_net = torch.nn.DataParallel(net)
milia_net = milia_net.to( DEVICE )
milia_net = milia_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/milia_like_cyst"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
milia_like_cyst_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
milia_like_cyst_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/milia_like_cyst/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(milia_like_cyst_Model_path)
milia_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Globules

# %%
net = Model()
globules_net = torch.nn.DataParallel(net)
globules_net = globules_net.to( DEVICE )
globules_net = globules_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/globules"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
globules_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
globules_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/globules/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(globules_Model_path)
globules_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # softmax

# %%
class LogisticRegression(torch.nn.Module): 
    def __init__(self, input_dim = 10240, output_dim = 1): 
        super(LogisticRegression, self).__init__() 
        #self.linear = torch.nn.Linear(input_dim, output_dim) 
        self.linear1 = torch.nn.Linear(input_dim, 2048) 
        self.linear2 = torch.nn.Linear(2048, 512) 
        self.linear3 = torch.nn.Linear(512, output_dim) 
        
    def forward(self, x): 
        #outputs = torch.sigmoid(self.linear(x)) 
        output1 = self.linear1(x)
        output2 = self.linear2(output1)
        output3 = self.linear3(output2)
        
        return nn.Sigmoid()(output3).type(torch.float64)

# %% [markdown]
# # Trainer

# %%
class AverageMeter:
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
class Trainer:
    def __init__(self, 
                 model, 
                 globules_net , milia_net, negative_net, pigment_net, streaks_net,
                 dataloader, 
                 args,
                ):
        
        self.model = model.to(args.device)
        self.dataloader = dataloader
        self.args = args
        self.best_loss = np.inf
        self.best_epoch = 0
        self.best_model = None
        self.current_epoch = 0

        self.globules_net = globules_net.to(args.device)
        self.milia_net = milia_net.to(args.device)
        self.negative_net = negative_net.to(args.device)
        self.pigment_net = pigment_net.to(args.device)
        self.streaks_net = streaks_net.to(args.device)


        self.globules_net.eval()
        self.milia_net.eval()
        self.negative_net.eval()
        self.pigment_net.eval()
        self.streaks_net.eval()
        

        self.criterion = nn.BCELoss()
        self.optimizer = torch.optim.Adam( params = self.model.parameters(),
                                           lr = self.args.learn_rate,
                                           weight_decay = self.args.weight_decay,
                                         )

        self.logger = self.setup_logger()
        self.setup_experiment()
        self.set_random_seeds()

    def setup_logger(self):
        log_file = 'log.txt'
        if os.path.exists(log_file):
            os.remove(log_file)  # Remove the existing log file if it exists
        
        logger = logging.getLogger('Trainer')
        logger.setLevel(logging.INFO)
    
        # File Handler for log files
        fh = logging.FileHandler(log_file)
        fh.setLevel(logging.INFO)
        file_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        fh.setFormatter(file_formatter)
        logger.addHandler(fh)
    
        # Stream Handler for console output
        ch = logging.StreamHandler()
        ch.setLevel(logging.INFO)
        console_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        ch.setFormatter(console_formatter)
        logger.addHandler(ch)
    
        return logger

    def setup_experiment(self):
        self.name = self.args.exp
        self.exp_dir = os.path.join(self.args.record_root_dir, self.name)
        self.logger.info(f'seed is: {self.args.seed}')
        self.logger.info(f'args: {self.args}')

    def set_random_seeds(self):
        seed = random.randint(0, 100000)
        torch.manual_seed(seed)
        random.seed(seed)
        np.random.seed(seed)
        self.args.seed = seed

    def get_accuracy(self, pred, labels):
        predicted_labels = (pred > 0.5).int()
        correct_predictions = (predicted_labels == labels).sum().item()
        total_predictions = labels.size(0)
        accuracy = correct_predictions / total_predictions
        return accuracy

    def concate_5120(self, imgs):
        # This function should include model evaluation calls
        # Assuming these models are attributes of the class
        with torch.no_grad():
            pred1, _ = self.globules_net(imgs)
            pred2, _ = self.negative_net(imgs)
            pred3, _ = self.milia_net(imgs)
            pred4, _ = self.pigment_net(imgs)
            pred5, _ = self.streaks_net(imgs)
            return torch.cat((pred1, pred2, pred3, pred4, pred5), 1)

    def train_or_val(self, mode='train'):
        
        assert mode in ['train', 'val'], "Mode must be 'train' or 'val'"
        dataloader = self.dataloader[mode]
        num_steps = len(dataloader)
        self.model.train() if mode == 'train' else self.model.eval()

        loss_meter = AverageMeter()
        acc_meter = AverageMeter()
        data_time_meter = AverageMeter()
        batch_time_meter = AverageMeter()
        all_preds = []
        all_labels = []

        start = time.time()
        for batch_id, (img_ids, imgs, labels, masks) in enumerate(dataloader):
            data_time = time.time() - start
            if batch_id >= num_steps: break

            imgs, labels = imgs.to(self.args.device), labels.to(self.args.device)
            
            if mode == 'train':
                self.optimizer.zero_grad()

            concate_input = self.concate_5120(imgs)
            pred = self.model(concate_input)

            
            loss = self.criterion(pred, labels)
            if mode == 'train':
                loss.backward()
                self.optimizer.step()

            loss_meter.update(loss.item(), len(imgs))
            acc = self.get_accuracy( pred.detach().cpu(), labels.cpu() )
            acc_meter.update(acc, len(imgs))
            batch_time = time.time() - start

            data_time_meter.update(data_time)
            batch_time_meter.update(batch_time)
            all_preds.append(pred.detach().cpu())
            all_labels.append(labels.cpu())

            # if (batch_id+1) % self.args.report_freq == 0:
            self.log_epoch_stats(mode.upper(), batch_id, num_steps, loss_meter.avg, acc_meter.avg, 0, data_time_meter.avg, batch_time_meter.avg)

            start = time.time()

        all_labels = torch.cat(all_labels, dim=0)
        all_preds = torch.cat(all_preds, dim=0)
        self.auc_scores = roc_auc_score( np.array(all_labels), np.array(all_preds), average=None)
        self.log_auc_scores(self.auc_scores)

        return loss_meter.avg, acc_meter.avg, self.auc_scores.mean()

    def log_epoch_stats(self, phase, batch_id, num_steps, avg_loss, avg_acc, mean_auc, avg_data_time, avg_batch_time):
        self.logger.info(f'{phase} Epoch: {self.current_epoch} Step: {batch_id}/{num_steps} Loss: {avg_loss:.4f} Accuracy: {avg_acc:.4f} AUC: {mean_auc:.4f} Data Time: {avg_data_time:.4f} Batch Time: {avg_batch_time:.4f}')

    def log_auc_scores(self, auc_scores):
        if isinstance(auc_scores, np.ndarray):
            for i, score in enumerate(auc_scores):
                self.logger.info(f'AUC Score {i}: {score:.4f}')
        else:
            self.logger.info(f'AUC Score: {auc_scores:.4f}')

    def save_model(self, save_path):
        torch.save(self.model.state_dict(), save_path)

    def train(self):
        for epoch in range(self.current_epoch, self.args.num_epochs):
            self.current_epoch = epoch
            self.logger.info(f'Starting Epoch: {epoch + 1}')
            train_loss, train_acc, train_auc = self.train_or_val('train')
            val_loss, val_acc, val_auc = self.train_or_val('val')

            if val_loss < self.best_loss:
                self.best_loss = val_loss
                self.best_model = copy.deepcopy(self.model)
                self.best_epoch = epoch + 1
                self.logger.info(f'New best model at epoch: {epoch + 1}')

                save_path = os.path.join( self.args.record_dir, self.args.save_name + '_best.pt')
                self.save_model(save_path)

            save_path = os.path.join( self.args.record_dir, self.args.save_name + '.pt')
            self.save_model(save_path)

# %%
dataloaders = get_dataloader( args )

# %%
trainer = Trainer(LogisticRegression(), 
                  globules_net , milia_net, negative_net, pigment_net, streaks_net,
                  dataloaders, 
                  args,
                 )
# Out:
# 2024-06-25 18:44:02,645 - INFO - seed is: 1111
# 2024-06-25 18:44:02,646 - INFO - args: Namespace(report_freq=1, tune_mode='fine-tune', backbone='resnet50', cls_type='single', hidden_dim=512, record_root_dir='./record-data', exp='default_exp', batch_size=120, num_workers=0, num_classes=1, num_epochs=100, num_steps=-1, learn_rate=0.01, weight_decay=0.01, resume=False, input_dir='../h5py/', save_name='Resnet50', device='cuda:0', gpu_ids=[0], seed=1111, root='/scratch/rs37890/CARC/Explainable-NN-model', sub_root='/Fold1_Bio-Unet-stage1', shallow_network_folder='/Mel-detection_effect_of_different_lr/1e-2', checkpoint_root='/F(CLR) + F(Res) + F(Seg)', csv_h5_dir='/scratch/rs37890/CARC/Explainable-NN-model/Data', record_dir='/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/Mel-detection_effect_of_different_lr/1e-2/record_dir')

# %%
trainer.train()
# Out:
# 2024-06-25 18:44:02,653 - INFO - Starting Epoch: 1
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1712608885084/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:84.)
#   return F.conv2d(input, weight, bias, self.stride,
# 2024-06-25 18:44:04,876 - INFO - TRAIN Epoch: 0 Step: 0/18 Loss: 0.7078 Accuracy: 0.2417 AUC: 0.0000 Data Time: 1.2087 Batch Time: 2.2218
# 2024-06-25 18:44:07,537 - INFO - TRAIN Epoch: 0 Step: 1/18 Loss: 6.6039 Accuracy: 0.5583 AUC: 0.0000 Data Time: 1.4766 Batch Time: 2.4404
# 2024-06-25 18:44:10,501 - INFO - TRAIN Epoch: 0 Step: 2/18 Loss: 10.7915 Accuracy: 0.6417 AUC: 0.0000 Data Time: 1.6337 Batch Time: 2.6145
# 2024-06-25 18:44:13,389 - INFO - TRAIN Epoch: 0 Step: 3/18 Loss: 12.0519 Accuracy: 0.6917 AUC: 0.0000 Data Time: 1.7154 Batch Time: 2.6823
# 2024-06-25 18:44:16,284 - INFO - TRAIN Epoch: 0 Step: 4/18 Loss: 13.6416 Accuracy: 0.7133 AUC: 0.0000 Data Time: 1.7652 Batch Time: 2.7245
# 2024-06-25 18:44:19,238 - INFO - TRAIN Epoch: 0 Step: 5/18 Loss: 13.6394 Accuracy: 0.7361 AUC: 0.0000 Data Time: 1.7768 Batch Time: 2.7623
# 2024-06-25 18:44:22,565 - INFO - TRAIN Epoch: 0 Step: 6/18 Loss: 12.4555 Accuracy: 0.7464 AUC: 0.0000 Data Time: 1.8720 Batch Time: 2.8428
# 2024-06-25 18:44:26,065 - INFO - TRAIN Epoch: 0 Step: 7/18 Loss: 20.6902 Accuracy: 0.6802 AUC: 0.0000 Data Time: 1.8962 Batch Time: 2.9247
# 2024-06-25 18:44:29,660 - INFO - TRAIN Epoch: 0 Step: 8/18 Loss: 27.7432 Accuracy: 0.6222 AUC: 0.0000 Data Time: 1.8647 Batch Time: 2.9989
# 2024-06-25 18:44:33,112 - INFO - TRAIN Epoch: 0 Step: 9/18 Loss: 32.5522 Accuracy: 0.5842 AUC: 0.0000 Data Time: 1.8135 Batch Time: 3.0441
# 2024-06-25 18:44:36,218 - INFO - TRAIN Epoch: 0 Step: 10/18 Loss: 36.4868 Accuracy: 0.5530 AUC: 0.0000 Data Time: 1.7536 Batch Time: 3.0490
# 2024-06-25 18:44:39,985 - INFO - TRAIN Epoch: 0 Step: 11/18 Loss: 40.4602 Accuracy: 0.5201 AUC: 0.0000 Data Time: 1.7557 Batch Time: 3.1087
# 2024-06-25 18:44:43,900 - INFO - TRAIN Epoch: 0 Step: 12/18 Loss: 43.5658 Accuracy: 0.4949 AUC: 0.0000 Data Time: 1.7537 Batch Time: 3.1705
# 2024-06-25 18:44:47,842 - INFO - TRAIN Epoch: 0 Step: 13/18 Loss: 46.1087 Accuracy: 0.4744 AUC: 0.0000 Data Time: 1.7590 Batch Time: 3.2255
# 2024-06-25 18:44:51,698 - INFO - TRAIN Epoch: 0 Step: 14/18 Loss: 48.4792 Accuracy: 0.4550 AUC: 0.0000 Data Time: 1.7595 Batch Time: 3.2673
# 2024-06-25 18:44:55,683 - INFO - TRAIN Epoch: 0 Step: 15/18 Loss: 49.8243 Accuracy: 0.4453 AUC: 0.0000 Data Time: 1.7634 Batch Time: 3.3120
# 2024-06-25 18:44:59,384 - INFO - TRAIN Epoch: 0 Step: 16/18 Loss: 51.1581 Accuracy: 0.4353 AUC: 0.0000 Data Time: 1.7602 Batch Time: 3.3347
# 2024-06-25 18:45:00,591 - INFO - TRAIN Epoch: 0 Step: 17/18 Loss: 51.6213 Accuracy: 0.4315 AUC: 0.0000 Data Time: 1.7067 Batch Time: 3.2164
# 2024-06-25 18:45:00,596 - INFO - AUC Score: 0.5362
# 2024-06-25 18:45:03,476 - INFO - VAL Epoch: 0 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.9431 Batch Time: 2.8763
# 2024-06-25 18:45:06,500 - INFO - VAL Epoch: 0 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 2.0112 Batch Time: 2.9494
# 2024-06-25 18:45:09,186 - INFO - VAL Epoch: 0 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 1.9365 Batch Time: 2.8588
# 2024-06-25 18:45:12,848 - INFO - VAL Epoch: 0 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 2.1068 Batch Time: 3.0576
# 2024-06-25 18:45:13,991 - INFO - VAL Epoch: 0 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 1.7704 Batch Time: 2.6744
# 2024-06-25 18:45:13,995 - INFO - AUC Score: 0.5000
# 2024-06-25 18:45:13,996 - INFO - New best model at epoch: 1
# 2024-06-25 18:45:14,178 - INFO - Starting Epoch: 2
# 2024-06-25 18:45:17,219 - INFO - TRAIN Epoch: 1 Step: 0/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 2.0315 Batch Time: 3.0391
# 2024-06-25 18:45:20,040 - INFO - TRAIN Epoch: 1 Step: 1/18 Loss: 81.2500 Accuracy: 0.1875 AUC: 0.0000 Data Time: 1.7579 Batch Time: 2.9286
# 2024-06-25 18:45:22,082 - INFO - TRAIN Epoch: 1 Step: 2/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.5670 Batch Time: 2.6327
# 2024-06-25 18:45:24,321 - INFO - TRAIN Epoch: 1 Step: 3/18 Loss: 79.7917 Accuracy: 0.2021 AUC: 0.0000 Data Time: 1.5192 Batch Time: 2.5339
# 2024-06-25 18:45:26,288 - INFO - TRAIN Epoch: 1 Step: 4/18 Loss: 78.5000 Accuracy: 0.2150 AUC: 0.0000 Data Time: 1.4362 Batch Time: 2.4205
# 2024-06-25 18:45:28,026 - INFO - TRAIN Epoch: 1 Step: 5/18 Loss: 78.1944 Accuracy: 0.2181 AUC: 0.0000 Data Time: 1.3424 Batch Time: 2.3063
# 2024-06-25 18:45:29,826 - INFO - TRAIN Epoch: 1 Step: 6/18 Loss: 79.2857 Accuracy: 0.2071 AUC: 0.0000 Data Time: 1.2845 Batch Time: 2.2338
# 2024-06-25 18:45:31,871 - INFO - TRAIN Epoch: 1 Step: 7/18 Loss: 78.8542 Accuracy: 0.2115 AUC: 0.0000 Data Time: 1.2716 Batch Time: 2.2100
# 2024-06-25 18:45:33,993 - INFO - TRAIN Epoch: 1 Step: 8/18 Loss: 78.6111 Accuracy: 0.2139 AUC: 0.0000 Data Time: 1.2702 Batch Time: 2.2001
# 2024-06-25 18:45:35,715 - INFO - TRAIN Epoch: 1 Step: 9/18 Loss: 79.0833 Accuracy: 0.2092 AUC: 0.0000 Data Time: 1.2292 Batch Time: 2.1523
# 2024-06-25 18:45:37,530 - INFO - TRAIN Epoch: 1 Step: 10/18 Loss: 78.4848 Accuracy: 0.2152 AUC: 0.0000 Data Time: 1.2040 Batch Time: 2.1216
# 2024-06-25 18:45:39,664 - INFO - TRAIN Epoch: 1 Step: 11/18 Loss: 78.9583 Accuracy: 0.2104 AUC: 0.0000 Data Time: 1.2096 Batch Time: 2.1225
# 2024-06-25 18:45:41,760 - INFO - TRAIN Epoch: 1 Step: 12/18 Loss: 79.0385 Accuracy: 0.2096 AUC: 0.0000 Data Time: 1.2114 Batch Time: 2.1204
# 2024-06-25 18:45:43,936 - INFO - TRAIN Epoch: 1 Step: 13/18 Loss: 79.6429 Accuracy: 0.2036 AUC: 0.0000 Data Time: 1.2187 Batch Time: 2.1243
# 2024-06-25 18:45:46,136 - INFO - TRAIN Epoch: 1 Step: 14/18 Loss: 79.7222 Accuracy: 0.2028 AUC: 0.0000 Data Time: 1.2266 Batch Time: 2.1293
# 2024-06-25 18:45:47,907 - INFO - TRAIN Epoch: 1 Step: 15/18 Loss: 79.5833 Accuracy: 0.2042 AUC: 0.0000 Data Time: 1.2067 Batch Time: 2.1069
# 2024-06-25 18:45:49,943 - INFO - TRAIN Epoch: 1 Step: 16/18 Loss: 79.9510 Accuracy: 0.2005 AUC: 0.0000 Data Time: 1.2047 Batch Time: 2.1026
# 2024-06-25 18:45:50,460 - INFO - TRAIN Epoch: 1 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 1.1520 Batch Time: 2.0145
# 2024-06-25 18:45:50,463 - INFO - AUC Score: 0.5000
# 2024-06-25 18:45:52,279 - INFO - VAL Epoch: 1 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.9545 Batch Time: 1.8144
# 2024-06-25 18:45:54,092 - INFO - VAL Epoch: 1 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 0.9532 Batch Time: 1.8131
# 2024-06-25 18:45:55,871 - INFO - VAL Epoch: 1 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 0.9413 Batch Time: 1.8013
# 2024-06-25 18:45:57,612 - INFO - VAL Epoch: 1 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.9260 Batch Time: 1.7860
# 2024-06-25 18:45:58,173 - INFO - VAL Epoch: 1 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 0.7945 Batch Time: 1.5410
# 2024-06-25 18:45:58,176 - INFO - AUC Score: 0.5000
# 2024-06-25 18:45:58,280 - INFO - Starting Epoch: 3
# 2024-06-25 18:45:59,998 - INFO - TRAIN Epoch: 2 Step: 0/18 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 0.8551 Batch Time: 1.7166
# 2024-06-25 18:46:01,735 - INFO - TRAIN Epoch: 2 Step: 1/18 Loss: 79.1667 Accuracy: 0.2083 AUC: 0.0000 Data Time: 0.8649 Batch Time: 1.7265
# 2024-06-25 18:46:03,431 - INFO - TRAIN Epoch: 2 Step: 2/18 Loss: 79.1667 Accuracy: 0.2083 AUC: 0.0000 Data Time: 0.8544 Batch Time: 1.7161
# 2024-06-25 18:46:05,103 - INFO - TRAIN Epoch: 2 Step: 3/18 Loss: 79.3750 Accuracy: 0.2062 AUC: 0.0000 Data Time: 0.8430 Batch Time: 1.7047
# 2024-06-25 18:46:06,904 - INFO - TRAIN Epoch: 2 Step: 4/18 Loss: 79.3333 Accuracy: 0.2067 AUC: 0.0000 Data Time: 0.8621 Batch Time: 1.7238
# 2024-06-25 18:46:08,694 - INFO - TRAIN Epoch: 2 Step: 5/18 Loss: 78.6111 Accuracy: 0.2139 AUC: 0.0000 Data Time: 0.8729 Batch Time: 1.7348
# 2024-06-25 18:46:10,501 - INFO - TRAIN Epoch: 2 Step: 6/18 Loss: 78.9286 Accuracy: 0.2107 AUC: 0.0000 Data Time: 0.8831 Batch Time: 1.7449
# 2024-06-25 18:46:12,294 - INFO - TRAIN Epoch: 2 Step: 7/18 Loss: 78.7500 Accuracy: 0.2125 AUC: 0.0000 Data Time: 0.8890 Batch Time: 1.7509
# 2024-06-25 18:46:14,051 - INFO - TRAIN Epoch: 2 Step: 8/18 Loss: 78.7963 Accuracy: 0.2120 AUC: 0.0000 Data Time: 0.8896 Batch Time: 1.7513
# 2024-06-25 18:46:16,178 - INFO - TRAIN Epoch: 2 Step: 9/18 Loss: 78.5833 Accuracy: 0.2142 AUC: 0.0000 Data Time: 0.9271 Batch Time: 1.7889
# 2024-06-25 18:46:17,982 - INFO - TRAIN Epoch: 2 Step: 10/18 Loss: 78.7879 Accuracy: 0.2121 AUC: 0.0000 Data Time: 0.9284 Batch Time: 1.7901
# 2024-06-25 18:46:20,111 - INFO - TRAIN Epoch: 2 Step: 11/18 Loss: 79.2361 Accuracy: 0.2076 AUC: 0.0000 Data Time: 0.9564 Batch Time: 1.8183
# 2024-06-25 18:46:21,845 - INFO - TRAIN Epoch: 2 Step: 12/18 Loss: 79.1667 Accuracy: 0.2083 AUC: 0.0000 Data Time: 0.9499 Batch Time: 1.8117
# 2024-06-25 18:46:23,940 - INFO - TRAIN Epoch: 2 Step: 13/18 Loss: 79.4048 Accuracy: 0.2060 AUC: 0.0000 Data Time: 0.9701 Batch Time: 1.8319
# 2024-06-25 18:46:26,058 - INFO - TRAIN Epoch: 2 Step: 14/18 Loss: 79.7222 Accuracy: 0.2028 AUC: 0.0000 Data Time: 0.9891 Batch Time: 1.8509
# 2024-06-25 18:46:27,873 - INFO - TRAIN Epoch: 2 Step: 15/18 Loss: 79.8438 Accuracy: 0.2016 AUC: 0.0000 Data Time: 0.9868 Batch Time: 1.8486
# 2024-06-25 18:46:29,914 - INFO - TRAIN Epoch: 2 Step: 16/18 Loss: 79.9020 Accuracy: 0.2010 AUC: 0.0000 Data Time: 0.9981 Batch Time: 1.8599
# 2024-06-25 18:46:30,576 - INFO - TRAIN Epoch: 2 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 0.9649 Batch Time: 1.7933
# 2024-06-25 18:46:30,578 - INFO - AUC Score: 0.5000
# 2024-06-25 18:46:32,377 - INFO - VAL Epoch: 2 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.9376 Batch Time: 1.7974
# 2024-06-25 18:46:34,404 - INFO - VAL Epoch: 2 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 1.0514 Batch Time: 1.9114
# 2024-06-25 18:46:36,487 - INFO - VAL Epoch: 2 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 1.1086 Batch Time: 1.9685
# 2024-06-25 18:46:38,223 - INFO - VAL Epoch: 2 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.0502 Batch Time: 1.9100
# 2024-06-25 18:46:38,832 - INFO - VAL Epoch: 2 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 0.9033 Batch Time: 1.6496
# 2024-06-25 18:46:38,834 - INFO - AUC Score: 0.5000
# 2024-06-25 18:46:38,938 - INFO - Starting Epoch: 4
# 2024-06-25 18:46:40,656 - INFO - TRAIN Epoch: 3 Step: 0/18 Loss: 76.6667 Accuracy: 0.2333 AUC: 0.0000 Data Time: 0.8546 Batch Time: 1.7160
# 2024-06-25 18:46:42,722 - INFO - TRAIN Epoch: 3 Step: 1/18 Loss: 77.9167 Accuracy: 0.2208 AUC: 0.0000 Data Time: 1.0292 Batch Time: 1.8907
# 2024-06-25 18:46:44,529 - INFO - TRAIN Epoch: 3 Step: 2/18 Loss: 79.1667 Accuracy: 0.2083 AUC: 0.0000 Data Time: 1.0007 Batch Time: 1.8624
# 2024-06-25 18:46:46,649 - INFO - TRAIN Epoch: 3 Step: 3/18 Loss: 79.3750 Accuracy: 0.2062 AUC: 0.0000 Data Time: 1.0648 Batch Time: 1.9266
# 2024-06-25 18:46:48,452 - INFO - TRAIN Epoch: 3 Step: 4/18 Loss: 79.6667 Accuracy: 0.2033 AUC: 0.0000 Data Time: 1.0400 Batch Time: 1.9018
# 2024-06-25 18:46:50,200 - INFO - TRAIN Epoch: 3 Step: 5/18 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.0141 Batch Time: 1.8759
# 2024-06-25 18:46:52,345 - INFO - TRAIN Epoch: 3 Step: 6/18 Loss: 80.5952 Accuracy: 0.1940 AUC: 0.0000 Data Time: 1.0524 Batch Time: 1.9142
# 2024-06-25 18:46:54,047 - INFO - TRAIN Epoch: 3 Step: 7/18 Loss: 80.3125 Accuracy: 0.1969 AUC: 0.0000 Data Time: 1.0257 Batch Time: 1.8875
# 2024-06-25 18:46:56,150 - INFO - TRAIN Epoch: 3 Step: 8/18 Loss: 80.6481 Accuracy: 0.1935 AUC: 0.0000 Data Time: 1.0496 Batch Time: 1.9114
# 2024-06-25 18:46:57,979 - INFO - TRAIN Epoch: 3 Step: 9/18 Loss: 80.6667 Accuracy: 0.1933 AUC: 0.0000 Data Time: 1.0413 Batch Time: 1.9031
# 2024-06-25 18:46:59,785 - INFO - TRAIN Epoch: 3 Step: 10/18 Loss: 79.7727 Accuracy: 0.2023 AUC: 0.0000 Data Time: 1.0324 Batch Time: 1.8942
# 2024-06-25 18:47:01,976 - INFO - TRAIN Epoch: 3 Step: 11/18 Loss: 79.6528 Accuracy: 0.2035 AUC: 0.0000 Data Time: 1.0570 Batch Time: 1.9188
# 2024-06-25 18:47:03,646 - INFO - TRAIN Epoch: 3 Step: 12/18 Loss: 79.3590 Accuracy: 0.2064 AUC: 0.0000 Data Time: 1.0378 Batch Time: 1.8997
# 2024-06-25 18:47:05,951 - INFO - TRAIN Epoch: 3 Step: 13/18 Loss: 79.7619 Accuracy: 0.2024 AUC: 0.0000 Data Time: 1.0667 Batch Time: 1.9285
# 2024-06-25 18:47:07,740 - INFO - TRAIN Epoch: 3 Step: 14/18 Loss: 80.1111 Accuracy: 0.1989 AUC: 0.0000 Data Time: 1.0573 Batch Time: 1.9192
# 2024-06-25 18:47:09,933 - INFO - TRAIN Epoch: 3 Step: 15/18 Loss: 80.0521 Accuracy: 0.1995 AUC: 0.0000 Data Time: 1.0744 Batch Time: 1.9362
# 2024-06-25 18:47:12,086 - INFO - TRAIN Epoch: 3 Step: 16/18 Loss: 80.1471 Accuracy: 0.1985 AUC: 0.0000 Data Time: 1.0871 Batch Time: 1.9489
# 2024-06-25 18:47:12,575 - INFO - TRAIN Epoch: 3 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 1.0393 Batch Time: 1.8677
# 2024-06-25 18:47:12,578 - INFO - AUC Score: 0.5000
# 2024-06-25 18:47:14,433 - INFO - VAL Epoch: 3 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.9943 Batch Time: 1.8538
# 2024-06-25 18:47:16,221 - INFO - VAL Epoch: 3 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 0.9604 Batch Time: 1.8204
# 2024-06-25 18:47:18,024 - INFO - VAL Epoch: 3 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 0.9546 Batch Time: 1.8144
# 2024-06-25 18:47:20,072 - INFO - VAL Epoch: 3 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.0127 Batch Time: 1.8725
# 2024-06-25 18:47:20,628 - INFO - VAL Epoch: 3 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 0.8628 Batch Time: 1.6090
# 2024-06-25 18:47:20,631 - INFO - AUC Score: 0.5000
# 2024-06-25 18:47:20,732 - INFO - Starting Epoch: 5
# 2024-06-25 18:47:22,526 - INFO - TRAIN Epoch: 4 Step: 0/18 Loss: 76.6667 Accuracy: 0.2333 AUC: 0.0000 Data Time: 0.9304 Batch Time: 1.7922
# 2024-06-25 18:47:24,555 - INFO - TRAIN Epoch: 4 Step: 1/18 Loss: 78.7500 Accuracy: 0.2125 AUC: 0.0000 Data Time: 1.0482 Batch Time: 1.9103
# 2024-06-25 18:47:26,357 - INFO - TRAIN Epoch: 4 Step: 2/18 Loss: 80.2778 Accuracy: 0.1972 AUC: 0.0000 Data Time: 1.0120 Batch Time: 1.8740
# 2024-06-25 18:47:28,484 - INFO - TRAIN Epoch: 4 Step: 3/18 Loss: 81.0417 Accuracy: 0.1896 AUC: 0.0000 Data Time: 1.0752 Batch Time: 1.9370
# 2024-06-25 18:47:30,523 - INFO - TRAIN Epoch: 4 Step: 4/18 Loss: 81.0000 Accuracy: 0.1900 AUC: 0.0000 Data Time: 1.0952 Batch Time: 1.9571
# 2024-06-25 18:47:32,163 - INFO - TRAIN Epoch: 4 Step: 5/18 Loss: 80.9722 Accuracy: 0.1903 AUC: 0.0000 Data Time: 1.0423 Batch Time: 1.9041
# 2024-06-25 18:47:34,257 - INFO - TRAIN Epoch: 4 Step: 6/18 Loss: 81.4286 Accuracy: 0.1857 AUC: 0.0000 Data Time: 1.0692 Batch Time: 1.9311
# 2024-06-25 18:47:36,430 - INFO - TRAIN Epoch: 4 Step: 7/18 Loss: 81.5625 Accuracy: 0.1844 AUC: 0.0000 Data Time: 1.0994 Batch Time: 1.9613
# 2024-06-25 18:47:38,464 - INFO - TRAIN Epoch: 4 Step: 8/18 Loss: 81.3889 Accuracy: 0.1861 AUC: 0.0000 Data Time: 1.1074 Batch Time: 1.9693
# 2024-06-25 18:47:40,671 - INFO - TRAIN Epoch: 4 Step: 9/18 Loss: 81.0833 Accuracy: 0.1892 AUC: 0.0000 Data Time: 1.1310 Batch Time: 1.9929
# 2024-06-25 18:47:42,749 - INFO - TRAIN Epoch: 4 Step: 10/18 Loss: 80.6818 Accuracy: 0.1932 AUC: 0.0000 Data Time: 1.1387 Batch Time: 2.0006
# 2024-06-25 18:47:44,875 - INFO - TRAIN Epoch: 4 Step: 11/18 Loss: 80.6944 Accuracy: 0.1931 AUC: 0.0000 Data Time: 1.1490 Batch Time: 2.0109
# 2024-06-25 18:47:46,684 - INFO - TRAIN Epoch: 4 Step: 12/18 Loss: 80.2564 Accuracy: 0.1974 AUC: 0.0000 Data Time: 1.1335 Batch Time: 1.9954
# 2024-06-25 18:47:48,494 - INFO - TRAIN Epoch: 4 Step: 13/18 Loss: 80.4762 Accuracy: 0.1952 AUC: 0.0000 Data Time: 1.1202 Batch Time: 1.9820
# 2024-06-25 18:47:50,622 - INFO - TRAIN Epoch: 4 Step: 14/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.1298 Batch Time: 1.9917
# 2024-06-25 18:47:52,337 - INFO - TRAIN Epoch: 4 Step: 15/18 Loss: 79.9479 Accuracy: 0.2005 AUC: 0.0000 Data Time: 1.1125 Batch Time: 1.9743
# 2024-06-25 18:47:54,533 - INFO - TRAIN Epoch: 4 Step: 16/18 Loss: 79.9510 Accuracy: 0.2005 AUC: 0.0000 Data Time: 1.1255 Batch Time: 1.9873
# 2024-06-25 18:47:55,099 - INFO - TRAIN Epoch: 4 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 1.0799 Batch Time: 1.9084
# 2024-06-25 18:47:55,102 - INFO - AUC Score: 0.5000
# 2024-06-25 18:47:56,855 - INFO - VAL Epoch: 4 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.8918 Batch Time: 1.7516
# 2024-06-25 18:47:58,653 - INFO - VAL Epoch: 4 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 0.9144 Batch Time: 1.7743
# 2024-06-25 18:48:00,335 - INFO - VAL Epoch: 4 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 0.8835 Batch Time: 1.7431
# 2024-06-25 18:48:02,135 - INFO - VAL Epoch: 4 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.8973 Batch Time: 1.7571
# 2024-06-25 18:48:02,690 - INFO - VAL Epoch: 4 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 0.7702 Batch Time: 1.5165
# 2024-06-25 18:48:02,693 - INFO - AUC Score: 0.5000
# 2024-06-25 18:48:02,794 - INFO - Starting Epoch: 6
# 2024-06-25 18:48:04,589 - INFO - TRAIN Epoch: 5 Step: 0/18 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.9322 Batch Time: 1.7941
# 2024-06-25 18:48:06,364 - INFO - TRAIN Epoch: 5 Step: 1/18 Loss: 82.0833 Accuracy: 0.1792 AUC: 0.0000 Data Time: 0.9217 Batch Time: 1.7838
# 2024-06-25 18:48:08,478 - INFO - TRAIN Epoch: 5 Step: 2/18 Loss: 82.5000 Accuracy: 0.1750 AUC: 0.0000 Data Time: 1.0314 Batch Time: 1.8935
# 2024-06-25 18:48:10,114 - INFO - TRAIN Epoch: 5 Step: 3/18 Loss: 82.0833 Accuracy: 0.1792 AUC: 0.0000 Data Time: 0.9668 Batch Time: 1.8291
# 2024-06-25 18:48:12,152 - INFO - TRAIN Epoch: 5 Step: 4/18 Loss: 80.6667 Accuracy: 0.1933 AUC: 0.0000 Data Time: 1.0084 Batch Time: 1.8706
# 2024-06-25 18:48:13,873 - INFO - TRAIN Epoch: 5 Step: 5/18 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 0.9835 Batch Time: 1.8455
# 2024-06-25 18:48:15,990 - INFO - TRAIN Epoch: 5 Step: 6/18 Loss: 81.3095 Accuracy: 0.1869 AUC: 0.0000 Data Time: 1.0221 Batch Time: 1.8842
# 2024-06-25 18:48:18,114 - INFO - TRAIN Epoch: 5 Step: 7/18 Loss: 81.3542 Accuracy: 0.1865 AUC: 0.0000 Data Time: 1.0520 Batch Time: 1.9141
# 2024-06-25 18:48:19,920 - INFO - TRAIN Epoch: 5 Step: 8/18 Loss: 81.2037 Accuracy: 0.1880 AUC: 0.0000 Data Time: 1.0399 Batch Time: 1.9019
# 2024-06-25 18:48:21,723 - INFO - TRAIN Epoch: 5 Step: 9/18 Loss: 80.5000 Accuracy: 0.1950 AUC: 0.0000 Data Time: 1.0300 Batch Time: 1.8920
# 2024-06-25 18:48:23,748 - INFO - TRAIN Epoch: 5 Step: 10/18 Loss: 80.5303 Accuracy: 0.1947 AUC: 0.0000 Data Time: 1.0420 Batch Time: 1.9040
# 2024-06-25 18:48:25,563 - INFO - TRAIN Epoch: 5 Step: 11/18 Loss: 80.5556 Accuracy: 0.1944 AUC: 0.0000 Data Time: 1.0345 Batch Time: 1.8965
# 2024-06-25 18:48:27,698 - INFO - TRAIN Epoch: 5 Step: 12/18 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.0528 Batch Time: 1.9148
# 2024-06-25 18:48:29,523 - INFO - TRAIN Epoch: 5 Step: 13/18 Loss: 80.7143 Accuracy: 0.1929 AUC: 0.0000 Data Time: 1.0463 Batch Time: 1.9083
# 2024-06-25 18:48:31,260 - INFO - TRAIN Epoch: 5 Step: 14/18 Loss: 80.7778 Accuracy: 0.1922 AUC: 0.0000 Data Time: 1.0348 Batch Time: 1.8968
# 2024-06-25 18:48:33,406 - INFO - TRAIN Epoch: 5 Step: 15/18 Loss: 80.3646 Accuracy: 0.1964 AUC: 0.0000 Data Time: 1.0503 Batch Time: 1.9123
# 2024-06-25 18:48:35,065 - INFO - TRAIN Epoch: 5 Step: 16/18 Loss: 80.2451 Accuracy: 0.1975 AUC: 0.0000 Data Time: 1.0354 Batch Time: 1.8974
# 2024-06-25 18:48:35,667 - INFO - TRAIN Epoch: 5 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 0.9968 Batch Time: 1.8253
# 2024-06-25 18:48:35,671 - INFO - AUC Score: 0.5000
# 2024-06-25 18:48:37,841 - INFO - VAL Epoch: 5 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.3096 Batch Time: 2.1689
# 2024-06-25 18:48:39,636 - INFO - VAL Epoch: 5 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 1.1218 Batch Time: 1.9814
# 2024-06-25 18:48:41,662 - INFO - VAL Epoch: 5 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 1.1362 Batch Time: 1.9957
# 2024-06-25 18:48:43,713 - INFO - VAL Epoch: 5 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.1498 Batch Time: 2.0094
# 2024-06-25 18:48:44,431 - INFO - VAL Epoch: 5 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 1.0048 Batch Time: 1.7510
# 2024-06-25 18:48:44,434 - INFO - AUC Score: 0.5000
# 2024-06-25 18:48:44,536 - INFO - Starting Epoch: 7
# 2024-06-25 18:48:46,689 - INFO - TRAIN Epoch: 6 Step: 0/18 Loss: 75.0000 Accuracy: 0.2500 AUC: 0.0000 Data Time: 1.2887 Batch Time: 2.1506
# 2024-06-25 18:48:48,449 - INFO - TRAIN Epoch: 6 Step: 1/18 Loss: 77.0833 Accuracy: 0.2292 AUC: 0.0000 Data Time: 1.0929 Batch Time: 1.9550
# 2024-06-25 18:48:50,501 - INFO - TRAIN Epoch: 6 Step: 2/18 Loss: 77.2222 Accuracy: 0.2278 AUC: 0.0000 Data Time: 1.1254 Batch Time: 1.9872
# 2024-06-25 18:48:52,320 - INFO - TRAIN Epoch: 6 Step: 3/18 Loss: 76.4583 Accuracy: 0.2354 AUC: 0.0000 Data Time: 1.0832 Batch Time: 1.9449
# 2024-06-25 18:48:54,132 - INFO - TRAIN Epoch: 6 Step: 4/18 Loss: 77.0000 Accuracy: 0.2300 AUC: 0.0000 Data Time: 1.0563 Batch Time: 1.9181
# 2024-06-25 18:48:56,182 - INFO - TRAIN Epoch: 6 Step: 5/18 Loss: 77.5000 Accuracy: 0.2250 AUC: 0.0000 Data Time: 1.0778 Batch Time: 1.9398
# 2024-06-25 18:48:57,973 - INFO - TRAIN Epoch: 6 Step: 6/18 Loss: 77.7381 Accuracy: 0.2226 AUC: 0.0000 Data Time: 1.0565 Batch Time: 1.9185
# 2024-06-25 18:49:00,014 - INFO - TRAIN Epoch: 6 Step: 7/18 Loss: 77.9167 Accuracy: 0.2208 AUC: 0.0000 Data Time: 1.0717 Batch Time: 1.9336
# 2024-06-25 18:49:02,117 - INFO - TRAIN Epoch: 6 Step: 8/18 Loss: 77.8704 Accuracy: 0.2213 AUC: 0.0000 Data Time: 1.0904 Batch Time: 1.9524
# 2024-06-25 18:49:04,252 - INFO - TRAIN Epoch: 6 Step: 9/18 Loss: 78.7500 Accuracy: 0.2125 AUC: 0.0000 Data Time: 1.1086 Batch Time: 1.9706
# 2024-06-25 18:49:06,382 - INFO - TRAIN Epoch: 6 Step: 10/18 Loss: 78.9394 Accuracy: 0.2106 AUC: 0.0000 Data Time: 1.1229 Batch Time: 1.9849
# 2024-06-25 18:49:08,083 - INFO - TRAIN Epoch: 6 Step: 11/18 Loss: 78.9583 Accuracy: 0.2104 AUC: 0.0000 Data Time: 1.0993 Batch Time: 1.9612
# 2024-06-25 18:49:09,883 - INFO - TRAIN Epoch: 6 Step: 12/18 Loss: 79.3590 Accuracy: 0.2064 AUC: 0.0000 Data Time: 1.0868 Batch Time: 1.9488
# 2024-06-25 18:49:12,018 - INFO - TRAIN Epoch: 6 Step: 13/18 Loss: 79.2857 Accuracy: 0.2071 AUC: 0.0000 Data Time: 1.1000 Batch Time: 1.9620
# 2024-06-25 18:49:13,804 - INFO - TRAIN Epoch: 6 Step: 14/18 Loss: 79.5556 Accuracy: 0.2044 AUC: 0.0000 Data Time: 1.0882 Batch Time: 1.9502
# 2024-06-25 18:49:15,951 - INFO - TRAIN Epoch: 6 Step: 15/18 Loss: 79.7396 Accuracy: 0.2026 AUC: 0.0000 Data Time: 1.1005 Batch Time: 1.9624
# 2024-06-25 18:49:18,088 - INFO - TRAIN Epoch: 6 Step: 16/18 Loss: 79.9510 Accuracy: 0.2005 AUC: 0.0000 Data Time: 1.1107 Batch Time: 1.9726
# 2024-06-25 18:49:18,694 - INFO - TRAIN Epoch: 6 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 1.0681 Batch Time: 1.8967
# 2024-06-25 18:49:18,696 - INFO - AUC Score: 0.5000
# 2024-06-25 18:49:20,879 - INFO - VAL Epoch: 6 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.3215 Batch Time: 2.1807
# 2024-06-25 18:49:22,875 - INFO - VAL Epoch: 6 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 1.2287 Batch Time: 2.0881
# 2024-06-25 18:49:25,020 - INFO - VAL Epoch: 6 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 1.2472 Batch Time: 2.1067
# 2024-06-25 18:49:26,825 - INFO - VAL Epoch: 6 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.1713 Batch Time: 2.0310
# 2024-06-25 18:49:27,533 - INFO - VAL Epoch: 6 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 1.0202 Batch Time: 1.7663
# 2024-06-25 18:49:27,536 - INFO - AUC Score: 0.5000
# 2024-06-25 18:49:27,635 - INFO - Starting Epoch: 8
# 2024-06-25 18:49:29,391 - INFO - TRAIN Epoch: 7 Step: 0/18 Loss: 75.0000 Accuracy: 0.2500 AUC: 0.0000 Data Time: 0.8925 Batch Time: 1.7546
# 2024-06-25 18:49:31,532 - INFO - TRAIN Epoch: 7 Step: 1/18 Loss: 78.3333 Accuracy: 0.2167 AUC: 0.0000 Data Time: 1.0850 Batch Time: 1.9472
# 2024-06-25 18:49:33,189 - INFO - TRAIN Epoch: 7 Step: 2/18 Loss: 79.7222 Accuracy: 0.2028 AUC: 0.0000 Data Time: 0.9881 Batch Time: 1.8501
# 2024-06-25 18:49:35,295 - INFO - TRAIN Epoch: 7 Step: 3/18 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.0520 Batch Time: 1.9139
# 2024-06-25 18:49:37,371 - INFO - TRAIN Epoch: 7 Step: 4/18 Loss: 81.1667 Accuracy: 0.1883 AUC: 0.0000 Data Time: 1.0843 Batch Time: 1.9461
# 2024-06-25 18:49:39,114 - INFO - TRAIN Epoch: 7 Step: 5/18 Loss: 80.2778 Accuracy: 0.1972 AUC: 0.0000 Data Time: 1.0503 Batch Time: 1.9121
# 2024-06-25 18:49:41,080 - INFO - TRAIN Epoch: 7 Step: 6/18 Loss: 79.6429 Accuracy: 0.2036 AUC: 0.0000 Data Time: 1.0579 Batch Time: 1.9197
# 2024-06-25 18:49:42,894 - INFO - TRAIN Epoch: 7 Step: 7/18 Loss: 80.1042 Accuracy: 0.1990 AUC: 0.0000 Data Time: 1.0447 Batch Time: 1.9064
# 2024-06-25 18:49:45,014 - INFO - TRAIN Epoch: 7 Step: 8/18 Loss: 80.1852 Accuracy: 0.1981 AUC: 0.0000 Data Time: 1.0684 Batch Time: 1.9300
# 2024-06-25 18:49:46,752 - INFO - TRAIN Epoch: 7 Step: 9/18 Loss: 79.6667 Accuracy: 0.2033 AUC: 0.0000 Data Time: 1.0491 Batch Time: 1.9107
# 2024-06-25 18:49:48,488 - INFO - TRAIN Epoch: 7 Step: 10/18 Loss: 79.5455 Accuracy: 0.2045 AUC: 0.0000 Data Time: 1.0331 Batch Time: 1.8947
# 2024-06-25 18:49:50,289 - INFO - TRAIN Epoch: 7 Step: 11/18 Loss: 79.6528 Accuracy: 0.2035 AUC: 0.0000 Data Time: 1.0252 Batch Time: 1.8868
# 2024-06-25 18:49:52,394 - INFO - TRAIN Epoch: 7 Step: 12/18 Loss: 79.6795 Accuracy: 0.2032 AUC: 0.0000 Data Time: 1.0420 Batch Time: 1.9036
# 2024-06-25 18:49:54,086 - INFO - TRAIN Epoch: 7 Step: 13/18 Loss: 79.7619 Accuracy: 0.2024 AUC: 0.0000 Data Time: 1.0268 Batch Time: 1.8883
# 2024-06-25 18:49:56,244 - INFO - TRAIN Epoch: 7 Step: 14/18 Loss: 80.0556 Accuracy: 0.1994 AUC: 0.0000 Data Time: 1.0447 Batch Time: 1.9063
# 2024-06-25 18:49:58,021 - INFO - TRAIN Epoch: 7 Step: 15/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.0366 Batch Time: 1.8982
# 2024-06-25 18:49:59,827 - INFO - TRAIN Epoch: 7 Step: 16/18 Loss: 79.8529 Accuracy: 0.2015 AUC: 0.0000 Data Time: 1.0311 Batch Time: 1.8927
# 2024-06-25 18:50:00,429 - INFO - TRAIN Epoch: 7 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 0.9927 Batch Time: 1.8209
# 2024-06-25 18:50:00,432 - INFO - AUC Score: 0.5000
# 2024-06-25 18:50:02,272 - INFO - VAL Epoch: 7 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.9784 Batch Time: 1.8385
# 2024-06-25 18:50:04,070 - INFO - VAL Epoch: 7 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 0.9581 Batch Time: 1.8179
# 2024-06-25 18:50:05,799 - INFO - VAL Epoch: 7 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 0.9280 Batch Time: 1.7879
# 2024-06-25 18:50:07,829 - INFO - VAL Epoch: 7 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.9885 Batch Time: 1.8482
# 2024-06-25 18:50:08,390 - INFO - VAL Epoch: 7 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 0.8445 Batch Time: 1.5907
# 2024-06-25 18:50:08,393 - INFO - AUC Score: 0.5000
# 2024-06-25 18:50:08,492 - INFO - Starting Epoch: 9
# 2024-06-25 18:50:10,547 - INFO - TRAIN Epoch: 8 Step: 0/18 Loss: 83.3333 Accuracy: 0.1667 AUC: 0.0000 Data Time: 1.1918 Batch Time: 2.0531
# 2024-06-25 18:50:12,681 - INFO - TRAIN Epoch: 8 Step: 1/18 Loss: 83.3333 Accuracy: 0.1667 AUC: 0.0000 Data Time: 1.2317 Batch Time: 2.0934
# 2024-06-25 18:50:14,313 - INFO - TRAIN Epoch: 8 Step: 2/18 Loss: 81.3889 Accuracy: 0.1861 AUC: 0.0000 Data Time: 1.0777 Batch Time: 1.9393
# 2024-06-25 18:50:16,342 - INFO - TRAIN Epoch: 8 Step: 3/18 Loss: 81.8750 Accuracy: 0.1812 AUC: 0.0000 Data Time: 1.0999 Batch Time: 1.9615
# 2024-06-25 18:50:18,141 - INFO - TRAIN Epoch: 8 Step: 4/18 Loss: 81.8333 Accuracy: 0.1817 AUC: 0.0000 Data Time: 1.0671 Batch Time: 1.9287
# 2024-06-25 18:50:19,955 - INFO - TRAIN Epoch: 8 Step: 5/18 Loss: 80.9722 Accuracy: 0.1903 AUC: 0.0000 Data Time: 1.0477 Batch Time: 1.9094
# 2024-06-25 18:50:22,057 - INFO - TRAIN Epoch: 8 Step: 6/18 Loss: 80.3571 Accuracy: 0.1964 AUC: 0.0000 Data Time: 1.0752 Batch Time: 1.9369
# 2024-06-25 18:50:23,755 - INFO - TRAIN Epoch: 8 Step: 7/18 Loss: 79.3750 Accuracy: 0.2062 AUC: 0.0000 Data Time: 1.0451 Batch Time: 1.9068
# 2024-06-25 18:50:25,860 - INFO - TRAIN Epoch: 8 Step: 8/18 Loss: 79.6296 Accuracy: 0.2037 AUC: 0.0000 Data Time: 1.0671 Batch Time: 1.9288
# 2024-06-25 18:50:27,991 - INFO - TRAIN Epoch: 8 Step: 9/18 Loss: 78.9167 Accuracy: 0.2108 AUC: 0.0000 Data Time: 1.0872 Batch Time: 1.9489
# 2024-06-25 18:50:30,129 - INFO - TRAIN Epoch: 8 Step: 10/18 Loss: 79.1667 Accuracy: 0.2083 AUC: 0.0000 Data Time: 1.1043 Batch Time: 1.9660
# 2024-06-25 18:50:31,908 - INFO - TRAIN Epoch: 8 Step: 11/18 Loss: 79.7222 Accuracy: 0.2028 AUC: 0.0000 Data Time: 1.0886 Batch Time: 1.9503
# 2024-06-25 18:50:33,970 - INFO - TRAIN Epoch: 8 Step: 12/18 Loss: 79.5513 Accuracy: 0.2045 AUC: 0.0000 Data Time: 1.0971 Batch Time: 1.9588
# 2024-06-25 18:50:35,697 - INFO - TRAIN Epoch: 8 Step: 13/18 Loss: 79.7024 Accuracy: 0.2030 AUC: 0.0000 Data Time: 1.0805 Batch Time: 1.9422
# 2024-06-25 18:50:37,806 - INFO - TRAIN Epoch: 8 Step: 14/18 Loss: 79.8889 Accuracy: 0.2011 AUC: 0.0000 Data Time: 1.0915 Batch Time: 1.9533
# 2024-06-25 18:50:39,869 - INFO - TRAIN Epoch: 8 Step: 15/18 Loss: 79.8438 Accuracy: 0.2016 AUC: 0.0000 Data Time: 1.0984 Batch Time: 1.9600
# 2024-06-25 18:50:41,929 - INFO - TRAIN Epoch: 8 Step: 16/18 Loss: 79.8757 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.1042 Batch Time: 1.9659
# 2024-06-25 18:50:42,534 - INFO - TRAIN Epoch: 8 Step: 17/18 Loss: 78.9038 Accuracy: 0.2097 AUC: 0.0000 Data Time: 1.0620 Batch Time: 1.8903
# 2024-06-25 18:50:42,537 - INFO - AUC Score: 0.4994
# 2024-06-25 18:50:44,662 - INFO - VAL Epoch: 8 Step: 0/5 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.2643 Batch Time: 2.1240
# 2024-06-25 18:50:46,451 - INFO - VAL Epoch: 8 Step: 1/5 Loss: 18.3333 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.0963 Batch Time: 1.9559
# 2024-06-25 18:50:48,185 - INFO - VAL Epoch: 8 Step: 2/5 Loss: 17.7778 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.0216 Batch Time: 1.8814
# 2024-06-25 18:50:49,959 - INFO - VAL Epoch: 8 Step: 3/5 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9947 Batch Time: 1.8544
# 2024-06-25 18:50:50,553 - INFO - VAL Epoch: 8 Step: 4/5 Loss: 20.0385 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.8558 Batch Time: 1.6020
# 2024-06-25 18:50:50,555 - INFO - AUC Score: 0.5000
# 2024-06-25 18:50:50,556 - INFO - New best model at epoch: 9
# 2024-06-25 18:50:50,751 - INFO - Starting Epoch: 10
# 2024-06-25 18:50:52,477 - INFO - TRAIN Epoch: 9 Step: 0/18 Loss: 22.5000 Accuracy: 0.7750 AUC: 0.0000 Data Time: 0.8634 Batch Time: 1.7245
# 2024-06-25 18:50:54,193 - INFO - TRAIN Epoch: 9 Step: 1/18 Loss: 20.0000 Accuracy: 0.8000 AUC: 0.0000 Data Time: 0.8586 Batch Time: 1.7199
# 2024-06-25 18:50:56,323 - INFO - TRAIN Epoch: 9 Step: 2/18 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9949 Batch Time: 1.8564
# 2024-06-25 18:50:58,071 - INFO - TRAIN Epoch: 9 Step: 3/18 Loss: 18.9583 Accuracy: 0.8104 AUC: 0.0000 Data Time: 0.9677 Batch Time: 1.8290
# 2024-06-25 18:50:59,718 - INFO - TRAIN Epoch: 9 Step: 4/18 Loss: 18.8333 Accuracy: 0.8117 AUC: 0.0000 Data Time: 0.9310 Batch Time: 1.7923
# 2024-06-25 18:51:01,830 - INFO - TRAIN Epoch: 9 Step: 5/18 Loss: 17.0833 Accuracy: 0.8292 AUC: 0.0000 Data Time: 0.9842 Batch Time: 1.8456
# 2024-06-25 18:51:03,950 - INFO - TRAIN Epoch: 9 Step: 6/18 Loss: 17.3810 Accuracy: 0.8262 AUC: 0.0000 Data Time: 1.0231 Batch Time: 1.8846
# 2024-06-25 18:51:05,789 - INFO - TRAIN Epoch: 9 Step: 7/18 Loss: 17.3958 Accuracy: 0.8260 AUC: 0.0000 Data Time: 1.0173 Batch Time: 1.8788
# 2024-06-25 18:51:07,841 - INFO - TRAIN Epoch: 9 Step: 8/18 Loss: 17.7778 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.0365 Batch Time: 1.8980
# 2024-06-25 18:51:10,044 - INFO - TRAIN Epoch: 9 Step: 9/18 Loss: 18.5833 Accuracy: 0.8142 AUC: 0.0000 Data Time: 1.0669 Batch Time: 1.9284
# 2024-06-25 18:51:11,768 - INFO - TRAIN Epoch: 9 Step: 10/18 Loss: 18.7121 Accuracy: 0.8129 AUC: 0.0000 Data Time: 1.0482 Batch Time: 1.9096
# 2024-06-25 18:51:13,906 - INFO - TRAIN Epoch: 9 Step: 11/18 Loss: 18.9583 Accuracy: 0.8104 AUC: 0.0000 Data Time: 1.0671 Batch Time: 1.9286
# 2024-06-25 18:51:16,054 - INFO - TRAIN Epoch: 9 Step: 12/18 Loss: 18.9744 Accuracy: 0.8103 AUC: 0.0000 Data Time: 1.0839 Batch Time: 1.9454
# 2024-06-25 18:51:17,698 - INFO - TRAIN Epoch: 9 Step: 13/18 Loss: 19.5238 Accuracy: 0.8048 AUC: 0.0000 Data Time: 1.0623 Batch Time: 1.9238
# 2024-06-25 18:51:19,743 - INFO - TRAIN Epoch: 9 Step: 14/18 Loss: 19.6111 Accuracy: 0.8039 AUC: 0.0000 Data Time: 1.0703 Batch Time: 1.9318
# 2024-06-25 18:51:21,897 - INFO - TRAIN Epoch: 9 Step: 15/18 Loss: 20.0000 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.0841 Batch Time: 1.9457
# 2024-06-25 18:51:23,609 - INFO - TRAIN Epoch: 9 Step: 16/18 Loss: 19.9510 Accuracy: 0.8005 AUC: 0.0000 Data Time: 1.0703 Batch Time: 1.9319
# 2024-06-25 18:51:24,211 - INFO - TRAIN Epoch: 9 Step: 17/18 Loss: 20.0096 Accuracy: 0.7999 AUC: 0.0000 Data Time: 1.0298 Batch Time: 1.8579
# 2024-06-25 18:51:24,215 - INFO - AUC Score: 0.5000
# 2024-06-25 18:51:26,029 - INFO - VAL Epoch: 9 Step: 0/5 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9534 Batch Time: 1.8130
# 2024-06-25 18:51:27,723 - INFO - VAL Epoch: 9 Step: 1/5 Loss: 18.3333 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.8933 Batch Time: 1.7527
# 2024-06-25 18:51:29,787 - INFO - VAL Epoch: 9 Step: 2/5 Loss: 17.7778 Accuracy: 0.8222 AUC: 0.0000 Data Time: 0.9967 Batch Time: 1.8563
# 2024-06-25 18:51:31,597 - INFO - VAL Epoch: 9 Step: 3/5 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9851 Batch Time: 1.8445
# 2024-06-25 18:51:32,270 - INFO - VAL Epoch: 9 Step: 4/5 Loss: 20.0385 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.8640 Batch Time: 1.6100
# 2024-06-25 18:51:32,272 - INFO - AUC Score: 0.5000
# 2024-06-25 18:51:32,374 - INFO - Starting Epoch: 11
# 2024-06-25 18:51:34,091 - INFO - TRAIN Epoch: 10 Step: 0/18 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8536 Batch Time: 1.7153
# 2024-06-25 18:51:35,878 - INFO - TRAIN Epoch: 10 Step: 1/18 Loss: 20.4167 Accuracy: 0.7958 AUC: 0.0000 Data Time: 0.8894 Batch Time: 1.7511
# 2024-06-25 18:51:37,589 - INFO - TRAIN Epoch: 10 Step: 2/18 Loss: 22.2222 Accuracy: 0.7778 AUC: 0.0000 Data Time: 0.8759 Batch Time: 1.7375
# 2024-06-25 18:51:39,674 - INFO - TRAIN Epoch: 10 Step: 3/18 Loss: 21.4583 Accuracy: 0.7854 AUC: 0.0000 Data Time: 0.9622 Batch Time: 1.8240
# 2024-06-25 18:51:41,565 - INFO - TRAIN Epoch: 10 Step: 4/18 Loss: 21.8333 Accuracy: 0.7817 AUC: 0.0000 Data Time: 0.9755 Batch Time: 1.8372
# 2024-06-25 18:51:43,484 - INFO - TRAIN Epoch: 10 Step: 5/18 Loss: 22.3611 Accuracy: 0.7764 AUC: 0.0000 Data Time: 0.9890 Batch Time: 1.8507
# 2024-06-25 18:51:45,546 - INFO - TRAIN Epoch: 10 Step: 6/18 Loss: 21.6667 Accuracy: 0.7833 AUC: 0.0000 Data Time: 1.0191 Batch Time: 1.8808
# 2024-06-25 18:51:47,282 - INFO - TRAIN Epoch: 10 Step: 7/18 Loss: 20.9375 Accuracy: 0.7906 AUC: 0.0000 Data Time: 1.0009 Batch Time: 1.8625
# 2024-06-25 18:51:49,332 - INFO - TRAIN Epoch: 10 Step: 8/18 Loss: 20.6481 Accuracy: 0.7935 AUC: 0.0000 Data Time: 1.0216 Batch Time: 1.8832
# 2024-06-25 18:51:51,489 - INFO - TRAIN Epoch: 10 Step: 9/18 Loss: 20.8333 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.0489 Batch Time: 1.9105
# 2024-06-25 18:51:53,745 - INFO - TRAIN Epoch: 10 Step: 10/18 Loss: 20.4545 Accuracy: 0.7955 AUC: 0.0000 Data Time: 1.0802 Batch Time: 1.9419
# 2024-06-25 18:51:55,871 - INFO - TRAIN Epoch: 10 Step: 11/18 Loss: 20.9028 Accuracy: 0.7910 AUC: 0.0000 Data Time: 1.0955 Batch Time: 1.9572
# 2024-06-25 18:51:58,087 - INFO - TRAIN Epoch: 10 Step: 12/18 Loss: 20.7051 Accuracy: 0.7929 AUC: 0.0000 Data Time: 1.1153 Batch Time: 1.9770
# 2024-06-25 18:51:59,820 - INFO - TRAIN Epoch: 10 Step: 13/18 Loss: 20.6294 Accuracy: 0.7929 AUC: 0.0000 Data Time: 1.0979 Batch Time: 1.9595
# 2024-06-25 18:52:01,920 - INFO - TRAIN Epoch: 10 Step: 14/18 Loss: 20.5319 Accuracy: 0.7939 AUC: 0.0000 Data Time: 1.1072 Batch Time: 1.9688
# 2024-06-25 18:52:04,044 - INFO - TRAIN Epoch: 10 Step: 15/18 Loss: 20.7590 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.1168 Batch Time: 1.9784
# 2024-06-25 18:52:05,787 - INFO - TRAIN Epoch: 10 Step: 16/18 Loss: 20.4203 Accuracy: 0.7951 AUC: 0.0000 Data Time: 1.1029 Batch Time: 1.9645
# 2024-06-25 18:52:06,453 - INFO - TRAIN Epoch: 10 Step: 17/18 Loss: 20.3266 Accuracy: 0.7960 AUC: 0.0000 Data Time: 1.0641 Batch Time: 1.8923
# 2024-06-25 18:52:06,457 - INFO - AUC Score: 0.4982
# 2024-06-25 18:52:08,321 - INFO - VAL Epoch: 10 Step: 0/5 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.0022 Batch Time: 1.8618
# 2024-06-25 18:52:10,061 - INFO - VAL Epoch: 10 Step: 1/5 Loss: 18.3333 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.9408 Batch Time: 1.8006
# 2024-06-25 18:52:11,855 - INFO - VAL Epoch: 10 Step: 2/5 Loss: 17.7778 Accuracy: 0.8222 AUC: 0.0000 Data Time: 0.9385 Batch Time: 1.7982
# 2024-06-25 18:52:13,996 - INFO - VAL Epoch: 10 Step: 3/5 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.0237 Batch Time: 1.8834
# 2024-06-25 18:52:14,558 - INFO - VAL Epoch: 10 Step: 4/5 Loss: 20.0385 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.8729 Batch Time: 1.6190
# 2024-06-25 18:52:14,561 - INFO - AUC Score: 0.5000
# 2024-06-25 18:52:14,661 - INFO - Starting Epoch: 12
# 2024-06-25 18:52:16,305 - INFO - TRAIN Epoch: 11 Step: 0/18 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.7807 Batch Time: 1.6429
# 2024-06-25 18:52:18,321 - INFO - TRAIN Epoch: 11 Step: 1/18 Loss: 18.3333 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.9666 Batch Time: 1.8286
# 2024-06-25 18:52:20,445 - INFO - TRAIN Epoch: 11 Step: 2/18 Loss: 21.6667 Accuracy: 0.7833 AUC: 0.0000 Data Time: 1.0647 Batch Time: 1.9268
# 2024-06-25 18:52:22,185 - INFO - TRAIN Epoch: 11 Step: 3/18 Loss: 21.6667 Accuracy: 0.7833 AUC: 0.0000 Data Time: 1.0181 Batch Time: 1.8800
# 2024-06-25 18:52:24,326 - INFO - TRAIN Epoch: 11 Step: 4/18 Loss: 21.6667 Accuracy: 0.7833 AUC: 0.0000 Data Time: 1.0700 Batch Time: 1.9318
# 2024-06-25 18:52:26,438 - INFO - TRAIN Epoch: 11 Step: 5/18 Loss: 20.6944 Accuracy: 0.7931 AUC: 0.0000 Data Time: 1.1000 Batch Time: 1.9618
# 2024-06-25 18:52:28,182 - INFO - TRAIN Epoch: 11 Step: 6/18 Loss: 21.4286 Accuracy: 0.7857 AUC: 0.0000 Data Time: 1.0688 Batch Time: 1.9306
# 2024-06-25 18:52:30,269 - INFO - TRAIN Epoch: 11 Step: 7/18 Loss: 20.3125 Accuracy: 0.7969 AUC: 0.0000 Data Time: 1.0884 Batch Time: 1.9500
# 2024-06-25 18:52:32,010 - INFO - TRAIN Epoch: 11 Step: 8/18 Loss: 20.6481 Accuracy: 0.7935 AUC: 0.0000 Data Time: 1.0651 Batch Time: 1.9267
# 2024-06-25 18:52:33,749 - INFO - TRAIN Epoch: 11 Step: 9/18 Loss: 20.5000 Accuracy: 0.7950 AUC: 0.0000 Data Time: 1.0462 Batch Time: 1.9078
# 2024-06-25 18:52:35,881 - INFO - TRAIN Epoch: 11 Step: 10/18 Loss: 20.3030 Accuracy: 0.7970 AUC: 0.0000 Data Time: 1.0664 Batch Time: 1.9281
# 2024-06-25 18:52:37,605 - INFO - TRAIN Epoch: 11 Step: 11/18 Loss: 20.0000 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.0494 Batch Time: 1.9110
# 2024-06-25 18:52:39,349 - INFO - TRAIN Epoch: 11 Step: 12/18 Loss: 20.3205 Accuracy: 0.7968 AUC: 0.0000 Data Time: 1.0364 Batch Time: 1.8981
# 2024-06-25 18:52:41,011 - INFO - TRAIN Epoch: 11 Step: 13/18 Loss: 20.0595 Accuracy: 0.7994 AUC: 0.0000 Data Time: 1.0195 Batch Time: 1.8812
# 2024-06-25 18:52:42,642 - INFO - TRAIN Epoch: 11 Step: 14/18 Loss: 20.1667 Accuracy: 0.7983 AUC: 0.0000 Data Time: 1.0028 Batch Time: 1.8644
# 2024-06-25 18:52:44,703 - INFO - TRAIN Epoch: 11 Step: 15/18 Loss: 20.1562 Accuracy: 0.7984 AUC: 0.0000 Data Time: 1.0150 Batch Time: 1.8767
# 2024-06-25 18:52:46,435 - INFO - TRAIN Epoch: 11 Step: 16/18 Loss: 20.0490 Accuracy: 0.7995 AUC: 0.0000 Data Time: 1.0065 Batch Time: 1.8681
# 2024-06-25 18:52:46,911 - INFO - TRAIN Epoch: 11 Step: 17/18 Loss: 20.0096 Accuracy: 0.7999 AUC: 0.0000 Data Time: 0.9624 Batch Time: 1.7907
# 2024-06-25 18:52:46,913 - INFO - AUC Score: 0.5000
# 2024-06-25 18:52:48,730 - INFO - VAL Epoch: 11 Step: 0/5 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9549 Batch Time: 1.8148
# 2024-06-25 18:52:50,472 - INFO - VAL Epoch: 11 Step: 1/5 Loss: 18.3333 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.9188 Batch Time: 1.7783
# 2024-06-25 18:52:52,498 - INFO - VAL Epoch: 11 Step: 2/5 Loss: 17.7778 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.0007 Batch Time: 1.8604
# 2024-06-25 18:52:54,642 - INFO - VAL Epoch: 11 Step: 3/5 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.0716 Batch Time: 1.9311
# 2024-06-25 18:52:55,374 - INFO - VAL Epoch: 11 Step: 4/5 Loss: 20.0385 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.9451 Batch Time: 1.6912
# 2024-06-25 18:52:55,377 - INFO - AUC Score: 0.5000
# 2024-06-25 18:52:55,475 - INFO - Starting Epoch: 13
# 2024-06-25 18:52:57,609 - INFO - TRAIN Epoch: 12 Step: 0/18 Loss: 20.8333 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.2704 Batch Time: 2.1326
# 2024-06-25 18:52:59,413 - INFO - TRAIN Epoch: 12 Step: 1/18 Loss: 18.7500 Accuracy: 0.8125 AUC: 0.0000 Data Time: 1.1055 Batch Time: 1.9674
# 2024-06-25 18:53:01,484 - INFO - TRAIN Epoch: 12 Step: 2/18 Loss: 19.1667 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.1400 Batch Time: 2.0018
# 2024-06-25 18:53:03,582 - INFO - TRAIN Epoch: 12 Step: 3/18 Loss: 18.5417 Accuracy: 0.8146 AUC: 0.0000 Data Time: 1.1640 Batch Time: 2.0256
# 2024-06-25 18:53:05,648 - INFO - TRAIN Epoch: 12 Step: 4/18 Loss: 18.5000 Accuracy: 0.8150 AUC: 0.0000 Data Time: 1.1719 Batch Time: 2.0335
# 2024-06-25 18:53:07,683 - INFO - TRAIN Epoch: 12 Step: 5/18 Loss: 18.6111 Accuracy: 0.8139 AUC: 0.0000 Data Time: 1.1720 Batch Time: 2.0336
# 2024-06-25 18:53:09,349 - INFO - TRAIN Epoch: 12 Step: 6/18 Loss: 19.6166 Accuracy: 0.8036 AUC: 0.0000 Data Time: 1.1193 Batch Time: 1.9810
# 2024-06-25 18:53:11,420 - INFO - TRAIN Epoch: 12 Step: 7/18 Loss: 21.8116 Accuracy: 0.7771 AUC: 0.0000 Data Time: 1.1305 Batch Time: 1.9921
# 2024-06-25 18:53:13,164 - INFO - TRAIN Epoch: 12 Step: 8/18 Loss: 21.3325 Accuracy: 0.7824 AUC: 0.0000 Data Time: 1.1027 Batch Time: 1.9644
# 2024-06-25 18:53:15,327 - INFO - TRAIN Epoch: 12 Step: 9/18 Loss: 21.1993 Accuracy: 0.7842 AUC: 0.0000 Data Time: 1.1225 Batch Time: 1.9842
# 2024-06-25 18:53:17,388 - INFO - TRAIN Epoch: 12 Step: 10/18 Loss: 20.4842 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.1294 Batch Time: 1.9911
# 2024-06-25 18:53:19,212 - INFO - TRAIN Epoch: 12 Step: 11/18 Loss: 20.2355 Accuracy: 0.7944 AUC: 0.0000 Data Time: 1.1155 Batch Time: 1.9772
# 2024-06-25 18:53:21,401 - INFO - TRAIN Epoch: 12 Step: 12/18 Loss: 20.3456 Accuracy: 0.7936 AUC: 0.0000 Data Time: 1.1317 Batch Time: 1.9933
# 2024-06-25 18:53:23,377 - INFO - TRAIN Epoch: 12 Step: 13/18 Loss: 20.3209 Accuracy: 0.7940 AUC: 0.0000 Data Time: 1.1304 Batch Time: 1.9920
# 2024-06-25 18:53:25,436 - INFO - TRAIN Epoch: 12 Step: 14/18 Loss: 20.6884 Accuracy: 0.7906 AUC: 0.0000 Data Time: 1.1348 Batch Time: 1.9964
# 2024-06-25 18:53:27,070 - INFO - TRAIN Epoch: 12 Step: 15/18 Loss: 20.5933 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.1121 Batch Time: 1.9737
# 2024-06-25 18:53:29,168 - INFO - TRAIN Epoch: 12 Step: 16/18 Loss: 20.5584 Accuracy: 0.7922 AUC: 0.0000 Data Time: 1.1194 Batch Time: 1.9810
# 2024-06-25 18:53:29,778 - INFO - TRAIN Epoch: 12 Step: 17/18 Loss: 21.3786 Accuracy: 0.7840 AUC: 0.0000 Data Time: 1.0766 Batch Time: 1.9048
# 2024-06-25 18:53:29,781 - INFO - AUC Score: 0.5113
# 2024-06-25 18:53:31,476 - INFO - VAL Epoch: 12 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.8333 Batch Time: 1.6929
# 2024-06-25 18:53:33,470 - INFO - VAL Epoch: 12 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 0.9838 Batch Time: 1.8432
# 2024-06-25 18:53:35,134 - INFO - VAL Epoch: 12 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 0.9237 Batch Time: 1.7831
# 2024-06-25 18:53:37,303 - INFO - VAL Epoch: 12 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.0199 Batch Time: 1.8793
# 2024-06-25 18:53:37,853 - INFO - VAL Epoch: 12 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 0.8674 Batch Time: 1.6134
# 2024-06-25 18:53:37,856 - INFO - AUC Score: 0.5000
# 2024-06-25 18:53:37,954 - INFO - Starting Epoch: 14
# 2024-06-25 18:53:40,042 - INFO - TRAIN Epoch: 13 Step: 0/18 Loss: 79.1667 Accuracy: 0.2083 AUC: 0.0000 Data Time: 1.2257 Batch Time: 2.0874
# 2024-06-25 18:53:41,726 - INFO - TRAIN Epoch: 13 Step: 1/18 Loss: 79.5833 Accuracy: 0.2042 AUC: 0.0000 Data Time: 1.0235 Batch Time: 1.8850
# 2024-06-25 18:53:43,769 - INFO - TRAIN Epoch: 13 Step: 2/18 Loss: 80.5556 Accuracy: 0.1944 AUC: 0.0000 Data Time: 1.0759 Batch Time: 1.9374
# 2024-06-25 18:53:45,736 - INFO - TRAIN Epoch: 13 Step: 3/18 Loss: 80.4167 Accuracy: 0.1958 AUC: 0.0000 Data Time: 1.0830 Batch Time: 1.9445
# 2024-06-25 18:53:47,741 - INFO - TRAIN Epoch: 13 Step: 4/18 Loss: 79.6667 Accuracy: 0.2033 AUC: 0.0000 Data Time: 1.0950 Batch Time: 1.9566
# 2024-06-25 18:53:49,414 - INFO - TRAIN Epoch: 13 Step: 5/18 Loss: 79.7222 Accuracy: 0.2028 AUC: 0.0000 Data Time: 1.0476 Batch Time: 1.9091
# 2024-06-25 18:53:51,163 - INFO - TRAIN Epoch: 13 Step: 6/18 Loss: 80.5952 Accuracy: 0.1940 AUC: 0.0000 Data Time: 1.0246 Batch Time: 1.8861
# 2024-06-25 18:53:53,211 - INFO - TRAIN Epoch: 13 Step: 7/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.0447 Batch Time: 1.9062
# 2024-06-25 18:53:55,281 - INFO - TRAIN Epoch: 13 Step: 8/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.0628 Batch Time: 1.9243
# 2024-06-25 18:53:56,945 - INFO - TRAIN Epoch: 13 Step: 9/18 Loss: 79.9167 Accuracy: 0.2008 AUC: 0.0000 Data Time: 1.0368 Batch Time: 1.8982
# 2024-06-25 18:53:59,012 - INFO - TRAIN Epoch: 13 Step: 10/18 Loss: 79.6970 Accuracy: 0.2030 AUC: 0.0000 Data Time: 1.0521 Batch Time: 1.9135
# 2024-06-25 18:54:00,984 - INFO - TRAIN Epoch: 13 Step: 11/18 Loss: 78.7235 Accuracy: 0.2090 AUC: 0.0000 Data Time: 1.0568 Batch Time: 1.9182
# 2024-06-25 18:54:02,738 - INFO - TRAIN Epoch: 13 Step: 12/18 Loss: 74.0781 Accuracy: 0.2558 AUC: 0.0000 Data Time: 1.0441 Batch Time: 1.9055
# 2024-06-25 18:54:04,839 - INFO - TRAIN Epoch: 13 Step: 13/18 Loss: 70.2154 Accuracy: 0.2946 AUC: 0.0000 Data Time: 1.0580 Batch Time: 1.9194
# 2024-06-25 18:54:06,603 - INFO - TRAIN Epoch: 13 Step: 14/18 Loss: 66.5344 Accuracy: 0.3317 AUC: 0.0000 Data Time: 1.0476 Batch Time: 1.9090
# 2024-06-25 18:54:08,331 - INFO - TRAIN Epoch: 13 Step: 15/18 Loss: 64.0947 Accuracy: 0.3563 AUC: 0.0000 Data Time: 1.0362 Batch Time: 1.8977
# 2024-06-25 18:54:10,015 - INFO - TRAIN Epoch: 13 Step: 16/18 Loss: 61.2068 Accuracy: 0.3853 AUC: 0.0000 Data Time: 1.0236 Batch Time: 1.8850
# 2024-06-25 18:54:10,623 - INFO - TRAIN Epoch: 13 Step: 17/18 Loss: 60.6373 Accuracy: 0.3910 AUC: 0.0000 Data Time: 0.9860 Batch Time: 1.8140
# 2024-06-25 18:54:10,626 - INFO - AUC Score: 0.5104
# 2024-06-25 18:54:12,681 - INFO - VAL Epoch: 13 Step: 0/5 Loss: 72.0058 Accuracy: 0.2667 AUC: 0.0000 Data Time: 1.1948 Batch Time: 2.0539
# 2024-06-25 18:54:14,568 - INFO - VAL Epoch: 13 Step: 1/5 Loss: 74.3437 Accuracy: 0.2458 AUC: 0.0000 Data Time: 1.1107 Batch Time: 1.9698
# 2024-06-25 18:54:16,547 - INFO - VAL Epoch: 13 Step: 2/5 Loss: 72.4353 Accuracy: 0.2667 AUC: 0.0000 Data Time: 1.1134 Batch Time: 1.9724
# 2024-06-25 18:54:18,307 - INFO - VAL Epoch: 13 Step: 3/5 Loss: 70.2413 Accuracy: 0.2875 AUC: 0.0000 Data Time: 1.0599 Batch Time: 1.9191
# 2024-06-25 18:54:18,882 - INFO - VAL Epoch: 13 Step: 4/5 Loss: 69.7800 Accuracy: 0.2929 AUC: 0.0000 Data Time: 0.9045 Batch Time: 1.6502
# 2024-06-25 18:54:18,885 - INFO - AUC Score: 0.4830
# 2024-06-25 18:54:18,984 - INFO - Starting Epoch: 15
# 2024-06-25 18:54:20,759 - INFO - TRAIN Epoch: 14 Step: 0/18 Loss: 73.9190 Accuracy: 0.2500 AUC: 0.0000 Data Time: 0.9112 Batch Time: 1.7733
# 2024-06-25 18:54:22,833 - INFO - TRAIN Epoch: 14 Step: 1/18 Loss: 47.3762 Accuracy: 0.5208 AUC: 0.0000 Data Time: 1.0615 Batch Time: 1.9230
# 2024-06-25 18:54:24,442 - INFO - TRAIN Epoch: 14 Step: 2/18 Loss: 37.9730 Accuracy: 0.6167 AUC: 0.0000 Data Time: 0.9568 Batch Time: 1.8180
# 2024-06-25 18:54:26,515 - INFO - TRAIN Epoch: 14 Step: 3/18 Loss: 32.8547 Accuracy: 0.6687 AUC: 0.0000 Data Time: 1.0204 Batch Time: 1.8817
# ...
# 2024-06-25 19:43:38,731 - INFO - TRAIN Epoch: 69 Step: 12/18 Loss: 80.3846 Accuracy: 0.1962 AUC: 0.0000 Data Time: 1.7286 Batch Time: 3.2940
# 2024-06-25 19:43:41,053 - INFO - TRAIN Epoch: 69 Step: 13/18 Loss: 80.2381 Accuracy: 0.1976 AUC: 0.0000 Data Time: 1.7088 Batch Time: 3.2245
# 2024-06-25 19:43:43,735 - INFO - TRAIN Epoch: 69 Step: 14/18 Loss: 80.2778 Accuracy: 0.1972 AUC: 0.0000 Data Time: 1.7112 Batch Time: 3.1882
# 2024-06-25 19:43:46,085 - INFO - TRAIN Epoch: 69 Step: 15/18 Loss: 80.6771 Accuracy: 0.1932 AUC: 0.0000 Data Time: 1.6685 Batch Time: 3.1357
# 2024-06-25 19:43:48,176 - INFO - TRAIN Epoch: 69 Step: 16/18 Loss: 79.9510 Accuracy: 0.2005 AUC: 0.0000 Data Time: 1.6261 Batch Time: 3.0740
# 2024-06-25 19:43:49,180 - INFO - TRAIN Epoch: 69 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 1.5562 Batch Time: 2.9588
# 2024-06-25 19:43:49,184 - INFO - AUC Score: 0.5000
# 2024-06-25 19:43:51,863 - INFO - VAL Epoch: 69 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.9932 Batch Time: 2.6771
# 2024-06-25 19:43:54,873 - INFO - VAL Epoch: 69 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 1.0814 Batch Time: 2.8419
# 2024-06-25 19:43:57,277 - INFO - VAL Epoch: 69 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 1.0295 Batch Time: 2.6953
# 2024-06-25 19:43:59,153 - INFO - VAL Epoch: 69 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.0154 Batch Time: 2.4896
# 2024-06-25 19:44:00,318 - INFO - VAL Epoch: 69 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 0.9021 Batch Time: 2.2241
# 2024-06-25 19:44:00,322 - INFO - AUC Score: 0.5000
# 2024-06-25 19:44:00,423 - INFO - Starting Epoch: 71
# 2024-06-25 19:44:03,395 - INFO - TRAIN Epoch: 70 Step: 0/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 0.8506 Batch Time: 2.9693
# 2024-06-25 19:44:06,329 - INFO - TRAIN Epoch: 70 Step: 1/18 Loss: 81.2500 Accuracy: 0.1875 AUC: 0.0000 Data Time: 0.9977 Batch Time: 2.9503
# 2024-06-25 19:44:09,151 - INFO - TRAIN Epoch: 70 Step: 2/18 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 0.9458 Batch Time: 2.9072
# 2024-06-25 19:44:10,889 - INFO - TRAIN Epoch: 70 Step: 3/18 Loss: 80.6250 Accuracy: 0.1938 AUC: 0.0000 Data Time: 0.9268 Batch Time: 2.6141
# 2024-06-25 19:44:13,754 - INFO - TRAIN Epoch: 70 Step: 4/18 Loss: 80.5000 Accuracy: 0.1950 AUC: 0.0000 Data Time: 1.0058 Batch Time: 2.6639
# 2024-06-25 19:44:16,751 - INFO - TRAIN Epoch: 70 Step: 5/18 Loss: 80.4167 Accuracy: 0.1958 AUC: 0.0000 Data Time: 1.0383 Batch Time: 2.7189
# 2024-06-25 19:44:19,860 - INFO - TRAIN Epoch: 70 Step: 6/18 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.0739 Batch Time: 2.7745
# 2024-06-25 19:44:22,907 - INFO - TRAIN Epoch: 70 Step: 7/18 Loss: 81.1458 Accuracy: 0.1885 AUC: 0.0000 Data Time: 1.0906 Batch Time: 2.8082
# 2024-06-25 19:44:25,265 - INFO - TRAIN Epoch: 70 Step: 8/18 Loss: 80.9259 Accuracy: 0.1907 AUC: 0.0000 Data Time: 1.0729 Batch Time: 2.7580
# 2024-06-25 19:44:28,478 - INFO - TRAIN Epoch: 70 Step: 9/18 Loss: 81.0000 Accuracy: 0.1900 AUC: 0.0000 Data Time: 1.0869 Batch Time: 2.8032
# 2024-06-25 19:44:31,605 - INFO - TRAIN Epoch: 70 Step: 10/18 Loss: 80.6818 Accuracy: 0.1932 AUC: 0.0000 Data Time: 1.0922 Batch Time: 2.8324
# 2024-06-25 19:44:33,978 - INFO - TRAIN Epoch: 70 Step: 11/18 Loss: 80.6944 Accuracy: 0.1931 AUC: 0.0000 Data Time: 1.0696 Batch Time: 2.7939
# 2024-06-25 19:44:36,287 - INFO - TRAIN Epoch: 70 Step: 12/18 Loss: 80.7051 Accuracy: 0.1929 AUC: 0.0000 Data Time: 1.0600 Batch Time: 2.7565
# 2024-06-25 19:44:39,226 - INFO - TRAIN Epoch: 70 Step: 13/18 Loss: 80.5357 Accuracy: 0.1946 AUC: 0.0000 Data Time: 1.0825 Batch Time: 2.7694
# 2024-06-25 19:44:42,215 - INFO - TRAIN Epoch: 70 Step: 14/18 Loss: 80.3333 Accuracy: 0.1967 AUC: 0.0000 Data Time: 1.0918 Batch Time: 2.7838
# 2024-06-25 19:44:44,902 - INFO - TRAIN Epoch: 70 Step: 15/18 Loss: 80.2083 Accuracy: 0.1979 AUC: 0.0000 Data Time: 1.0804 Batch Time: 2.7776
# 2024-06-25 19:44:47,201 - INFO - TRAIN Epoch: 70 Step: 16/18 Loss: 80.1471 Accuracy: 0.1985 AUC: 0.0000 Data Time: 1.0703 Batch Time: 2.7493
# 2024-06-25 19:44:48,004 - INFO - TRAIN Epoch: 70 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 1.0313 Batch Time: 2.6411
# 2024-06-25 19:44:48,008 - INFO - AUC Score: 0.5000
# 2024-06-25 19:44:50,550 - INFO - VAL Epoch: 70 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.8419 Batch Time: 2.5393
# 2024-06-25 19:44:53,841 - INFO - VAL Epoch: 70 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 1.0184 Batch Time: 2.9139
# 2024-06-25 19:44:56,788 - INFO - VAL Epoch: 70 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 1.0683 Batch Time: 2.9243
# 2024-06-25 19:44:59,983 - INFO - VAL Epoch: 70 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.1064 Batch Time: 2.9916
# 2024-06-25 19:45:00,690 - INFO - VAL Epoch: 70 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 0.9677 Batch Time: 2.5341
# 2024-06-25 19:45:00,694 - INFO - AUC Score: 0.5000
# 2024-06-25 19:45:00,789 - INFO - Starting Epoch: 72
# 2024-06-25 19:45:03,353 - INFO - TRAIN Epoch: 71 Step: 0/18 Loss: 76.6667 Accuracy: 0.2333 AUC: 0.0000 Data Time: 1.3767 Batch Time: 2.5611
# 2024-06-25 19:45:06,436 - INFO - TRAIN Epoch: 71 Step: 1/18 Loss: 81.2500 Accuracy: 0.1875 AUC: 0.0000 Data Time: 1.3331 Batch Time: 2.8210
# 2024-06-25 19:45:08,992 - INFO - TRAIN Epoch: 71 Step: 2/18 Loss: 78.6111 Accuracy: 0.2139 AUC: 0.0000 Data Time: 1.3177 Batch Time: 2.7316
# 2024-06-25 19:45:11,737 - INFO - TRAIN Epoch: 71 Step: 3/18 Loss: 79.7917 Accuracy: 0.2021 AUC: 0.0000 Data Time: 1.3191 Batch Time: 2.7343
# 2024-06-25 19:45:14,597 - INFO - TRAIN Epoch: 71 Step: 4/18 Loss: 80.1667 Accuracy: 0.1983 AUC: 0.0000 Data Time: 1.3195 Batch Time: 2.7591
# 2024-06-25 19:45:16,610 - INFO - TRAIN Epoch: 71 Step: 5/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.2426 Batch Time: 2.6343
# 2024-06-25 19:45:18,632 - INFO - TRAIN Epoch: 71 Step: 6/18 Loss: 79.5238 Accuracy: 0.2048 AUC: 0.0000 Data Time: 1.2130 Batch Time: 2.5464
# 2024-06-25 19:45:21,221 - INFO - TRAIN Epoch: 71 Step: 7/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.2352 Batch Time: 2.5514
# 2024-06-25 19:45:23,289 - INFO - TRAIN Epoch: 71 Step: 8/18 Loss: 79.9074 Accuracy: 0.2009 AUC: 0.0000 Data Time: 1.2093 Batch Time: 2.4974
# 2024-06-25 19:45:25,205 - INFO - TRAIN Epoch: 71 Step: 9/18 Loss: 79.5833 Accuracy: 0.2042 AUC: 0.0000 Data Time: 1.1884 Batch Time: 2.4391
# 2024-06-25 19:45:27,729 - INFO - TRAIN Epoch: 71 Step: 10/18 Loss: 79.9242 Accuracy: 0.2008 AUC: 0.0000 Data Time: 1.1961 Batch Time: 2.4465
# 2024-06-25 19:45:30,499 - INFO - TRAIN Epoch: 71 Step: 11/18 Loss: 79.7222 Accuracy: 0.2028 AUC: 0.0000 Data Time: 1.2016 Batch Time: 2.4733
# 2024-06-25 19:45:33,475 - INFO - TRAIN Epoch: 71 Step: 12/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.2071 Batch Time: 2.5117
# 2024-06-25 19:45:36,571 - INFO - TRAIN Epoch: 71 Step: 13/18 Loss: 79.5238 Accuracy: 0.2048 AUC: 0.0000 Data Time: 1.2164 Batch Time: 2.5533
# 2024-06-25 19:45:39,515 - INFO - TRAIN Epoch: 71 Step: 14/18 Loss: 79.8889 Accuracy: 0.2011 AUC: 0.0000 Data Time: 1.2131 Batch Time: 2.5792
# 2024-06-25 19:45:41,788 - INFO - TRAIN Epoch: 71 Step: 15/18 Loss: 79.9479 Accuracy: 0.2005 AUC: 0.0000 Data Time: 1.1920 Batch Time: 2.5599
# 2024-06-25 19:45:44,055 - INFO - TRAIN Epoch: 71 Step: 16/18 Loss: 79.8529 Accuracy: 0.2015 AUC: 0.0000 Data Time: 1.1775 Batch Time: 2.5425
# 2024-06-25 19:45:44,909 - INFO - TRAIN Epoch: 71 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 1.1322 Batch Time: 2.4486
# 2024-06-25 19:45:44,913 - INFO - AUC Score: 0.5000
# 2024-06-25 19:45:47,412 - INFO - VAL Epoch: 71 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.8212 Batch Time: 2.4965
# 2024-06-25 19:45:50,412 - INFO - VAL Epoch: 71 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 1.0340 Batch Time: 2.7473
# 2024-06-25 19:45:53,126 - INFO - VAL Epoch: 71 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 1.1128 Batch Time: 2.7354
# 2024-06-25 19:45:55,909 - INFO - VAL Epoch: 71 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.1483 Batch Time: 2.7467
# 2024-06-25 19:45:56,689 - INFO - VAL Epoch: 71 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 1.0136 Batch Time: 2.3530
# 2024-06-25 19:45:56,693 - INFO - AUC Score: 0.5000
# 2024-06-25 19:45:56,790 - INFO - Starting Epoch: 73
# 2024-06-25 19:45:59,000 - INFO - TRAIN Epoch: 72 Step: 0/18 Loss: 85.0000 Accuracy: 0.1500 AUC: 0.0000 Data Time: 1.2324 Batch Time: 2.2069
# 2024-06-25 19:46:01,436 - INFO - TRAIN Epoch: 72 Step: 1/18 Loss: 83.3333 Accuracy: 0.1667 AUC: 0.0000 Data Time: 1.2745 Batch Time: 2.3204
# 2024-06-25 19:46:03,498 - INFO - TRAIN Epoch: 72 Step: 2/18 Loss: 81.9444 Accuracy: 0.1806 AUC: 0.0000 Data Time: 1.2368 Batch Time: 2.2337
# 2024-06-25 19:46:06,212 - INFO - TRAIN Epoch: 72 Step: 3/18 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 1.2592 Batch Time: 2.3532
# 2024-06-25 19:46:08,955 - INFO - TRAIN Epoch: 72 Step: 4/18 Loss: 80.3333 Accuracy: 0.1967 AUC: 0.0000 Data Time: 1.2542 Batch Time: 2.4307
# 2024-06-25 19:46:11,277 - INFO - TRAIN Epoch: 72 Step: 5/18 Loss: 80.9722 Accuracy: 0.1903 AUC: 0.0000 Data Time: 1.2044 Batch Time: 2.4124
# 2024-06-25 19:46:14,505 - INFO - TRAIN Epoch: 72 Step: 6/18 Loss: 80.5952 Accuracy: 0.1940 AUC: 0.0000 Data Time: 1.2105 Batch Time: 2.5285
# 2024-06-25 19:46:17,485 - INFO - TRAIN Epoch: 72 Step: 7/18 Loss: 80.3125 Accuracy: 0.1969 AUC: 0.0000 Data Time: 1.2074 Batch Time: 2.5846
# 2024-06-25 19:46:20,182 - INFO - TRAIN Epoch: 72 Step: 8/18 Loss: 79.7222 Accuracy: 0.2028 AUC: 0.0000 Data Time: 1.1730 Batch Time: 2.5969
# 2024-06-25 19:46:23,003 - INFO - TRAIN Epoch: 72 Step: 9/18 Loss: 80.2500 Accuracy: 0.1975 AUC: 0.0000 Data Time: 1.1460 Batch Time: 2.6193
# 2024-06-25 19:46:25,640 - INFO - TRAIN Epoch: 72 Step: 10/18 Loss: 80.1515 Accuracy: 0.1985 AUC: 0.0000 Data Time: 1.1166 Batch Time: 2.6206
# 2024-06-25 19:46:27,908 - INFO - TRAIN Epoch: 72 Step: 11/18 Loss: 80.4167 Accuracy: 0.1958 AUC: 0.0000 Data Time: 1.0963 Batch Time: 2.5911
# 2024-06-25 19:46:30,516 - INFO - TRAIN Epoch: 72 Step: 12/18 Loss: 80.1923 Accuracy: 0.1981 AUC: 0.0000 Data Time: 1.0863 Batch Time: 2.5922
# 2024-06-25 19:46:33,190 - INFO - TRAIN Epoch: 72 Step: 13/18 Loss: 80.1786 Accuracy: 0.1982 AUC: 0.0000 Data Time: 1.0755 Batch Time: 2.5979
# 2024-06-25 19:46:35,540 - INFO - TRAIN Epoch: 72 Step: 14/18 Loss: 80.5000 Accuracy: 0.1950 AUC: 0.0000 Data Time: 1.0669 Batch Time: 2.5812
# 2024-06-25 19:46:38,395 - INFO - TRAIN Epoch: 72 Step: 15/18 Loss: 80.4167 Accuracy: 0.1958 AUC: 0.0000 Data Time: 1.0820 Batch Time: 2.5982
# 2024-06-25 19:46:40,460 - INFO - TRAIN Epoch: 72 Step: 16/18 Loss: 80.0490 Accuracy: 0.1995 AUC: 0.0000 Data Time: 1.0694 Batch Time: 2.5666
# 2024-06-25 19:46:41,376 - INFO - TRAIN Epoch: 72 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 1.0255 Batch Time: 2.4748
# 2024-06-25 19:46:41,380 - INFO - AUC Score: 0.5000
# 2024-06-25 19:46:43,951 - INFO - VAL Epoch: 72 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.8861 Batch Time: 2.5695
# 2024-06-25 19:46:46,665 - INFO - VAL Epoch: 72 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 1.0674 Batch Time: 2.6403
# 2024-06-25 19:46:48,724 - INFO - VAL Epoch: 72 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 1.0227 Batch Time: 2.4456
# 2024-06-25 19:46:50,580 - INFO - VAL Epoch: 72 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.0117 Batch Time: 2.2977
# 2024-06-25 19:46:51,739 - INFO - VAL Epoch: 72 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 0.8967 Batch Time: 2.0694
# 2024-06-25 19:46:51,742 - INFO - AUC Score: 0.5000
# 2024-06-25 19:46:51,883 - INFO - Starting Epoch: 74
# 2024-06-25 19:46:54,417 - INFO - TRAIN Epoch: 73 Step: 0/18 Loss: 79.1667 Accuracy: 0.2083 AUC: 0.0000 Data Time: 0.8162 Batch Time: 2.5311
# 2024-06-25 19:46:56,466 - INFO - TRAIN Epoch: 73 Step: 1/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.0000 Batch Time: 2.2888
# 2024-06-25 19:46:59,338 - INFO - TRAIN Epoch: 73 Step: 2/18 Loss: 78.6111 Accuracy: 0.2139 AUC: 0.0000 Data Time: 1.0893 Batch Time: 2.4828
# 2024-06-25 19:47:01,629 - INFO - TRAIN Epoch: 73 Step: 3/18 Loss: 80.4167 Accuracy: 0.1958 AUC: 0.0000 Data Time: 1.0577 Batch Time: 2.4342
# 2024-06-25 19:47:03,583 - INFO - TRAIN Epoch: 73 Step: 4/18 Loss: 80.1667 Accuracy: 0.1983 AUC: 0.0000 Data Time: 1.0361 Batch Time: 2.3376
# 2024-06-25 19:47:06,160 - INFO - TRAIN Epoch: 73 Step: 5/18 Loss: 79.7222 Accuracy: 0.2028 AUC: 0.0000 Data Time: 1.0783 Batch Time: 2.3770
# 2024-06-25 19:47:08,212 - INFO - TRAIN Epoch: 73 Step: 6/18 Loss: 79.5238 Accuracy: 0.2048 AUC: 0.0000 Data Time: 1.0600 Batch Time: 2.3303
# 2024-06-25 19:47:10,652 - INFO - TRAIN Epoch: 73 Step: 7/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.0535 Batch Time: 2.3437
# 2024-06-25 19:47:12,775 - INFO - TRAIN Epoch: 73 Step: 8/18 Loss: 80.3704 Accuracy: 0.1963 AUC: 0.0000 Data Time: 1.0408 Batch Time: 2.3189
# 2024-06-25 19:47:15,454 - INFO - TRAIN Epoch: 73 Step: 9/18 Loss: 80.3333 Accuracy: 0.1967 AUC: 0.0000 Data Time: 1.0697 Batch Time: 2.3547
# 2024-06-25 19:47:18,259 - INFO - TRAIN Epoch: 73 Step: 10/18 Loss: 80.4545 Accuracy: 0.1955 AUC: 0.0000 Data Time: 1.0921 Batch Time: 2.3953
# 2024-06-25 19:47:21,077 - INFO - TRAIN Epoch: 73 Step: 11/18 Loss: 79.4444 Accuracy: 0.2056 AUC: 0.0000 Data Time: 1.1071 Batch Time: 2.4304
# 2024-06-25 19:47:24,379 - INFO - TRAIN Epoch: 73 Step: 12/18 Loss: 79.8718 Accuracy: 0.2013 AUC: 0.0000 Data Time: 1.1164 Batch Time: 2.4972
# 2024-06-25 19:47:27,336 - INFO - TRAIN Epoch: 73 Step: 13/18 Loss: 79.5238 Accuracy: 0.2048 AUC: 0.0000 Data Time: 1.0986 Batch Time: 2.5299
# 2024-06-25 19:47:30,569 - INFO - TRAIN Epoch: 73 Step: 14/18 Loss: 79.5556 Accuracy: 0.2044 AUC: 0.0000 Data Time: 1.1061 Batch Time: 2.5766
# 2024-06-25 19:47:33,862 - INFO - TRAIN Epoch: 73 Step: 15/18 Loss: 79.6354 Accuracy: 0.2036 AUC: 0.0000 Data Time: 1.1164 Batch Time: 2.6212
# 2024-06-25 19:47:36,847 - INFO - TRAIN Epoch: 73 Step: 16/18 Loss: 80.0000 Accuracy: 0.2000 AUC: 0.0000 Data Time: 1.1228 Batch Time: 2.6425
# 2024-06-25 19:47:37,419 - INFO - TRAIN Epoch: 73 Step: 17/18 Loss: 79.9904 Accuracy: 0.2001 AUC: 0.0000 Data Time: 1.0777 Batch Time: 2.5274
# 2024-06-25 19:47:37,422 - INFO - AUC Score: 0.5000
# 2024-06-25 19:47:39,649 - INFO - VAL Epoch: 73 Step: 0/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 0.9248 Batch Time: 2.2260
# 2024-06-25 19:47:42,389 - INFO - VAL Epoch: 73 Step: 1/5 Loss: 81.6667 Accuracy: 0.1833 AUC: 0.0000 Data Time: 1.0510 Batch Time: 2.4819
# 2024-06-25 19:47:44,745 - INFO - VAL Epoch: 73 Step: 2/5 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 1.1115 Batch Time: 2.4398
# 2024-06-25 19:47:47,002 - INFO - VAL Epoch: 73 Step: 3/5 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.1695 Batch Time: 2.3936
# 2024-06-25 19:47:48,145 - INFO - VAL Epoch: 73 Step: 4/5 Loss: 79.9615 Accuracy: 0.2004 AUC: 0.0000 Data Time: 1.0207 Batch Time: 2.1431
# 2024-06-25 19:47:48,149 - INFO - AUC Score: 0.5000
# 2024-06-25 19:47:48,249 - INFO - Starting Epoch: 75
# 2024-06-25 19:47:49,949 - INFO - TRAIN Epoch: 74 Step: 0/18 Loss: 83.3333 Accuracy: 0.1667 AUC: 0.0000 Data Time: 0.8060 Batch Time: 1.6981
# 2024-06-25 19:47:52,339 - INFO - TRAIN Epoch: 74 Step: 1/18 Loss: 80.8333 Accuracy: 0.1917 AUC: 0.0000 Data Time: 1.1005 Batch Time: 2.0430
# 2024-06-25 19:47:54,852 - INFO - TRAIN Epoch: 74 Step: 2/18 Loss: 82.2222 Accuracy: 0.1778 AUC: 0.0000 Data Time: 1.1659 Batch Time: 2.1992
# 2024-06-25 19:47:57,341 - INFO - TRAIN Epoch: 74 Step: 3/18 Loss: 81.4583 Accuracy: 0.1854 AUC: 0.0000 Data Time: 1.1429 Batch Time: 2.2711
# 2024-06-25 19:48:00,667 - INFO - TRAIN Epoch: 74 Step: 4/18 Loss: 81.1667 Accuracy: 0.1883 AUC: 0.0000 Data Time: 1.1713 Batch Time: 2.4815
# 2024-06-25 19:48:03,625 - INFO - TRAIN Epoch: 74 Step: 5/18 Loss: 81.3889 Accuracy: 0.1861 AUC: 0.0000 Data Time: 1.1238 Batch Time: 2.5606

# %%
trainer.auc_scores
