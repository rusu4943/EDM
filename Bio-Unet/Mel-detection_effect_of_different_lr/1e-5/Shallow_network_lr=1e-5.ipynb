# %%
import sys
sys.executable
# Out:
# '/home/rs37890/.conda/envs/UDA/bin/python'

# %%
import os
import re
import sys
import time
import copy
import h5py
import random
import logging
import argparse
import numpy as np
import pandas as pd
from PIL import Image

# %%
import torch
import torch.nn as nn

# %%
from torchvision import *
import torchvision.models

# %%
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # args

# %%
parser = argparse.ArgumentParser()

parser.add_argument('--report-freq', type=int, default=1, help='logging frequency')
parser.add_argument('--tune-mode', type=str, default='fine-tune', choices=['fine-tune', 'feature-extract'], help='tuning mode' )
parser.add_argument('--backbone', type=str, default='resnet50', choices=['resnet50', 'vgg19', 'inception_v3'], 
                    help='backbone architecture' )
parser.add_argument('--cls-type', type=str, default='single', choices=['single', 
                   'double', 'double-bn', 'double-dropout'], help='classifier architecture' )
parser.add_argument('--hidden-dim', type=int, default=512, help='hidden dimension of classifier' )
parser.add_argument('--record-root-dir', type=str, default='./record-data', help='record data root dir' )
parser.add_argument('--exp', type=str, default='default_exp', help='name of experiment' )
parser.add_argument('--batch-size', type=int, default=8, help='batch size' )
parser.add_argument('--num-workers', type=int, default=0, help='number of processes working on cpu.')
parser.add_argument('--num-classes', type=int, default=5, help='number of classes')
parser.add_argument('--num-epochs', type=int, default=20,  help='number of epochs.')
parser.add_argument( '--num-steps', type=int, default=-1, help='number of steps per epoch. '+ '-1 means use entire data' )
parser.add_argument('--learn-rate', type=float, default=1e-3, help='learning rate for gradient descent')
parser.add_argument('--weight-decay', type=float, default=1e-3, help='weight decay for optimization')
parser.add_argument('--resume', action='store_true', help='resume experiment <exp> from last checkpoint' )
parser.add_argument('--input-dir', type=str, default= r'../h5py/', help='data root dir' )
parser.add_argument('--save-name', type=str, default='model.pt', help='saved model name' )

args, unknown =  parser.parse_known_args()

# %%
# device
DEVICE = 'cuda:1' if torch.cuda.is_available() else 'cpu'
args.device = DEVICE
args.gpu_ids = [1]

# %%
args.num_epochs = 100
args.learn_rate = 1e-5
args.weight_decay = 1e-5 
args.batch_size = 120
args.num_classes = 1
args.seed = 1111

# %%
args.root = '/scratch/rs37890/CARC/Explainable-NN-model'
args.sub_root = '/Fold1_Bio-Unet-stage1'
args.checkpoint_root = '/F(CLR) + F(Res) + F(Seg)'
args.shallow_network_folder = '/Mel-detection_effect_of_different_lr/1e-5'

args.csv_h5_dir = args.root + '/Data'

args.record_dir = args.root  + args.sub_root + args.shallow_network_folder + '/record_dir'
args.save_name = 'Resnet50'

# %% [markdown]
# # dataset

# %%
def get_transform(split):
    
    img_size = ( 512, 512 )
    Normal_transform = transforms.Compose([ transforms.Resize( img_size ),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])],
                                         )

    return Normal_transform

# %%
class SkinDataset( torch.utils.data.Dataset ):

    def __init__( self, h5_file_path, transform, split, args):
        self.h5_file_path = h5_file_path
        self.h5_file = None
        self.transform = transform
        self.split = split
        self.img_id_to_h5idx = self.build_img_id_to_h5idx()
        self.num_imgs = self.get_num_imgs() 

        self.args = args

        self.ATTR_TO_INDEX = { 'globules': 0,
                               'milia_like_cyst': 1,
                               'negative_network': 2,
                               'pigment_network': 3,
                               'streaks': 4,
                             }

    def get_num_imgs( self ):
        with h5py.File( self.h5_file_path, 'r' ) as f:
            return len( f['image_ids'] )

    def build_img_id_to_h5idx( self ):
        with h5py.File( self.h5_file_path, 'r' ) as f:
            
            img_ids = f['image_ids']
            img_id_to_h5idx = { img_id : idx for idx, img_id in enumerate( img_ids ) }
            
            return img_id_to_h5idx

    def __len__( self ):
        return self.get_num_imgs()

    def __getitem__( self, idx ):
        # import pdb; pdb.set_trace()
        if not self.h5_file:
            self.h5_file = h5py.File( self.h5_file_path, 'r' )
            
        img_id = self.h5_file['image_ids'][idx]
        img = self.h5_file['images'][idx]
        img = img.transpose([1, 2, 0])

        assert img.shape == (512, 512, 3)

        img = Image.fromarray( np.uint8(img) )
        
        if self.split == 'unsup':
            img1 = self.transform( img )
            img2 = self.transform( img )
            return img_id, img1, img2
        
        else:
            masks = self.h5_file['masks'][idx]
            labels = self.h5_file['labels'][idx].astype(np.float64)
            img = self.transform( img )

            # labels[0] globus
            # labels[1] milia_like_cyst
            # labels[2] negative
            # labels[3] pigment
            # labels[4] streaks
            # labels[5] melanoma
            
            index = 5

            assert masks.shape == (5, 512, 512)
            assert np.expand_dims(labels[index], axis=0).shape == (1,)
            
            return img_id, img, np.expand_dims(labels[index], axis=0), masks

# %%
def get_dataloader( args ):
    
    dataloader = {}
    splits = [ 'train', 'val' ]
    
    for split in splits:
        
        h5_file_path = os.path.join( args.csv_h5_dir, f'{split}.h5' )
        transform = get_transform(split)

        bsz = args.batch_size
        
        dataset = SkinDataset( h5_file_path, transform, split, args)
        loader = torch.utils.data.DataLoader( dataset = dataset,
                                              batch_size = bsz,
                                              shuffle = True if split != 'val' else False,
                                              num_workers = args.num_workers,
                                              drop_last = False,
                                            )
        
        dataloader[ split ] = loader
        
    return dataloader

# %% [markdown]
# # Load model

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.base_model = torchvision.models.resnet50(pretrained=True)
        self.base_layers = list(self.base_model.children())
        
        self.layer0 = nn.Sequential(*self.base_layers[:3])
        self.layer1 = nn.Sequential(*self.base_layers[3:5]) # size=(N, 256, x.H/4, x.W/4)
        self.layer2 = self.base_layers[5]  # size=(N, 512, x.H/8, x.W/8)
        self.layer3 = self.base_layers[6]  # size=(N, 1024, x.H/16, x.W/16)
        self.layer4 = self.base_layers[7]  # size=(N, 2048, x.H/32, x.W/32)
        self.Avgpooling = nn.Sequential(self.base_layers[8])
        
        self.mlp = torch.nn.Sequential( torch.nn.Linear(2048,1), )# only one linear layer on top
        
    def forward(self, X):
        layer0 = self.layer0(X)  # layer0:  torch.Size([1, 64, 256, 256])
        layer1 = self.layer1(layer0) # layer1:  torch.Size([1, 256, 128, 128])
        layer2 = self.layer2(layer1) # layer2:  torch.Size([1, 512, 64, 64])
        layer3 = self.layer3(layer2) # layer3:  torch.Size([1, 1024, 32, 32])
        layer4 = self.layer4(layer3) # layer4:  torch.Size([1, 2048, 16, 16])
        out    = self.Avgpooling(layer4)
        
        out1 = torch.squeeze(out) 
        if X.size(0) == 1: # torch.Size([1, 2048, 1, 1]) => torch.Size([2048])
            out1 = torch.unsqueeze(out1, 0) # torch.Size([1, 2048])
        out = self.mlp(out1)
        return out1, out

# %% [markdown]
# # Streaks

# %%
net = Model()
streaks_net = torch.nn.DataParallel(net)
streaks_net = streaks_net.module.to( DEVICE )
# Out:
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/streaks"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
streaks_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
streaks_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/streaks/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(streaks_Model_path)
streaks_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Pigment

# %%
net = Model()
pigment_net = torch.nn.DataParallel(net)
pigment_net = pigment_net.to( DEVICE )
pigment_net = pigment_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/pigment"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
pigment_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
pigment_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/pigment/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(pigment_Model_path)
pigment_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Negative

# %%
net = Model()
negative_net = torch.nn.DataParallel(net)
negative_net = negative_net.to( DEVICE )
negative_net = negative_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/negative"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
negative_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
negative_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/negative/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(negative_Model_path)
negative_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Milia

# %%
net = Model()
milia_net = torch.nn.DataParallel(net)
milia_net = milia_net.to( DEVICE )
milia_net = milia_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/milia_like_cyst"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
milia_like_cyst_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
milia_like_cyst_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/milia_like_cyst/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(milia_like_cyst_Model_path)
milia_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Globules

# %%
net = Model()
globules_net = torch.nn.DataParallel(net)
globules_net = globules_net.to( DEVICE )
globules_net = globules_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/globules"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
globules_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
globules_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/globules/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(globules_Model_path)
globules_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # softmax

# %%
class LogisticRegression(torch.nn.Module): 
    def __init__(self, input_dim = 10240, output_dim = 1): 
        super(LogisticRegression, self).__init__() 
        #self.linear = torch.nn.Linear(input_dim, output_dim) 
        self.linear1 = torch.nn.Linear(input_dim, 2048) 
        self.linear2 = torch.nn.Linear(2048, 512) 
        self.linear3 = torch.nn.Linear(512, output_dim) 
        
    def forward(self, x): 
        #outputs = torch.sigmoid(self.linear(x)) 
        output1 = self.linear1(x)
        output2 = self.linear2(output1)
        output3 = self.linear3(output2)
        
        return nn.Sigmoid()(output3).type(torch.float64)

# %% [markdown]
# # Trainer

# %%
class AverageMeter:
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
class Trainer:
    def __init__(self, 
                 model, 
                 globules_net , milia_net, negative_net, pigment_net, streaks_net,
                 dataloader, 
                 args,
                ):
        
        self.model = model.to(args.device)
        self.dataloader = dataloader
        self.args = args
        self.best_loss = np.inf
        self.best_epoch = 0
        self.best_model = None
        self.current_epoch = 0

        self.globules_net = globules_net.to(args.device)
        self.milia_net = milia_net.to(args.device)
        self.negative_net = negative_net.to(args.device)
        self.pigment_net = pigment_net.to(args.device)
        self.streaks_net = streaks_net.to(args.device)


        self.globules_net.eval()
        self.milia_net.eval()
        self.negative_net.eval()
        self.pigment_net.eval()
        self.streaks_net.eval()
        

        self.criterion = nn.BCELoss()
        self.optimizer = torch.optim.Adam( params = self.model.parameters(),
                                           lr = self.args.learn_rate,
                                           weight_decay = self.args.weight_decay,
                                         )

        self.logger = self.setup_logger()
        self.setup_experiment()
        self.set_random_seeds()

    def setup_logger(self):
        log_file = 'log.txt'
        if os.path.exists(log_file):
            os.remove(log_file)  # Remove the existing log file if it exists
        
        logger = logging.getLogger('Trainer')
        logger.setLevel(logging.INFO)
    
        # File Handler for log files
        fh = logging.FileHandler(log_file)
        fh.setLevel(logging.INFO)
        file_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        fh.setFormatter(file_formatter)
        logger.addHandler(fh)
    
        # Stream Handler for console output
        ch = logging.StreamHandler()
        ch.setLevel(logging.INFO)
        console_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        ch.setFormatter(console_formatter)
        logger.addHandler(ch)
    
        return logger

    def setup_experiment(self):
        self.name = self.args.exp
        self.exp_dir = os.path.join(self.args.record_root_dir, self.name)
        self.logger.info(f'seed is: {self.args.seed}')
        self.logger.info(f'args: {self.args}')

    def set_random_seeds(self):
        seed = random.randint(0, 100000)
        torch.manual_seed(seed)
        random.seed(seed)
        np.random.seed(seed)
        self.args.seed = seed

    def get_accuracy(self, pred, labels):
        predicted_labels = (pred > 0.5).int()
        correct_predictions = (predicted_labels == labels).sum().item()
        total_predictions = labels.size(0)
        accuracy = correct_predictions / total_predictions
        return accuracy

    def concate_5120(self, imgs):
        # This function should include model evaluation calls
        # Assuming these models are attributes of the class
        with torch.no_grad():
            pred1, _ = self.globules_net(imgs)
            pred2, _ = self.negative_net(imgs)
            pred3, _ = self.milia_net(imgs)
            pred4, _ = self.pigment_net(imgs)
            pred5, _ = self.streaks_net(imgs)
            return torch.cat((pred1, pred2, pred3, pred4, pred5), 1)

    def train_or_val(self, mode='train'):
        
        assert mode in ['train', 'val'], "Mode must be 'train' or 'val'"
        dataloader = self.dataloader[mode]
        num_steps = len(dataloader)
        self.model.train() if mode == 'train' else self.model.eval()

        loss_meter = AverageMeter()
        acc_meter = AverageMeter()
        data_time_meter = AverageMeter()
        batch_time_meter = AverageMeter()
        all_preds = []
        all_labels = []

        start = time.time()
        for batch_id, (img_ids, imgs, labels, masks) in enumerate(dataloader):
            data_time = time.time() - start
            if batch_id >= num_steps: break

            imgs, labels = imgs.to(self.args.device), labels.to(self.args.device)
            
            if mode == 'train':
                self.optimizer.zero_grad()

            concate_input = self.concate_5120(imgs)
            pred = self.model(concate_input)

            
            loss = self.criterion(pred, labels)
            if mode == 'train':
                loss.backward()
                self.optimizer.step()

            loss_meter.update(loss.item(), len(imgs))
            acc = self.get_accuracy( pred.detach().cpu(), labels.cpu() )
            acc_meter.update(acc, len(imgs))
            batch_time = time.time() - start

            data_time_meter.update(data_time)
            batch_time_meter.update(batch_time)
            all_preds.append(pred.detach().cpu())
            all_labels.append(labels.cpu())

            # if (batch_id+1) % self.args.report_freq == 0:
            self.log_epoch_stats(mode.upper(), batch_id, num_steps, loss_meter.avg, acc_meter.avg, 0, data_time_meter.avg, batch_time_meter.avg)

            start = time.time()

        all_labels = torch.cat(all_labels, dim=0)
        all_preds = torch.cat(all_preds, dim=0)
        self.auc_scores = roc_auc_score( np.array(all_labels), np.array(all_preds), average=None)
        self.log_auc_scores(self.auc_scores)

        return loss_meter.avg, acc_meter.avg, self.auc_scores.mean()

    def log_epoch_stats(self, phase, batch_id, num_steps, avg_loss, avg_acc, mean_auc, avg_data_time, avg_batch_time):
        self.logger.info(f'{phase} Epoch: {self.current_epoch} Step: {batch_id}/{num_steps} Loss: {avg_loss:.4f} Accuracy: {avg_acc:.4f} AUC: {mean_auc:.4f} Data Time: {avg_data_time:.4f} Batch Time: {avg_batch_time:.4f}')

    def log_auc_scores(self, auc_scores):
        if isinstance(auc_scores, np.ndarray):
            for i, score in enumerate(auc_scores):
                self.logger.info(f'AUC Score {i}: {score:.4f}')
        else:
            self.logger.info(f'AUC Score: {auc_scores:.4f}')

    def save_model(self, save_path):
        torch.save(self.model.state_dict(), save_path)

    def train(self):
        for epoch in range(self.current_epoch, self.args.num_epochs):
            self.current_epoch = epoch
            self.logger.info(f'Starting Epoch: {epoch + 1}')
            train_loss, train_acc, train_auc = self.train_or_val('train')
            val_loss, val_acc, val_auc = self.train_or_val('val')

            if val_loss < self.best_loss:
                self.best_loss = val_loss
                self.best_model = copy.deepcopy(self.model)
                self.best_epoch = epoch + 1
                self.logger.info(f'New best model at epoch: {epoch + 1}')

                save_path = os.path.join( self.args.record_dir, self.args.save_name + '_best.pt')
                self.save_model(save_path)

            save_path = os.path.join( self.args.record_dir, self.args.save_name + '.pt')
            self.save_model(save_path)

# %%
dataloaders = get_dataloader( args )

# %%
trainer = Trainer(LogisticRegression(), 
                  globules_net , milia_net, negative_net, pigment_net, streaks_net,
                  dataloaders, 
                  args,
                 )
# Out:
# 2024-06-25 16:57:52,370 - INFO - seed is: 1111
# 2024-06-25 16:57:52,371 - INFO - args: Namespace(report_freq=1, tune_mode='fine-tune', backbone='resnet50', cls_type='single', hidden_dim=512, record_root_dir='./record-data', exp='default_exp', batch_size=120, num_workers=0, num_classes=1, num_epochs=100, num_steps=-1, learn_rate=1e-05, weight_decay=1e-05, resume=False, input_dir='../h5py/', save_name='Resnet50', device='cuda:1', gpu_ids=[1], seed=1111, root='/scratch/rs37890/CARC/Explainable-NN-model', sub_root='/Fold1_Bio-Unet-stage1', checkpoint_root='/F(CLR) + F(Res) + F(Seg)', shallow_network_folder='/Mel-detection_effect_of_different_lr/1e-5', csv_h5_dir='/scratch/rs37890/CARC/Explainable-NN-model/Data', record_dir='/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/Mel-detection_effect_of_different_lr/1e-5/record_dir')

# %%
trainer.train()
# Out:
# 2024-06-25 16:57:52,378 - INFO - Starting Epoch: 1
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1712608885084/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:84.)
#   return F.conv2d(input, weight, bias, self.stride,
# 2024-06-25 16:57:58,207 - INFO - TRAIN Epoch: 0 Step: 0/18 Loss: 0.7323 Accuracy: 0.2750 AUC: 0.0000 Data Time: 3.6495 Batch Time: 5.8265
# 2024-06-25 16:58:03,591 - INFO - TRAIN Epoch: 0 Step: 1/18 Loss: 0.6801 Accuracy: 0.5042 AUC: 0.0000 Data Time: 3.5470 Batch Time: 5.6030
# 2024-06-25 16:58:07,709 - INFO - TRAIN Epoch: 0 Step: 2/18 Loss: 0.6229 Accuracy: 0.6111 AUC: 0.0000 Data Time: 3.1750 Batch Time: 5.1075
# 2024-06-25 16:58:12,393 - INFO - TRAIN Epoch: 0 Step: 3/18 Loss: 0.5929 Accuracy: 0.6583 AUC: 0.0000 Data Time: 3.0705 Batch Time: 5.0010
# 2024-06-25 16:58:15,250 - INFO - TRAIN Epoch: 0 Step: 4/18 Loss: 0.5696 Accuracy: 0.6900 AUC: 0.0000 Data Time: 2.8451 Batch Time: 4.5718
# 2024-06-25 16:58:18,086 - INFO - TRAIN Epoch: 0 Step: 5/18 Loss: 0.5488 Accuracy: 0.7153 AUC: 0.0000 Data Time: 2.6938 Batch Time: 4.2821
# 2024-06-25 16:58:21,575 - INFO - TRAIN Epoch: 0 Step: 6/18 Loss: 0.5533 Accuracy: 0.7238 AUC: 0.0000 Data Time: 2.6583 Batch Time: 4.1687
# 2024-06-25 16:58:24,751 - INFO - TRAIN Epoch: 0 Step: 7/18 Loss: 0.5522 Accuracy: 0.7344 AUC: 0.0000 Data Time: 2.6090 Batch Time: 4.0445
# 2024-06-25 16:58:28,213 - INFO - TRAIN Epoch: 0 Step: 8/18 Loss: 0.5554 Accuracy: 0.7389 AUC: 0.0000 Data Time: 2.6031 Batch Time: 3.9794
# 2024-06-25 16:58:31,679 - INFO - TRAIN Epoch: 0 Step: 9/18 Loss: 0.5562 Accuracy: 0.7425 AUC: 0.0000 Data Time: 2.5958 Batch Time: 3.9278
# 2024-06-25 16:58:37,513 - INFO - TRAIN Epoch: 0 Step: 10/18 Loss: 0.5414 Accuracy: 0.7530 AUC: 0.0000 Data Time: 2.6999 Batch Time: 4.1009
# 2024-06-25 16:58:40,617 - INFO - TRAIN Epoch: 0 Step: 11/18 Loss: 0.5388 Accuracy: 0.7576 AUC: 0.0000 Data Time: 2.6429 Batch Time: 4.0175
# 2024-06-25 16:58:43,934 - INFO - TRAIN Epoch: 0 Step: 12/18 Loss: 0.5398 Accuracy: 0.7583 AUC: 0.0000 Data Time: 2.6235 Batch Time: 3.9635
# 2024-06-25 16:58:48,031 - INFO - TRAIN Epoch: 0 Step: 13/18 Loss: 0.5364 Accuracy: 0.7619 AUC: 0.0000 Data Time: 2.6331 Batch Time: 3.9729
# 2024-06-25 16:58:51,441 - INFO - TRAIN Epoch: 0 Step: 14/18 Loss: 0.5302 Accuracy: 0.7667 AUC: 0.0000 Data Time: 2.6235 Batch Time: 3.9349
# 2024-06-25 16:58:54,351 - INFO - TRAIN Epoch: 0 Step: 15/18 Loss: 0.5240 Accuracy: 0.7719 AUC: 0.0000 Data Time: 2.5812 Batch Time: 3.8707
# 2024-06-25 16:58:58,207 - INFO - TRAIN Epoch: 0 Step: 16/18 Loss: 0.5212 Accuracy: 0.7740 AUC: 0.0000 Data Time: 2.5519 Batch Time: 3.8698
# 2024-06-25 16:58:58,986 - INFO - TRAIN Epoch: 0 Step: 17/18 Loss: 0.5215 Accuracy: 0.7739 AUC: 0.0000 Data Time: 2.4362 Batch Time: 3.6980
# 2024-06-25 16:58:58,990 - INFO - AUC Score: 0.5592
# 2024-06-25 16:59:01,584 - INFO - VAL Epoch: 0 Step: 0/5 Loss: 0.5011 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.6791 Batch Time: 2.5919
# 2024-06-25 16:59:04,115 - INFO - VAL Epoch: 0 Step: 1/5 Loss: 0.4813 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.6607 Batch Time: 2.5613
# 2024-06-25 16:59:07,547 - INFO - VAL Epoch: 0 Step: 2/5 Loss: 0.4808 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.6332 Batch Time: 2.8492
# 2024-06-25 16:59:10,079 - INFO - VAL Epoch: 0 Step: 3/5 Loss: 0.4954 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.6288 Batch Time: 2.7691
# 2024-06-25 16:59:11,191 - INFO - VAL Epoch: 0 Step: 4/5 Loss: 0.5057 Accuracy: 0.7996 AUC: 0.0000 Data Time: 1.3935 Batch Time: 2.4370
# 2024-06-25 16:59:11,194 - INFO - AUC Score: 0.5637
# 2024-06-25 16:59:11,195 - INFO - New best model at epoch: 1
# 2024-06-25 16:59:11,365 - INFO - Starting Epoch: 2
# 2024-06-25 16:59:16,054 - INFO - TRAIN Epoch: 1 Step: 0/18 Loss: 0.5968 Accuracy: 0.7000 AUC: 0.0000 Data Time: 2.8836 Batch Time: 4.6856
# 2024-06-25 16:59:20,645 - INFO - TRAIN Epoch: 1 Step: 1/18 Loss: 0.5278 Accuracy: 0.7667 AUC: 0.0000 Data Time: 2.8408 Batch Time: 4.6370
# 2024-06-25 16:59:25,138 - INFO - TRAIN Epoch: 1 Step: 2/18 Loss: 0.5149 Accuracy: 0.7750 AUC: 0.0000 Data Time: 2.8189 Batch Time: 4.5882
# 2024-06-25 16:59:28,030 - INFO - TRAIN Epoch: 1 Step: 3/18 Loss: 0.5142 Accuracy: 0.7812 AUC: 0.0000 Data Time: 2.6115 Batch Time: 4.1641
# 2024-06-25 16:59:31,084 - INFO - TRAIN Epoch: 1 Step: 4/18 Loss: 0.5077 Accuracy: 0.7900 AUC: 0.0000 Data Time: 2.5177 Batch Time: 3.9417
# 2024-06-25 16:59:34,921 - INFO - TRAIN Epoch: 1 Step: 5/18 Loss: 0.5049 Accuracy: 0.7931 AUC: 0.0000 Data Time: 2.4200 Batch Time: 3.9230
# 2024-06-25 16:59:37,699 - INFO - TRAIN Epoch: 1 Step: 6/18 Loss: 0.4951 Accuracy: 0.7988 AUC: 0.0000 Data Time: 2.3400 Batch Time: 3.7592
# 2024-06-25 16:59:40,559 - INFO - TRAIN Epoch: 1 Step: 7/18 Loss: 0.4918 Accuracy: 0.8021 AUC: 0.0000 Data Time: 2.2912 Batch Time: 3.6467
# 2024-06-25 16:59:44,741 - INFO - TRAIN Epoch: 1 Step: 8/18 Loss: 0.4930 Accuracy: 0.7991 AUC: 0.0000 Data Time: 2.2788 Batch Time: 3.7060
# 2024-06-25 16:59:48,688 - INFO - TRAIN Epoch: 1 Step: 9/18 Loss: 0.4940 Accuracy: 0.7958 AUC: 0.0000 Data Time: 2.2989 Batch Time: 3.7299
# 2024-06-25 16:59:52,161 - INFO - TRAIN Epoch: 1 Step: 10/18 Loss: 0.4926 Accuracy: 0.7947 AUC: 0.0000 Data Time: 2.3185 Batch Time: 3.7065
# 2024-06-25 16:59:55,314 - INFO - TRAIN Epoch: 1 Step: 11/18 Loss: 0.4877 Accuracy: 0.7972 AUC: 0.0000 Data Time: 2.3114 Batch Time: 3.6592
# 2024-06-25 16:59:58,520 - INFO - TRAIN Epoch: 1 Step: 12/18 Loss: 0.4889 Accuracy: 0.7968 AUC: 0.0000 Data Time: 2.3098 Batch Time: 3.6243
# 2024-06-25 17:00:01,692 - INFO - TRAIN Epoch: 1 Step: 13/18 Loss: 0.4953 Accuracy: 0.7935 AUC: 0.0000 Data Time: 2.2662 Batch Time: 3.5918
# 2024-06-25 17:00:06,015 - INFO - TRAIN Epoch: 1 Step: 14/18 Loss: 0.4939 Accuracy: 0.7944 AUC: 0.0000 Data Time: 2.2647 Batch Time: 3.6405
# 2024-06-25 17:00:11,338 - INFO - TRAIN Epoch: 1 Step: 15/18 Loss: 0.4906 Accuracy: 0.7969 AUC: 0.0000 Data Time: 2.3301 Batch Time: 3.7455
# 2024-06-25 17:00:14,947 - INFO - TRAIN Epoch: 1 Step: 16/18 Loss: 0.4869 Accuracy: 0.7990 AUC: 0.0000 Data Time: 2.3495 Batch Time: 3.7374
# 2024-06-25 17:00:16,412 - INFO - TRAIN Epoch: 1 Step: 17/18 Loss: 0.4853 Accuracy: 0.7999 AUC: 0.0000 Data Time: 2.2747 Batch Time: 3.6107
# 2024-06-25 17:00:16,424 - INFO - AUC Score: 0.6262
# 2024-06-25 17:00:20,575 - INFO - VAL Epoch: 1 Step: 0/5 Loss: 0.4818 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.8865 Batch Time: 4.1416
# 2024-06-25 17:00:24,014 - INFO - VAL Epoch: 1 Step: 1/5 Loss: 0.4567 Accuracy: 0.8167 AUC: 0.0000 Data Time: 2.6974 Batch Time: 3.7883
# 2024-06-25 17:00:28,110 - INFO - VAL Epoch: 1 Step: 2/5 Loss: 0.4548 Accuracy: 0.8222 AUC: 0.0000 Data Time: 2.8531 Batch Time: 3.8901
# 2024-06-25 17:00:32,040 - INFO - VAL Epoch: 1 Step: 3/5 Loss: 0.4766 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.7831 Batch Time: 3.8997
# 2024-06-25 17:00:33,300 - INFO - VAL Epoch: 1 Step: 4/5 Loss: 0.4908 Accuracy: 0.7996 AUC: 0.0000 Data Time: 2.4034 Batch Time: 3.3714
# 2024-06-25 17:00:33,304 - INFO - AUC Score: 0.6050
# 2024-06-25 17:00:33,309 - INFO - New best model at epoch: 2
# 2024-06-25 17:00:33,498 - INFO - Starting Epoch: 3
# 2024-06-25 17:00:37,830 - INFO - TRAIN Epoch: 2 Step: 0/18 Loss: 0.4772 Accuracy: 0.7833 AUC: 0.0000 Data Time: 3.3743 Batch Time: 4.3286
# 2024-06-25 17:00:41,168 - INFO - TRAIN Epoch: 2 Step: 1/18 Loss: 0.4666 Accuracy: 0.8000 AUC: 0.0000 Data Time: 2.8800 Batch Time: 3.8317
# 2024-06-25 17:00:44,393 - INFO - TRAIN Epoch: 2 Step: 2/18 Loss: 0.4598 Accuracy: 0.8028 AUC: 0.0000 Data Time: 2.6448 Batch Time: 3.6281
# 2024-06-25 17:00:47,849 - INFO - TRAIN Epoch: 2 Step: 3/18 Loss: 0.4558 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.4968 Batch Time: 3.5824
# 2024-06-25 17:00:51,564 - INFO - TRAIN Epoch: 2 Step: 4/18 Loss: 0.4513 Accuracy: 0.8117 AUC: 0.0000 Data Time: 2.3496 Batch Time: 3.6082
# 2024-06-25 17:00:56,270 - INFO - TRAIN Epoch: 2 Step: 5/18 Loss: 0.4425 Accuracy: 0.8208 AUC: 0.0000 Data Time: 2.4326 Batch Time: 3.7903
# 2024-06-25 17:01:00,805 - INFO - TRAIN Epoch: 2 Step: 6/18 Loss: 0.4580 Accuracy: 0.8095 AUC: 0.0000 Data Time: 2.5015 Batch Time: 3.8963
# 2024-06-25 17:01:03,821 - INFO - TRAIN Epoch: 2 Step: 7/18 Loss: 0.4586 Accuracy: 0.8073 AUC: 0.0000 Data Time: 2.4491 Batch Time: 3.7858
# 2024-06-25 17:01:07,404 - INFO - TRAIN Epoch: 2 Step: 8/18 Loss: 0.4656 Accuracy: 0.8009 AUC: 0.0000 Data Time: 2.4729 Batch Time: 3.7630
# 2024-06-25 17:01:10,879 - INFO - TRAIN Epoch: 2 Step: 9/18 Loss: 0.4678 Accuracy: 0.7992 AUC: 0.0000 Data Time: 2.4758 Batch Time: 3.7335
# 2024-06-25 17:01:14,344 - INFO - TRAIN Epoch: 2 Step: 10/18 Loss: 0.4618 Accuracy: 0.8053 AUC: 0.0000 Data Time: 2.4316 Batch Time: 3.7080
# 2024-06-25 17:01:19,023 - INFO - TRAIN Epoch: 2 Step: 11/18 Loss: 0.4627 Accuracy: 0.8056 AUC: 0.0000 Data Time: 2.4586 Batch Time: 3.7887
# 2024-06-25 17:01:23,164 - INFO - TRAIN Epoch: 2 Step: 12/18 Loss: 0.4625 Accuracy: 0.8051 AUC: 0.0000 Data Time: 2.4886 Batch Time: 3.8156
# 2024-06-25 17:01:25,959 - INFO - TRAIN Epoch: 2 Step: 13/18 Loss: 0.4589 Accuracy: 0.8077 AUC: 0.0000 Data Time: 2.4466 Batch Time: 3.7427
# 2024-06-25 17:01:28,967 - INFO - TRAIN Epoch: 2 Step: 14/18 Loss: 0.4597 Accuracy: 0.8056 AUC: 0.0000 Data Time: 2.4227 Batch Time: 3.6935
# 2024-06-25 17:01:31,949 - INFO - TRAIN Epoch: 2 Step: 15/18 Loss: 0.4612 Accuracy: 0.8042 AUC: 0.0000 Data Time: 2.3984 Batch Time: 3.6486
# 2024-06-25 17:01:36,318 - INFO - TRAIN Epoch: 2 Step: 16/18 Loss: 0.4650 Accuracy: 0.8010 AUC: 0.0000 Data Time: 2.4501 Batch Time: 3.6909
# 2024-06-25 17:01:37,364 - INFO - TRAIN Epoch: 2 Step: 17/18 Loss: 0.4662 Accuracy: 0.7999 AUC: 0.0000 Data Time: 2.3557 Batch Time: 3.5438
# 2024-06-25 17:01:37,377 - INFO - AUC Score: 0.7031
# 2024-06-25 17:01:40,341 - INFO - VAL Epoch: 2 Step: 0/5 Loss: 0.4668 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.8964 Batch Time: 2.9606
# 2024-06-25 17:01:43,166 - INFO - VAL Epoch: 2 Step: 1/5 Loss: 0.4438 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.8958 Batch Time: 2.8919
# 2024-06-25 17:01:46,934 - INFO - VAL Epoch: 2 Step: 2/5 Loss: 0.4387 Accuracy: 0.8222 AUC: 0.0000 Data Time: 2.2201 Batch Time: 3.1829
# 2024-06-25 17:01:50,513 - INFO - VAL Epoch: 2 Step: 3/5 Loss: 0.4601 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.3244 Batch Time: 3.2816
# 2024-06-25 17:01:51,641 - INFO - VAL Epoch: 2 Step: 4/5 Loss: 0.4738 Accuracy: 0.7996 AUC: 0.0000 Data Time: 2.0229 Batch Time: 2.8492
# 2024-06-25 17:01:51,645 - INFO - AUC Score: 0.6644
# 2024-06-25 17:01:51,647 - INFO - New best model at epoch: 3
# 2024-06-25 17:01:51,834 - INFO - Starting Epoch: 4
# 2024-06-25 17:01:55,682 - INFO - TRAIN Epoch: 3 Step: 0/18 Loss: 0.4984 Accuracy: 0.7833 AUC: 0.0000 Data Time: 2.9052 Batch Time: 3.8463
# 2024-06-25 17:01:58,985 - INFO - TRAIN Epoch: 3 Step: 1/18 Loss: 0.4963 Accuracy: 0.7833 AUC: 0.0000 Data Time: 2.5294 Batch Time: 3.5735
# 2024-06-25 17:02:03,869 - INFO - TRAIN Epoch: 3 Step: 2/18 Loss: 0.4964 Accuracy: 0.7861 AUC: 0.0000 Data Time: 2.6672 Batch Time: 4.0096
# 2024-06-25 17:02:09,713 - INFO - TRAIN Epoch: 3 Step: 3/18 Loss: 0.4814 Accuracy: 0.7979 AUC: 0.0000 Data Time: 2.9367 Batch Time: 4.4665
# 2024-06-25 17:02:14,333 - INFO - TRAIN Epoch: 3 Step: 4/18 Loss: 0.4703 Accuracy: 0.8000 AUC: 0.0000 Data Time: 2.8846 Batch Time: 4.4966
# 2024-06-25 17:02:18,791 - INFO - TRAIN Epoch: 3 Step: 5/18 Loss: 0.4681 Accuracy: 0.7986 AUC: 0.0000 Data Time: 2.8276 Batch Time: 4.4898
# 2024-06-25 17:02:23,529 - INFO - TRAIN Epoch: 3 Step: 6/18 Loss: 0.4627 Accuracy: 0.7988 AUC: 0.0000 Data Time: 2.8486 Batch Time: 4.5249
# 2024-06-25 17:02:27,821 - INFO - TRAIN Epoch: 3 Step: 7/18 Loss: 0.4647 Accuracy: 0.7969 AUC: 0.0000 Data Time: 2.9154 Batch Time: 4.4955
# 2024-06-25 17:02:32,309 - INFO - TRAIN Epoch: 3 Step: 8/18 Loss: 0.4622 Accuracy: 0.7981 AUC: 0.0000 Data Time: 2.9513 Batch Time: 4.4943
# 2024-06-25 17:02:37,094 - INFO - TRAIN Epoch: 3 Step: 9/18 Loss: 0.4619 Accuracy: 0.7983 AUC: 0.0000 Data Time: 2.9440 Batch Time: 4.5224
# 2024-06-25 17:02:40,977 - INFO - TRAIN Epoch: 3 Step: 10/18 Loss: 0.4614 Accuracy: 0.7985 AUC: 0.0000 Data Time: 2.9417 Batch Time: 4.4640
# 2024-06-25 17:02:45,162 - INFO - TRAIN Epoch: 3 Step: 11/18 Loss: 0.4603 Accuracy: 0.7986 AUC: 0.0000 Data Time: 2.9393 Batch Time: 4.4403
# 2024-06-25 17:02:50,310 - INFO - TRAIN Epoch: 3 Step: 12/18 Loss: 0.4609 Accuracy: 0.7981 AUC: 0.0000 Data Time: 2.9484 Batch Time: 4.4943
# 2024-06-25 17:02:54,864 - INFO - TRAIN Epoch: 3 Step: 13/18 Loss: 0.4589 Accuracy: 0.7976 AUC: 0.0000 Data Time: 2.9794 Batch Time: 4.4984
# 2024-06-25 17:02:59,070 - INFO - TRAIN Epoch: 3 Step: 14/18 Loss: 0.4519 Accuracy: 0.8017 AUC: 0.0000 Data Time: 2.9996 Batch Time: 4.4782
# 2024-06-25 17:03:03,566 - INFO - TRAIN Epoch: 3 Step: 15/18 Loss: 0.4517 Accuracy: 0.8010 AUC: 0.0000 Data Time: 2.9972 Batch Time: 4.4792
# 2024-06-25 17:03:08,876 - INFO - TRAIN Epoch: 3 Step: 16/18 Loss: 0.4514 Accuracy: 0.8005 AUC: 0.0000 Data Time: 3.0358 Batch Time: 4.5280
# 2024-06-25 17:03:10,090 - INFO - TRAIN Epoch: 3 Step: 17/18 Loss: 0.4530 Accuracy: 0.7999 AUC: 0.0000 Data Time: 2.9168 Batch Time: 4.3438
# 2024-06-25 17:03:10,099 - INFO - AUC Score: 0.7356
# 2024-06-25 17:03:14,162 - INFO - VAL Epoch: 3 Step: 0/5 Loss: 0.4609 Accuracy: 0.8083 AUC: 0.0000 Data Time: 3.1331 Batch Time: 4.0577
# 2024-06-25 17:03:17,838 - INFO - VAL Epoch: 3 Step: 1/5 Loss: 0.4351 Accuracy: 0.8167 AUC: 0.0000 Data Time: 2.8584 Batch Time: 3.8650
# 2024-06-25 17:03:21,944 - INFO - VAL Epoch: 3 Step: 2/5 Loss: 0.4280 Accuracy: 0.8222 AUC: 0.0000 Data Time: 2.9030 Batch Time: 3.9438
# 2024-06-25 17:03:26,974 - INFO - VAL Epoch: 3 Step: 3/5 Loss: 0.4502 Accuracy: 0.8083 AUC: 0.0000 Data Time: 3.0927 Batch Time: 4.2146
# 2024-06-25 17:03:28,041 - INFO - VAL Epoch: 3 Step: 4/5 Loss: 0.4658 Accuracy: 0.7996 AUC: 0.0000 Data Time: 2.5891 Batch Time: 3.5850
# 2024-06-25 17:03:28,045 - INFO - AUC Score: 0.6839
# 2024-06-25 17:03:28,047 - INFO - New best model at epoch: 4
# 2024-06-25 17:03:28,385 - INFO - Starting Epoch: 5
# 2024-06-25 17:03:31,747 - INFO - TRAIN Epoch: 4 Step: 0/18 Loss: 0.4780 Accuracy: 0.7750 AUC: 0.0000 Data Time: 1.9047 Batch Time: 3.3601
# 2024-06-25 17:03:35,482 - INFO - TRAIN Epoch: 4 Step: 1/18 Loss: 0.4634 Accuracy: 0.7875 AUC: 0.0000 Data Time: 2.3532 Batch Time: 3.5456
# 2024-06-25 17:03:39,872 - INFO - TRAIN Epoch: 4 Step: 2/18 Loss: 0.4748 Accuracy: 0.7750 AUC: 0.0000 Data Time: 2.6389 Batch Time: 3.8200
# 2024-06-25 17:03:43,490 - INFO - TRAIN Epoch: 4 Step: 3/18 Loss: 0.4701 Accuracy: 0.7854 AUC: 0.0000 Data Time: 2.5253 Batch Time: 3.7686
# 2024-06-25 17:03:46,037 - INFO - TRAIN Epoch: 4 Step: 4/18 Loss: 0.4638 Accuracy: 0.7950 AUC: 0.0000 Data Time: 2.3442 Batch Time: 3.5241
# 2024-06-25 17:03:49,593 - INFO - TRAIN Epoch: 4 Step: 5/18 Loss: 0.4642 Accuracy: 0.7958 AUC: 0.0000 Data Time: 2.2268 Batch Time: 3.5293
# 2024-06-25 17:03:51,844 - INFO - TRAIN Epoch: 4 Step: 6/18 Loss: 0.4567 Accuracy: 0.8000 AUC: 0.0000 Data Time: 2.1021 Batch Time: 3.3464
# 2024-06-25 17:03:54,153 - INFO - TRAIN Epoch: 4 Step: 7/18 Loss: 0.4578 Accuracy: 0.8010 AUC: 0.0000 Data Time: 2.0157 Batch Time: 3.2166
# 2024-06-25 17:03:57,488 - INFO - TRAIN Epoch: 4 Step: 8/18 Loss: 0.4584 Accuracy: 0.7991 AUC: 0.0000 Data Time: 1.9633 Batch Time: 3.2296
# 2024-06-25 17:04:00,663 - INFO - TRAIN Epoch: 4 Step: 9/18 Loss: 0.4565 Accuracy: 0.7983 AUC: 0.0000 Data Time: 1.9677 Batch Time: 3.2241
# 2024-06-25 17:04:03,342 - INFO - TRAIN Epoch: 4 Step: 10/18 Loss: 0.4537 Accuracy: 0.7992 AUC: 0.0000 Data Time: 1.9509 Batch Time: 3.1745
# 2024-06-25 17:04:05,992 - INFO - TRAIN Epoch: 4 Step: 11/18 Loss: 0.4546 Accuracy: 0.7979 AUC: 0.0000 Data Time: 1.9101 Batch Time: 3.1307
# 2024-06-25 17:04:08,376 - INFO - TRAIN Epoch: 4 Step: 12/18 Loss: 0.4496 Accuracy: 0.8019 AUC: 0.0000 Data Time: 1.8779 Batch Time: 3.0731
# 2024-06-25 17:04:11,418 - INFO - TRAIN Epoch: 4 Step: 13/18 Loss: 0.4461 Accuracy: 0.8036 AUC: 0.0000 Data Time: 1.8344 Batch Time: 3.0709
# 2024-06-25 17:04:13,897 - INFO - TRAIN Epoch: 4 Step: 14/18 Loss: 0.4421 Accuracy: 0.8050 AUC: 0.0000 Data Time: 1.8177 Batch Time: 3.0314
# 2024-06-25 17:04:16,886 - INFO - TRAIN Epoch: 4 Step: 15/18 Loss: 0.4410 Accuracy: 0.8057 AUC: 0.0000 Data Time: 1.8350 Batch Time: 3.0286
# 2024-06-25 17:04:20,034 - INFO - TRAIN Epoch: 4 Step: 16/18 Loss: 0.4391 Accuracy: 0.8064 AUC: 0.0000 Data Time: 1.8199 Batch Time: 3.0356
# 2024-06-25 17:04:20,778 - INFO - TRAIN Epoch: 4 Step: 17/18 Loss: 0.4425 Accuracy: 0.8047 AUC: 0.0000 Data Time: 1.7410 Batch Time: 2.9083
# 2024-06-25 17:04:20,781 - INFO - AUC Score: 0.7515
# 2024-06-25 17:04:23,005 - INFO - VAL Epoch: 4 Step: 0/5 Loss: 0.4554 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.3377 Batch Time: 2.2227
# 2024-06-25 17:04:26,565 - INFO - VAL Epoch: 4 Step: 1/5 Loss: 0.4242 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.8927 Batch Time: 2.8905
# 2024-06-25 17:04:31,091 - INFO - VAL Epoch: 4 Step: 2/5 Loss: 0.4150 Accuracy: 0.8278 AUC: 0.0000 Data Time: 2.4005 Batch Time: 3.4331
# 2024-06-25 17:04:34,046 - INFO - VAL Epoch: 4 Step: 3/5 Loss: 0.4395 Accuracy: 0.8125 AUC: 0.0000 Data Time: 2.2225 Batch Time: 3.3134
# 2024-06-25 17:04:34,849 - INFO - VAL Epoch: 4 Step: 4/5 Loss: 0.4569 Accuracy: 0.8054 AUC: 0.0000 Data Time: 1.8784 Batch Time: 2.8111
# 2024-06-25 17:04:34,851 - INFO - AUC Score: 0.7057
# 2024-06-25 17:04:34,852 - INFO - New best model at epoch: 5
# 2024-06-25 17:04:35,024 - INFO - Starting Epoch: 6
# 2024-06-25 17:04:37,843 - INFO - TRAIN Epoch: 5 Step: 0/18 Loss: 0.5215 Accuracy: 0.7250 AUC: 0.0000 Data Time: 1.8508 Batch Time: 2.8181
# 2024-06-25 17:04:40,765 - INFO - TRAIN Epoch: 5 Step: 1/18 Loss: 0.4565 Accuracy: 0.7833 AUC: 0.0000 Data Time: 1.6921 Batch Time: 2.8692
# 2024-06-25 17:04:43,782 - INFO - TRAIN Epoch: 5 Step: 2/18 Loss: 0.4377 Accuracy: 0.7944 AUC: 0.0000 Data Time: 1.5937 Batch Time: 2.9183
# 2024-06-25 17:04:46,123 - INFO - TRAIN Epoch: 5 Step: 3/18 Loss: 0.4269 Accuracy: 0.8104 AUC: 0.0000 Data Time: 1.5548 Batch Time: 2.7739
# 2024-06-25 17:04:48,504 - INFO - TRAIN Epoch: 5 Step: 4/18 Loss: 0.4258 Accuracy: 0.8117 AUC: 0.0000 Data Time: 1.5306 Batch Time: 2.6951
# 2024-06-25 17:04:50,827 - INFO - TRAIN Epoch: 5 Step: 5/18 Loss: 0.4365 Accuracy: 0.8097 AUC: 0.0000 Data Time: 1.5133 Batch Time: 2.6330
# 2024-06-25 17:04:53,348 - INFO - TRAIN Epoch: 5 Step: 6/18 Loss: 0.4428 Accuracy: 0.8048 AUC: 0.0000 Data Time: 1.5292 Batch Time: 2.6169
# 2024-06-25 17:04:56,996 - INFO - TRAIN Epoch: 5 Step: 7/18 Loss: 0.4452 Accuracy: 0.7990 AUC: 0.0000 Data Time: 1.5416 Batch Time: 2.7456
# 2024-06-25 17:04:59,783 - INFO - TRAIN Epoch: 5 Step: 8/18 Loss: 0.4458 Accuracy: 0.7963 AUC: 0.0000 Data Time: 1.5642 Batch Time: 2.7502
# 2024-06-25 17:05:02,150 - INFO - TRAIN Epoch: 5 Step: 9/18 Loss: 0.4379 Accuracy: 0.8042 AUC: 0.0000 Data Time: 1.5562 Batch Time: 2.7117
# 2024-06-25 17:05:05,704 - INFO - TRAIN Epoch: 5 Step: 10/18 Loss: 0.4361 Accuracy: 0.8061 AUC: 0.0000 Data Time: 1.5780 Batch Time: 2.7883
# 2024-06-25 17:05:08,068 - INFO - TRAIN Epoch: 5 Step: 11/18 Loss: 0.4403 Accuracy: 0.8021 AUC: 0.0000 Data Time: 1.5716 Batch Time: 2.7528
# 2024-06-25 17:05:11,173 - INFO - TRAIN Epoch: 5 Step: 12/18 Loss: 0.4403 Accuracy: 0.8013 AUC: 0.0000 Data Time: 1.6196 Batch Time: 2.7799
# 2024-06-25 17:05:14,352 - INFO - TRAIN Epoch: 5 Step: 13/18 Loss: 0.4401 Accuracy: 0.8018 AUC: 0.0000 Data Time: 1.6665 Batch Time: 2.8083
# 2024-06-25 17:05:17,282 - INFO - TRAIN Epoch: 5 Step: 14/18 Loss: 0.4387 Accuracy: 0.8028 AUC: 0.0000 Data Time: 1.6910 Batch Time: 2.8164
# 2024-06-25 17:05:20,934 - INFO - TRAIN Epoch: 5 Step: 15/18 Loss: 0.4345 Accuracy: 0.8078 AUC: 0.0000 Data Time: 1.7567 Batch Time: 2.8685
# 2024-06-25 17:05:23,896 - INFO - TRAIN Epoch: 5 Step: 16/18 Loss: 0.4353 Accuracy: 0.8078 AUC: 0.0000 Data Time: 1.7745 Batch Time: 2.8740
# 2024-06-25 17:05:25,040 - INFO - TRAIN Epoch: 5 Step: 17/18 Loss: 0.4331 Accuracy: 0.8091 AUC: 0.0000 Data Time: 1.7088 Batch Time: 2.7778
# 2024-06-25 17:05:25,043 - INFO - AUC Score: 0.7638
# 2024-06-25 17:05:28,482 - INFO - VAL Epoch: 5 Step: 0/5 Loss: 0.4585 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.5392 Batch Time: 3.4361
# 2024-06-25 17:05:32,013 - INFO - VAL Epoch: 5 Step: 1/5 Loss: 0.4221 Accuracy: 0.8208 AUC: 0.0000 Data Time: 2.5862 Batch Time: 3.4822
# 2024-06-25 17:05:35,622 - INFO - VAL Epoch: 5 Step: 2/5 Loss: 0.4121 Accuracy: 0.8250 AUC: 0.0000 Data Time: 2.6106 Batch Time: 3.5239
# 2024-06-25 17:05:39,715 - INFO - VAL Epoch: 5 Step: 3/5 Loss: 0.4392 Accuracy: 0.8125 AUC: 0.0000 Data Time: 2.6345 Batch Time: 3.6657
# 2024-06-25 17:05:40,794 - INFO - VAL Epoch: 5 Step: 4/5 Loss: 0.4589 Accuracy: 0.8035 AUC: 0.0000 Data Time: 2.2603 Batch Time: 3.1482
# 2024-06-25 17:05:40,797 - INFO - AUC Score: 0.7136
# 2024-06-25 17:05:40,893 - INFO - Starting Epoch: 7
# 2024-06-25 17:05:44,202 - INFO - TRAIN Epoch: 6 Step: 0/18 Loss: 0.4458 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.1871 Batch Time: 3.3071
# 2024-06-25 17:05:47,738 - INFO - TRAIN Epoch: 6 Step: 1/18 Loss: 0.4558 Accuracy: 0.8042 AUC: 0.0000 Data Time: 2.2366 Batch Time: 3.4212
# 2024-06-25 17:05:51,325 - INFO - TRAIN Epoch: 6 Step: 2/18 Loss: 0.4678 Accuracy: 0.7917 AUC: 0.0000 Data Time: 2.1960 Batch Time: 3.4763
# 2024-06-25 17:05:53,516 - INFO - TRAIN Epoch: 6 Step: 3/18 Loss: 0.4566 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.9700 Batch Time: 3.1548
# 2024-06-25 17:05:56,138 - INFO - TRAIN Epoch: 6 Step: 4/18 Loss: 0.4467 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.8915 Batch Time: 3.0481
# 2024-06-25 17:05:58,950 - INFO - TRAIN Epoch: 6 Step: 5/18 Loss: 0.4430 Accuracy: 0.7972 AUC: 0.0000 Data Time: 1.8223 Batch Time: 3.0085
# 2024-06-25 17:06:01,250 - INFO - TRAIN Epoch: 6 Step: 6/18 Loss: 0.4288 Accuracy: 0.8071 AUC: 0.0000 Data Time: 1.7639 Batch Time: 2.9072
# 2024-06-25 17:06:04,314 - INFO - TRAIN Epoch: 6 Step: 7/18 Loss: 0.4273 Accuracy: 0.8094 AUC: 0.0000 Data Time: 1.7172 Batch Time: 2.9267
# 2024-06-25 17:06:06,850 - INFO - TRAIN Epoch: 6 Step: 8/18 Loss: 0.4283 Accuracy: 0.8046 AUC: 0.0000 Data Time: 1.6938 Batch Time: 2.8831
# 2024-06-25 17:06:09,770 - INFO - TRAIN Epoch: 6 Step: 9/18 Loss: 0.4311 Accuracy: 0.8067 AUC: 0.0000 Data Time: 1.6836 Batch Time: 2.8867
# 2024-06-25 17:06:11,976 - INFO - TRAIN Epoch: 6 Step: 10/18 Loss: 0.4332 Accuracy: 0.8061 AUC: 0.0000 Data Time: 1.6504 Batch Time: 2.8248
# 2024-06-25 17:06:14,490 - INFO - TRAIN Epoch: 6 Step: 11/18 Loss: 0.4295 Accuracy: 0.8118 AUC: 0.0000 Data Time: 1.6482 Batch Time: 2.7988
# 2024-06-25 17:06:16,794 - INFO - TRAIN Epoch: 6 Step: 12/18 Loss: 0.4256 Accuracy: 0.8147 AUC: 0.0000 Data Time: 1.6297 Batch Time: 2.7607
# 2024-06-25 17:06:19,715 - INFO - TRAIN Epoch: 6 Step: 13/18 Loss: 0.4233 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.6193 Batch Time: 2.7721
# 2024-06-25 17:06:21,972 - INFO - TRAIN Epoch: 6 Step: 14/18 Loss: 0.4294 Accuracy: 0.8128 AUC: 0.0000 Data Time: 1.6021 Batch Time: 2.7377
# 2024-06-25 17:06:24,313 - INFO - TRAIN Epoch: 6 Step: 15/18 Loss: 0.4340 Accuracy: 0.8094 AUC: 0.0000 Data Time: 1.5873 Batch Time: 2.7129
# 2024-06-25 17:06:26,657 - INFO - TRAIN Epoch: 6 Step: 16/18 Loss: 0.4285 Accuracy: 0.8127 AUC: 0.0000 Data Time: 1.5792 Batch Time: 2.6911
# 2024-06-25 17:06:27,372 - INFO - TRAIN Epoch: 6 Step: 17/18 Loss: 0.4299 Accuracy: 0.8120 AUC: 0.0000 Data Time: 1.5158 Batch Time: 2.5813
# 2024-06-25 17:06:27,374 - INFO - AUC Score: 0.7622
# 2024-06-25 17:06:30,687 - INFO - VAL Epoch: 6 Step: 0/5 Loss: 0.4465 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.3613 Batch Time: 3.3106
# 2024-06-25 17:06:33,583 - INFO - VAL Epoch: 6 Step: 1/5 Loss: 0.4109 Accuracy: 0.8292 AUC: 0.0000 Data Time: 1.6817 Batch Time: 3.1029
# 2024-06-25 17:06:36,777 - INFO - VAL Epoch: 6 Step: 2/5 Loss: 0.4028 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.7086 Batch Time: 3.1329
# 2024-06-25 17:06:40,330 - INFO - VAL Epoch: 6 Step: 3/5 Loss: 0.4255 Accuracy: 0.8187 AUC: 0.0000 Data Time: 1.9435 Batch Time: 3.2378
# 2024-06-25 17:06:41,353 - INFO - VAL Epoch: 6 Step: 4/5 Loss: 0.4427 Accuracy: 0.8073 AUC: 0.0000 Data Time: 1.6623 Batch Time: 2.7947
# 2024-06-25 17:06:41,356 - INFO - AUC Score: 0.7296
# 2024-06-25 17:06:41,357 - INFO - New best model at epoch: 7
# 2024-06-25 17:06:41,546 - INFO - Starting Epoch: 8
# 2024-06-25 17:06:44,582 - INFO - TRAIN Epoch: 7 Step: 0/18 Loss: 0.5089 Accuracy: 0.7833 AUC: 0.0000 Data Time: 2.1646 Batch Time: 3.0343
# 2024-06-25 17:06:47,619 - INFO - TRAIN Epoch: 7 Step: 1/18 Loss: 0.4374 Accuracy: 0.8208 AUC: 0.0000 Data Time: 2.0127 Batch Time: 3.0354
# 2024-06-25 17:06:49,848 - INFO - TRAIN Epoch: 7 Step: 2/18 Loss: 0.4246 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.7891 Batch Time: 2.7664
# 2024-06-25 17:06:53,250 - INFO - TRAIN Epoch: 7 Step: 3/18 Loss: 0.4091 Accuracy: 0.8396 AUC: 0.0000 Data Time: 1.7228 Batch Time: 2.9252
# 2024-06-25 17:06:57,348 - INFO - TRAIN Epoch: 7 Step: 4/18 Loss: 0.4144 Accuracy: 0.8350 AUC: 0.0000 Data Time: 1.8163 Batch Time: 3.1595
# 2024-06-25 17:07:01,429 - INFO - TRAIN Epoch: 7 Step: 5/18 Loss: 0.4128 Accuracy: 0.8347 AUC: 0.0000 Data Time: 1.8989 Batch Time: 3.3129
# 2024-06-25 17:07:05,258 - INFO - TRAIN Epoch: 7 Step: 6/18 Loss: 0.4135 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.9240 Batch Time: 3.3864
# 2024-06-25 17:07:08,723 - INFO - TRAIN Epoch: 7 Step: 7/18 Loss: 0.4136 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.9363 Batch Time: 3.3960
# 2024-06-25 17:07:12,910 - INFO - TRAIN Epoch: 7 Step: 8/18 Loss: 0.4110 Accuracy: 0.8213 AUC: 0.0000 Data Time: 1.9966 Batch Time: 3.4838
# 2024-06-25 17:07:17,077 - INFO - TRAIN Epoch: 7 Step: 9/18 Loss: 0.4063 Accuracy: 0.8283 AUC: 0.0000 Data Time: 2.0297 Batch Time: 3.5520
# 2024-06-25 17:07:20,735 - INFO - TRAIN Epoch: 7 Step: 10/18 Loss: 0.4143 Accuracy: 0.8227 AUC: 0.0000 Data Time: 2.0347 Batch Time: 3.5616
# 2024-06-25 17:07:23,488 - INFO - TRAIN Epoch: 7 Step: 11/18 Loss: 0.4143 Accuracy: 0.8250 AUC: 0.0000 Data Time: 2.0194 Batch Time: 3.4939
# 2024-06-25 17:07:26,031 - INFO - TRAIN Epoch: 7 Step: 12/18 Loss: 0.4171 Accuracy: 0.8218 AUC: 0.0000 Data Time: 1.9770 Batch Time: 3.4207
# 2024-06-25 17:07:28,384 - INFO - TRAIN Epoch: 7 Step: 13/18 Loss: 0.4170 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.9402 Batch Time: 3.3443
# 2024-06-25 17:07:31,020 - INFO - TRAIN Epoch: 7 Step: 14/18 Loss: 0.4199 Accuracy: 0.8178 AUC: 0.0000 Data Time: 1.9273 Batch Time: 3.2969
# 2024-06-25 17:07:34,933 - INFO - TRAIN Epoch: 7 Step: 15/18 Loss: 0.4170 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.9344 Batch Time: 3.3353
# 2024-06-25 17:07:38,019 - INFO - TRAIN Epoch: 7 Step: 16/18 Loss: 0.4192 Accuracy: 0.8181 AUC: 0.0000 Data Time: 1.9301 Batch Time: 3.3205
# 2024-06-25 17:07:39,046 - INFO - TRAIN Epoch: 7 Step: 17/18 Loss: 0.4192 Accuracy: 0.8182 AUC: 0.0000 Data Time: 1.8469 Batch Time: 3.1931
# 2024-06-25 17:07:39,050 - INFO - AUC Score: 0.7805
# 2024-06-25 17:07:41,516 - INFO - VAL Epoch: 7 Step: 0/5 Loss: 0.4458 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.5725 Batch Time: 2.4644
# 2024-06-25 17:07:43,906 - INFO - VAL Epoch: 7 Step: 1/5 Loss: 0.4114 Accuracy: 0.8583 AUC: 0.0000 Data Time: 1.5322 Batch Time: 2.4264
# 2024-06-25 17:07:46,271 - INFO - VAL Epoch: 7 Step: 2/5 Loss: 0.4043 Accuracy: 0.8556 AUC: 0.0000 Data Time: 1.5136 Batch Time: 2.4057
# 2024-06-25 17:07:48,833 - INFO - VAL Epoch: 7 Step: 3/5 Loss: 0.4243 Accuracy: 0.8375 AUC: 0.0000 Data Time: 1.4897 Batch Time: 2.4444
# 2024-06-25 17:07:49,942 - INFO - VAL Epoch: 7 Step: 4/5 Loss: 0.4407 Accuracy: 0.8247 AUC: 0.0000 Data Time: 1.3022 Batch Time: 2.1774
# 2024-06-25 17:07:49,945 - INFO - AUC Score: 0.7392
# 2024-06-25 17:07:49,946 - INFO - New best model at epoch: 8
# 2024-06-25 17:07:50,164 - INFO - Starting Epoch: 9
# 2024-06-25 17:07:52,611 - INFO - TRAIN Epoch: 8 Step: 0/18 Loss: 0.4079 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.5498 Batch Time: 2.4450
# 2024-06-25 17:07:54,936 - INFO - TRAIN Epoch: 8 Step: 1/18 Loss: 0.4131 Accuracy: 0.8292 AUC: 0.0000 Data Time: 1.4904 Batch Time: 2.3848
# 2024-06-25 17:07:57,183 - INFO - TRAIN Epoch: 8 Step: 2/18 Loss: 0.4139 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.4465 Batch Time: 2.3384
# 2024-06-25 17:07:59,895 - INFO - TRAIN Epoch: 8 Step: 3/18 Loss: 0.3958 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.4465 Batch Time: 2.4317
# 2024-06-25 17:08:02,596 - INFO - TRAIN Epoch: 8 Step: 4/18 Loss: 0.4236 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.4522 Batch Time: 2.4854
# 2024-06-25 17:08:04,936 - INFO - TRAIN Epoch: 8 Step: 5/18 Loss: 0.4286 Accuracy: 0.8097 AUC: 0.0000 Data Time: 1.4508 Batch Time: 2.4611
# 2024-06-25 17:08:07,737 - INFO - TRAIN Epoch: 8 Step: 6/18 Loss: 0.4301 Accuracy: 0.8119 AUC: 0.0000 Data Time: 1.4448 Batch Time: 2.5095
# 2024-06-25 17:08:10,042 - INFO - TRAIN Epoch: 8 Step: 7/18 Loss: 0.4255 Accuracy: 0.8104 AUC: 0.0000 Data Time: 1.4411 Batch Time: 2.4838
# 2024-06-25 17:08:13,136 - INFO - TRAIN Epoch: 8 Step: 8/18 Loss: 0.4187 Accuracy: 0.8130 AUC: 0.0000 Data Time: 1.4426 Batch Time: 2.5516
# 2024-06-25 17:08:15,474 - INFO - TRAIN Epoch: 8 Step: 9/18 Loss: 0.4181 Accuracy: 0.8117 AUC: 0.0000 Data Time: 1.4425 Batch Time: 2.5301
# 2024-06-25 17:08:18,920 - INFO - TRAIN Epoch: 8 Step: 10/18 Loss: 0.4206 Accuracy: 0.8114 AUC: 0.0000 Data Time: 1.4566 Batch Time: 2.6133
# 2024-06-25 17:08:23,219 - INFO - TRAIN Epoch: 8 Step: 11/18 Loss: 0.4203 Accuracy: 0.8118 AUC: 0.0000 Data Time: 1.5255 Batch Time: 2.7537
# 2024-06-25 17:08:27,499 - INFO - TRAIN Epoch: 8 Step: 12/18 Loss: 0.4183 Accuracy: 0.8154 AUC: 0.0000 Data Time: 1.5939 Batch Time: 2.8710
# 2024-06-25 17:08:30,959 - INFO - TRAIN Epoch: 8 Step: 13/18 Loss: 0.4203 Accuracy: 0.8149 AUC: 0.0000 Data Time: 1.6215 Batch Time: 2.9129
# 2024-06-25 17:08:34,106 - INFO - TRAIN Epoch: 8 Step: 14/18 Loss: 0.4173 Accuracy: 0.8183 AUC: 0.0000 Data Time: 1.6496 Batch Time: 2.9284
# 2024-06-25 17:08:37,426 - INFO - TRAIN Epoch: 8 Step: 15/18 Loss: 0.4153 Accuracy: 0.8198 AUC: 0.0000 Data Time: 1.6844 Batch Time: 2.9528
# 2024-06-25 17:08:41,672 - INFO - TRAIN Epoch: 8 Step: 16/18 Loss: 0.4170 Accuracy: 0.8191 AUC: 0.0000 Data Time: 1.7414 Batch Time: 3.0288
# 2024-06-25 17:08:42,568 - INFO - TRAIN Epoch: 8 Step: 17/18 Loss: 0.4189 Accuracy: 0.8182 AUC: 0.0000 Data Time: 1.6786 Batch Time: 2.9102
# 2024-06-25 17:08:42,572 - INFO - AUC Score: 0.7744
# 2024-06-25 17:08:46,250 - INFO - VAL Epoch: 8 Step: 0/5 Loss: 0.4626 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.9159 Batch Time: 3.6768
# 2024-06-25 17:08:49,461 - INFO - VAL Epoch: 8 Step: 1/5 Loss: 0.4142 Accuracy: 0.8292 AUC: 0.0000 Data Time: 2.0063 Batch Time: 3.4427
# 2024-06-25 17:08:51,894 - INFO - VAL Epoch: 8 Step: 2/5 Loss: 0.4066 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.8510 Batch Time: 3.1059
# 2024-06-25 17:08:54,886 - INFO - VAL Epoch: 8 Step: 3/5 Loss: 0.4329 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.7328 Batch Time: 3.0774
# 2024-06-25 17:08:55,572 - INFO - VAL Epoch: 8 Step: 4/5 Loss: 0.4555 Accuracy: 0.8073 AUC: 0.0000 Data Time: 1.4630 Batch Time: 2.5988
# 2024-06-25 17:08:55,574 - INFO - AUC Score: 0.7263
# 2024-06-25 17:08:55,661 - INFO - Starting Epoch: 10
# 2024-06-25 17:08:58,372 - INFO - TRAIN Epoch: 9 Step: 0/18 Loss: 0.3725 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.1377 Batch Time: 2.7088
# 2024-06-25 17:09:00,900 - INFO - TRAIN Epoch: 9 Step: 1/18 Loss: 0.4530 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.3705 Batch Time: 2.6181
# 2024-06-25 17:09:03,605 - INFO - TRAIN Epoch: 9 Step: 2/18 Loss: 0.4232 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.4764 Batch Time: 2.6468
# 2024-06-25 17:09:07,482 - INFO - TRAIN Epoch: 9 Step: 3/18 Loss: 0.4178 Accuracy: 0.8146 AUC: 0.0000 Data Time: 1.6269 Batch Time: 2.9541
# 2024-06-25 17:09:10,176 - INFO - TRAIN Epoch: 9 Step: 4/18 Loss: 0.4057 Accuracy: 0.8217 AUC: 0.0000 Data Time: 1.6603 Batch Time: 2.9019
# 2024-06-25 17:09:13,481 - INFO - TRAIN Epoch: 9 Step: 5/18 Loss: 0.3944 Accuracy: 0.8319 AUC: 0.0000 Data Time: 1.7867 Batch Time: 2.9689
# 2024-06-25 17:09:16,857 - INFO - TRAIN Epoch: 9 Step: 6/18 Loss: 0.3924 Accuracy: 0.8298 AUC: 0.0000 Data Time: 1.8498 Batch Time: 3.0269
# 2024-06-25 17:09:20,388 - INFO - TRAIN Epoch: 9 Step: 7/18 Loss: 0.3886 Accuracy: 0.8354 AUC: 0.0000 Data Time: 1.9281 Batch Time: 3.0898
# 2024-06-25 17:09:23,572 - INFO - TRAIN Epoch: 9 Step: 8/18 Loss: 0.3895 Accuracy: 0.8380 AUC: 0.0000 Data Time: 1.9651 Batch Time: 3.1002
# 2024-06-25 17:09:26,983 - INFO - TRAIN Epoch: 9 Step: 9/18 Loss: 0.3927 Accuracy: 0.8358 AUC: 0.0000 Data Time: 2.0145 Batch Time: 3.1311
# 2024-06-25 17:09:30,604 - INFO - TRAIN Epoch: 9 Step: 10/18 Loss: 0.3965 Accuracy: 0.8318 AUC: 0.0000 Data Time: 1.9967 Batch Time: 3.1756
# 2024-06-25 17:09:34,826 - INFO - TRAIN Epoch: 9 Step: 11/18 Loss: 0.4006 Accuracy: 0.8292 AUC: 0.0000 Data Time: 2.0178 Batch Time: 3.2627
# 2024-06-25 17:09:38,937 - INFO - TRAIN Epoch: 9 Step: 12/18 Loss: 0.4058 Accuracy: 0.8295 AUC: 0.0000 Data Time: 2.0351 Batch Time: 3.3279
# 2024-06-25 17:09:41,912 - INFO - TRAIN Epoch: 9 Step: 13/18 Loss: 0.4059 Accuracy: 0.8268 AUC: 0.0000 Data Time: 2.0336 Batch Time: 3.3027
# 2024-06-25 17:09:45,309 - INFO - TRAIN Epoch: 9 Step: 14/18 Loss: 0.4051 Accuracy: 0.8283 AUC: 0.0000 Data Time: 2.0642 Batch Time: 3.3088
# 2024-06-25 17:09:48,341 - INFO - TRAIN Epoch: 9 Step: 15/18 Loss: 0.4086 Accuracy: 0.8260 AUC: 0.0000 Data Time: 2.0675 Batch Time: 3.2913
# 2024-06-25 17:09:52,410 - INFO - TRAIN Epoch: 9 Step: 16/18 Loss: 0.4134 Accuracy: 0.8216 AUC: 0.0000 Data Time: 2.0671 Batch Time: 3.3370
# 2024-06-25 17:09:53,236 - INFO - TRAIN Epoch: 9 Step: 17/18 Loss: 0.4135 Accuracy: 0.8206 AUC: 0.0000 Data Time: 1.9832 Batch Time: 3.1975
# 2024-06-25 17:09:53,240 - INFO - AUC Score: 0.7826
# 2024-06-25 17:09:56,124 - INFO - VAL Epoch: 9 Step: 0/5 Loss: 0.4479 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.9925 Batch Time: 2.8824
# 2024-06-25 17:10:00,638 - INFO - VAL Epoch: 9 Step: 1/5 Loss: 0.4089 Accuracy: 0.8333 AUC: 0.0000 Data Time: 2.5340 Batch Time: 3.6973
# 2024-06-25 17:10:03,745 - INFO - VAL Epoch: 9 Step: 2/5 Loss: 0.4048 Accuracy: 0.8306 AUC: 0.0000 Data Time: 2.4365 Batch Time: 3.5003
# 2024-06-25 17:10:06,894 - INFO - VAL Epoch: 9 Step: 3/5 Loss: 0.4234 Accuracy: 0.8229 AUC: 0.0000 Data Time: 2.3899 Batch Time: 3.4122
# 2024-06-25 17:10:08,022 - INFO - VAL Epoch: 9 Step: 4/5 Loss: 0.4404 Accuracy: 0.8112 AUC: 0.0000 Data Time: 2.0749 Batch Time: 2.9552
# 2024-06-25 17:10:08,025 - INFO - AUC Score: 0.7429
# 2024-06-25 17:10:08,026 - INFO - New best model at epoch: 10
# 2024-06-25 17:10:08,193 - INFO - Starting Epoch: 11
# 2024-06-25 17:10:11,465 - INFO - TRAIN Epoch: 10 Step: 0/18 Loss: 0.3528 Accuracy: 0.8833 AUC: 0.0000 Data Time: 2.3444 Batch Time: 3.2705
# 2024-06-25 17:10:15,933 - INFO - TRAIN Epoch: 10 Step: 1/18 Loss: 0.3767 Accuracy: 0.8625 AUC: 0.0000 Data Time: 2.7880 Batch Time: 3.8688
# 2024-06-25 17:10:20,079 - INFO - TRAIN Epoch: 10 Step: 2/18 Loss: 0.3891 Accuracy: 0.8389 AUC: 0.0000 Data Time: 2.7761 Batch Time: 3.9609
# 2024-06-25 17:10:23,576 - INFO - TRAIN Epoch: 10 Step: 3/18 Loss: 0.4059 Accuracy: 0.8229 AUC: 0.0000 Data Time: 2.7377 Batch Time: 3.8448
# 2024-06-25 17:10:26,668 - INFO - TRAIN Epoch: 10 Step: 4/18 Loss: 0.4088 Accuracy: 0.8200 AUC: 0.0000 Data Time: 2.5730 Batch Time: 3.6941
# 2024-06-25 17:10:29,683 - INFO - TRAIN Epoch: 10 Step: 5/18 Loss: 0.4067 Accuracy: 0.8208 AUC: 0.0000 Data Time: 2.4735 Batch Time: 3.5808
# 2024-06-25 17:10:34,388 - INFO - TRAIN Epoch: 10 Step: 6/18 Loss: 0.4128 Accuracy: 0.8179 AUC: 0.0000 Data Time: 2.5636 Batch Time: 3.7413
# 2024-06-25 17:10:38,990 - INFO - TRAIN Epoch: 10 Step: 7/18 Loss: 0.4069 Accuracy: 0.8219 AUC: 0.0000 Data Time: 2.5996 Batch Time: 3.8483
# 2024-06-25 17:10:44,324 - INFO - TRAIN Epoch: 10 Step: 8/18 Loss: 0.4057 Accuracy: 0.8259 AUC: 0.0000 Data Time: 2.7391 Batch Time: 4.0131
# 2024-06-25 17:10:48,940 - INFO - TRAIN Epoch: 10 Step: 9/18 Loss: 0.4054 Accuracy: 0.8258 AUC: 0.0000 Data Time: 2.7452 Batch Time: 4.0729
# 2024-06-25 17:10:53,407 - INFO - TRAIN Epoch: 10 Step: 10/18 Loss: 0.4099 Accuracy: 0.8220 AUC: 0.0000 Data Time: 2.7199 Batch Time: 4.1086
# 2024-06-25 17:10:56,804 - INFO - TRAIN Epoch: 10 Step: 11/18 Loss: 0.4102 Accuracy: 0.8222 AUC: 0.0000 Data Time: 2.6378 Batch Time: 4.0492
# 2024-06-25 17:11:00,755 - INFO - TRAIN Epoch: 10 Step: 12/18 Loss: 0.4068 Accuracy: 0.8224 AUC: 0.0000 Data Time: 2.5996 Batch Time: 4.0414
# 2024-06-25 17:11:05,056 - INFO - TRAIN Epoch: 10 Step: 13/18 Loss: 0.4102 Accuracy: 0.8208 AUC: 0.0000 Data Time: 2.5839 Batch Time: 4.0598
# 2024-06-25 17:11:09,606 - INFO - TRAIN Epoch: 10 Step: 14/18 Loss: 0.4106 Accuracy: 0.8206 AUC: 0.0000 Data Time: 2.5869 Batch Time: 4.0923
# 2024-06-25 17:11:12,964 - INFO - TRAIN Epoch: 10 Step: 15/18 Loss: 0.4081 Accuracy: 0.8219 AUC: 0.0000 Data Time: 2.5355 Batch Time: 4.0463
# 2024-06-25 17:11:16,759 - INFO - TRAIN Epoch: 10 Step: 16/18 Loss: 0.4096 Accuracy: 0.8191 AUC: 0.0000 Data Time: 2.5121 Batch Time: 4.0314
# 2024-06-25 17:11:17,683 - INFO - TRAIN Epoch: 10 Step: 17/18 Loss: 0.4088 Accuracy: 0.8202 AUC: 0.0000 Data Time: 2.4087 Batch Time: 3.8586
# 2024-06-25 17:11:17,687 - INFO - AUC Score: 0.7921
# 2024-06-25 17:11:21,166 - INFO - VAL Epoch: 10 Step: 0/5 Loss: 0.4433 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.8451 Batch Time: 3.4772
# 2024-06-25 17:11:25,470 - INFO - VAL Epoch: 10 Step: 1/5 Loss: 0.3990 Accuracy: 0.8542 AUC: 0.0000 Data Time: 2.0841 Batch Time: 3.8882
# 2024-06-25 17:11:29,174 - INFO - VAL Epoch: 10 Step: 2/5 Loss: 0.3941 Accuracy: 0.8528 AUC: 0.0000 Data Time: 2.0198 Batch Time: 3.8262
# 2024-06-25 17:11:33,943 - INFO - VAL Epoch: 10 Step: 3/5 Loss: 0.4151 Accuracy: 0.8354 AUC: 0.0000 Data Time: 2.2482 Batch Time: 4.0613
# 2024-06-25 17:11:35,070 - INFO - VAL Epoch: 10 Step: 4/5 Loss: 0.4347 Accuracy: 0.8227 AUC: 0.0000 Data Time: 1.9617 Batch Time: 3.4738
# 2024-06-25 17:11:35,072 - INFO - AUC Score: 0.7414
# 2024-06-25 17:11:35,073 - INFO - New best model at epoch: 11
# 2024-06-25 17:11:35,241 - INFO - Starting Epoch: 12
# 2024-06-25 17:11:37,666 - INFO - TRAIN Epoch: 11 Step: 0/18 Loss: 0.4168 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.5613 Batch Time: 2.4233
# 2024-06-25 17:11:40,668 - INFO - TRAIN Epoch: 11 Step: 1/18 Loss: 0.3846 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.8510 Batch Time: 2.7122
# 2024-06-25 17:11:43,867 - INFO - TRAIN Epoch: 11 Step: 2/18 Loss: 0.3781 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.9731 Batch Time: 2.8738
# 2024-06-25 17:11:47,336 - INFO - TRAIN Epoch: 11 Step: 3/18 Loss: 0.3920 Accuracy: 0.8229 AUC: 0.0000 Data Time: 2.0767 Batch Time: 3.0220
# 2024-06-25 17:11:51,117 - INFO - TRAIN Epoch: 11 Step: 4/18 Loss: 0.4103 Accuracy: 0.8183 AUC: 0.0000 Data Time: 2.1121 Batch Time: 3.1733
# 2024-06-25 17:11:54,652 - INFO - TRAIN Epoch: 11 Step: 5/18 Loss: 0.4042 Accuracy: 0.8194 AUC: 0.0000 Data Time: 2.1968 Batch Time: 3.2324
# 2024-06-25 17:11:57,944 - INFO - TRAIN Epoch: 11 Step: 6/18 Loss: 0.3940 Accuracy: 0.8286 AUC: 0.0000 Data Time: 2.2173 Batch Time: 3.2403
# 2024-06-25 17:12:01,376 - INFO - TRAIN Epoch: 11 Step: 7/18 Loss: 0.4008 Accuracy: 0.8229 AUC: 0.0000 Data Time: 2.2595 Batch Time: 3.2637
# 2024-06-25 17:12:05,598 - INFO - TRAIN Epoch: 11 Step: 8/18 Loss: 0.4036 Accuracy: 0.8222 AUC: 0.0000 Data Time: 2.2542 Batch Time: 3.3693
# 2024-06-25 17:12:10,973 - INFO - TRAIN Epoch: 11 Step: 9/18 Loss: 0.4048 Accuracy: 0.8200 AUC: 0.0000 Data Time: 2.3607 Batch Time: 3.5696
# 2024-06-25 17:12:14,729 - INFO - TRAIN Epoch: 11 Step: 10/18 Loss: 0.4039 Accuracy: 0.8205 AUC: 0.0000 Data Time: 2.3921 Batch Time: 3.5864
# 2024-06-25 17:12:18,122 - INFO - TRAIN Epoch: 11 Step: 11/18 Loss: 0.4044 Accuracy: 0.8201 AUC: 0.0000 Data Time: 2.3821 Batch Time: 3.5700
# 2024-06-25 17:12:22,330 - INFO - TRAIN Epoch: 11 Step: 12/18 Loss: 0.4015 Accuracy: 0.8205 AUC: 0.0000 Data Time: 2.4192 Batch Time: 3.6186
# 2024-06-25 17:12:26,342 - INFO - TRAIN Epoch: 11 Step: 13/18 Loss: 0.3963 Accuracy: 0.8250 AUC: 0.0000 Data Time: 2.4100 Batch Time: 3.6465
# 2024-06-25 17:12:30,754 - INFO - TRAIN Epoch: 11 Step: 14/18 Loss: 0.3957 Accuracy: 0.8256 AUC: 0.0000 Data Time: 2.4172 Batch Time: 3.6974
# 2024-06-25 17:12:35,125 - INFO - TRAIN Epoch: 11 Step: 15/18 Loss: 0.3962 Accuracy: 0.8260 AUC: 0.0000 Data Time: 2.4818 Batch Time: 3.7393
# 2024-06-25 17:12:38,166 - INFO - TRAIN Epoch: 11 Step: 16/18 Loss: 0.4080 Accuracy: 0.8196 AUC: 0.0000 Data Time: 2.4606 Batch Time: 3.6981
# 2024-06-25 17:12:39,689 - INFO - TRAIN Epoch: 11 Step: 17/18 Loss: 0.4111 Accuracy: 0.8182 AUC: 0.0000 Data Time: 2.3743 Batch Time: 3.5772
# 2024-06-25 17:12:39,694 - INFO - AUC Score: 0.7875
# 2024-06-25 17:12:42,059 - INFO - VAL Epoch: 11 Step: 0/5 Loss: 0.4434 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.5001 Batch Time: 2.3626
# 2024-06-25 17:12:44,717 - INFO - VAL Epoch: 11 Step: 1/5 Loss: 0.3960 Accuracy: 0.8500 AUC: 0.0000 Data Time: 1.6364 Batch Time: 2.5097
# 2024-06-25 17:12:47,212 - INFO - VAL Epoch: 11 Step: 2/5 Loss: 0.3941 Accuracy: 0.8472 AUC: 0.0000 Data Time: 1.5386 Batch Time: 2.5041
# 2024-06-25 17:12:52,011 - INFO - VAL Epoch: 11 Step: 3/5 Loss: 0.4150 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.9677 Batch Time: 3.0771
# 2024-06-25 17:12:53,217 - INFO - VAL Epoch: 11 Step: 4/5 Loss: 0.4343 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.7462 Batch Time: 2.7024
# 2024-06-25 17:12:53,226 - INFO - AUC Score: 0.7426
# 2024-06-25 17:12:53,229 - INFO - New best model at epoch: 12
# 2024-06-25 17:12:53,570 - INFO - Starting Epoch: 13
# 2024-06-25 17:12:57,549 - INFO - TRAIN Epoch: 12 Step: 0/18 Loss: 0.4270 Accuracy: 0.8167 AUC: 0.0000 Data Time: 3.0785 Batch Time: 3.9771
# 2024-06-25 17:13:00,501 - INFO - TRAIN Epoch: 12 Step: 1/18 Loss: 0.4103 Accuracy: 0.8292 AUC: 0.0000 Data Time: 2.4648 Batch Time: 3.4630
# 2024-06-25 17:13:04,031 - INFO - TRAIN Epoch: 12 Step: 2/18 Loss: 0.4122 Accuracy: 0.8306 AUC: 0.0000 Data Time: 2.4634 Batch Time: 3.4843
# 2024-06-25 17:13:07,531 - INFO - TRAIN Epoch: 12 Step: 3/18 Loss: 0.4263 Accuracy: 0.8104 AUC: 0.0000 Data Time: 2.4808 Batch Time: 3.4870
# 2024-06-25 17:13:11,437 - INFO - TRAIN Epoch: 12 Step: 4/18 Loss: 0.4352 Accuracy: 0.8067 AUC: 0.0000 Data Time: 2.3960 Batch Time: 3.5686
# 2024-06-25 17:13:15,802 - INFO - TRAIN Epoch: 12 Step: 5/18 Loss: 0.4320 Accuracy: 0.8028 AUC: 0.0000 Data Time: 2.5236 Batch Time: 3.7007
# 2024-06-25 17:13:20,432 - INFO - TRAIN Epoch: 12 Step: 6/18 Loss: 0.4252 Accuracy: 0.8071 AUC: 0.0000 Data Time: 2.5605 Batch Time: 3.8331
# 2024-06-25 17:13:23,990 - INFO - TRAIN Epoch: 12 Step: 7/18 Loss: 0.4238 Accuracy: 0.8073 AUC: 0.0000 Data Time: 2.5476 Batch Time: 3.7986
# 2024-06-25 17:13:26,918 - INFO - TRAIN Epoch: 12 Step: 8/18 Loss: 0.4241 Accuracy: 0.8056 AUC: 0.0000 Data Time: 2.4855 Batch Time: 3.7018
# 2024-06-25 17:13:31,972 - INFO - TRAIN Epoch: 12 Step: 9/18 Loss: 0.4232 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.6431 Batch Time: 3.8369
# 2024-06-25 17:13:37,640 - INFO - TRAIN Epoch: 12 Step: 10/18 Loss: 0.4160 Accuracy: 0.8121 AUC: 0.0000 Data Time: 2.7660 Batch Time: 4.0032
# 2024-06-25 17:13:41,438 - INFO - TRAIN Epoch: 12 Step: 11/18 Loss: 0.4169 Accuracy: 0.8132 AUC: 0.0000 Data Time: 2.7384 Batch Time: 3.9855
# 2024-06-25 17:13:46,615 - INFO - TRAIN Epoch: 12 Step: 12/18 Loss: 0.4163 Accuracy: 0.8128 AUC: 0.0000 Data Time: 2.8340 Batch Time: 4.0769
# 2024-06-25 17:13:50,371 - INFO - TRAIN Epoch: 12 Step: 13/18 Loss: 0.4129 Accuracy: 0.8143 AUC: 0.0000 Data Time: 2.7686 Batch Time: 4.0538
# 2024-06-25 17:13:54,916 - INFO - TRAIN Epoch: 12 Step: 14/18 Loss: 0.4082 Accuracy: 0.8167 AUC: 0.0000 Data Time: 2.7721 Batch Time: 4.0860
# 2024-06-25 17:13:58,970 - INFO - TRAIN Epoch: 12 Step: 15/18 Loss: 0.4053 Accuracy: 0.8203 AUC: 0.0000 Data Time: 2.7354 Batch Time: 4.0839
# 2024-06-25 17:14:02,161 - INFO - TRAIN Epoch: 12 Step: 16/18 Loss: 0.4012 Accuracy: 0.8230 AUC: 0.0000 Data Time: 2.7102 Batch Time: 4.0313
# 2024-06-25 17:14:03,448 - INFO - TRAIN Epoch: 12 Step: 17/18 Loss: 0.4031 Accuracy: 0.8216 AUC: 0.0000 Data Time: 2.5972 Batch Time: 3.8787
# 2024-06-25 17:14:03,451 - INFO - AUC Score: 0.7984
# 2024-06-25 17:14:06,963 - INFO - VAL Epoch: 12 Step: 0/5 Loss: 0.4442 Accuracy: 0.8000 AUC: 0.0000 Data Time: 2.1467 Batch Time: 3.5102
# 2024-06-25 17:14:09,926 - INFO - VAL Epoch: 12 Step: 1/5 Loss: 0.3984 Accuracy: 0.8417 AUC: 0.0000 Data Time: 2.1006 Batch Time: 3.2362
# 2024-06-25 17:14:13,372 - INFO - VAL Epoch: 12 Step: 2/5 Loss: 0.3968 Accuracy: 0.8389 AUC: 0.0000 Data Time: 2.2340 Batch Time: 3.3039
# 2024-06-25 17:14:17,149 - INFO - VAL Epoch: 12 Step: 3/5 Loss: 0.4162 Accuracy: 0.8292 AUC: 0.0000 Data Time: 2.3942 Batch Time: 3.4194
# 2024-06-25 17:14:18,510 - INFO - VAL Epoch: 12 Step: 4/5 Loss: 0.4357 Accuracy: 0.8170 AUC: 0.0000 Data Time: 2.0526 Batch Time: 3.0074
# 2024-06-25 17:14:18,519 - INFO - AUC Score: 0.7406
# 2024-06-25 17:14:18,689 - INFO - Starting Epoch: 14
# 2024-06-25 17:14:22,075 - INFO - TRAIN Epoch: 13 Step: 0/18 Loss: 0.4039 Accuracy: 0.8583 AUC: 0.0000 Data Time: 2.2577 Batch Time: 3.3834
# 2024-06-25 17:14:25,295 - INFO - TRAIN Epoch: 13 Step: 1/18 Loss: 0.3515 Accuracy: 0.8792 AUC: 0.0000 Data Time: 2.2835 Batch Time: 3.3005
# 2024-06-25 17:14:28,316 - INFO - TRAIN Epoch: 13 Step: 2/18 Loss: 0.3563 Accuracy: 0.8611 AUC: 0.0000 Data Time: 2.2276 Batch Time: 3.2069
# 2024-06-25 17:14:31,669 - INFO - TRAIN Epoch: 13 Step: 3/18 Loss: 0.3857 Accuracy: 0.8396 AUC: 0.0000 Data Time: 2.2722 Batch Time: 3.2427
# 2024-06-25 17:14:35,172 - INFO - TRAIN Epoch: 13 Step: 4/18 Loss: 0.3845 Accuracy: 0.8400 AUC: 0.0000 Data Time: 2.2755 Batch Time: 3.2938
# 2024-06-25 17:14:39,151 - INFO - TRAIN Epoch: 13 Step: 5/18 Loss: 0.3913 Accuracy: 0.8292 AUC: 0.0000 Data Time: 2.2415 Batch Time: 3.4075
# 2024-06-25 17:14:42,006 - INFO - TRAIN Epoch: 13 Step: 6/18 Loss: 0.3863 Accuracy: 0.8369 AUC: 0.0000 Data Time: 2.1977 Batch Time: 3.3281
# 2024-06-25 17:14:44,818 - INFO - TRAIN Epoch: 13 Step: 7/18 Loss: 0.3929 Accuracy: 0.8313 AUC: 0.0000 Data Time: 2.1607 Batch Time: 3.2633
# 2024-06-25 17:14:47,888 - INFO - TRAIN Epoch: 13 Step: 8/18 Loss: 0.3894 Accuracy: 0.8315 AUC: 0.0000 Data Time: 2.1501 Batch Time: 3.2416
# 2024-06-25 17:14:52,094 - INFO - TRAIN Epoch: 13 Step: 9/18 Loss: 0.3893 Accuracy: 0.8325 AUC: 0.0000 Data Time: 2.1690 Batch Time: 3.3376
# 2024-06-25 17:14:56,068 - INFO - TRAIN Epoch: 13 Step: 10/18 Loss: 0.3885 Accuracy: 0.8356 AUC: 0.0000 Data Time: 2.2105 Batch Time: 3.3952
# 2024-06-25 17:15:00,269 - INFO - TRAIN Epoch: 13 Step: 11/18 Loss: 0.3840 Accuracy: 0.8382 AUC: 0.0000 Data Time: 2.2411 Batch Time: 3.4621
# 2024-06-25 17:15:05,010 - INFO - TRAIN Epoch: 13 Step: 12/18 Loss: 0.3916 Accuracy: 0.8308 AUC: 0.0000 Data Time: 2.2799 Batch Time: 3.5604
# 2024-06-25 17:15:07,429 - INFO - TRAIN Epoch: 13 Step: 13/18 Loss: 0.3892 Accuracy: 0.8315 AUC: 0.0000 Data Time: 2.2262 Batch Time: 3.4788
# 2024-06-25 17:15:10,244 - INFO - TRAIN Epoch: 13 Step: 14/18 Loss: 0.3948 Accuracy: 0.8278 AUC: 0.0000 Data Time: 2.1880 Batch Time: 3.4344
# 2024-06-25 17:15:13,332 - INFO - TRAIN Epoch: 13 Step: 15/18 Loss: 0.3980 Accuracy: 0.8255 AUC: 0.0000 Data Time: 2.1532 Batch Time: 3.4125
# 2024-06-25 17:15:15,939 - INFO - TRAIN Epoch: 13 Step: 16/18 Loss: 0.3944 Accuracy: 0.8279 AUC: 0.0000 Data Time: 2.1204 Batch Time: 3.3650
# 2024-06-25 17:15:16,994 - INFO - TRAIN Epoch: 13 Step: 17/18 Loss: 0.3963 Accuracy: 0.8274 AUC: 0.0000 Data Time: 2.0453 Batch Time: 3.2361
# 2024-06-25 17:15:16,999 - INFO - AUC Score: 0.8073
# 2024-06-25 17:15:20,859 - INFO - VAL Epoch: 13 Step: 0/5 Loss: 0.4480 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.8933 Batch Time: 3.8559
# 2024-06-25 17:15:24,685 - INFO - VAL Epoch: 13 Step: 1/5 Loss: 0.3980 Accuracy: 0.8417 AUC: 0.0000 Data Time: 2.8958 Batch Time: 3.8390
# 2024-06-25 17:15:28,246 - INFO - VAL Epoch: 13 Step: 2/5 Loss: 0.3964 Accuracy: 0.8417 AUC: 0.0000 Data Time: 2.6414 Batch Time: 3.7447
# 2024-06-25 17:15:32,359 - INFO - VAL Epoch: 13 Step: 3/5 Loss: 0.4168 Accuracy: 0.8271 AUC: 0.0000 Data Time: 2.5040 Batch Time: 3.8364
# 2024-06-25 17:15:33,457 - INFO - VAL Epoch: 13 Step: 4/5 Loss: 0.4384 Accuracy: 0.8150 AUC: 0.0000 Data Time: 2.1567 Batch Time: 3.2883
# 2024-06-25 17:15:33,463 - INFO - AUC Score: 0.7396
# 2024-06-25 17:15:33,756 - INFO - Starting Epoch: 15
# 2024-06-25 17:15:37,363 - INFO - TRAIN Epoch: 14 Step: 0/18 Loss: 0.4834 Accuracy: 0.7833 AUC: 0.0000 Data Time: 2.5834 Batch Time: 3.6046
# 2024-06-25 17:15:42,056 - INFO - TRAIN Epoch: 14 Step: 1/18 Loss: 0.4237 Accuracy: 0.8167 AUC: 0.0000 Data Time: 2.9592 Batch Time: 4.1481
# 2024-06-25 17:15:47,368 - INFO - TRAIN Epoch: 14 Step: 2/18 Loss: 0.4182 Accuracy: 0.8139 AUC: 0.0000 Data Time: 3.1744 Batch Time: 4.5350
# ...
# 2024-06-25 18:50:11,348 - INFO - TRAIN Epoch: 95 Step: 5/18 Loss: 0.2400 Accuracy: 0.9028 AUC: 0.0000 Data Time: 1.4071 Batch Time: 2.2949
# 2024-06-25 18:50:13,939 - INFO - TRAIN Epoch: 95 Step: 6/18 Loss: 0.2398 Accuracy: 0.9024 AUC: 0.0000 Data Time: 1.4460 Batch Time: 2.3370
# 2024-06-25 18:50:16,304 - INFO - TRAIN Epoch: 95 Step: 7/18 Loss: 0.2406 Accuracy: 0.9010 AUC: 0.0000 Data Time: 1.4532 Batch Time: 2.3403
# 2024-06-25 18:50:17,900 - INFO - TRAIN Epoch: 95 Step: 8/18 Loss: 0.2374 Accuracy: 0.9028 AUC: 0.0000 Data Time: 1.3734 Batch Time: 2.2574
# 2024-06-25 18:50:19,456 - INFO - TRAIN Epoch: 95 Step: 9/18 Loss: 0.2351 Accuracy: 0.9050 AUC: 0.0000 Data Time: 1.3057 Batch Time: 2.1872
# 2024-06-25 18:50:21,176 - INFO - TRAIN Epoch: 95 Step: 10/18 Loss: 0.2463 Accuracy: 0.8970 AUC: 0.0000 Data Time: 1.2651 Batch Time: 2.1445
# 2024-06-25 18:50:22,778 - INFO - TRAIN Epoch: 95 Step: 11/18 Loss: 0.2451 Accuracy: 0.8951 AUC: 0.0000 Data Time: 1.2214 Batch Time: 2.0992
# 2024-06-25 18:50:24,389 - INFO - TRAIN Epoch: 95 Step: 12/18 Loss: 0.2478 Accuracy: 0.8917 AUC: 0.0000 Data Time: 1.1851 Batch Time: 2.0615
# 2024-06-25 18:50:26,063 - INFO - TRAIN Epoch: 95 Step: 13/18 Loss: 0.2492 Accuracy: 0.8929 AUC: 0.0000 Data Time: 1.1567 Batch Time: 2.0338
# 2024-06-25 18:50:27,669 - INFO - TRAIN Epoch: 95 Step: 14/18 Loss: 0.2538 Accuracy: 0.8917 AUC: 0.0000 Data Time: 1.1292 Batch Time: 2.0052
# 2024-06-25 18:50:29,273 - INFO - TRAIN Epoch: 95 Step: 15/18 Loss: 0.2537 Accuracy: 0.8927 AUC: 0.0000 Data Time: 1.1050 Batch Time: 1.9800
# 2024-06-25 18:50:30,901 - INFO - TRAIN Epoch: 95 Step: 16/18 Loss: 0.2521 Accuracy: 0.8941 AUC: 0.0000 Data Time: 1.0851 Batch Time: 1.9592
# 2024-06-25 18:50:31,372 - INFO - TRAIN Epoch: 95 Step: 17/18 Loss: 0.2514 Accuracy: 0.8949 AUC: 0.0000 Data Time: 1.0365 Batch Time: 1.8765
# 2024-06-25 18:50:31,377 - INFO - AUC Score: 0.9365
# 2024-06-25 18:50:33,032 - INFO - VAL Epoch: 95 Step: 0/5 Loss: 0.4930 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.7961 Batch Time: 1.6527
# 2024-06-25 18:50:34,622 - INFO - VAL Epoch: 95 Step: 1/5 Loss: 0.4456 Accuracy: 0.8417 AUC: 0.0000 Data Time: 0.7633 Batch Time: 1.6205
# 2024-06-25 18:50:36,235 - INFO - VAL Epoch: 95 Step: 2/5 Loss: 0.4728 Accuracy: 0.8472 AUC: 0.0000 Data Time: 0.7602 Batch Time: 1.6174
# 2024-06-25 18:50:37,879 - INFO - VAL Epoch: 95 Step: 3/5 Loss: 0.5223 Accuracy: 0.8250 AUC: 0.0000 Data Time: 0.7664 Batch Time: 1.6237
# 2024-06-25 18:50:38,458 - INFO - VAL Epoch: 95 Step: 4/5 Loss: 0.5498 Accuracy: 0.8150 AUC: 0.0000 Data Time: 0.6701 Batch Time: 1.4145
# 2024-06-25 18:50:38,462 - INFO - AUC Score: 0.7616
# 2024-06-25 18:50:38,559 - INFO - Starting Epoch: 97
# 2024-06-25 18:50:40,168 - INFO - TRAIN Epoch: 96 Step: 0/18 Loss: 0.2614 Accuracy: 0.8583 AUC: 0.0000 Data Time: 0.7473 Batch Time: 1.6070
# 2024-06-25 18:50:41,793 - INFO - TRAIN Epoch: 96 Step: 1/18 Loss: 0.2693 Accuracy: 0.8583 AUC: 0.0000 Data Time: 0.7556 Batch Time: 1.6151
# 2024-06-25 18:50:43,360 - INFO - TRAIN Epoch: 96 Step: 2/18 Loss: 0.2418 Accuracy: 0.8833 AUC: 0.0000 Data Time: 0.7380 Batch Time: 1.5987
# 2024-06-25 18:50:45,006 - INFO - TRAIN Epoch: 96 Step: 3/18 Loss: 0.2424 Accuracy: 0.8896 AUC: 0.0000 Data Time: 0.7498 Batch Time: 1.6101
# 2024-06-25 18:50:46,592 - INFO - TRAIN Epoch: 96 Step: 4/18 Loss: 0.2493 Accuracy: 0.8933 AUC: 0.0000 Data Time: 0.7449 Batch Time: 1.6051
# 2024-06-25 18:50:48,201 - INFO - TRAIN Epoch: 96 Step: 5/18 Loss: 0.2519 Accuracy: 0.9000 AUC: 0.0000 Data Time: 0.7455 Batch Time: 1.6055
# 2024-06-25 18:50:49,817 - INFO - TRAIN Epoch: 96 Step: 6/18 Loss: 0.2558 Accuracy: 0.8964 AUC: 0.0000 Data Time: 0.7468 Batch Time: 1.6067
# 2024-06-25 18:50:51,364 - INFO - TRAIN Epoch: 96 Step: 7/18 Loss: 0.2512 Accuracy: 0.9000 AUC: 0.0000 Data Time: 0.7392 Batch Time: 1.5992
# 2024-06-25 18:50:52,962 - INFO - TRAIN Epoch: 96 Step: 8/18 Loss: 0.2616 Accuracy: 0.8963 AUC: 0.0000 Data Time: 0.7389 Batch Time: 1.5988
# 2024-06-25 18:50:54,585 - INFO - TRAIN Epoch: 96 Step: 9/18 Loss: 0.2669 Accuracy: 0.8933 AUC: 0.0000 Data Time: 0.7413 Batch Time: 1.6012
# 2024-06-25 18:50:56,242 - INFO - TRAIN Epoch: 96 Step: 10/18 Loss: 0.2630 Accuracy: 0.8932 AUC: 0.0000 Data Time: 0.7463 Batch Time: 1.6061
# 2024-06-25 18:50:57,872 - INFO - TRAIN Epoch: 96 Step: 11/18 Loss: 0.2664 Accuracy: 0.8896 AUC: 0.0000 Data Time: 0.7481 Batch Time: 1.6079
# 2024-06-25 18:50:59,518 - INFO - TRAIN Epoch: 96 Step: 12/18 Loss: 0.2628 Accuracy: 0.8923 AUC: 0.0000 Data Time: 0.7510 Batch Time: 1.6108
# 2024-06-25 18:51:01,143 - INFO - TRAIN Epoch: 96 Step: 13/18 Loss: 0.2607 Accuracy: 0.8958 AUC: 0.0000 Data Time: 0.7519 Batch Time: 1.6117
# 2024-06-25 18:51:02,804 - INFO - TRAIN Epoch: 96 Step: 14/18 Loss: 0.2673 Accuracy: 0.8894 AUC: 0.0000 Data Time: 0.7551 Batch Time: 1.6149
# 2024-06-25 18:51:04,401 - INFO - TRAIN Epoch: 96 Step: 15/18 Loss: 0.2668 Accuracy: 0.8911 AUC: 0.0000 Data Time: 0.7539 Batch Time: 1.6137
# 2024-06-25 18:51:06,156 - INFO - TRAIN Epoch: 96 Step: 16/18 Loss: 0.2674 Accuracy: 0.8887 AUC: 0.0000 Data Time: 0.7622 Batch Time: 1.6219
# 2024-06-25 18:51:06,663 - INFO - TRAIN Epoch: 96 Step: 17/18 Loss: 0.2694 Accuracy: 0.8881 AUC: 0.0000 Data Time: 0.7335 Batch Time: 1.5599
# 2024-06-25 18:51:06,667 - INFO - AUC Score: 0.9206
# 2024-06-25 18:51:08,297 - INFO - VAL Epoch: 96 Step: 0/5 Loss: 0.3969 Accuracy: 0.8333 AUC: 0.0000 Data Time: 0.7703 Batch Time: 1.6278
# 2024-06-25 18:51:09,844 - INFO - VAL Epoch: 96 Step: 1/5 Loss: 0.3568 Accuracy: 0.8625 AUC: 0.0000 Data Time: 0.7289 Batch Time: 1.5864
# 2024-06-25 18:51:11,454 - INFO - VAL Epoch: 96 Step: 2/5 Loss: 0.3869 Accuracy: 0.8500 AUC: 0.0000 Data Time: 0.7362 Batch Time: 1.5937
# 2024-06-25 18:51:13,099 - INFO - VAL Epoch: 96 Step: 3/5 Loss: 0.4361 Accuracy: 0.8313 AUC: 0.0000 Data Time: 0.7490 Batch Time: 1.6064
# 2024-06-25 18:51:13,654 - INFO - VAL Epoch: 96 Step: 4/5 Loss: 0.4553 Accuracy: 0.8266 AUC: 0.0000 Data Time: 0.6512 Batch Time: 1.3958
# 2024-06-25 18:51:13,658 - INFO - AUC Score: 0.7786
# 2024-06-25 18:51:13,763 - INFO - Starting Epoch: 98
# 2024-06-25 18:51:15,403 - INFO - TRAIN Epoch: 97 Step: 0/18 Loss: 0.2344 Accuracy: 0.9000 AUC: 0.0000 Data Time: 0.7780 Batch Time: 1.6373
# 2024-06-25 18:51:16,967 - INFO - TRAIN Epoch: 97 Step: 1/18 Loss: 0.2573 Accuracy: 0.8917 AUC: 0.0000 Data Time: 0.7401 Batch Time: 1.5999
# 2024-06-25 18:51:18,572 - INFO - TRAIN Epoch: 97 Step: 2/18 Loss: 0.2705 Accuracy: 0.8806 AUC: 0.0000 Data Time: 0.7416 Batch Time: 1.6014
# 2024-06-25 18:51:20,235 - INFO - TRAIN Epoch: 97 Step: 3/18 Loss: 0.2690 Accuracy: 0.8854 AUC: 0.0000 Data Time: 0.7565 Batch Time: 1.6163
# 2024-06-25 18:51:21,864 - INFO - TRAIN Epoch: 97 Step: 4/18 Loss: 0.2692 Accuracy: 0.8867 AUC: 0.0000 Data Time: 0.7587 Batch Time: 1.6186
# 2024-06-25 18:51:23,446 - INFO - TRAIN Epoch: 97 Step: 5/18 Loss: 0.2552 Accuracy: 0.8958 AUC: 0.0000 Data Time: 0.7524 Batch Time: 1.6123
# 2024-06-25 18:51:25,036 - INFO - TRAIN Epoch: 97 Step: 6/18 Loss: 0.2440 Accuracy: 0.9000 AUC: 0.0000 Data Time: 0.7490 Batch Time: 1.6088
# 2024-06-25 18:51:26,652 - INFO - TRAIN Epoch: 97 Step: 7/18 Loss: 0.2407 Accuracy: 0.9010 AUC: 0.0000 Data Time: 0.7497 Batch Time: 1.6096
# 2024-06-25 18:51:28,304 - INFO - TRAIN Epoch: 97 Step: 8/18 Loss: 0.2437 Accuracy: 0.8991 AUC: 0.0000 Data Time: 0.7544 Batch Time: 1.6142
# 2024-06-25 18:51:29,938 - INFO - TRAIN Epoch: 97 Step: 9/18 Loss: 0.2492 Accuracy: 0.8958 AUC: 0.0000 Data Time: 0.7549 Batch Time: 1.6159
# 2024-06-25 18:51:31,622 - INFO - TRAIN Epoch: 97 Step: 10/18 Loss: 0.2452 Accuracy: 0.8985 AUC: 0.0000 Data Time: 0.7612 Batch Time: 1.6220
# 2024-06-25 18:51:33,159 - INFO - TRAIN Epoch: 97 Step: 11/18 Loss: 0.2493 Accuracy: 0.8951 AUC: 0.0000 Data Time: 0.7541 Batch Time: 1.6148
# 2024-06-25 18:51:34,763 - INFO - TRAIN Epoch: 97 Step: 12/18 Loss: 0.2524 Accuracy: 0.8936 AUC: 0.0000 Data Time: 0.7531 Batch Time: 1.6139
# 2024-06-25 18:51:36,418 - INFO - TRAIN Epoch: 97 Step: 13/18 Loss: 0.2492 Accuracy: 0.8958 AUC: 0.0000 Data Time: 0.7560 Batch Time: 1.6168
# 2024-06-25 18:51:38,054 - INFO - TRAIN Epoch: 97 Step: 14/18 Loss: 0.2576 Accuracy: 0.8894 AUC: 0.0000 Data Time: 0.7573 Batch Time: 1.6179
# 2024-06-25 18:51:39,629 - INFO - TRAIN Epoch: 97 Step: 15/18 Loss: 0.2561 Accuracy: 0.8880 AUC: 0.0000 Data Time: 0.7546 Batch Time: 1.6151
# 2024-06-25 18:51:41,272 - INFO - TRAIN Epoch: 97 Step: 16/18 Loss: 0.2507 Accuracy: 0.8902 AUC: 0.0000 Data Time: 0.7562 Batch Time: 1.6167
# 2024-06-25 18:51:41,804 - INFO - TRAIN Epoch: 97 Step: 17/18 Loss: 0.2512 Accuracy: 0.8901 AUC: 0.0000 Data Time: 0.7293 Batch Time: 1.5564
# 2024-06-25 18:51:41,808 - INFO - AUC Score: 0.9370
# 2024-06-25 18:51:43,451 - INFO - VAL Epoch: 97 Step: 0/5 Loss: 0.4213 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.7838 Batch Time: 1.6409
# 2024-06-25 18:51:45,104 - INFO - VAL Epoch: 97 Step: 1/5 Loss: 0.3729 Accuracy: 0.8375 AUC: 0.0000 Data Time: 0.7891 Batch Time: 1.6461
# 2024-06-25 18:51:46,821 - INFO - VAL Epoch: 97 Step: 2/5 Loss: 0.4131 Accuracy: 0.8111 AUC: 0.0000 Data Time: 0.8118 Batch Time: 1.6691
# 2024-06-25 18:51:48,463 - INFO - VAL Epoch: 97 Step: 3/5 Loss: 0.4591 Accuracy: 0.8000 AUC: 0.0000 Data Time: 0.8045 Batch Time: 1.6620
# 2024-06-25 18:51:49,047 - INFO - VAL Epoch: 97 Step: 4/5 Loss: 0.4713 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.7015 Batch Time: 1.4462
# 2024-06-25 18:51:49,051 - INFO - AUC Score: 0.7812
# 2024-06-25 18:51:49,152 - INFO - Starting Epoch: 99
# 2024-06-25 18:51:50,803 - INFO - TRAIN Epoch: 98 Step: 0/18 Loss: 0.2008 Accuracy: 0.9417 AUC: 0.0000 Data Time: 0.7906 Batch Time: 1.6499
# 2024-06-25 18:51:52,397 - INFO - TRAIN Epoch: 98 Step: 1/18 Loss: 0.2182 Accuracy: 0.9208 AUC: 0.0000 Data Time: 0.7622 Batch Time: 1.6212
# 2024-06-25 18:51:53,994 - INFO - TRAIN Epoch: 98 Step: 2/18 Loss: 0.2305 Accuracy: 0.9056 AUC: 0.0000 Data Time: 0.7535 Batch Time: 1.6125
# 2024-06-25 18:51:55,610 - INFO - TRAIN Epoch: 98 Step: 3/18 Loss: 0.2225 Accuracy: 0.9062 AUC: 0.0000 Data Time: 0.7539 Batch Time: 1.6131
# 2024-06-25 18:51:57,240 - INFO - TRAIN Epoch: 98 Step: 4/18 Loss: 0.2317 Accuracy: 0.9050 AUC: 0.0000 Data Time: 0.7569 Batch Time: 1.6162
# 2024-06-25 18:51:58,847 - INFO - TRAIN Epoch: 98 Step: 5/18 Loss: 0.2266 Accuracy: 0.9083 AUC: 0.0000 Data Time: 0.7542 Batch Time: 1.6143
# 2024-06-25 18:52:00,474 - INFO - TRAIN Epoch: 98 Step: 6/18 Loss: 0.2319 Accuracy: 0.9048 AUC: 0.0000 Data Time: 0.7559 Batch Time: 1.6160
# 2024-06-25 18:52:02,088 - INFO - TRAIN Epoch: 98 Step: 7/18 Loss: 0.2381 Accuracy: 0.9000 AUC: 0.0000 Data Time: 0.7555 Batch Time: 1.6156
# 2024-06-25 18:52:03,657 - INFO - TRAIN Epoch: 98 Step: 8/18 Loss: 0.2329 Accuracy: 0.9056 AUC: 0.0000 Data Time: 0.7501 Batch Time: 1.6102
# 2024-06-25 18:52:05,254 - INFO - TRAIN Epoch: 98 Step: 9/18 Loss: 0.2393 Accuracy: 0.9042 AUC: 0.0000 Data Time: 0.7488 Batch Time: 1.6088
# 2024-06-25 18:52:06,882 - INFO - TRAIN Epoch: 98 Step: 10/18 Loss: 0.2457 Accuracy: 0.9015 AUC: 0.0000 Data Time: 0.7504 Batch Time: 1.6104
# 2024-06-25 18:52:08,444 - INFO - TRAIN Epoch: 98 Step: 11/18 Loss: 0.2464 Accuracy: 0.9000 AUC: 0.0000 Data Time: 0.7462 Batch Time: 1.6062
# 2024-06-25 18:52:10,013 - INFO - TRAIN Epoch: 98 Step: 12/18 Loss: 0.2452 Accuracy: 0.9000 AUC: 0.0000 Data Time: 0.7433 Batch Time: 1.6033
# 2024-06-25 18:52:11,663 - INFO - TRAIN Epoch: 98 Step: 13/18 Loss: 0.2458 Accuracy: 0.8994 AUC: 0.0000 Data Time: 0.7466 Batch Time: 1.6065
# 2024-06-25 18:52:13,241 - INFO - TRAIN Epoch: 98 Step: 14/18 Loss: 0.2478 Accuracy: 0.8972 AUC: 0.0000 Data Time: 0.7447 Batch Time: 1.6045
# 2024-06-25 18:52:14,858 - INFO - TRAIN Epoch: 98 Step: 15/18 Loss: 0.2508 Accuracy: 0.8948 AUC: 0.0000 Data Time: 0.7453 Batch Time: 1.6052
# 2024-06-25 18:52:16,485 - INFO - TRAIN Epoch: 98 Step: 16/18 Loss: 0.2488 Accuracy: 0.8956 AUC: 0.0000 Data Time: 0.7466 Batch Time: 1.6064
# 2024-06-25 18:52:16,960 - INFO - TRAIN Epoch: 98 Step: 17/18 Loss: 0.2482 Accuracy: 0.8959 AUC: 0.0000 Data Time: 0.7169 Batch Time: 1.5435
# 2024-06-25 18:52:16,964 - INFO - AUC Score: 0.9381
# 2024-06-25 18:52:18,638 - INFO - VAL Epoch: 98 Step: 0/5 Loss: 0.4090 Accuracy: 0.8250 AUC: 0.0000 Data Time: 0.8145 Batch Time: 1.6718
# 2024-06-25 18:52:20,270 - INFO - VAL Epoch: 98 Step: 1/5 Loss: 0.3584 Accuracy: 0.8542 AUC: 0.0000 Data Time: 0.7935 Batch Time: 1.6509
# 2024-06-25 18:52:21,926 - INFO - VAL Epoch: 98 Step: 2/5 Loss: 0.3965 Accuracy: 0.8444 AUC: 0.0000 Data Time: 0.7947 Batch Time: 1.6522
# 2024-06-25 18:52:23,545 - INFO - VAL Epoch: 98 Step: 3/5 Loss: 0.4413 Accuracy: 0.8271 AUC: 0.0000 Data Time: 0.7858 Batch Time: 1.6435
# 2024-06-25 18:52:24,124 - INFO - VAL Epoch: 98 Step: 4/5 Loss: 0.4595 Accuracy: 0.8266 AUC: 0.0000 Data Time: 0.6855 Batch Time: 1.4303
# 2024-06-25 18:52:24,128 - INFO - AUC Score: 0.7715
# 2024-06-25 18:52:24,234 - INFO - Starting Epoch: 100
# 2024-06-25 18:52:25,813 - INFO - TRAIN Epoch: 99 Step: 0/18 Loss: 0.2317 Accuracy: 0.9167 AUC: 0.0000 Data Time: 0.7182 Batch Time: 1.5772
# 2024-06-25 18:52:27,453 - INFO - TRAIN Epoch: 99 Step: 1/18 Loss: 0.2424 Accuracy: 0.8875 AUC: 0.0000 Data Time: 0.7490 Batch Time: 1.6080
# 2024-06-25 18:52:29,070 - INFO - TRAIN Epoch: 99 Step: 2/18 Loss: 0.2376 Accuracy: 0.8972 AUC: 0.0000 Data Time: 0.7513 Batch Time: 1.6105
# 2024-06-25 18:52:30,705 - INFO - TRAIN Epoch: 99 Step: 3/18 Loss: 0.2309 Accuracy: 0.8958 AUC: 0.0000 Data Time: 0.7570 Batch Time: 1.6163
# 2024-06-25 18:52:32,297 - INFO - TRAIN Epoch: 99 Step: 4/18 Loss: 0.2373 Accuracy: 0.8883 AUC: 0.0000 Data Time: 0.7518 Batch Time: 1.6112
# 2024-06-25 18:52:33,918 - INFO - TRAIN Epoch: 99 Step: 5/18 Loss: 0.2351 Accuracy: 0.8917 AUC: 0.0000 Data Time: 0.7532 Batch Time: 1.6125
# 2024-06-25 18:52:35,552 - INFO - TRAIN Epoch: 99 Step: 6/18 Loss: 0.2375 Accuracy: 0.8964 AUC: 0.0000 Data Time: 0.7561 Batch Time: 1.6154
# 2024-06-25 18:52:37,137 - INFO - TRAIN Epoch: 99 Step: 7/18 Loss: 0.2356 Accuracy: 0.9010 AUC: 0.0000 Data Time: 0.7521 Batch Time: 1.6114
# 2024-06-25 18:52:38,804 - INFO - TRAIN Epoch: 99 Step: 8/18 Loss: 0.2416 Accuracy: 0.8972 AUC: 0.0000 Data Time: 0.7582 Batch Time: 1.6175
# 2024-06-25 18:52:40,428 - INFO - TRAIN Epoch: 99 Step: 9/18 Loss: 0.2477 Accuracy: 0.8950 AUC: 0.0000 Data Time: 0.7586 Batch Time: 1.6180
# 2024-06-25 18:52:41,995 - INFO - TRAIN Epoch: 99 Step: 10/18 Loss: 0.2484 Accuracy: 0.8962 AUC: 0.0000 Data Time: 0.7538 Batch Time: 1.6132
# 2024-06-25 18:52:43,603 - INFO - TRAIN Epoch: 99 Step: 11/18 Loss: 0.2500 Accuracy: 0.8951 AUC: 0.0000 Data Time: 0.7533 Batch Time: 1.6127
# 2024-06-25 18:52:45,277 - INFO - TRAIN Epoch: 99 Step: 12/18 Loss: 0.2548 Accuracy: 0.8936 AUC: 0.0000 Data Time: 0.7579 Batch Time: 1.6173
# 2024-06-25 18:52:46,875 - INFO - TRAIN Epoch: 99 Step: 13/18 Loss: 0.2567 Accuracy: 0.8940 AUC: 0.0000 Data Time: 0.7564 Batch Time: 1.6158
# 2024-06-25 18:52:48,432 - INFO - TRAIN Epoch: 99 Step: 14/18 Loss: 0.2554 Accuracy: 0.8944 AUC: 0.0000 Data Time: 0.7524 Batch Time: 1.6118
# 2024-06-25 18:52:50,060 - INFO - TRAIN Epoch: 99 Step: 15/18 Loss: 0.2558 Accuracy: 0.8953 AUC: 0.0000 Data Time: 0.7533 Batch Time: 1.6127
# 2024-06-25 18:52:51,637 - INFO - TRAIN Epoch: 99 Step: 16/18 Loss: 0.2526 Accuracy: 0.8966 AUC: 0.0000 Data Time: 0.7511 Batch Time: 1.6105
# 2024-06-25 18:52:52,155 - INFO - TRAIN Epoch: 99 Step: 17/18 Loss: 0.2519 Accuracy: 0.8963 AUC: 0.0000 Data Time: 0.7236 Batch Time: 1.5498
# 2024-06-25 18:52:52,159 - INFO - AUC Score: 0.9347
# 2024-06-25 18:52:53,731 - INFO - VAL Epoch: 99 Step: 0/5 Loss: 0.4257 Accuracy: 0.8250 AUC: 0.0000 Data Time: 0.7127 Batch Time: 1.5696
# 2024-06-25 18:52:55,338 - INFO - VAL Epoch: 99 Step: 1/5 Loss: 0.3866 Accuracy: 0.8542 AUC: 0.0000 Data Time: 0.7301 Batch Time: 1.5874
# 2024-06-25 18:52:56,995 - INFO - VAL Epoch: 99 Step: 2/5 Loss: 0.4159 Accuracy: 0.8472 AUC: 0.0000 Data Time: 0.7529 Batch Time: 1.6103
# 2024-06-25 18:52:58,598 - INFO - VAL Epoch: 99 Step: 3/5 Loss: 0.4627 Accuracy: 0.8250 AUC: 0.0000 Data Time: 0.7505 Batch Time: 1.6080
# 2024-06-25 18:52:59,177 - INFO - VAL Epoch: 99 Step: 4/5 Loss: 0.4854 Accuracy: 0.8189 AUC: 0.0000 Data Time: 0.6572 Batch Time: 1.4018
# 2024-06-25 18:52:59,180 - INFO - AUC Score: 0.7745

# %%
trainer.auc_scores
# Out:
# 0.77451343836886
