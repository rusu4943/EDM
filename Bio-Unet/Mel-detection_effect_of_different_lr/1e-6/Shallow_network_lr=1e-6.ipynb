# %%
import sys
sys.executable
# Out:
# '/home/rs37890/.conda/envs/UDA/bin/python'

# %%
import os
import re
import sys
import time
import copy
import h5py
import random
import logging
import argparse
import numpy as np
import pandas as pd
from PIL import Image

# %%
import torch
import torch.nn as nn

# %%
from torchvision import *
import torchvision.models

# %%
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # args

# %%
parser = argparse.ArgumentParser()

parser.add_argument('--report-freq', type=int, default=1, help='logging frequency')
parser.add_argument('--tune-mode', type=str, default='fine-tune', choices=['fine-tune', 'feature-extract'], help='tuning mode' )
parser.add_argument('--backbone', type=str, default='resnet50', choices=['resnet50', 'vgg19', 'inception_v3'], 
                    help='backbone architecture' )
parser.add_argument('--cls-type', type=str, default='single', choices=['single', 
                   'double', 'double-bn', 'double-dropout'], help='classifier architecture' )
parser.add_argument('--hidden-dim', type=int, default=512, help='hidden dimension of classifier' )
parser.add_argument('--record-root-dir', type=str, default='./record-data', help='record data root dir' )
parser.add_argument('--exp', type=str, default='default_exp', help='name of experiment' )
parser.add_argument('--batch-size', type=int, default=8, help='batch size' )
parser.add_argument('--num-workers', type=int, default=0, help='number of processes working on cpu.')
parser.add_argument('--num-classes', type=int, default=5, help='number of classes')
parser.add_argument('--num-epochs', type=int, default=20,  help='number of epochs.')
parser.add_argument( '--num-steps', type=int, default=-1, help='number of steps per epoch. '+ '-1 means use entire data' )
parser.add_argument('--learn-rate', type=float, default=1e-3, help='learning rate for gradient descent')
parser.add_argument('--weight-decay', type=float, default=1e-3, help='weight decay for optimization')
parser.add_argument('--resume', action='store_true', help='resume experiment <exp> from last checkpoint' )
parser.add_argument('--input-dir', type=str, default= r'../h5py/', help='data root dir' )
parser.add_argument('--save-name', type=str, default='model.pt', help='saved model name' )

args, unknown =  parser.parse_known_args()

# %%
# device
DEVICE = 'cuda:0' if torch.cuda.is_available() else 'cpu'
args.device = DEVICE
args.gpu_ids = [0]

# %%
args.num_epochs = 100
args.learn_rate = 1e-6
args.weight_decay = 1e-6 
args.batch_size = 120
args.num_classes = 1
args.seed = 1111

# %%
args.root = '/scratch/rs37890/CARC/Explainable-NN-model'
args.sub_root = '/Fold1_Bio-Unet-stage1'
args.checkpoint_root = '/F(CLR) + F(Res) + F(Seg)'
args.shallow_network_folder = '/Mel-detection_effect_of_different_lr/1e-6'

args.csv_h5_dir = args.root + '/Data'

args.record_dir = args.root  + args.sub_root + args.shallow_network_folder + '/record_dir'
args.save_name = 'Resnet50'

# %% [markdown]
# # dataset

# %%
def get_transform(split):
    
    img_size = ( 512, 512 )
    Normal_transform = transforms.Compose([ transforms.Resize( img_size ),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])],
                                         )

    return Normal_transform

# %%
class SkinDataset( torch.utils.data.Dataset ):

    def __init__( self, h5_file_path, transform, split, args):
        self.h5_file_path = h5_file_path
        self.h5_file = None
        self.transform = transform
        self.split = split
        self.img_id_to_h5idx = self.build_img_id_to_h5idx()
        self.num_imgs = self.get_num_imgs() 

        self.args = args

        self.ATTR_TO_INDEX = { 'globules': 0,
                               'milia_like_cyst': 1,
                               'negative_network': 2,
                               'pigment_network': 3,
                               'streaks': 4,
                             }

    def get_num_imgs( self ):
        with h5py.File( self.h5_file_path, 'r' ) as f:
            return len( f['image_ids'] )

    def build_img_id_to_h5idx( self ):
        with h5py.File( self.h5_file_path, 'r' ) as f:
            
            img_ids = f['image_ids']
            img_id_to_h5idx = { img_id : idx for idx, img_id in enumerate( img_ids ) }
            
            return img_id_to_h5idx

    def __len__( self ):
        return self.get_num_imgs()

    def __getitem__( self, idx ):
        # import pdb; pdb.set_trace()
        if not self.h5_file:
            self.h5_file = h5py.File( self.h5_file_path, 'r' )
            
        img_id = self.h5_file['image_ids'][idx]
        img = self.h5_file['images'][idx]
        img = img.transpose([1, 2, 0])

        assert img.shape == (512, 512, 3)

        img = Image.fromarray( np.uint8(img) )
        
        if self.split == 'unsup':
            img1 = self.transform( img )
            img2 = self.transform( img )
            return img_id, img1, img2
        
        else:
            masks = self.h5_file['masks'][idx]
            labels = self.h5_file['labels'][idx].astype(np.float64)
            img = self.transform( img )

            # labels[0] globus
            # labels[1] milia_like_cyst
            # labels[2] negative
            # labels[3] pigment
            # labels[4] streaks
            # labels[5] melanoma
            
            index = 5

            assert masks.shape == (5, 512, 512)
            assert np.expand_dims(labels[index], axis=0).shape == (1,)
            
            return img_id, img, np.expand_dims(labels[index], axis=0), masks

# %%
def get_dataloader( args ):
    
    dataloader = {}
    splits = [ 'train', 'val' ]
    
    for split in splits:
        
        h5_file_path = os.path.join( args.csv_h5_dir, f'{split}.h5' )
        transform = get_transform(split)

        bsz = args.batch_size
        
        dataset = SkinDataset( h5_file_path, transform, split, args)
        loader = torch.utils.data.DataLoader( dataset = dataset,
                                              batch_size = bsz,
                                              shuffle = True if split != 'val' else False,
                                              num_workers = args.num_workers,
                                              drop_last = False,
                                            )
        
        dataloader[ split ] = loader
        
    return dataloader

# %% [markdown]
# # Load model

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.base_model = torchvision.models.resnet50(pretrained=True)
        self.base_layers = list(self.base_model.children())
        
        self.layer0 = nn.Sequential(*self.base_layers[:3])
        self.layer1 = nn.Sequential(*self.base_layers[3:5]) # size=(N, 256, x.H/4, x.W/4)
        self.layer2 = self.base_layers[5]  # size=(N, 512, x.H/8, x.W/8)
        self.layer3 = self.base_layers[6]  # size=(N, 1024, x.H/16, x.W/16)
        self.layer4 = self.base_layers[7]  # size=(N, 2048, x.H/32, x.W/32)
        self.Avgpooling = nn.Sequential(self.base_layers[8])
        
        self.mlp = torch.nn.Sequential( torch.nn.Linear(2048,1), )# only one linear layer on top
        
    def forward(self, X):
        layer0 = self.layer0(X)  # layer0:  torch.Size([1, 64, 256, 256])
        layer1 = self.layer1(layer0) # layer1:  torch.Size([1, 256, 128, 128])
        layer2 = self.layer2(layer1) # layer2:  torch.Size([1, 512, 64, 64])
        layer3 = self.layer3(layer2) # layer3:  torch.Size([1, 1024, 32, 32])
        layer4 = self.layer4(layer3) # layer4:  torch.Size([1, 2048, 16, 16])
        out    = self.Avgpooling(layer4)
        
        out1 = torch.squeeze(out) 
        if X.size(0) == 1: # torch.Size([1, 2048, 1, 1]) => torch.Size([2048])
            out1 = torch.unsqueeze(out1, 0) # torch.Size([1, 2048])
        out = self.mlp(out1)
        return out1, out

# %% [markdown]
# # Streaks

# %%
net = Model()
streaks_net = torch.nn.DataParallel(net)
streaks_net = streaks_net.module.to( DEVICE )
# Out:
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/streaks"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
streaks_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
streaks_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/streaks/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(streaks_Model_path)
streaks_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Pigment

# %%
net = Model()
pigment_net = torch.nn.DataParallel(net)
pigment_net = pigment_net.to( DEVICE )
pigment_net = pigment_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/pigment"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
pigment_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
pigment_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/pigment/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(pigment_Model_path)
pigment_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Negative

# %%
net = Model()
negative_net = torch.nn.DataParallel(net)
negative_net = negative_net.to( DEVICE )
negative_net = negative_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/negative"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
negative_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
negative_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/negative/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(negative_Model_path)
negative_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Milia

# %%
net = Model()
milia_net = torch.nn.DataParallel(net)
milia_net = milia_net.to( DEVICE )
milia_net = milia_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/milia_like_cyst"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
milia_like_cyst_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
milia_like_cyst_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/milia_like_cyst/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(milia_like_cyst_Model_path)
milia_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Globules

# %%
net = Model()
globules_net = torch.nn.DataParallel(net)
globules_net = globules_net.to( DEVICE )
globules_net = globules_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/globules"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
globules_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
globules_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/globules/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(globules_Model_path)
globules_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # softmax

# %%
class LogisticRegression(torch.nn.Module): 
    def __init__(self, input_dim = 10240, output_dim = 1): 
        super(LogisticRegression, self).__init__() 
        #self.linear = torch.nn.Linear(input_dim, output_dim) 
        self.linear1 = torch.nn.Linear(input_dim, 2048) 
        self.linear2 = torch.nn.Linear(2048, 512) 
        self.linear3 = torch.nn.Linear(512, output_dim) 
        
    def forward(self, x): 
        #outputs = torch.sigmoid(self.linear(x)) 
        output1 = self.linear1(x)
        output2 = self.linear2(output1)
        output3 = self.linear3(output2)
        
        return nn.Sigmoid()(output3).type(torch.float64)

# %% [markdown]
# # Trainer

# %%
class AverageMeter:
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
class Trainer:
    def __init__(self, 
                 model, 
                 globules_net , milia_net, negative_net, pigment_net, streaks_net,
                 dataloader, 
                 args,
                ):
        
        self.model = model.to(args.device)
        self.dataloader = dataloader
        self.args = args
        self.best_loss = np.inf
        self.best_epoch = 0
        self.best_model = None
        self.current_epoch = 0

        self.globules_net = globules_net.to(args.device)
        self.milia_net = milia_net.to(args.device)
        self.negative_net = negative_net.to(args.device)
        self.pigment_net = pigment_net.to(args.device)
        self.streaks_net = streaks_net.to(args.device)


        self.globules_net.eval()
        self.milia_net.eval()
        self.negative_net.eval()
        self.pigment_net.eval()
        self.streaks_net.eval()
        

        self.criterion = nn.BCELoss()
        self.optimizer = torch.optim.Adam( params = self.model.parameters(),
                                           lr = self.args.learn_rate,
                                           weight_decay = self.args.weight_decay,
                                         )

        self.logger = self.setup_logger()
        self.setup_experiment()
        self.set_random_seeds()

    def setup_logger(self):
        log_file = 'log.txt'
        if os.path.exists(log_file):
            os.remove(log_file)  # Remove the existing log file if it exists
        
        logger = logging.getLogger('Trainer')
        logger.setLevel(logging.INFO)
    
        # File Handler for log files
        fh = logging.FileHandler(log_file)
        fh.setLevel(logging.INFO)
        file_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        fh.setFormatter(file_formatter)
        logger.addHandler(fh)
    
        # Stream Handler for console output
        ch = logging.StreamHandler()
        ch.setLevel(logging.INFO)
        console_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        ch.setFormatter(console_formatter)
        logger.addHandler(ch)
    
        return logger

    def setup_experiment(self):
        self.name = self.args.exp
        self.exp_dir = os.path.join(self.args.record_root_dir, self.name)
        self.logger.info(f'seed is: {self.args.seed}')
        self.logger.info(f'args: {self.args}')

    def set_random_seeds(self):
        seed = random.randint(0, 100000)
        torch.manual_seed(seed)
        random.seed(seed)
        np.random.seed(seed)
        self.args.seed = seed

    def get_accuracy(self, pred, labels):
        predicted_labels = (pred > 0.5).int()
        correct_predictions = (predicted_labels == labels).sum().item()
        total_predictions = labels.size(0)
        accuracy = correct_predictions / total_predictions
        return accuracy

    def concate_5120(self, imgs):
        # This function should include model evaluation calls
        # Assuming these models are attributes of the class
        with torch.no_grad():
            pred1, _ = self.globules_net(imgs)
            pred2, _ = self.negative_net(imgs)
            pred3, _ = self.milia_net(imgs)
            pred4, _ = self.pigment_net(imgs)
            pred5, _ = self.streaks_net(imgs)
            return torch.cat((pred1, pred2, pred3, pred4, pred5), 1)

    def train_or_val(self, mode='train'):
        
        assert mode in ['train', 'val'], "Mode must be 'train' or 'val'"
        dataloader = self.dataloader[mode]
        num_steps = len(dataloader)
        self.model.train() if mode == 'train' else self.model.eval()

        loss_meter = AverageMeter()
        acc_meter = AverageMeter()
        data_time_meter = AverageMeter()
        batch_time_meter = AverageMeter()
        all_preds = []
        all_labels = []

        start = time.time()
        for batch_id, (img_ids, imgs, labels, masks) in enumerate(dataloader):
            data_time = time.time() - start
            if batch_id >= num_steps: break

            imgs, labels = imgs.to(self.args.device), labels.to(self.args.device)
            
            if mode == 'train':
                self.optimizer.zero_grad()

            concate_input = self.concate_5120(imgs)
            pred = self.model(concate_input)

            
            loss = self.criterion(pred, labels)
            if mode == 'train':
                loss.backward()
                self.optimizer.step()

            loss_meter.update(loss.item(), len(imgs))
            acc = self.get_accuracy( pred.detach().cpu(), labels.cpu() )
            acc_meter.update(acc, len(imgs))
            batch_time = time.time() - start

            data_time_meter.update(data_time)
            batch_time_meter.update(batch_time)
            all_preds.append(pred.detach().cpu())
            all_labels.append(labels.cpu())

            # if (batch_id+1) % self.args.report_freq == 0:
            self.log_epoch_stats(mode.upper(), batch_id, num_steps, loss_meter.avg, acc_meter.avg, 0, data_time_meter.avg, batch_time_meter.avg)

            start = time.time()

        all_labels = torch.cat(all_labels, dim=0)
        all_preds = torch.cat(all_preds, dim=0)
        self.auc_scores = roc_auc_score( np.array(all_labels), np.array(all_preds), average=None)
        self.log_auc_scores(self.auc_scores)

        return loss_meter.avg, acc_meter.avg, self.auc_scores.mean()

    def log_epoch_stats(self, phase, batch_id, num_steps, avg_loss, avg_acc, mean_auc, avg_data_time, avg_batch_time):
        self.logger.info(f'{phase} Epoch: {self.current_epoch} Step: {batch_id}/{num_steps} Loss: {avg_loss:.4f} Accuracy: {avg_acc:.4f} AUC: {mean_auc:.4f} Data Time: {avg_data_time:.4f} Batch Time: {avg_batch_time:.4f}')

    def log_auc_scores(self, auc_scores):
        if isinstance(auc_scores, np.ndarray):
            for i, score in enumerate(auc_scores):
                self.logger.info(f'AUC Score {i}: {score:.4f}')
        else:
            self.logger.info(f'AUC Score: {auc_scores:.4f}')

    def save_model(self, save_path):
        torch.save(self.model.state_dict(), save_path)

    def train(self):
        for epoch in range(self.current_epoch, self.args.num_epochs):
            self.current_epoch = epoch
            self.logger.info(f'Starting Epoch: {epoch + 1}')
            train_loss, train_acc, train_auc = self.train_or_val('train')
            val_loss, val_acc, val_auc = self.train_or_val('val')

            if val_loss < self.best_loss:
                self.best_loss = val_loss
                self.best_model = copy.deepcopy(self.model)
                self.best_epoch = epoch + 1
                self.logger.info(f'New best model at epoch: {epoch + 1}')

                save_path = os.path.join( self.args.record_dir, self.args.save_name + '_best.pt')
                self.save_model(save_path)

            save_path = os.path.join( self.args.record_dir, self.args.save_name + '.pt')
            self.save_model(save_path)

# %%
dataloaders = get_dataloader( args )

# %%
trainer = Trainer(LogisticRegression(), 
                  globules_net , milia_net, negative_net, pigment_net, streaks_net,
                  dataloaders, 
                  args,
                 )
# Out:
# 2024-06-25 19:06:50,674 - INFO - seed is: 1111
# 2024-06-25 19:06:50,677 - INFO - args: Namespace(report_freq=1, tune_mode='fine-tune', backbone='resnet50', cls_type='single', hidden_dim=512, record_root_dir='./record-data', exp='default_exp', batch_size=120, num_workers=0, num_classes=1, num_epochs=100, num_steps=-1, learn_rate=1e-06, weight_decay=1e-06, resume=False, input_dir='../h5py/', save_name='Resnet50', device='cuda:0', gpu_ids=[0], seed=1111, root='/scratch/rs37890/CARC/Explainable-NN-model', sub_root='/Fold1_Bio-Unet-stage1', checkpoint_root='/F(CLR) + F(Res) + F(Seg)', shallow_network_folder='/Mel-detection_effect_of_different_lr/1e-6', csv_h5_dir='/scratch/rs37890/CARC/Explainable-NN-model/Data', record_dir='/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/Mel-detection_effect_of_different_lr/1e-6/record_dir')

# %%
trainer.train()
# Out:
# 2024-06-25 19:06:50,685 - INFO - Starting Epoch: 1
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1712608885084/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:84.)
#   return F.conv2d(input, weight, bias, self.stride,
# 2024-06-25 19:06:54,352 - INFO - TRAIN Epoch: 0 Step: 0/18 Loss: 0.7172 Accuracy: 0.2333 AUC: 0.0000 Data Time: 1.7792 Batch Time: 3.6651
# 2024-06-25 19:06:56,263 - INFO - TRAIN Epoch: 0 Step: 1/18 Loss: 0.7087 Accuracy: 0.3042 AUC: 0.0000 Data Time: 1.3422 Batch Time: 2.7869
# 2024-06-25 19:06:58,647 - INFO - TRAIN Epoch: 0 Step: 2/18 Loss: 0.7009 Accuracy: 0.4306 AUC: 0.0000 Data Time: 1.2373 Batch Time: 2.6523
# 2024-06-25 19:07:01,357 - INFO - TRAIN Epoch: 0 Step: 3/18 Loss: 0.6935 Accuracy: 0.5167 AUC: 0.0000 Data Time: 1.3651 Batch Time: 2.6658
# 2024-06-25 19:07:03,539 - INFO - TRAIN Epoch: 0 Step: 4/18 Loss: 0.6850 Accuracy: 0.5833 AUC: 0.0000 Data Time: 1.2981 Batch Time: 2.5688
# 2024-06-25 19:07:05,970 - INFO - TRAIN Epoch: 0 Step: 5/18 Loss: 0.6779 Accuracy: 0.6208 AUC: 0.0000 Data Time: 1.2550 Batch Time: 2.5456
# 2024-06-25 19:07:08,653 - INFO - TRAIN Epoch: 0 Step: 6/18 Loss: 0.6715 Accuracy: 0.6440 AUC: 0.0000 Data Time: 1.2236 Batch Time: 2.5651
# 2024-06-25 19:07:10,784 - INFO - TRAIN Epoch: 0 Step: 7/18 Loss: 0.6658 Accuracy: 0.6615 AUC: 0.0000 Data Time: 1.2001 Batch Time: 2.5107
# 2024-06-25 19:07:12,722 - INFO - TRAIN Epoch: 0 Step: 8/18 Loss: 0.6618 Accuracy: 0.6704 AUC: 0.0000 Data Time: 1.1814 Batch Time: 2.4469
# 2024-06-25 19:07:14,667 - INFO - TRAIN Epoch: 0 Step: 9/18 Loss: 0.6555 Accuracy: 0.6842 AUC: 0.0000 Data Time: 1.1658 Batch Time: 2.3966
# 2024-06-25 19:07:16,782 - INFO - TRAIN Epoch: 0 Step: 10/18 Loss: 0.6494 Accuracy: 0.6947 AUC: 0.0000 Data Time: 1.1534 Batch Time: 2.3708
# 2024-06-25 19:07:19,067 - INFO - TRAIN Epoch: 0 Step: 11/18 Loss: 0.6433 Accuracy: 0.7035 AUC: 0.0000 Data Time: 1.1431 Batch Time: 2.3635
# 2024-06-25 19:07:21,580 - INFO - TRAIN Epoch: 0 Step: 12/18 Loss: 0.6405 Accuracy: 0.7058 AUC: 0.0000 Data Time: 1.1350 Batch Time: 2.3750
# 2024-06-25 19:07:24,363 - INFO - TRAIN Epoch: 0 Step: 13/18 Loss: 0.6342 Accuracy: 0.7143 AUC: 0.0000 Data Time: 1.1275 Batch Time: 2.4040
# 2024-06-25 19:07:27,741 - INFO - TRAIN Epoch: 0 Step: 14/18 Loss: 0.6289 Accuracy: 0.7211 AUC: 0.0000 Data Time: 1.1340 Batch Time: 2.4689
# 2024-06-25 19:07:30,838 - INFO - TRAIN Epoch: 0 Step: 15/18 Loss: 0.6243 Accuracy: 0.7260 AUC: 0.0000 Data Time: 1.1323 Batch Time: 2.5080
# 2024-06-25 19:07:33,320 - INFO - TRAIN Epoch: 0 Step: 16/18 Loss: 0.6202 Accuracy: 0.7299 AUC: 0.0000 Data Time: 1.1264 Batch Time: 2.5064
# 2024-06-25 19:07:34,079 - INFO - TRAIN Epoch: 0 Step: 17/18 Loss: 0.6183 Accuracy: 0.7319 AUC: 0.0000 Data Time: 1.0803 Batch Time: 2.4092
# 2024-06-25 19:07:34,082 - INFO - AUC Score: 0.5122
# 2024-06-25 19:07:37,451 - INFO - VAL Epoch: 0 Step: 0/5 Loss: 0.5400 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.2983 Batch Time: 3.3669
# 2024-06-25 19:07:40,762 - INFO - VAL Epoch: 0 Step: 1/5 Loss: 0.5287 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.2420 Batch Time: 3.3386
# 2024-06-25 19:07:42,289 - INFO - VAL Epoch: 0 Step: 2/5 Loss: 0.5295 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.0388 Batch Time: 2.7340
# 2024-06-25 19:07:44,113 - INFO - VAL Epoch: 0 Step: 3/5 Loss: 0.5381 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.0098 Batch Time: 2.5063
# 2024-06-25 19:07:45,132 - INFO - VAL Epoch: 0 Step: 4/5 Loss: 0.5439 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.8598 Batch Time: 2.2086
# 2024-06-25 19:07:45,135 - INFO - AUC Score: 0.4815
# 2024-06-25 19:07:45,136 - INFO - New best model at epoch: 1
# 2024-06-25 19:07:45,298 - INFO - Starting Epoch: 2
# 2024-06-25 19:07:47,411 - INFO - TRAIN Epoch: 1 Step: 0/18 Loss: 0.5372 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.0391 Batch Time: 2.1110
# 2024-06-25 19:07:49,369 - INFO - TRAIN Epoch: 1 Step: 1/18 Loss: 0.5361 Accuracy: 0.7833 AUC: 0.0000 Data Time: 1.0346 Batch Time: 2.0336
# 2024-06-25 19:07:51,315 - INFO - TRAIN Epoch: 1 Step: 2/18 Loss: 0.5374 Accuracy: 0.7861 AUC: 0.0000 Data Time: 1.0323 Batch Time: 2.0039
# 2024-06-25 19:07:53,475 - INFO - TRAIN Epoch: 1 Step: 3/18 Loss: 0.5388 Accuracy: 0.7812 AUC: 0.0000 Data Time: 1.0311 Batch Time: 2.0425
# 2024-06-25 19:07:56,083 - INFO - TRAIN Epoch: 1 Step: 4/18 Loss: 0.5450 Accuracy: 0.7783 AUC: 0.0000 Data Time: 1.0305 Batch Time: 2.1554
# 2024-06-25 19:07:58,984 - INFO - TRAIN Epoch: 1 Step: 5/18 Loss: 0.5392 Accuracy: 0.7833 AUC: 0.0000 Data Time: 1.0450 Batch Time: 2.2794
# 2024-06-25 19:08:01,366 - INFO - TRAIN Epoch: 1 Step: 6/18 Loss: 0.5322 Accuracy: 0.7893 AUC: 0.0000 Data Time: 1.0433 Batch Time: 2.2939
# 2024-06-25 19:08:03,301 - INFO - TRAIN Epoch: 1 Step: 7/18 Loss: 0.5250 Accuracy: 0.7958 AUC: 0.0000 Data Time: 1.0412 Batch Time: 2.2488
# 2024-06-25 19:08:05,238 - INFO - TRAIN Epoch: 1 Step: 8/18 Loss: 0.5221 Accuracy: 0.7981 AUC: 0.0000 Data Time: 1.0391 Batch Time: 2.2141
# 2024-06-25 19:08:07,698 - INFO - TRAIN Epoch: 1 Step: 9/18 Loss: 0.5167 Accuracy: 0.8025 AUC: 0.0000 Data Time: 1.0383 Batch Time: 2.2385
# 2024-06-25 19:08:10,582 - INFO - TRAIN Epoch: 1 Step: 10/18 Loss: 0.5155 Accuracy: 0.8023 AUC: 0.0000 Data Time: 1.0386 Batch Time: 2.2971
# 2024-06-25 19:08:13,078 - INFO - TRAIN Epoch: 1 Step: 11/18 Loss: 0.5168 Accuracy: 0.8007 AUC: 0.0000 Data Time: 1.0380 Batch Time: 2.3135
# 2024-06-25 19:08:15,084 - INFO - TRAIN Epoch: 1 Step: 12/18 Loss: 0.5142 Accuracy: 0.8019 AUC: 0.0000 Data Time: 1.0376 Batch Time: 2.2897
# 2024-06-25 19:08:16,867 - INFO - TRAIN Epoch: 1 Step: 13/18 Loss: 0.5078 Accuracy: 0.8071 AUC: 0.0000 Data Time: 1.0241 Batch Time: 2.2535
# 2024-06-25 19:08:18,991 - INFO - TRAIN Epoch: 1 Step: 14/18 Loss: 0.5103 Accuracy: 0.8028 AUC: 0.0000 Data Time: 1.0257 Batch Time: 2.2447
# 2024-06-25 19:08:21,469 - INFO - TRAIN Epoch: 1 Step: 15/18 Loss: 0.5097 Accuracy: 0.8026 AUC: 0.0000 Data Time: 1.0266 Batch Time: 2.2592
# 2024-06-25 19:08:24,010 - INFO - TRAIN Epoch: 1 Step: 16/18 Loss: 0.5111 Accuracy: 0.8010 AUC: 0.0000 Data Time: 1.0033 Batch Time: 2.2757
# 2024-06-25 19:08:24,457 - INFO - TRAIN Epoch: 1 Step: 17/18 Loss: 0.5119 Accuracy: 0.7999 AUC: 0.0000 Data Time: 0.9573 Batch Time: 2.1741
# 2024-06-25 19:08:24,461 - INFO - AUC Score: 0.5550
# 2024-06-25 19:08:27,346 - INFO - VAL Epoch: 1 Step: 0/5 Loss: 0.5024 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.5968 Batch Time: 2.8844
# 2024-06-25 19:08:30,116 - INFO - VAL Epoch: 1 Step: 1/5 Loss: 0.4837 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.2920 Batch Time: 2.8262
# 2024-06-25 19:08:33,272 - INFO - VAL Epoch: 1 Step: 2/5 Loss: 0.4855 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.2051 Batch Time: 2.9356
# 2024-06-25 19:08:35,907 - INFO - VAL Epoch: 1 Step: 3/5 Loss: 0.5016 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.1603 Batch Time: 2.8600
# 2024-06-25 19:08:36,646 - INFO - VAL Epoch: 1 Step: 4/5 Loss: 0.5120 Accuracy: 0.7996 AUC: 0.0000 Data Time: 1.0073 Batch Time: 2.4357
# 2024-06-25 19:08:36,650 - INFO - AUC Score: 0.4800
# 2024-06-25 19:08:36,651 - INFO - New best model at epoch: 2
# 2024-06-25 19:08:36,840 - INFO - Starting Epoch: 3
# 2024-06-25 19:08:39,463 - INFO - TRAIN Epoch: 2 Step: 0/18 Loss: 0.4959 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.2238 Batch Time: 2.6220
# 2024-06-25 19:08:42,499 - INFO - TRAIN Epoch: 2 Step: 1/18 Loss: 0.5123 Accuracy: 0.7833 AUC: 0.0000 Data Time: 1.1325 Batch Time: 2.8273
# 2024-06-25 19:08:45,439 - INFO - TRAIN Epoch: 2 Step: 2/18 Loss: 0.4976 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.1012 Batch Time: 2.8647
# 2024-06-25 19:08:47,909 - INFO - TRAIN Epoch: 2 Step: 3/18 Loss: 0.4964 Accuracy: 0.7979 AUC: 0.0000 Data Time: 1.0860 Batch Time: 2.7656
# 2024-06-25 19:08:52,050 - INFO - TRAIN Epoch: 2 Step: 4/18 Loss: 0.4933 Accuracy: 0.8017 AUC: 0.0000 Data Time: 1.2345 Batch Time: 3.0403
# 2024-06-25 19:08:54,819 - INFO - TRAIN Epoch: 2 Step: 5/18 Loss: 0.4901 Accuracy: 0.8042 AUC: 0.0000 Data Time: 1.2009 Batch Time: 2.9949
# 2024-06-25 19:08:57,148 - INFO - TRAIN Epoch: 2 Step: 6/18 Loss: 0.4811 Accuracy: 0.8119 AUC: 0.0000 Data Time: 1.1772 Batch Time: 2.8996
# 2024-06-25 19:08:59,270 - INFO - TRAIN Epoch: 2 Step: 7/18 Loss: 0.4875 Accuracy: 0.8073 AUC: 0.0000 Data Time: 1.1585 Batch Time: 2.8021
# 2024-06-25 19:09:01,656 - INFO - TRAIN Epoch: 2 Step: 8/18 Loss: 0.4819 Accuracy: 0.8111 AUC: 0.0000 Data Time: 1.1441 Batch Time: 2.7557
# 2024-06-25 19:09:04,343 - INFO - TRAIN Epoch: 2 Step: 9/18 Loss: 0.4874 Accuracy: 0.8067 AUC: 0.0000 Data Time: 1.1297 Batch Time: 2.7487
# 2024-06-25 19:09:07,343 - INFO - TRAIN Epoch: 2 Step: 10/18 Loss: 0.4836 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.1208 Batch Time: 2.7714
# 2024-06-25 19:09:10,276 - INFO - TRAIN Epoch: 2 Step: 11/18 Loss: 0.4820 Accuracy: 0.8097 AUC: 0.0000 Data Time: 1.1136 Batch Time: 2.7848
# 2024-06-25 19:09:12,117 - INFO - TRAIN Epoch: 2 Step: 12/18 Loss: 0.4874 Accuracy: 0.8071 AUC: 0.0000 Data Time: 1.0772 Batch Time: 2.7122
# 2024-06-25 19:09:14,969 - INFO - TRAIN Epoch: 2 Step: 13/18 Loss: 0.4877 Accuracy: 0.8060 AUC: 0.0000 Data Time: 1.0704 Batch Time: 2.7220
# 2024-06-25 19:09:18,132 - INFO - TRAIN Epoch: 2 Step: 14/18 Loss: 0.4907 Accuracy: 0.8039 AUC: 0.0000 Data Time: 1.0675 Batch Time: 2.7513
# 2024-06-25 19:09:20,823 - INFO - TRAIN Epoch: 2 Step: 15/18 Loss: 0.4938 Accuracy: 0.8016 AUC: 0.0000 Data Time: 1.0656 Batch Time: 2.7475
# 2024-06-25 19:09:24,682 - INFO - TRAIN Epoch: 2 Step: 16/18 Loss: 0.4946 Accuracy: 0.8015 AUC: 0.0000 Data Time: 1.1285 Batch Time: 2.8127
# 2024-06-25 19:09:25,264 - INFO - TRAIN Epoch: 2 Step: 17/18 Loss: 0.4969 Accuracy: 0.7999 AUC: 0.0000 Data Time: 1.0825 Batch Time: 2.6887
# 2024-06-25 19:09:25,268 - INFO - AUC Score: 0.5678
# 2024-06-25 19:09:27,548 - INFO - VAL Epoch: 2 Step: 0/5 Loss: 0.5003 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.2050 Batch Time: 2.2786
# 2024-06-25 19:09:29,697 - INFO - VAL Epoch: 2 Step: 1/5 Loss: 0.4791 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.1146 Batch Time: 2.2127
# 2024-06-25 19:09:32,088 - INFO - VAL Epoch: 2 Step: 2/5 Loss: 0.4813 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.0879 Batch Time: 2.2718
# 2024-06-25 19:09:34,778 - INFO - VAL Epoch: 2 Step: 3/5 Loss: 0.5000 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.0733 Batch Time: 2.3760
# 2024-06-25 19:09:35,510 - INFO - VAL Epoch: 2 Step: 4/5 Loss: 0.5119 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.9416 Batch Time: 2.0468
# 2024-06-25 19:09:35,513 - INFO - AUC Score: 0.4877
# 2024-06-25 19:09:35,514 - INFO - New best model at epoch: 3
# 2024-06-25 19:09:35,705 - INFO - Starting Epoch: 4
# 2024-06-25 19:09:37,657 - INFO - TRAIN Epoch: 3 Step: 0/18 Loss: 0.5030 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.0361 Batch Time: 1.9498
# 2024-06-25 19:09:39,686 - INFO - TRAIN Epoch: 3 Step: 1/18 Loss: 0.5047 Accuracy: 0.7958 AUC: 0.0000 Data Time: 1.0369 Batch Time: 1.9889
# 2024-06-25 19:09:42,087 - INFO - TRAIN Epoch: 3 Step: 2/18 Loss: 0.5120 Accuracy: 0.7889 AUC: 0.0000 Data Time: 1.0343 Batch Time: 2.1256
# 2024-06-25 19:09:44,775 - INFO - TRAIN Epoch: 3 Step: 3/18 Loss: 0.5091 Accuracy: 0.7896 AUC: 0.0000 Data Time: 1.0330 Batch Time: 2.2661
# 2024-06-25 19:09:47,756 - INFO - TRAIN Epoch: 3 Step: 4/18 Loss: 0.5233 Accuracy: 0.7767 AUC: 0.0000 Data Time: 1.0361 Batch Time: 2.4088
# 2024-06-25 19:09:50,942 - INFO - TRAIN Epoch: 3 Step: 5/18 Loss: 0.5119 Accuracy: 0.7875 AUC: 0.0000 Data Time: 1.0363 Batch Time: 2.5380
# 2024-06-25 19:09:53,602 - INFO - TRAIN Epoch: 3 Step: 6/18 Loss: 0.5094 Accuracy: 0.7881 AUC: 0.0000 Data Time: 1.0350 Batch Time: 2.5553
# 2024-06-25 19:09:55,887 - INFO - TRAIN Epoch: 3 Step: 7/18 Loss: 0.5037 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.0346 Batch Time: 2.5213
# 2024-06-25 19:09:57,831 - INFO - TRAIN Epoch: 3 Step: 8/18 Loss: 0.4958 Accuracy: 0.7972 AUC: 0.0000 Data Time: 1.0334 Batch Time: 2.4570
# 2024-06-25 19:10:00,139 - INFO - TRAIN Epoch: 3 Step: 9/18 Loss: 0.4951 Accuracy: 0.7992 AUC: 0.0000 Data Time: 1.0332 Batch Time: 2.4419
# 2024-06-25 19:10:03,419 - INFO - TRAIN Epoch: 3 Step: 10/18 Loss: 0.4944 Accuracy: 0.8008 AUC: 0.0000 Data Time: 1.0660 Batch Time: 2.5180
# 2024-06-25 19:10:06,944 - INFO - TRAIN Epoch: 3 Step: 11/18 Loss: 0.4950 Accuracy: 0.7993 AUC: 0.0000 Data Time: 1.1190 Batch Time: 2.6017
# 2024-06-25 19:10:10,022 - INFO - TRAIN Epoch: 3 Step: 12/18 Loss: 0.4917 Accuracy: 0.8026 AUC: 0.0000 Data Time: 1.1537 Batch Time: 2.6382
# 2024-06-25 19:10:13,450 - INFO - TRAIN Epoch: 3 Step: 13/18 Loss: 0.4932 Accuracy: 0.8012 AUC: 0.0000 Data Time: 1.2199 Batch Time: 2.6945
# 2024-06-25 19:10:16,474 - INFO - TRAIN Epoch: 3 Step: 14/18 Loss: 0.4975 Accuracy: 0.7989 AUC: 0.0000 Data Time: 1.2811 Batch Time: 2.7163
# 2024-06-25 19:10:20,114 - INFO - TRAIN Epoch: 3 Step: 15/18 Loss: 0.4964 Accuracy: 0.7995 AUC: 0.0000 Data Time: 1.3201 Batch Time: 2.7739
# 2024-06-25 19:10:23,769 - INFO - TRAIN Epoch: 3 Step: 16/18 Loss: 0.4936 Accuracy: 0.8010 AUC: 0.0000 Data Time: 1.3362 Batch Time: 2.8257
# 2024-06-25 19:10:24,275 - INFO - TRAIN Epoch: 3 Step: 17/18 Loss: 0.4948 Accuracy: 0.7999 AUC: 0.0000 Data Time: 1.2756 Batch Time: 2.6967
# 2024-06-25 19:10:24,280 - INFO - AUC Score: 0.5809
# 2024-06-25 19:10:26,885 - INFO - VAL Epoch: 3 Step: 0/5 Loss: 0.4987 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8483 Batch Time: 2.6010
# 2024-06-25 19:10:30,034 - INFO - VAL Epoch: 3 Step: 1/5 Loss: 0.4778 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.9119 Batch Time: 2.8742
# 2024-06-25 19:10:32,753 - INFO - VAL Epoch: 3 Step: 2/5 Loss: 0.4796 Accuracy: 0.8222 AUC: 0.0000 Data Time: 0.9100 Batch Time: 2.8220
# 2024-06-25 19:10:35,171 - INFO - VAL Epoch: 3 Step: 3/5 Loss: 0.4978 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9171 Batch Time: 2.7206
# 2024-06-25 19:10:35,926 - INFO - VAL Epoch: 3 Step: 4/5 Loss: 0.5095 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.8048 Batch Time: 2.3270
# 2024-06-25 19:10:35,932 - INFO - AUC Score: 0.4996
# 2024-06-25 19:10:35,933 - INFO - New best model at epoch: 4
# 2024-06-25 19:10:36,126 - INFO - Starting Epoch: 5
# 2024-06-25 19:10:38,975 - INFO - TRAIN Epoch: 4 Step: 0/18 Loss: 0.4506 Accuracy: 0.8333 AUC: 0.0000 Data Time: 0.8706 Batch Time: 2.8467
# 2024-06-25 19:10:41,801 - INFO - TRAIN Epoch: 4 Step: 1/18 Loss: 0.4842 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8671 Batch Time: 2.8349
# 2024-06-25 19:10:44,626 - INFO - TRAIN Epoch: 4 Step: 2/18 Loss: 0.5104 Accuracy: 0.7889 AUC: 0.0000 Data Time: 0.8835 Batch Time: 2.8308
# 2024-06-25 19:10:47,477 - INFO - TRAIN Epoch: 4 Step: 3/18 Loss: 0.4875 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8781 Batch Time: 2.8355
# 2024-06-25 19:10:50,068 - INFO - TRAIN Epoch: 4 Step: 4/18 Loss: 0.5065 Accuracy: 0.7950 AUC: 0.0000 Data Time: 0.8736 Batch Time: 2.7861
# 2024-06-25 19:10:52,429 - INFO - TRAIN Epoch: 4 Step: 5/18 Loss: 0.5156 Accuracy: 0.7875 AUC: 0.0000 Data Time: 0.8839 Batch Time: 2.7150
# 2024-06-25 19:10:54,295 - INFO - TRAIN Epoch: 4 Step: 6/18 Loss: 0.5115 Accuracy: 0.7905 AUC: 0.0000 Data Time: 0.8913 Batch Time: 2.5933
# 2024-06-25 19:10:57,064 - INFO - TRAIN Epoch: 4 Step: 7/18 Loss: 0.5041 Accuracy: 0.7958 AUC: 0.0000 Data Time: 0.9339 Batch Time: 2.6150
# 2024-06-25 19:11:00,304 - INFO - TRAIN Epoch: 4 Step: 8/18 Loss: 0.5067 Accuracy: 0.7917 AUC: 0.0000 Data Time: 0.9607 Batch Time: 2.6842
# 2024-06-25 19:11:02,141 - INFO - TRAIN Epoch: 4 Step: 9/18 Loss: 0.5043 Accuracy: 0.7942 AUC: 0.0000 Data Time: 0.9588 Batch Time: 2.5992
# 2024-06-25 19:11:04,202 - INFO - TRAIN Epoch: 4 Step: 10/18 Loss: 0.5111 Accuracy: 0.7879 AUC: 0.0000 Data Time: 0.9454 Batch Time: 2.5500
# 2024-06-25 19:11:06,762 - INFO - TRAIN Epoch: 4 Step: 11/18 Loss: 0.5047 Accuracy: 0.7917 AUC: 0.0000 Data Time: 0.9611 Batch Time: 2.5507
# 2024-06-25 19:11:09,544 - INFO - TRAIN Epoch: 4 Step: 12/18 Loss: 0.5020 Accuracy: 0.7923 AUC: 0.0000 Data Time: 0.9511 Batch Time: 2.5684
# 2024-06-25 19:11:12,356 - INFO - TRAIN Epoch: 4 Step: 13/18 Loss: 0.4960 Accuracy: 0.7964 AUC: 0.0000 Data Time: 0.9459 Batch Time: 2.5857
# 2024-06-25 19:11:14,228 - INFO - TRAIN Epoch: 4 Step: 14/18 Loss: 0.5005 Accuracy: 0.7939 AUC: 0.0000 Data Time: 0.9435 Batch Time: 2.5379
# 2024-06-25 19:11:15,872 - INFO - TRAIN Epoch: 4 Step: 15/18 Loss: 0.4960 Accuracy: 0.7974 AUC: 0.0000 Data Time: 0.9330 Batch Time: 2.4818
# 2024-06-25 19:11:18,261 - INFO - TRAIN Epoch: 4 Step: 16/18 Loss: 0.4931 Accuracy: 0.7995 AUC: 0.0000 Data Time: 0.9231 Batch Time: 2.4763
# 2024-06-25 19:11:18,858 - INFO - TRAIN Epoch: 4 Step: 17/18 Loss: 0.4930 Accuracy: 0.7999 AUC: 0.0000 Data Time: 0.8904 Batch Time: 2.3717
# 2024-06-25 19:11:18,863 - INFO - AUC Score: 0.5912
# 2024-06-25 19:11:21,034 - INFO - VAL Epoch: 4 Step: 0/5 Loss: 0.4974 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.7775 Batch Time: 2.1674
# 2024-06-25 19:11:23,381 - INFO - VAL Epoch: 4 Step: 1/5 Loss: 0.4766 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.7767 Batch Time: 2.2557
# 2024-06-25 19:11:26,324 - INFO - VAL Epoch: 4 Step: 2/5 Loss: 0.4782 Accuracy: 0.8222 AUC: 0.0000 Data Time: 0.7880 Batch Time: 2.4839
# 2024-06-25 19:11:29,524 - INFO - VAL Epoch: 4 Step: 3/5 Loss: 0.4959 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8891 Batch Time: 2.6624
# 2024-06-25 19:11:30,192 - INFO - VAL Epoch: 4 Step: 4/5 Loss: 0.5074 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.7863 Batch Time: 2.2632
# 2024-06-25 19:11:30,196 - INFO - AUC Score: 0.5127
# 2024-06-25 19:11:30,197 - INFO - New best model at epoch: 5
# 2024-06-25 19:11:30,408 - INFO - Starting Epoch: 6
# 2024-06-25 19:11:32,085 - INFO - TRAIN Epoch: 5 Step: 0/18 Loss: 0.5868 Accuracy: 0.7333 AUC: 0.0000 Data Time: 0.7882 Batch Time: 1.6750
# 2024-06-25 19:11:34,374 - INFO - TRAIN Epoch: 5 Step: 1/18 Loss: 0.5329 Accuracy: 0.7625 AUC: 0.0000 Data Time: 0.7661 Batch Time: 1.9814
# 2024-06-25 19:11:36,759 - INFO - TRAIN Epoch: 5 Step: 2/18 Loss: 0.5160 Accuracy: 0.7806 AUC: 0.0000 Data Time: 0.9127 Batch Time: 2.1147
# 2024-06-25 19:11:38,898 - INFO - TRAIN Epoch: 5 Step: 3/18 Loss: 0.4996 Accuracy: 0.7937 AUC: 0.0000 Data Time: 0.9645 Batch Time: 2.1200
# 2024-06-25 19:11:41,298 - INFO - TRAIN Epoch: 5 Step: 4/18 Loss: 0.4922 Accuracy: 0.7983 AUC: 0.0000 Data Time: 1.0000 Batch Time: 2.1758
# 2024-06-25 19:11:43,864 - INFO - TRAIN Epoch: 5 Step: 5/18 Loss: 0.4920 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.0262 Batch Time: 2.2405
# 2024-06-25 19:11:46,087 - INFO - TRAIN Epoch: 5 Step: 6/18 Loss: 0.4870 Accuracy: 0.8024 AUC: 0.0000 Data Time: 1.0368 Batch Time: 2.2375
# 2024-06-25 19:11:48,680 - INFO - TRAIN Epoch: 5 Step: 7/18 Loss: 0.4841 Accuracy: 0.8042 AUC: 0.0000 Data Time: 1.0160 Batch Time: 2.2817
# 2024-06-25 19:11:51,587 - INFO - TRAIN Epoch: 5 Step: 8/18 Loss: 0.5003 Accuracy: 0.7917 AUC: 0.0000 Data Time: 1.0000 Batch Time: 2.3511
# 2024-06-25 19:11:54,585 - INFO - TRAIN Epoch: 5 Step: 9/18 Loss: 0.5009 Accuracy: 0.7925 AUC: 0.0000 Data Time: 0.9879 Batch Time: 2.4155
# 2024-06-25 19:11:57,189 - INFO - TRAIN Epoch: 5 Step: 10/18 Loss: 0.4951 Accuracy: 0.7977 AUC: 0.0000 Data Time: 0.9744 Batch Time: 2.4323
# 2024-06-25 19:11:59,828 - INFO - TRAIN Epoch: 5 Step: 11/18 Loss: 0.5003 Accuracy: 0.7931 AUC: 0.0000 Data Time: 0.9898 Batch Time: 2.4494
# 2024-06-25 19:12:02,791 - INFO - TRAIN Epoch: 5 Step: 12/18 Loss: 0.5047 Accuracy: 0.7897 AUC: 0.0000 Data Time: 1.0208 Batch Time: 2.4887
# 2024-06-25 19:12:06,051 - INFO - TRAIN Epoch: 5 Step: 13/18 Loss: 0.5041 Accuracy: 0.7905 AUC: 0.0000 Data Time: 1.0311 Batch Time: 2.5436
# 2024-06-25 19:12:08,839 - INFO - TRAIN Epoch: 5 Step: 14/18 Loss: 0.5003 Accuracy: 0.7933 AUC: 0.0000 Data Time: 1.0399 Batch Time: 2.5597
# 2024-06-25 19:12:12,166 - INFO - TRAIN Epoch: 5 Step: 15/18 Loss: 0.4964 Accuracy: 0.7958 AUC: 0.0000 Data Time: 1.0551 Batch Time: 2.6076
# 2024-06-25 19:12:15,516 - INFO - TRAIN Epoch: 5 Step: 16/18 Loss: 0.4912 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.0694 Batch Time: 2.6511
# 2024-06-25 19:12:16,114 - INFO - TRAIN Epoch: 5 Step: 17/18 Loss: 0.4910 Accuracy: 0.7999 AUC: 0.0000 Data Time: 1.0287 Batch Time: 2.5370
# 2024-06-25 19:12:16,121 - INFO - AUC Score: 0.6025
# 2024-06-25 19:12:18,722 - INFO - VAL Epoch: 5 Step: 0/5 Loss: 0.4955 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9065 Batch Time: 2.5995
# 2024-06-25 19:12:21,331 - INFO - VAL Epoch: 5 Step: 1/5 Loss: 0.4746 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.8973 Batch Time: 2.6036
# 2024-06-25 19:12:23,982 - INFO - VAL Epoch: 5 Step: 2/5 Loss: 0.4760 Accuracy: 0.8222 AUC: 0.0000 Data Time: 0.8740 Batch Time: 2.6180
# 2024-06-25 19:12:26,622 - INFO - VAL Epoch: 5 Step: 3/5 Loss: 0.4939 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9532 Batch Time: 2.6230
# 2024-06-25 19:12:27,318 - INFO - VAL Epoch: 5 Step: 4/5 Loss: 0.5056 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.8430 Batch Time: 2.2371
# 2024-06-25 19:12:27,323 - INFO - AUC Score: 0.5235
# 2024-06-25 19:12:27,324 - INFO - New best model at epoch: 6
# 2024-06-25 19:12:27,526 - INFO - Starting Epoch: 7
# 2024-06-25 19:12:29,145 - INFO - TRAIN Epoch: 6 Step: 0/18 Loss: 0.5110 Accuracy: 0.7917 AUC: 0.0000 Data Time: 0.7518 Batch Time: 1.6165
# 2024-06-25 19:12:31,588 - INFO - TRAIN Epoch: 6 Step: 1/18 Loss: 0.4605 Accuracy: 0.8250 AUC: 0.0000 Data Time: 0.7763 Batch Time: 2.0288
# 2024-06-25 19:12:34,237 - INFO - TRAIN Epoch: 6 Step: 2/18 Loss: 0.4582 Accuracy: 0.8222 AUC: 0.0000 Data Time: 0.8231 Batch Time: 2.2349
# 2024-06-25 19:12:37,251 - INFO - TRAIN Epoch: 6 Step: 3/18 Loss: 0.4606 Accuracy: 0.8187 AUC: 0.0000 Data Time: 0.9386 Batch Time: 2.4292
# 2024-06-25 19:12:40,225 - INFO - TRAIN Epoch: 6 Step: 4/18 Loss: 0.4540 Accuracy: 0.8233 AUC: 0.0000 Data Time: 1.0069 Batch Time: 2.5377
# 2024-06-25 19:12:42,739 - INFO - TRAIN Epoch: 6 Step: 5/18 Loss: 0.4561 Accuracy: 0.8236 AUC: 0.0000 Data Time: 1.0301 Batch Time: 2.5333
# 2024-06-25 19:12:45,464 - INFO - TRAIN Epoch: 6 Step: 6/18 Loss: 0.4631 Accuracy: 0.8202 AUC: 0.0000 Data Time: 1.0633 Batch Time: 2.5602
# 2024-06-25 19:12:47,790 - INFO - TRAIN Epoch: 6 Step: 7/18 Loss: 0.4726 Accuracy: 0.8125 AUC: 0.0000 Data Time: 1.0717 Batch Time: 2.5306
# 2024-06-25 19:12:49,809 - INFO - TRAIN Epoch: 6 Step: 8/18 Loss: 0.4812 Accuracy: 0.8065 AUC: 0.0000 Data Time: 1.0727 Batch Time: 2.4736
# 2024-06-25 19:12:52,288 - INFO - TRAIN Epoch: 6 Step: 9/18 Loss: 0.4850 Accuracy: 0.8025 AUC: 0.0000 Data Time: 1.0823 Batch Time: 2.4739
# 2024-06-25 19:12:54,890 - INFO - TRAIN Epoch: 6 Step: 10/18 Loss: 0.4880 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.0924 Batch Time: 2.4853
# 2024-06-25 19:12:58,120 - INFO - TRAIN Epoch: 6 Step: 11/18 Loss: 0.4909 Accuracy: 0.7972 AUC: 0.0000 Data Time: 1.1031 Batch Time: 2.5472
# 2024-06-25 19:13:01,265 - INFO - TRAIN Epoch: 6 Step: 12/18 Loss: 0.4885 Accuracy: 0.8006 AUC: 0.0000 Data Time: 1.1077 Batch Time: 2.5931
# 2024-06-25 19:13:03,934 - INFO - TRAIN Epoch: 6 Step: 13/18 Loss: 0.4870 Accuracy: 0.8018 AUC: 0.0000 Data Time: 1.1094 Batch Time: 2.5984
# 2024-06-25 19:13:06,758 - INFO - TRAIN Epoch: 6 Step: 14/18 Loss: 0.4867 Accuracy: 0.8017 AUC: 0.0000 Data Time: 1.1129 Batch Time: 2.6132
# 2024-06-25 19:13:10,109 - INFO - TRAIN Epoch: 6 Step: 15/18 Loss: 0.4895 Accuracy: 0.7995 AUC: 0.0000 Data Time: 1.1212 Batch Time: 2.6593
# 2024-06-25 19:13:12,977 - INFO - TRAIN Epoch: 6 Step: 16/18 Loss: 0.4896 Accuracy: 0.7995 AUC: 0.0000 Data Time: 1.1249 Batch Time: 2.6714
# 2024-06-25 19:13:13,587 - INFO - TRAIN Epoch: 6 Step: 17/18 Loss: 0.4893 Accuracy: 0.7999 AUC: 0.0000 Data Time: 1.0818 Batch Time: 2.5567
# 2024-06-25 19:13:13,591 - INFO - AUC Score: 0.6110
# 2024-06-25 19:13:16,460 - INFO - VAL Epoch: 6 Step: 0/5 Loss: 0.4939 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.3108 Batch Time: 2.8671
# 2024-06-25 19:13:18,879 - INFO - VAL Epoch: 6 Step: 1/5 Loss: 0.4724 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.0734 Batch Time: 2.6417
# 2024-06-25 19:13:21,369 - INFO - VAL Epoch: 6 Step: 2/5 Loss: 0.4736 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.0072 Batch Time: 2.5901
# 2024-06-25 19:13:23,542 - INFO - VAL Epoch: 6 Step: 3/5 Loss: 0.4922 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9752 Batch Time: 2.4852
# 2024-06-25 19:13:24,441 - INFO - VAL Epoch: 6 Step: 4/5 Loss: 0.5042 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.8572 Batch Time: 2.1674
# 2024-06-25 19:13:24,447 - INFO - AUC Score: 0.5333
# 2024-06-25 19:13:24,449 - INFO - New best model at epoch: 7
# 2024-06-25 19:13:24,648 - INFO - Starting Epoch: 8
# 2024-06-25 19:13:27,574 - INFO - TRAIN Epoch: 7 Step: 0/18 Loss: 0.5836 Accuracy: 0.7250 AUC: 0.0000 Data Time: 0.8632 Batch Time: 2.9227
# 2024-06-25 19:13:30,487 - INFO - TRAIN Epoch: 7 Step: 1/18 Loss: 0.5634 Accuracy: 0.7500 AUC: 0.0000 Data Time: 0.8712 Batch Time: 2.9166
# 2024-06-25 19:13:33,749 - INFO - TRAIN Epoch: 7 Step: 2/18 Loss: 0.5095 Accuracy: 0.7917 AUC: 0.0000 Data Time: 0.9811 Batch Time: 3.0311
# 2024-06-25 19:13:36,353 - INFO - TRAIN Epoch: 7 Step: 3/18 Loss: 0.4957 Accuracy: 0.7979 AUC: 0.0000 Data Time: 0.9440 Batch Time: 2.9236
# 2024-06-25 19:13:39,014 - INFO - TRAIN Epoch: 7 Step: 4/18 Loss: 0.5016 Accuracy: 0.7933 AUC: 0.0000 Data Time: 0.9349 Batch Time: 2.8705
# 2024-06-25 19:13:41,362 - INFO - TRAIN Epoch: 7 Step: 5/18 Loss: 0.5025 Accuracy: 0.7917 AUC: 0.0000 Data Time: 0.9244 Batch Time: 2.7833
# 2024-06-25 19:13:43,248 - INFO - TRAIN Epoch: 7 Step: 6/18 Loss: 0.4877 Accuracy: 0.8024 AUC: 0.0000 Data Time: 0.9139 Batch Time: 2.6547
# 2024-06-25 19:13:44,971 - INFO - TRAIN Epoch: 7 Step: 7/18 Loss: 0.4827 Accuracy: 0.8052 AUC: 0.0000 Data Time: 0.9029 Batch Time: 2.5379
# 2024-06-25 19:13:47,121 - INFO - TRAIN Epoch: 7 Step: 8/18 Loss: 0.4888 Accuracy: 0.8019 AUC: 0.0000 Data Time: 0.8963 Batch Time: 2.4946
# 2024-06-25 19:13:49,800 - INFO - TRAIN Epoch: 7 Step: 9/18 Loss: 0.4839 Accuracy: 0.8033 AUC: 0.0000 Data Time: 0.8973 Batch Time: 2.5127
# 2024-06-25 19:13:52,777 - INFO - TRAIN Epoch: 7 Step: 10/18 Loss: 0.4807 Accuracy: 0.8061 AUC: 0.0000 Data Time: 0.9013 Batch Time: 2.5548
# 2024-06-25 19:13:55,018 - INFO - TRAIN Epoch: 7 Step: 11/18 Loss: 0.4874 Accuracy: 0.8021 AUC: 0.0000 Data Time: 0.9021 Batch Time: 2.5286
# 2024-06-25 19:13:56,720 - INFO - TRAIN Epoch: 7 Step: 12/18 Loss: 0.4844 Accuracy: 0.8032 AUC: 0.0000 Data Time: 0.8970 Batch Time: 2.4648
# 2024-06-25 19:13:58,414 - INFO - TRAIN Epoch: 7 Step: 13/18 Loss: 0.4869 Accuracy: 0.8012 AUC: 0.0000 Data Time: 0.8902 Batch Time: 2.4096
# 2024-06-25 19:14:00,928 - INFO - TRAIN Epoch: 7 Step: 14/18 Loss: 0.4879 Accuracy: 0.8000 AUC: 0.0000 Data Time: 0.8911 Batch Time: 2.4163
# 2024-06-25 19:14:03,452 - INFO - TRAIN Epoch: 7 Step: 15/18 Loss: 0.4886 Accuracy: 0.7995 AUC: 0.0000 Data Time: 0.8857 Batch Time: 2.4230
# 2024-06-25 19:14:05,344 - INFO - TRAIN Epoch: 7 Step: 16/18 Loss: 0.4871 Accuracy: 0.8005 AUC: 0.0000 Data Time: 0.8923 Batch Time: 2.3916
# 2024-06-25 19:14:06,269 - INFO - TRAIN Epoch: 7 Step: 17/18 Loss: 0.4872 Accuracy: 0.7999 AUC: 0.0000 Data Time: 0.8588 Batch Time: 2.3100
# 2024-06-25 19:14:06,273 - INFO - AUC Score: 0.6228
# 2024-06-25 19:14:08,736 - INFO - VAL Epoch: 7 Step: 0/5 Loss: 0.4921 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.0003 Batch Time: 2.4604
# 2024-06-25 19:14:11,195 - INFO - VAL Epoch: 7 Step: 1/5 Loss: 0.4709 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.9478 Batch Time: 2.4589
# 2024-06-25 19:14:13,230 - INFO - VAL Epoch: 7 Step: 2/5 Loss: 0.4717 Accuracy: 0.8222 AUC: 0.0000 Data Time: 0.9212 Batch Time: 2.3168
# 2024-06-25 19:14:16,230 - INFO - VAL Epoch: 7 Step: 3/5 Loss: 0.4900 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9938 Batch Time: 2.4870
# 2024-06-25 19:14:16,945 - INFO - VAL Epoch: 7 Step: 4/5 Loss: 0.5021 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.8793 Batch Time: 2.1321
# 2024-06-25 19:14:16,950 - INFO - AUC Score: 0.5447
# 2024-06-25 19:14:16,953 - INFO - New best model at epoch: 8
# 2024-06-25 19:14:17,153 - INFO - Starting Epoch: 9
# 2024-06-25 19:14:19,172 - INFO - TRAIN Epoch: 8 Step: 0/18 Loss: 0.4786 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.7347 Batch Time: 2.0166
# 2024-06-25 19:14:21,978 - INFO - TRAIN Epoch: 8 Step: 1/18 Loss: 0.5194 Accuracy: 0.7708 AUC: 0.0000 Data Time: 0.8079 Batch Time: 2.4097
# 2024-06-25 19:14:24,827 - INFO - TRAIN Epoch: 8 Step: 2/18 Loss: 0.5140 Accuracy: 0.7778 AUC: 0.0000 Data Time: 0.8333 Batch Time: 2.5557
# 2024-06-25 19:14:27,392 - INFO - TRAIN Epoch: 8 Step: 3/18 Loss: 0.4999 Accuracy: 0.7875 AUC: 0.0000 Data Time: 0.8411 Batch Time: 2.5576
# 2024-06-25 19:14:29,656 - INFO - TRAIN Epoch: 8 Step: 4/18 Loss: 0.4942 Accuracy: 0.7933 AUC: 0.0000 Data Time: 0.8482 Batch Time: 2.4984
# 2024-06-25 19:14:31,454 - INFO - TRAIN Epoch: 8 Step: 5/18 Loss: 0.4990 Accuracy: 0.7903 AUC: 0.0000 Data Time: 0.8578 Batch Time: 2.3814
# 2024-06-25 19:14:34,076 - INFO - TRAIN Epoch: 8 Step: 6/18 Loss: 0.4952 Accuracy: 0.7917 AUC: 0.0000 Data Time: 0.9098 Batch Time: 2.4154
# 2024-06-25 19:14:37,341 - INFO - TRAIN Epoch: 8 Step: 7/18 Loss: 0.4835 Accuracy: 0.8010 AUC: 0.0000 Data Time: 0.9523 Batch Time: 2.5212
# 2024-06-25 19:14:40,686 - INFO - TRAIN Epoch: 8 Step: 8/18 Loss: 0.4861 Accuracy: 0.8009 AUC: 0.0000 Data Time: 0.9922 Batch Time: 2.6125
# 2024-06-25 19:14:43,537 - INFO - TRAIN Epoch: 8 Step: 9/18 Loss: 0.4901 Accuracy: 0.7975 AUC: 0.0000 Data Time: 0.9744 Batch Time: 2.6361
# 2024-06-25 19:14:46,238 - INFO - TRAIN Epoch: 8 Step: 10/18 Loss: 0.4884 Accuracy: 0.7992 AUC: 0.0000 Data Time: 0.9639 Batch Time: 2.6419
# 2024-06-25 19:14:48,902 - INFO - TRAIN Epoch: 8 Step: 11/18 Loss: 0.4883 Accuracy: 0.7993 AUC: 0.0000 Data Time: 0.9575 Batch Time: 2.6436
# 2024-06-25 19:14:50,849 - INFO - TRAIN Epoch: 8 Step: 12/18 Loss: 0.4894 Accuracy: 0.7981 AUC: 0.0000 Data Time: 0.9648 Batch Time: 2.5898
# 2024-06-25 19:14:52,948 - INFO - TRAIN Epoch: 8 Step: 13/18 Loss: 0.4875 Accuracy: 0.7988 AUC: 0.0000 Data Time: 0.9815 Batch Time: 2.5546
# 2024-06-25 19:14:54,937 - INFO - TRAIN Epoch: 8 Step: 14/18 Loss: 0.4864 Accuracy: 0.7989 AUC: 0.0000 Data Time: 0.9895 Batch Time: 2.5167
# 2024-06-25 19:14:57,017 - INFO - TRAIN Epoch: 8 Step: 15/18 Loss: 0.4877 Accuracy: 0.7979 AUC: 0.0000 Data Time: 1.0034 Batch Time: 2.4893
# 2024-06-25 19:14:59,432 - INFO - TRAIN Epoch: 8 Step: 16/18 Loss: 0.4867 Accuracy: 0.7990 AUC: 0.0000 Data Time: 1.0090 Batch Time: 2.4848
# 2024-06-25 19:15:00,048 - INFO - TRAIN Epoch: 8 Step: 17/18 Loss: 0.4853 Accuracy: 0.7999 AUC: 0.0000 Data Time: 0.9726 Batch Time: 2.3808
# 2024-06-25 19:15:00,054 - INFO - AUC Score: 0.6335
# 2024-06-25 19:15:02,284 - INFO - VAL Epoch: 8 Step: 0/5 Loss: 0.4904 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9042 Batch Time: 2.2262
# 2024-06-25 19:15:04,949 - INFO - VAL Epoch: 8 Step: 1/5 Loss: 0.4691 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.0001 Batch Time: 2.4446
# 2024-06-25 19:15:07,759 - INFO - VAL Epoch: 8 Step: 2/5 Loss: 0.4696 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.0240 Batch Time: 2.5657
# 2024-06-25 19:15:10,676 - INFO - VAL Epoch: 8 Step: 3/5 Loss: 0.4879 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.0575 Batch Time: 2.6532
# 2024-06-25 19:15:11,347 - INFO - VAL Epoch: 8 Step: 4/5 Loss: 0.5000 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.9214 Batch Time: 2.2561
# 2024-06-25 19:15:11,350 - INFO - AUC Score: 0.5561
# 2024-06-25 19:15:11,351 - INFO - New best model at epoch: 9
# 2024-06-25 19:15:11,552 - INFO - Starting Epoch: 10
# 2024-06-25 19:15:13,451 - INFO - TRAIN Epoch: 9 Step: 0/18 Loss: 0.5038 Accuracy: 0.7917 AUC: 0.0000 Data Time: 0.7723 Batch Time: 1.8968
# 2024-06-25 19:15:16,192 - INFO - TRAIN Epoch: 9 Step: 1/18 Loss: 0.5058 Accuracy: 0.7875 AUC: 0.0000 Data Time: 1.0870 Batch Time: 2.3177
# 2024-06-25 19:15:19,825 - INFO - TRAIN Epoch: 9 Step: 2/18 Loss: 0.4854 Accuracy: 0.8028 AUC: 0.0000 Data Time: 1.2615 Batch Time: 2.7520
# 2024-06-25 19:15:24,728 - INFO - TRAIN Epoch: 9 Step: 3/18 Loss: 0.4904 Accuracy: 0.7979 AUC: 0.0000 Data Time: 1.7335 Batch Time: 3.2894
# 2024-06-25 19:15:29,104 - INFO - TRAIN Epoch: 9 Step: 4/18 Loss: 0.4878 Accuracy: 0.7983 AUC: 0.0000 Data Time: 1.9053 Batch Time: 3.5058
# 2024-06-25 19:15:31,999 - INFO - TRAIN Epoch: 9 Step: 5/18 Loss: 0.4908 Accuracy: 0.7958 AUC: 0.0000 Data Time: 1.9181 Batch Time: 3.4037
# 2024-06-25 19:15:35,122 - INFO - TRAIN Epoch: 9 Step: 6/18 Loss: 0.4839 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.9593 Batch Time: 3.3630
# 2024-06-25 19:15:38,597 - INFO - TRAIN Epoch: 9 Step: 7/18 Loss: 0.4876 Accuracy: 0.7958 AUC: 0.0000 Data Time: 2.0342 Batch Time: 3.3766
# 2024-06-25 19:15:42,116 - INFO - TRAIN Epoch: 9 Step: 8/18 Loss: 0.4847 Accuracy: 0.7991 AUC: 0.0000 Data Time: 2.0982 Batch Time: 3.3921
# 2024-06-25 19:15:46,459 - INFO - TRAIN Epoch: 9 Step: 9/18 Loss: 0.4900 Accuracy: 0.7958 AUC: 0.0000 Data Time: 2.1908 Batch Time: 3.4869
# 2024-06-25 19:15:49,056 - INFO - TRAIN Epoch: 9 Step: 10/18 Loss: 0.4875 Accuracy: 0.7970 AUC: 0.0000 Data Time: 2.1445 Batch Time: 3.4059
# 2024-06-25 19:15:51,137 - INFO - TRAIN Epoch: 9 Step: 11/18 Loss: 0.4904 Accuracy: 0.7951 AUC: 0.0000 Data Time: 2.0654 Batch Time: 3.2949
# 2024-06-25 19:15:53,556 - INFO - TRAIN Epoch: 9 Step: 12/18 Loss: 0.4878 Accuracy: 0.7974 AUC: 0.0000 Data Time: 1.9970 Batch Time: 3.2274
# 2024-06-25 19:15:57,330 - INFO - TRAIN Epoch: 9 Step: 13/18 Loss: 0.4843 Accuracy: 0.7994 AUC: 0.0000 Data Time: 2.0307 Batch Time: 3.2662
# 2024-06-25 19:15:59,810 - INFO - TRAIN Epoch: 9 Step: 14/18 Loss: 0.4833 Accuracy: 0.7994 AUC: 0.0000 Data Time: 1.9884 Batch Time: 3.2137
# 2024-06-25 19:16:03,599 - INFO - TRAIN Epoch: 9 Step: 15/18 Loss: 0.4873 Accuracy: 0.7974 AUC: 0.0000 Data Time: 1.9922 Batch Time: 3.2496
# 2024-06-25 19:16:07,003 - INFO - TRAIN Epoch: 9 Step: 16/18 Loss: 0.4834 Accuracy: 0.7995 AUC: 0.0000 Data Time: 1.9625 Batch Time: 3.2586
# 2024-06-25 19:16:08,802 - INFO - TRAIN Epoch: 9 Step: 17/18 Loss: 0.4833 Accuracy: 0.7999 AUC: 0.0000 Data Time: 1.9382 Batch Time: 3.1774
# 2024-06-25 19:16:08,806 - INFO - AUC Score: 0.6428
# 2024-06-25 19:16:11,104 - INFO - VAL Epoch: 9 Step: 0/5 Loss: 0.4887 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.4326 Batch Time: 2.2946
# 2024-06-25 19:16:13,516 - INFO - VAL Epoch: 9 Step: 1/5 Loss: 0.4671 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.4607 Batch Time: 2.3526
# 2024-06-25 19:16:15,920 - INFO - VAL Epoch: 9 Step: 2/5 Loss: 0.4672 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.4802 Batch Time: 2.3692
# 2024-06-25 19:16:18,364 - INFO - VAL Epoch: 9 Step: 3/5 Loss: 0.4860 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.4870 Batch Time: 2.3868
# 2024-06-25 19:16:19,545 - INFO - VAL Epoch: 9 Step: 4/5 Loss: 0.4984 Accuracy: 0.7996 AUC: 0.0000 Data Time: 1.3355 Batch Time: 2.1454
# 2024-06-25 19:16:19,548 - INFO - AUC Score: 0.5650
# 2024-06-25 19:16:19,549 - INFO - New best model at epoch: 10
# 2024-06-25 19:16:19,748 - INFO - Starting Epoch: 11
# 2024-06-25 19:16:28,108 - INFO - TRAIN Epoch: 10 Step: 0/18 Loss: 0.4812 Accuracy: 0.8000 AUC: 0.0000 Data Time: 6.7089 Batch Time: 8.3572
# 2024-06-25 19:16:36,257 - INFO - TRAIN Epoch: 10 Step: 1/18 Loss: 0.4656 Accuracy: 0.8125 AUC: 0.0000 Data Time: 6.5438 Batch Time: 8.2521
# 2024-06-25 19:16:42,269 - INFO - TRAIN Epoch: 10 Step: 2/18 Loss: 0.4546 Accuracy: 0.8194 AUC: 0.0000 Data Time: 6.0576 Batch Time: 7.5049
# 2024-06-25 19:16:48,681 - INFO - TRAIN Epoch: 10 Step: 3/18 Loss: 0.4741 Accuracy: 0.8021 AUC: 0.0000 Data Time: 5.9146 Batch Time: 7.2314
# 2024-06-25 19:16:54,225 - INFO - TRAIN Epoch: 10 Step: 4/18 Loss: 0.4635 Accuracy: 0.8117 AUC: 0.0000 Data Time: 5.6532 Batch Time: 6.8935
# 2024-06-25 19:16:59,597 - INFO - TRAIN Epoch: 10 Step: 5/18 Loss: 0.4683 Accuracy: 0.8083 AUC: 0.0000 Data Time: 5.4521 Batch Time: 6.6397
# 2024-06-25 19:17:04,231 - INFO - TRAIN Epoch: 10 Step: 6/18 Loss: 0.4715 Accuracy: 0.8071 AUC: 0.0000 Data Time: 5.2092 Batch Time: 6.3528
# 2024-06-25 19:17:09,208 - INFO - TRAIN Epoch: 10 Step: 7/18 Loss: 0.4724 Accuracy: 0.8052 AUC: 0.0000 Data Time: 5.0659 Batch Time: 6.1806
# 2024-06-25 19:17:13,778 - INFO - TRAIN Epoch: 10 Step: 8/18 Loss: 0.4872 Accuracy: 0.7944 AUC: 0.0000 Data Time: 4.8802 Batch Time: 6.0015
# 2024-06-25 19:17:17,151 - INFO - TRAIN Epoch: 10 Step: 9/18 Loss: 0.4895 Accuracy: 0.7933 AUC: 0.0000 Data Time: 4.6197 Batch Time: 5.7385
# 2024-06-25 19:17:20,353 - INFO - TRAIN Epoch: 10 Step: 10/18 Loss: 0.4897 Accuracy: 0.7932 AUC: 0.0000 Data Time: 4.3817 Batch Time: 5.5078
# 2024-06-25 19:17:24,971 - INFO - TRAIN Epoch: 10 Step: 11/18 Loss: 0.4885 Accuracy: 0.7951 AUC: 0.0000 Data Time: 4.2217 Batch Time: 5.4335
# 2024-06-25 19:17:28,696 - INFO - TRAIN Epoch: 10 Step: 12/18 Loss: 0.4876 Accuracy: 0.7955 AUC: 0.0000 Data Time: 4.0545 Batch Time: 5.3020
# 2024-06-25 19:17:31,678 - INFO - TRAIN Epoch: 10 Step: 13/18 Loss: 0.4921 Accuracy: 0.7911 AUC: 0.0000 Data Time: 3.9127 Batch Time: 5.1362
# 2024-06-25 19:17:34,687 - INFO - TRAIN Epoch: 10 Step: 14/18 Loss: 0.4925 Accuracy: 0.7917 AUC: 0.0000 Data Time: 3.7923 Batch Time: 4.9943
# 2024-06-25 19:17:37,831 - INFO - TRAIN Epoch: 10 Step: 15/18 Loss: 0.4833 Accuracy: 0.7984 AUC: 0.0000 Data Time: 3.6936 Batch Time: 4.8782
# 2024-06-25 19:17:40,768 - INFO - TRAIN Epoch: 10 Step: 16/18 Loss: 0.4820 Accuracy: 0.7995 AUC: 0.0000 Data Time: 3.5968 Batch Time: 4.7639
# 2024-06-25 19:17:41,569 - INFO - TRAIN Epoch: 10 Step: 17/18 Loss: 0.4816 Accuracy: 0.7999 AUC: 0.0000 Data Time: 3.4265 Batch Time: 4.5437
# 2024-06-25 19:17:41,574 - INFO - AUC Score: 0.6500
# 2024-06-25 19:17:44,881 - INFO - VAL Epoch: 10 Step: 0/5 Loss: 0.4868 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.2525 Batch Time: 3.3040
# 2024-06-25 19:17:47,396 - INFO - VAL Epoch: 10 Step: 1/5 Loss: 0.4654 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.8744 Batch Time: 2.9090
# 2024-06-25 19:17:50,073 - INFO - VAL Epoch: 10 Step: 2/5 Loss: 0.4652 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.7596 Batch Time: 2.8306
# 2024-06-25 19:17:53,339 - INFO - VAL Epoch: 10 Step: 3/5 Loss: 0.4839 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.9046 Batch Time: 2.9389
# 2024-06-25 19:17:54,566 - INFO - VAL Epoch: 10 Step: 4/5 Loss: 0.4963 Accuracy: 0.7996 AUC: 0.0000 Data Time: 1.6260 Batch Time: 2.5961
# 2024-06-25 19:17:54,570 - INFO - AUC Score: 0.5741
# 2024-06-25 19:17:54,572 - INFO - New best model at epoch: 11
# 2024-06-25 19:17:54,844 - INFO - Starting Epoch: 12
# 2024-06-25 19:17:56,716 - INFO - TRAIN Epoch: 11 Step: 0/18 Loss: 0.5650 Accuracy: 0.7333 AUC: 0.0000 Data Time: 0.9963 Batch Time: 1.8673
# 2024-06-25 19:17:59,867 - INFO - TRAIN Epoch: 11 Step: 1/18 Loss: 0.5351 Accuracy: 0.7583 AUC: 0.0000 Data Time: 1.5737 Batch Time: 2.5077
# 2024-06-25 19:18:02,504 - INFO - TRAIN Epoch: 11 Step: 2/18 Loss: 0.5076 Accuracy: 0.7806 AUC: 0.0000 Data Time: 1.5373 Batch Time: 2.5500
# 2024-06-25 19:18:04,813 - INFO - TRAIN Epoch: 11 Step: 3/18 Loss: 0.5017 Accuracy: 0.7875 AUC: 0.0000 Data Time: 1.4949 Batch Time: 2.4893
# 2024-06-25 19:18:06,909 - INFO - TRAIN Epoch: 11 Step: 4/18 Loss: 0.4943 Accuracy: 0.7933 AUC: 0.0000 Data Time: 1.3658 Batch Time: 2.4104
# 2024-06-25 19:18:10,023 - INFO - TRAIN Epoch: 11 Step: 5/18 Loss: 0.4894 Accuracy: 0.7958 AUC: 0.0000 Data Time: 1.3237 Batch Time: 2.5271
# 2024-06-25 19:18:12,772 - INFO - TRAIN Epoch: 11 Step: 6/18 Loss: 0.4728 Accuracy: 0.8071 AUC: 0.0000 Data Time: 1.3001 Batch Time: 2.5586
# 2024-06-25 19:18:16,066 - INFO - TRAIN Epoch: 11 Step: 7/18 Loss: 0.4742 Accuracy: 0.8052 AUC: 0.0000 Data Time: 1.3027 Batch Time: 2.6504
# 2024-06-25 19:18:19,525 - INFO - TRAIN Epoch: 11 Step: 8/18 Loss: 0.4738 Accuracy: 0.8046 AUC: 0.0000 Data Time: 1.3449 Batch Time: 2.7400
# 2024-06-25 19:18:22,414 - INFO - TRAIN Epoch: 11 Step: 9/18 Loss: 0.4687 Accuracy: 0.8075 AUC: 0.0000 Data Time: 1.3898 Batch Time: 2.7543
# 2024-06-25 19:18:24,608 - INFO - TRAIN Epoch: 11 Step: 10/18 Loss: 0.4783 Accuracy: 0.8015 AUC: 0.0000 Data Time: 1.3818 Batch Time: 2.7032
# 2024-06-25 19:18:28,121 - INFO - TRAIN Epoch: 11 Step: 11/18 Loss: 0.4846 Accuracy: 0.7958 AUC: 0.0000 Data Time: 1.4388 Batch Time: 2.7707
# 2024-06-25 19:18:31,134 - INFO - TRAIN Epoch: 11 Step: 12/18 Loss: 0.4837 Accuracy: 0.7974 AUC: 0.0000 Data Time: 1.4163 Batch Time: 2.7892
# 2024-06-25 19:18:35,040 - INFO - TRAIN Epoch: 11 Step: 13/18 Loss: 0.4796 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.4439 Batch Time: 2.8689
# 2024-06-25 19:18:38,831 - INFO - TRAIN Epoch: 11 Step: 14/18 Loss: 0.4799 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.4885 Batch Time: 2.9304
# 2024-06-25 19:18:42,244 - INFO - TRAIN Epoch: 11 Step: 15/18 Loss: 0.4785 Accuracy: 0.8010 AUC: 0.0000 Data Time: 1.5163 Batch Time: 2.9603
# 2024-06-25 19:18:45,074 - INFO - TRAIN Epoch: 11 Step: 16/18 Loss: 0.4791 Accuracy: 0.8005 AUC: 0.0000 Data Time: 1.4774 Batch Time: 2.9525
# 2024-06-25 19:18:45,587 - INFO - TRAIN Epoch: 11 Step: 17/18 Loss: 0.4795 Accuracy: 0.7999 AUC: 0.0000 Data Time: 1.4093 Batch Time: 2.8169
# 2024-06-25 19:18:45,591 - INFO - AUC Score: 0.6605
# 2024-06-25 19:18:47,796 - INFO - VAL Epoch: 11 Step: 0/5 Loss: 0.4851 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8356 Batch Time: 2.2018
# 2024-06-25 19:18:50,211 - INFO - VAL Epoch: 11 Step: 1/5 Loss: 0.4633 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.7983 Batch Time: 2.3073
# 2024-06-25 19:18:52,894 - INFO - VAL Epoch: 11 Step: 2/5 Loss: 0.4628 Accuracy: 0.8222 AUC: 0.0000 Data Time: 0.8193 Batch Time: 2.4318
# 2024-06-25 19:18:55,187 - INFO - VAL Epoch: 11 Step: 3/5 Loss: 0.4820 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8405 Batch Time: 2.3967
# 2024-06-25 19:18:56,052 - INFO - VAL Epoch: 11 Step: 4/5 Loss: 0.4945 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.7253 Batch Time: 2.0899
# 2024-06-25 19:18:56,056 - INFO - AUC Score: 0.5812
# 2024-06-25 19:18:56,059 - INFO - New best model at epoch: 12
# 2024-06-25 19:18:56,255 - INFO - Starting Epoch: 13
# 2024-06-25 19:18:58,851 - INFO - TRAIN Epoch: 12 Step: 0/18 Loss: 0.5473 Accuracy: 0.7500 AUC: 0.0000 Data Time: 0.8462 Batch Time: 2.5937
# 2024-06-25 19:19:01,517 - INFO - TRAIN Epoch: 12 Step: 1/18 Loss: 0.5618 Accuracy: 0.7417 AUC: 0.0000 Data Time: 0.8490 Batch Time: 2.6289
# 2024-06-25 19:19:04,246 - INFO - TRAIN Epoch: 12 Step: 2/18 Loss: 0.5285 Accuracy: 0.7611 AUC: 0.0000 Data Time: 0.8395 Batch Time: 2.6615
# 2024-06-25 19:19:07,053 - INFO - TRAIN Epoch: 12 Step: 3/18 Loss: 0.5296 Accuracy: 0.7604 AUC: 0.0000 Data Time: 0.8343 Batch Time: 2.6973
# 2024-06-25 19:19:09,930 - INFO - TRAIN Epoch: 12 Step: 4/18 Loss: 0.5147 Accuracy: 0.7750 AUC: 0.0000 Data Time: 0.8322 Batch Time: 2.7326
# 2024-06-25 19:19:12,850 - INFO - TRAIN Epoch: 12 Step: 5/18 Loss: 0.5088 Accuracy: 0.7764 AUC: 0.0000 Data Time: 0.8309 Batch Time: 2.7636
# 2024-06-25 19:19:15,780 - INFO - TRAIN Epoch: 12 Step: 6/18 Loss: 0.4922 Accuracy: 0.7893 AUC: 0.0000 Data Time: 0.8331 Batch Time: 2.7871
# 2024-06-25 19:19:18,731 - INFO - TRAIN Epoch: 12 Step: 7/18 Loss: 0.4917 Accuracy: 0.7906 AUC: 0.0000 Data Time: 0.8345 Batch Time: 2.8074
# 2024-06-25 19:19:21,669 - INFO - TRAIN Epoch: 12 Step: 8/18 Loss: 0.4950 Accuracy: 0.7870 AUC: 0.0000 Data Time: 0.8379 Batch Time: 2.8217
# 2024-06-25 19:19:24,644 - INFO - TRAIN Epoch: 12 Step: 9/18 Loss: 0.4967 Accuracy: 0.7858 AUC: 0.0000 Data Time: 0.8377 Batch Time: 2.8368
# 2024-06-25 19:19:27,594 - INFO - TRAIN Epoch: 12 Step: 10/18 Loss: 0.4967 Accuracy: 0.7848 AUC: 0.0000 Data Time: 0.8392 Batch Time: 2.8469
# 2024-06-25 19:19:30,522 - INFO - TRAIN Epoch: 12 Step: 11/18 Loss: 0.4950 Accuracy: 0.7868 AUC: 0.0000 Data Time: 0.8399 Batch Time: 2.8534
# 2024-06-25 19:19:33,500 - INFO - TRAIN Epoch: 12 Step: 12/18 Loss: 0.4846 Accuracy: 0.7955 AUC: 0.0000 Data Time: 0.8399 Batch Time: 2.8629
# 2024-06-25 19:19:36,483 - INFO - TRAIN Epoch: 12 Step: 13/18 Loss: 0.4818 Accuracy: 0.7976 AUC: 0.0000 Data Time: 0.8403 Batch Time: 2.8714
# 2024-06-25 19:19:39,489 - INFO - TRAIN Epoch: 12 Step: 14/18 Loss: 0.4817 Accuracy: 0.7972 AUC: 0.0000 Data Time: 0.8437 Batch Time: 2.8802
# 2024-06-25 19:19:42,439 - INFO - TRAIN Epoch: 12 Step: 15/18 Loss: 0.4796 Accuracy: 0.7984 AUC: 0.0000 Data Time: 0.8463 Batch Time: 2.8844
# 2024-06-25 19:19:44,968 - INFO - TRAIN Epoch: 12 Step: 16/18 Loss: 0.4764 Accuracy: 0.8010 AUC: 0.0000 Data Time: 0.8533 Batch Time: 2.8634
# 2024-06-25 19:19:45,644 - INFO - TRAIN Epoch: 12 Step: 17/18 Loss: 0.4780 Accuracy: 0.7999 AUC: 0.0000 Data Time: 0.8190 Batch Time: 2.7417
# 2024-06-25 19:19:45,648 - INFO - AUC Score: 0.6678
# 2024-06-25 19:19:48,434 - INFO - VAL Epoch: 12 Step: 0/5 Loss: 0.4835 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8431 Batch Time: 2.7840
# 2024-06-25 19:19:51,292 - INFO - VAL Epoch: 12 Step: 1/5 Loss: 0.4618 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.8400 Batch Time: 2.8191
# 2024-06-25 19:19:54,142 - INFO - VAL Epoch: 12 Step: 2/5 Loss: 0.4610 Accuracy: 0.8222 AUC: 0.0000 Data Time: 0.8381 Batch Time: 2.8288
# 2024-06-25 19:19:56,229 - INFO - VAL Epoch: 12 Step: 3/5 Loss: 0.4799 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8527 Batch Time: 2.6429
# 2024-06-25 19:19:57,200 - INFO - VAL Epoch: 12 Step: 4/5 Loss: 0.4925 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.7343 Batch Time: 2.3080
# 2024-06-25 19:19:57,205 - INFO - AUC Score: 0.5913
# 2024-06-25 19:19:57,206 - INFO - New best model at epoch: 13
# 2024-06-25 19:19:57,398 - INFO - Starting Epoch: 14
# 2024-06-25 19:20:00,247 - INFO - TRAIN Epoch: 13 Step: 0/18 Loss: 0.5221 Accuracy: 0.7667 AUC: 0.0000 Data Time: 0.8947 Batch Time: 2.8465
# 2024-06-25 19:20:03,096 - INFO - TRAIN Epoch: 13 Step: 1/18 Loss: 0.5139 Accuracy: 0.7708 AUC: 0.0000 Data Time: 0.8831 Batch Time: 2.8467
# 2024-06-25 19:20:06,013 - INFO - TRAIN Epoch: 13 Step: 2/18 Loss: 0.4696 Accuracy: 0.8056 AUC: 0.0000 Data Time: 0.8846 Batch Time: 2.8692
# 2024-06-25 19:20:08,951 - INFO - TRAIN Epoch: 13 Step: 3/18 Loss: 0.4638 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8837 Batch Time: 2.8861
# 2024-06-25 19:20:11,894 - INFO - TRAIN Epoch: 13 Step: 4/18 Loss: 0.4538 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.8859 Batch Time: 2.8971
# 2024-06-25 19:20:14,828 - INFO - TRAIN Epoch: 13 Step: 5/18 Loss: 0.4707 Accuracy: 0.8042 AUC: 0.0000 Data Time: 0.8882 Batch Time: 2.9029
# 2024-06-25 19:20:17,768 - INFO - TRAIN Epoch: 13 Step: 6/18 Loss: 0.4886 Accuracy: 0.7905 AUC: 0.0000 Data Time: 0.8878 Batch Time: 2.9080
# 2024-06-25 19:20:20,708 - INFO - TRAIN Epoch: 13 Step: 7/18 Loss: 0.4823 Accuracy: 0.7937 AUC: 0.0000 Data Time: 0.8903 Batch Time: 2.9118
# 2024-06-25 19:20:23,650 - INFO - TRAIN Epoch: 13 Step: 8/18 Loss: 0.4736 Accuracy: 0.8000 AUC: 0.0000 Data Time: 0.8907 Batch Time: 2.9148
# 2024-06-25 19:20:26,593 - INFO - TRAIN Epoch: 13 Step: 9/18 Loss: 0.4701 Accuracy: 0.8025 AUC: 0.0000 Data Time: 0.8900 Batch Time: 2.9174
# 2024-06-25 19:20:29,535 - INFO - TRAIN Epoch: 13 Step: 10/18 Loss: 0.4774 Accuracy: 0.7977 AUC: 0.0000 Data Time: 0.8886 Batch Time: 2.9195
# 2024-06-25 19:20:32,398 - INFO - TRAIN Epoch: 13 Step: 11/18 Loss: 0.4759 Accuracy: 0.8000 AUC: 0.0000 Data Time: 0.8932 Batch Time: 2.9146
# 2024-06-25 19:20:35,331 - INFO - TRAIN Epoch: 13 Step: 12/18 Loss: 0.4737 Accuracy: 0.8019 AUC: 0.0000 Data Time: 0.8971 Batch Time: 2.9159
# 2024-06-25 19:20:38,369 - INFO - TRAIN Epoch: 13 Step: 13/18 Loss: 0.4748 Accuracy: 0.8018 AUC: 0.0000 Data Time: 0.8997 Batch Time: 2.9245
# 2024-06-25 19:20:41,373 - INFO - TRAIN Epoch: 13 Step: 14/18 Loss: 0.4806 Accuracy: 0.7972 AUC: 0.0000 Data Time: 0.8990 Batch Time: 2.9297
# 2024-06-25 19:20:44,312 - INFO - TRAIN Epoch: 13 Step: 15/18 Loss: 0.4775 Accuracy: 0.7990 AUC: 0.0000 Data Time: 0.8984 Batch Time: 2.9302
# 2024-06-25 19:20:46,864 - INFO - TRAIN Epoch: 13 Step: 16/18 Loss: 0.4788 Accuracy: 0.7975 AUC: 0.0000 Data Time: 0.9049 Batch Time: 2.9078
# 2024-06-25 19:20:47,586 - INFO - TRAIN Epoch: 13 Step: 17/18 Loss: 0.4758 Accuracy: 0.7999 AUC: 0.0000 Data Time: 0.8676 Batch Time: 2.7863
# 2024-06-25 19:20:47,591 - INFO - AUC Score: 0.6751
# 2024-06-25 19:20:50,466 - INFO - VAL Epoch: 13 Step: 0/5 Loss: 0.4819 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8989 Batch Time: 2.8727
# 2024-06-25 19:20:53,369 - INFO - VAL Epoch: 13 Step: 1/5 Loss: 0.4596 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.8878 Batch Time: 2.8871
# 2024-06-25 19:20:56,240 - INFO - VAL Epoch: 13 Step: 2/5 Loss: 0.4586 Accuracy: 0.8222 AUC: 0.0000 Data Time: 0.8827 Batch Time: 2.8807
# 2024-06-25 19:20:58,391 - INFO - VAL Epoch: 13 Step: 3/5 Loss: 0.4782 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8917 Batch Time: 2.6980
# 2024-06-25 19:20:59,370 - INFO - VAL Epoch: 13 Step: 4/5 Loss: 0.4911 Accuracy: 0.7996 AUC: 0.0000 Data Time: 0.7651 Batch Time: 2.3539
# 2024-06-25 19:20:59,374 - INFO - AUC Score: 0.5978
# 2024-06-25 19:20:59,376 - INFO - New best model at epoch: 14
# 2024-06-25 19:20:59,574 - INFO - Starting Epoch: 15
# 2024-06-25 19:21:02,382 - INFO - TRAIN Epoch: 14 Step: 0/18 Loss: 0.4669 Accuracy: 0.8000 AUC: 0.0000 Data Time: 0.8525 Batch Time: 2.8052
# ...
# 2024-06-25 19:43:58,297 - INFO - AUC Score: 0.7585
# 2024-06-25 19:44:00,393 - INFO - VAL Epoch: 38 Step: 0/5 Loss: 0.4521 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.7962 Batch Time: 2.0939
# 2024-06-25 19:44:03,399 - INFO - VAL Epoch: 38 Step: 1/5 Loss: 0.4244 Accuracy: 0.8208 AUC: 0.0000 Data Time: 0.8414 Batch Time: 2.5491
# 2024-06-25 19:44:06,100 - INFO - VAL Epoch: 38 Step: 2/5 Loss: 0.4172 Accuracy: 0.8278 AUC: 0.0000 Data Time: 0.8581 Batch Time: 2.5992
# 2024-06-25 19:44:09,244 - INFO - VAL Epoch: 38 Step: 3/5 Loss: 0.4397 Accuracy: 0.8146 AUC: 0.0000 Data Time: 0.9357 Batch Time: 2.7349
# 2024-06-25 19:44:09,930 - INFO - VAL Epoch: 38 Step: 4/5 Loss: 0.4555 Accuracy: 0.8073 AUC: 0.0000 Data Time: 0.8271 Batch Time: 2.3247
# 2024-06-25 19:44:09,934 - INFO - AUC Score: 0.7083
# 2024-06-25 19:44:09,935 - INFO - New best model at epoch: 39
# 2024-06-25 19:44:10,141 - INFO - Starting Epoch: 40
# 2024-06-25 19:44:11,806 - INFO - TRAIN Epoch: 39 Step: 0/18 Loss: 0.4726 Accuracy: 0.7750 AUC: 0.0000 Data Time: 0.7847 Batch Time: 1.6635
# 2024-06-25 19:44:14,131 - INFO - TRAIN Epoch: 39 Step: 1/18 Loss: 0.4883 Accuracy: 0.7583 AUC: 0.0000 Data Time: 0.7824 Batch Time: 1.9935
# 2024-06-25 19:44:16,992 - INFO - TRAIN Epoch: 39 Step: 2/18 Loss: 0.4717 Accuracy: 0.7722 AUC: 0.0000 Data Time: 0.8855 Batch Time: 2.2820
# 2024-06-25 19:44:20,082 - INFO - TRAIN Epoch: 39 Step: 3/18 Loss: 0.4691 Accuracy: 0.7792 AUC: 0.0000 Data Time: 0.9879 Batch Time: 2.4835
# 2024-06-25 19:44:23,118 - INFO - TRAIN Epoch: 39 Step: 4/18 Loss: 0.4575 Accuracy: 0.7867 AUC: 0.0000 Data Time: 1.0349 Batch Time: 2.5937
# 2024-06-25 19:44:25,742 - INFO - TRAIN Epoch: 39 Step: 5/18 Loss: 0.4657 Accuracy: 0.7792 AUC: 0.0000 Data Time: 1.0662 Batch Time: 2.5984
# 2024-06-25 19:44:28,560 - INFO - TRAIN Epoch: 39 Step: 6/18 Loss: 0.4593 Accuracy: 0.7833 AUC: 0.0000 Data Time: 1.0314 Batch Time: 2.6294
# 2024-06-25 19:44:31,700 - INFO - TRAIN Epoch: 39 Step: 7/18 Loss: 0.4545 Accuracy: 0.7885 AUC: 0.0000 Data Time: 1.0482 Batch Time: 2.6930
# 2024-06-25 19:44:34,355 - INFO - TRAIN Epoch: 39 Step: 8/18 Loss: 0.4509 Accuracy: 0.7898 AUC: 0.0000 Data Time: 1.0542 Batch Time: 2.6884
# 2024-06-25 19:44:36,811 - INFO - TRAIN Epoch: 39 Step: 9/18 Loss: 0.4465 Accuracy: 0.7942 AUC: 0.0000 Data Time: 1.0609 Batch Time: 2.6648
# 2024-06-25 19:44:39,616 - INFO - TRAIN Epoch: 39 Step: 10/18 Loss: 0.4503 Accuracy: 0.7924 AUC: 0.0000 Data Time: 1.0794 Batch Time: 2.6774
# 2024-06-25 19:44:42,470 - INFO - TRAIN Epoch: 39 Step: 11/18 Loss: 0.4488 Accuracy: 0.7944 AUC: 0.0000 Data Time: 1.0824 Batch Time: 2.6920
# 2024-06-25 19:44:45,127 - INFO - TRAIN Epoch: 39 Step: 12/18 Loss: 0.4486 Accuracy: 0.7955 AUC: 0.0000 Data Time: 1.0650 Batch Time: 2.6892
# 2024-06-25 19:44:47,869 - INFO - TRAIN Epoch: 39 Step: 13/18 Loss: 0.4457 Accuracy: 0.7958 AUC: 0.0000 Data Time: 1.0752 Batch Time: 2.6929
# 2024-06-25 19:44:50,831 - INFO - TRAIN Epoch: 39 Step: 14/18 Loss: 0.4391 Accuracy: 0.8017 AUC: 0.0000 Data Time: 1.0855 Batch Time: 2.7107
# 2024-06-25 19:44:53,817 - INFO - TRAIN Epoch: 39 Step: 15/18 Loss: 0.4386 Accuracy: 0.8036 AUC: 0.0000 Data Time: 1.0733 Batch Time: 2.7278
# 2024-06-25 19:44:56,555 - INFO - TRAIN Epoch: 39 Step: 16/18 Loss: 0.4358 Accuracy: 0.8064 AUC: 0.0000 Data Time: 1.0651 Batch Time: 2.7282
# 2024-06-25 19:44:57,224 - INFO - TRAIN Epoch: 39 Step: 17/18 Loss: 0.4375 Accuracy: 0.8052 AUC: 0.0000 Data Time: 1.0286 Batch Time: 2.6137
# 2024-06-25 19:44:57,228 - INFO - AUC Score: 0.7598
# 2024-06-25 19:45:00,079 - INFO - VAL Epoch: 39 Step: 0/5 Loss: 0.4516 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8812 Batch Time: 2.8497
# 2024-06-25 19:45:01,898 - INFO - VAL Epoch: 39 Step: 1/5 Loss: 0.4234 Accuracy: 0.8250 AUC: 0.0000 Data Time: 0.9033 Batch Time: 2.3337
# 2024-06-25 19:45:03,969 - INFO - VAL Epoch: 39 Step: 2/5 Loss: 0.4161 Accuracy: 0.8306 AUC: 0.0000 Data Time: 0.8890 Batch Time: 2.2453
# 2024-06-25 19:45:06,658 - INFO - VAL Epoch: 39 Step: 3/5 Loss: 0.4386 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.8913 Batch Time: 2.3556
# 2024-06-25 19:45:07,319 - INFO - VAL Epoch: 39 Step: 4/5 Loss: 0.4543 Accuracy: 0.8092 AUC: 0.0000 Data Time: 0.7866 Batch Time: 2.0162
# 2024-06-25 19:45:07,322 - INFO - AUC Score: 0.7106
# 2024-06-25 19:45:07,324 - INFO - New best model at epoch: 40
# 2024-06-25 19:45:07,528 - INFO - Starting Epoch: 41
# 2024-06-25 19:45:09,579 - INFO - TRAIN Epoch: 40 Step: 0/18 Loss: 0.4327 Accuracy: 0.8000 AUC: 0.0000 Data Time: 0.8160 Batch Time: 2.0483
# 2024-06-25 19:45:12,218 - INFO - TRAIN Epoch: 40 Step: 1/18 Loss: 0.3990 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.0294 Batch Time: 2.3430
# 2024-06-25 19:45:15,003 - INFO - TRAIN Epoch: 40 Step: 2/18 Loss: 0.4170 Accuracy: 0.8111 AUC: 0.0000 Data Time: 1.1106 Batch Time: 2.4897
# 2024-06-25 19:45:17,250 - INFO - TRAIN Epoch: 40 Step: 3/18 Loss: 0.4223 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.1059 Batch Time: 2.4284
# 2024-06-25 19:45:19,398 - INFO - TRAIN Epoch: 40 Step: 4/18 Loss: 0.4188 Accuracy: 0.8133 AUC: 0.0000 Data Time: 1.1227 Batch Time: 2.3719
# 2024-06-25 19:45:21,848 - INFO - TRAIN Epoch: 40 Step: 5/18 Loss: 0.4055 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.1485 Batch Time: 2.3847
# 2024-06-25 19:45:24,005 - INFO - TRAIN Epoch: 40 Step: 6/18 Loss: 0.4139 Accuracy: 0.8131 AUC: 0.0000 Data Time: 1.1440 Batch Time: 2.3517
# 2024-06-25 19:45:26,018 - INFO - TRAIN Epoch: 40 Step: 7/18 Loss: 0.4188 Accuracy: 0.8115 AUC: 0.0000 Data Time: 1.1412 Batch Time: 2.3092
# 2024-06-25 19:45:28,305 - INFO - TRAIN Epoch: 40 Step: 8/18 Loss: 0.4248 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.1295 Batch Time: 2.3065
# 2024-06-25 19:45:30,926 - INFO - TRAIN Epoch: 40 Step: 9/18 Loss: 0.4250 Accuracy: 0.8092 AUC: 0.0000 Data Time: 1.1306 Batch Time: 2.3376
# 2024-06-25 19:45:33,775 - INFO - TRAIN Epoch: 40 Step: 10/18 Loss: 0.4284 Accuracy: 0.8076 AUC: 0.0000 Data Time: 1.1351 Batch Time: 2.3838
# 2024-06-25 19:45:36,826 - INFO - TRAIN Epoch: 40 Step: 11/18 Loss: 0.4328 Accuracy: 0.8049 AUC: 0.0000 Data Time: 1.1499 Batch Time: 2.4390
# 2024-06-25 19:45:39,740 - INFO - TRAIN Epoch: 40 Step: 12/18 Loss: 0.4317 Accuracy: 0.8051 AUC: 0.0000 Data Time: 1.1485 Batch Time: 2.4754
# 2024-06-25 19:45:42,267 - INFO - TRAIN Epoch: 40 Step: 13/18 Loss: 0.4358 Accuracy: 0.8030 AUC: 0.0000 Data Time: 1.1471 Batch Time: 2.4790
# 2024-06-25 19:45:44,813 - INFO - TRAIN Epoch: 40 Step: 14/18 Loss: 0.4380 Accuracy: 0.8017 AUC: 0.0000 Data Time: 1.1369 Batch Time: 2.4833
# 2024-06-25 19:45:47,705 - INFO - TRAIN Epoch: 40 Step: 15/18 Loss: 0.4370 Accuracy: 0.8036 AUC: 0.0000 Data Time: 1.1399 Batch Time: 2.5088
# 2024-06-25 19:45:50,678 - INFO - TRAIN Epoch: 40 Step: 16/18 Loss: 0.4374 Accuracy: 0.8025 AUC: 0.0000 Data Time: 1.1446 Batch Time: 2.5359
# 2024-06-25 19:45:51,299 - INFO - TRAIN Epoch: 40 Step: 17/18 Loss: 0.4363 Accuracy: 0.8042 AUC: 0.0000 Data Time: 1.1010 Batch Time: 2.4294
# 2024-06-25 19:45:51,303 - INFO - AUC Score: 0.7608
# 2024-06-25 19:45:53,575 - INFO - VAL Epoch: 40 Step: 0/5 Loss: 0.4513 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.8280 Batch Time: 2.2701
# 2024-06-25 19:45:56,294 - INFO - VAL Epoch: 40 Step: 1/5 Loss: 0.4225 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.0094 Batch Time: 2.4936
# 2024-06-25 19:45:58,244 - INFO - VAL Epoch: 40 Step: 2/5 Loss: 0.4152 Accuracy: 0.8306 AUC: 0.0000 Data Time: 0.9889 Batch Time: 2.3117
# 2024-06-25 19:45:59,934 - INFO - VAL Epoch: 40 Step: 3/5 Loss: 0.4378 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.9429 Batch Time: 2.1558
# 2024-06-25 19:46:00,757 - INFO - VAL Epoch: 40 Step: 4/5 Loss: 0.4538 Accuracy: 0.8092 AUC: 0.0000 Data Time: 0.8145 Batch Time: 1.8888
# 2024-06-25 19:46:00,762 - INFO - AUC Score: 0.7111
# 2024-06-25 19:46:00,763 - INFO - New best model at epoch: 41
# 2024-06-25 19:46:00,951 - INFO - Starting Epoch: 42
# 2024-06-25 19:46:02,695 - INFO - TRAIN Epoch: 41 Step: 0/18 Loss: 0.4109 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.8431 Batch Time: 1.7415
# 2024-06-25 19:46:04,336 - INFO - TRAIN Epoch: 41 Step: 1/18 Loss: 0.4135 Accuracy: 0.8125 AUC: 0.0000 Data Time: 0.8098 Batch Time: 1.6905
# 2024-06-25 19:46:06,711 - INFO - TRAIN Epoch: 41 Step: 2/18 Loss: 0.4073 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.8779 Batch Time: 1.9180
# 2024-06-25 19:46:09,362 - INFO - TRAIN Epoch: 41 Step: 3/18 Loss: 0.4053 Accuracy: 0.8167 AUC: 0.0000 Data Time: 0.9441 Batch Time: 2.1009
# 2024-06-25 19:46:11,797 - INFO - TRAIN Epoch: 41 Step: 4/18 Loss: 0.4103 Accuracy: 0.8200 AUC: 0.0000 Data Time: 0.9750 Batch Time: 2.1675
# 2024-06-25 19:46:14,601 - INFO - TRAIN Epoch: 41 Step: 5/18 Loss: 0.4174 Accuracy: 0.8153 AUC: 0.0000 Data Time: 0.9507 Batch Time: 2.2731
# 2024-06-25 19:46:17,248 - INFO - TRAIN Epoch: 41 Step: 6/18 Loss: 0.4168 Accuracy: 0.8131 AUC: 0.0000 Data Time: 0.9372 Batch Time: 2.3263
# 2024-06-25 19:46:19,958 - INFO - TRAIN Epoch: 41 Step: 7/18 Loss: 0.4114 Accuracy: 0.8156 AUC: 0.0000 Data Time: 0.9334 Batch Time: 2.3741
# 2024-06-25 19:46:22,866 - INFO - TRAIN Epoch: 41 Step: 8/18 Loss: 0.4125 Accuracy: 0.8148 AUC: 0.0000 Data Time: 0.9354 Batch Time: 2.4331
# 2024-06-25 19:46:25,864 - INFO - TRAIN Epoch: 41 Step: 9/18 Loss: 0.4236 Accuracy: 0.8092 AUC: 0.0000 Data Time: 0.9631 Batch Time: 2.4893
# 2024-06-25 19:46:28,390 - INFO - TRAIN Epoch: 41 Step: 10/18 Loss: 0.4300 Accuracy: 0.8061 AUC: 0.0000 Data Time: 0.9780 Batch Time: 2.4922
# 2024-06-25 19:46:30,837 - INFO - TRAIN Epoch: 41 Step: 11/18 Loss: 0.4296 Accuracy: 0.8069 AUC: 0.0000 Data Time: 0.9637 Batch Time: 2.4883
# 2024-06-25 19:46:33,442 - INFO - TRAIN Epoch: 41 Step: 12/18 Loss: 0.4286 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9543 Batch Time: 2.4970
# 2024-06-25 19:46:36,031 - INFO - TRAIN Epoch: 41 Step: 13/18 Loss: 0.4276 Accuracy: 0.8101 AUC: 0.0000 Data Time: 0.9727 Batch Time: 2.5034
# 2024-06-25 19:46:38,795 - INFO - TRAIN Epoch: 41 Step: 14/18 Loss: 0.4322 Accuracy: 0.8061 AUC: 0.0000 Data Time: 0.9908 Batch Time: 2.5206
# 2024-06-25 19:46:41,444 - INFO - TRAIN Epoch: 41 Step: 15/18 Loss: 0.4301 Accuracy: 0.8068 AUC: 0.0000 Data Time: 0.9964 Batch Time: 2.5285
# 2024-06-25 19:46:44,259 - INFO - TRAIN Epoch: 41 Step: 16/18 Loss: 0.4346 Accuracy: 0.8049 AUC: 0.0000 Data Time: 1.0058 Batch Time: 2.5452
# 2024-06-25 19:46:44,843 - INFO - TRAIN Epoch: 41 Step: 17/18 Loss: 0.4350 Accuracy: 0.8057 AUC: 0.0000 Data Time: 0.9679 Batch Time: 2.4361
# 2024-06-25 19:46:44,847 - INFO - AUC Score: 0.7630
# 2024-06-25 19:46:47,099 - INFO - VAL Epoch: 41 Step: 0/5 Loss: 0.4502 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.7858 Batch Time: 2.2501
# 2024-06-25 19:46:49,396 - INFO - VAL Epoch: 41 Step: 1/5 Loss: 0.4217 Accuracy: 0.8250 AUC: 0.0000 Data Time: 0.9915 Batch Time: 2.2729
# 2024-06-25 19:46:51,822 - INFO - VAL Epoch: 41 Step: 2/5 Loss: 0.4142 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.0350 Batch Time: 2.3233
# 2024-06-25 19:46:54,705 - INFO - VAL Epoch: 41 Step: 3/5 Loss: 0.4366 Accuracy: 0.8187 AUC: 0.0000 Data Time: 1.0757 Batch Time: 2.4629
# 2024-06-25 19:46:55,391 - INFO - VAL Epoch: 41 Step: 4/5 Loss: 0.4525 Accuracy: 0.8112 AUC: 0.0000 Data Time: 0.9392 Batch Time: 2.1072
# 2024-06-25 19:46:55,395 - INFO - AUC Score: 0.7141
# 2024-06-25 19:46:55,396 - INFO - New best model at epoch: 42
# 2024-06-25 19:46:55,665 - INFO - Starting Epoch: 43
# 2024-06-25 19:46:57,319 - INFO - TRAIN Epoch: 42 Step: 0/18 Loss: 0.4582 Accuracy: 0.8000 AUC: 0.0000 Data Time: 0.7857 Batch Time: 1.6511
# 2024-06-25 19:46:59,682 - INFO - TRAIN Epoch: 42 Step: 1/18 Loss: 0.4226 Accuracy: 0.8125 AUC: 0.0000 Data Time: 0.7723 Batch Time: 2.0057
# 2024-06-25 19:47:02,174 - INFO - TRAIN Epoch: 42 Step: 2/18 Loss: 0.4167 Accuracy: 0.8139 AUC: 0.0000 Data Time: 0.9121 Batch Time: 2.1669
# 2024-06-25 19:47:04,321 - INFO - TRAIN Epoch: 42 Step: 3/18 Loss: 0.4295 Accuracy: 0.8063 AUC: 0.0000 Data Time: 0.9695 Batch Time: 2.1617
# 2024-06-25 19:47:06,713 - INFO - TRAIN Epoch: 42 Step: 4/18 Loss: 0.4287 Accuracy: 0.8117 AUC: 0.0000 Data Time: 0.9961 Batch Time: 2.2071
# 2024-06-25 19:47:08,886 - INFO - TRAIN Epoch: 42 Step: 5/18 Loss: 0.4389 Accuracy: 0.8028 AUC: 0.0000 Data Time: 1.0086 Batch Time: 2.2012
# 2024-06-25 19:47:11,111 - INFO - TRAIN Epoch: 42 Step: 6/18 Loss: 0.4414 Accuracy: 0.7988 AUC: 0.0000 Data Time: 0.9774 Batch Time: 2.2043
# 2024-06-25 19:47:13,414 - INFO - TRAIN Epoch: 42 Step: 7/18 Loss: 0.4492 Accuracy: 0.7937 AUC: 0.0000 Data Time: 0.9985 Batch Time: 2.2163
# 2024-06-25 19:47:15,985 - INFO - TRAIN Epoch: 42 Step: 8/18 Loss: 0.4458 Accuracy: 0.7935 AUC: 0.0000 Data Time: 1.0259 Batch Time: 2.2554
# 2024-06-25 19:47:18,696 - INFO - TRAIN Epoch: 42 Step: 9/18 Loss: 0.4445 Accuracy: 0.7958 AUC: 0.0000 Data Time: 1.0478 Batch Time: 2.3008
# 2024-06-25 19:47:21,473 - INFO - TRAIN Epoch: 42 Step: 10/18 Loss: 0.4391 Accuracy: 0.8008 AUC: 0.0000 Data Time: 1.0670 Batch Time: 2.3438
# 2024-06-25 19:47:24,413 - INFO - TRAIN Epoch: 42 Step: 11/18 Loss: 0.4359 Accuracy: 0.8035 AUC: 0.0000 Data Time: 1.0503 Batch Time: 2.3933
# 2024-06-25 19:47:27,361 - INFO - TRAIN Epoch: 42 Step: 12/18 Loss: 0.4355 Accuracy: 0.8038 AUC: 0.0000 Data Time: 1.0361 Batch Time: 2.4358
# 2024-06-25 19:47:30,639 - INFO - TRAIN Epoch: 42 Step: 13/18 Loss: 0.4351 Accuracy: 0.8060 AUC: 0.0000 Data Time: 1.0523 Batch Time: 2.4958
# 2024-06-25 19:47:33,927 - INFO - TRAIN Epoch: 42 Step: 14/18 Loss: 0.4352 Accuracy: 0.8061 AUC: 0.0000 Data Time: 1.0666 Batch Time: 2.5485
# 2024-06-25 19:47:36,586 - INFO - TRAIN Epoch: 42 Step: 15/18 Loss: 0.4356 Accuracy: 0.8073 AUC: 0.0000 Data Time: 1.0561 Batch Time: 2.5553
# 2024-06-25 19:47:38,500 - INFO - TRAIN Epoch: 42 Step: 16/18 Loss: 0.4347 Accuracy: 0.8074 AUC: 0.0000 Data Time: 1.0495 Batch Time: 2.5174
# 2024-06-25 19:47:39,448 - INFO - TRAIN Epoch: 42 Step: 17/18 Loss: 0.4343 Accuracy: 0.8086 AUC: 0.0000 Data Time: 1.0088 Batch Time: 2.4301
# 2024-06-25 19:47:39,454 - INFO - AUC Score: 0.7654
# 2024-06-25 19:47:42,016 - INFO - VAL Epoch: 42 Step: 0/5 Loss: 0.4487 Accuracy: 0.8083 AUC: 0.0000 Data Time: 0.9732 Batch Time: 2.5601
# 2024-06-25 19:47:44,092 - INFO - VAL Epoch: 42 Step: 1/5 Loss: 0.4209 Accuracy: 0.8250 AUC: 0.0000 Data Time: 0.9475 Batch Time: 2.3164
# 2024-06-25 19:47:45,805 - INFO - VAL Epoch: 42 Step: 2/5 Loss: 0.4132 Accuracy: 0.8333 AUC: 0.0000 Data Time: 0.9052 Batch Time: 2.1146
# 2024-06-25 19:47:48,218 - INFO - VAL Epoch: 42 Step: 3/5 Loss: 0.4354 Accuracy: 0.8187 AUC: 0.0000 Data Time: 0.9470 Batch Time: 2.1880
# 2024-06-25 19:47:48,888 - INFO - VAL Epoch: 42 Step: 4/5 Loss: 0.4511 Accuracy: 0.8112 AUC: 0.0000 Data Time: 0.8331 Batch Time: 1.8841
# 2024-06-25 19:47:48,893 - INFO - AUC Score: 0.7177
# 2024-06-25 19:47:48,896 - INFO - New best model at epoch: 43
# 2024-06-25 19:47:49,115 - INFO - Starting Epoch: 44
# 2024-06-25 19:47:50,913 - INFO - TRAIN Epoch: 43 Step: 0/18 Loss: 0.4464 Accuracy: 0.8000 AUC: 0.0000 Data Time: 0.9007 Batch Time: 1.7933
# 2024-06-25 19:47:53,098 - INFO - TRAIN Epoch: 43 Step: 1/18 Loss: 0.4415 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.0559 Batch Time: 1.9876
# 2024-06-25 19:47:55,451 - INFO - TRAIN Epoch: 43 Step: 2/18 Loss: 0.4498 Accuracy: 0.7833 AUC: 0.0000 Data Time: 1.0815 Batch Time: 2.1081
# 2024-06-25 19:47:57,809 - INFO - TRAIN Epoch: 43 Step: 3/18 Loss: 0.4617 Accuracy: 0.7854 AUC: 0.0000 Data Time: 1.0463 Batch Time: 2.1702
# 2024-06-25 19:48:00,721 - INFO - TRAIN Epoch: 43 Step: 4/18 Loss: 0.4584 Accuracy: 0.7900 AUC: 0.0000 Data Time: 1.0121 Batch Time: 2.3182
# 2024-06-25 19:48:03,659 - INFO - TRAIN Epoch: 43 Step: 5/18 Loss: 0.4656 Accuracy: 0.7847 AUC: 0.0000 Data Time: 0.9881 Batch Time: 2.4213
# 2024-06-25 19:48:06,313 - INFO - TRAIN Epoch: 43 Step: 6/18 Loss: 0.4639 Accuracy: 0.7869 AUC: 0.0000 Data Time: 0.9758 Batch Time: 2.4541
# 2024-06-25 19:48:09,021 - INFO - TRAIN Epoch: 43 Step: 7/18 Loss: 0.4532 Accuracy: 0.7948 AUC: 0.0000 Data Time: 0.9673 Batch Time: 2.4857
# 2024-06-25 19:48:11,795 - INFO - TRAIN Epoch: 43 Step: 8/18 Loss: 0.4504 Accuracy: 0.7963 AUC: 0.0000 Data Time: 0.9598 Batch Time: 2.5176
# 2024-06-25 19:48:15,183 - INFO - TRAIN Epoch: 43 Step: 9/18 Loss: 0.4499 Accuracy: 0.7950 AUC: 0.0000 Data Time: 0.9985 Batch Time: 2.6043

# %%
trainer.auc_scores
