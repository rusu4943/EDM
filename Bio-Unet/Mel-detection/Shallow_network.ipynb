# %%
import sys
sys.executable
# Out:
# '/home/rs37890/.conda/envs/UDA/bin/python'

# %%
import os
import re
import sys
import time
import copy
import h5py
import random
import logging
import argparse
import numpy as np
import pandas as pd
from PIL import Image

# %%
import torch
import torch.nn as nn

# %%
from torchvision import *
import torchvision.models

# %%
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # args

# %%
parser = argparse.ArgumentParser()

parser.add_argument('--report-freq', type=int, default=1, help='logging frequency')
parser.add_argument('--tune-mode', type=str, default='fine-tune', choices=['fine-tune', 'feature-extract'], help='tuning mode' )
parser.add_argument('--backbone', type=str, default='resnet50', choices=['resnet50', 'vgg19', 'inception_v3'], 
                    help='backbone architecture' )
parser.add_argument('--cls-type', type=str, default='single', choices=['single', 
                   'double', 'double-bn', 'double-dropout'], help='classifier architecture' )
parser.add_argument('--hidden-dim', type=int, default=512, help='hidden dimension of classifier' )
parser.add_argument('--record-root-dir', type=str, default='./record-data', help='record data root dir' )
parser.add_argument('--exp', type=str, default='default_exp', help='name of experiment' )
parser.add_argument('--batch-size', type=int, default=8, help='batch size' )
parser.add_argument('--num-workers', type=int, default=0, help='number of processes working on cpu.')
parser.add_argument('--num-classes', type=int, default=5, help='number of classes')
parser.add_argument('--num-epochs', type=int, default=20,  help='number of epochs.')
parser.add_argument( '--num-steps', type=int, default=-1, help='number of steps per epoch. '+ '-1 means use entire data' )
parser.add_argument('--learn-rate', type=float, default=1e-3, help='learning rate for gradient descent')
parser.add_argument('--weight-decay', type=float, default=1e-3, help='weight decay for optimization')
parser.add_argument('--resume', action='store_true', help='resume experiment <exp> from last checkpoint' )
parser.add_argument('--input-dir', type=str, default= r'../h5py/', help='data root dir' )
parser.add_argument('--save-name', type=str, default='model.pt', help='saved model name' )

args, unknown =  parser.parse_known_args()

# %%
# device
DEVICE = 'cuda:0' if torch.cuda.is_available() else 'cpu'
args.device = DEVICE
args.gpu_ids = [0]

# %%
args.num_epochs = 100
args.learn_rate = 1e-4
args.weight_decay = 1e-4 
args.batch_size = 120
args.num_classes = 1
args.seed = 1111

# %%
args.root = '/scratch/rs37890/CARC/Explainable-NN-model'
args.sub_root = '/Fold1_Bio-Unet-stage1'
args.checkpoint_root = '/F(CLR) + F(Res) + F(Seg)'
args.shallow_network_folder = '/Mel-detection'

args.csv_h5_dir = args.root + '/Data'

args.record_dir = args.root  + args.sub_root + args.shallow_network_folder + '/record_dir'
args.save_name = 'Resnet50'

# %% [markdown]
# # dataset

# %%
def get_transform(split):
    
    img_size = ( 512, 512 )
    Normal_transform = transforms.Compose([ transforms.Resize( img_size ),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])],
                                         )

    return Normal_transform

# %%
class SkinDataset( torch.utils.data.Dataset ):

    def __init__( self, h5_file_path, transform, split, args):
        self.h5_file_path = h5_file_path
        self.h5_file = None
        self.transform = transform
        self.split = split
        self.img_id_to_h5idx = self.build_img_id_to_h5idx()
        self.num_imgs = self.get_num_imgs() 

        self.args = args

        self.ATTR_TO_INDEX = { 'globules': 0,
                               'milia_like_cyst': 1,
                               'negative_network': 2,
                               'pigment_network': 3,
                               'streaks': 4,
                             }

    def get_num_imgs( self ):
        with h5py.File( self.h5_file_path, 'r' ) as f:
            return len( f['image_ids'] )

    def build_img_id_to_h5idx( self ):
        with h5py.File( self.h5_file_path, 'r' ) as f:
            
            img_ids = f['image_ids']
            img_id_to_h5idx = { img_id : idx for idx, img_id in enumerate( img_ids ) }
            
            return img_id_to_h5idx

    def __len__( self ):
        return self.get_num_imgs()

    def __getitem__( self, idx ):
        # import pdb; pdb.set_trace()
        if not self.h5_file:
            self.h5_file = h5py.File( self.h5_file_path, 'r' )
            
        img_id = self.h5_file['image_ids'][idx]
        img = self.h5_file['images'][idx]
        img = img.transpose([1, 2, 0])

        assert img.shape == (512, 512, 3)

        img = Image.fromarray( np.uint8(img) )
        
        if self.split == 'unsup':
            img1 = self.transform( img )
            img2 = self.transform( img )
            return img_id, img1, img2
        
        else:
            masks = self.h5_file['masks'][idx]
            labels = self.h5_file['labels'][idx].astype(np.float64)
            img = self.transform( img )

            # labels[0] globus
            # labels[1] milia_like_cyst
            # labels[2] negative
            # labels[3] pigment
            # labels[4] streaks
            # labels[5] melanoma
            
            index = 5

            assert masks.shape == (5, 512, 512)
            assert np.expand_dims(labels[index], axis=0).shape == (1,)
            
            return img_id, img, np.expand_dims(labels[index], axis=0), masks

# %%
def get_dataloader( args ):
    
    dataloader = {}
    splits = [ 'train', 'val' ]
    
    for split in splits:
        
        h5_file_path = os.path.join( args.csv_h5_dir, f'{split}.h5' )
        transform = get_transform(split)

        bsz = args.batch_size
        
        dataset = SkinDataset( h5_file_path, transform, split, args)
        loader = torch.utils.data.DataLoader( dataset = dataset,
                                              batch_size = bsz,
                                              shuffle = True if split != 'val' else False,
                                              num_workers = args.num_workers,
                                              drop_last = False,
                                            )
        
        dataloader[ split ] = loader
        
    return dataloader

# %% [markdown]
# # Load model

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.base_model = torchvision.models.resnet50(pretrained=True)
        self.base_layers = list(self.base_model.children())
        
        self.layer0 = nn.Sequential(*self.base_layers[:3])
        self.layer1 = nn.Sequential(*self.base_layers[3:5]) # size=(N, 256, x.H/4, x.W/4)
        self.layer2 = self.base_layers[5]  # size=(N, 512, x.H/8, x.W/8)
        self.layer3 = self.base_layers[6]  # size=(N, 1024, x.H/16, x.W/16)
        self.layer4 = self.base_layers[7]  # size=(N, 2048, x.H/32, x.W/32)
        self.Avgpooling = nn.Sequential(self.base_layers[8])
        
        self.mlp = torch.nn.Sequential( torch.nn.Linear(2048,1), )# only one linear layer on top
        
    def forward(self, X):
        layer0 = self.layer0(X)  # layer0:  torch.Size([1, 64, 256, 256])
        layer1 = self.layer1(layer0) # layer1:  torch.Size([1, 256, 128, 128])
        layer2 = self.layer2(layer1) # layer2:  torch.Size([1, 512, 64, 64])
        layer3 = self.layer3(layer2) # layer3:  torch.Size([1, 1024, 32, 32])
        layer4 = self.layer4(layer3) # layer4:  torch.Size([1, 2048, 16, 16])
        out    = self.Avgpooling(layer4)
        
        out1 = torch.squeeze(out) 
        if X.size(0) == 1: # torch.Size([1, 2048, 1, 1]) => torch.Size([2048])
            out1 = torch.unsqueeze(out1, 0) # torch.Size([1, 2048])
        out = self.mlp(out1)
        return out1, out

# %% [markdown]
# # Streaks

# %%
net = Model()
streaks_net = torch.nn.DataParallel(net)
streaks_net = streaks_net.module.to( DEVICE )
# Out:
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/streaks"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
streaks_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
streaks_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/streaks/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(streaks_Model_path)
streaks_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Pigment

# %%
net = Model()
pigment_net = torch.nn.DataParallel(net)
pigment_net = pigment_net.to( DEVICE )
pigment_net = pigment_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/pigment"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
pigment_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
pigment_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/pigment/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(pigment_Model_path)
pigment_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Negative

# %%
net = Model()
negative_net = torch.nn.DataParallel(net)
negative_net = negative_net.to( DEVICE )
negative_net = negative_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/negative"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
negative_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
negative_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/negative/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(negative_Model_path)
negative_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Milia

# %%
net = Model()
milia_net = torch.nn.DataParallel(net)
milia_net = milia_net.to( DEVICE )
milia_net = milia_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/milia_like_cyst"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
milia_like_cyst_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
milia_like_cyst_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/milia_like_cyst/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(milia_like_cyst_Model_path)
milia_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Globules

# %%
net = Model()
globules_net = torch.nn.DataParallel(net)
globules_net = globules_net.to( DEVICE )
globules_net = globules_net.module

# %%
#Model path
Main_folder = args.root  + args.sub_root + args.checkpoint_root
attribute = "/globules"
model_name = '/SIMCLR+Resnet50+Unet_model.pt'
best_model_name = '/SIMCLR+Resnet50+Unet_best_model.pt'
globules_Model_path = Main_folder + attribute + '/record_dir' + best_model_name
globules_Model_path
# Out:
# '/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/F(CLR) + F(Res) + F(Seg)/globules/record_dir/SIMCLR+Resnet50+Unet_best_model.pt'

# %%
checkpoint = torch.load(globules_Model_path)
globules_net.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # softmax

# %%
class LogisticRegression(torch.nn.Module): 
    def __init__(self, input_dim = 10240, output_dim = 1): 
        super(LogisticRegression, self).__init__() 
        #self.linear = torch.nn.Linear(input_dim, output_dim) 
        self.linear1 = torch.nn.Linear(input_dim, 2048) 
        self.linear2 = torch.nn.Linear(2048, 512) 
        self.linear3 = torch.nn.Linear(512, output_dim) 
        
    def forward(self, x): 
        #outputs = torch.sigmoid(self.linear(x)) 
        output1 = self.linear1(x)
        output2 = self.linear2(output1)
        output3 = self.linear3(output2)
        
        return nn.Sigmoid()(output3).type(torch.float64)

# %% [markdown]
# # Trainer

# %%
class AverageMeter:
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
class Trainer:
    def __init__(self, 
                 model, 
                 globules_net , milia_net, negative_net, pigment_net, streaks_net,
                 dataloader, 
                 args,
                ):
        
        self.model = model.to(args.device)
        self.dataloader = dataloader
        self.args = args
        self.best_loss = np.inf
        self.best_epoch = 0
        self.best_model = None
        self.current_epoch = 0

        self.globules_net = globules_net.to(args.device)
        self.milia_net = milia_net.to(args.device)
        self.negative_net = negative_net.to(args.device)
        self.pigment_net = pigment_net.to(args.device)
        self.streaks_net = streaks_net.to(args.device)


        self.globules_net.eval()
        self.milia_net.eval()
        self.negative_net.eval()
        self.pigment_net.eval()
        self.streaks_net.eval()
        

        self.criterion = nn.BCELoss()
        self.optimizer = torch.optim.Adam( params = self.model.parameters(),
                                           lr = self.args.learn_rate,
                                           weight_decay = self.args.weight_decay,
                                         )

        self.logger = self.setup_logger()
        self.setup_experiment()
        self.set_random_seeds()

    def setup_logger(self):
        log_file = 'log.txt'
        if os.path.exists(log_file):
            os.remove(log_file)  # Remove the existing log file if it exists
        
        logger = logging.getLogger('Trainer')
        logger.setLevel(logging.INFO)
    
        # File Handler for log files
        fh = logging.FileHandler(log_file)
        fh.setLevel(logging.INFO)
        file_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        fh.setFormatter(file_formatter)
        logger.addHandler(fh)
    
        # Stream Handler for console output
        ch = logging.StreamHandler()
        ch.setLevel(logging.INFO)
        console_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        ch.setFormatter(console_formatter)
        logger.addHandler(ch)
    
        return logger

    def setup_experiment(self):
        self.name = self.args.exp
        self.exp_dir = os.path.join(self.args.record_root_dir, self.name)
        self.logger.info(f'seed is: {self.args.seed}')
        self.logger.info(f'args: {self.args}')

    def set_random_seeds(self):
        seed = random.randint(0, 100000)
        torch.manual_seed(seed)
        random.seed(seed)
        np.random.seed(seed)
        self.args.seed = seed

    def get_accuracy(self, pred, labels):
        predicted_labels = (pred > 0.5).int()
        correct_predictions = (predicted_labels == labels).sum().item()
        total_predictions = labels.size(0)
        accuracy = correct_predictions / total_predictions
        return accuracy

    def concate_5120(self, imgs):
        # This function should include model evaluation calls
        # Assuming these models are attributes of the class
        with torch.no_grad():
            pred1, _ = self.globules_net(imgs)
            pred2, _ = self.negative_net(imgs)
            pred3, _ = self.milia_net(imgs)
            pred4, _ = self.pigment_net(imgs)
            pred5, _ = self.streaks_net(imgs)
            return torch.cat((pred1, pred2, pred3, pred4, pred5), 1)

    def train_or_val(self, mode='train'):
        
        assert mode in ['train', 'val'], "Mode must be 'train' or 'val'"
        dataloader = self.dataloader[mode]
        num_steps = len(dataloader)
        self.model.train() if mode == 'train' else self.model.eval()

        loss_meter = AverageMeter()
        acc_meter = AverageMeter()
        data_time_meter = AverageMeter()
        batch_time_meter = AverageMeter()
        all_preds = []
        all_labels = []

        start = time.time()
        for batch_id, (img_ids, imgs, labels, masks) in enumerate(dataloader):
            data_time = time.time() - start
            if batch_id >= num_steps: break

            imgs, labels = imgs.to(self.args.device), labels.to(self.args.device)
            
            if mode == 'train':
                self.optimizer.zero_grad()

            concate_input = self.concate_5120(imgs)
            pred = self.model(concate_input)

            
            loss = self.criterion(pred, labels)
            if mode == 'train':
                loss.backward()
                self.optimizer.step()

            loss_meter.update(loss.item(), len(imgs))
            acc = self.get_accuracy( pred.detach().cpu(), labels.cpu() )
            acc_meter.update(acc, len(imgs))
            batch_time = time.time() - start

            data_time_meter.update(data_time)
            batch_time_meter.update(batch_time)
            all_preds.append(pred.detach().cpu())
            all_labels.append(labels.cpu())

            # if (batch_id+1) % self.args.report_freq == 0:
            self.log_epoch_stats(mode.upper(), batch_id, num_steps, loss_meter.avg, acc_meter.avg, 0, data_time_meter.avg, batch_time_meter.avg)

            start = time.time()

        all_labels = torch.cat(all_labels, dim=0)
        all_preds = torch.cat(all_preds, dim=0)
        self.auc_scores = roc_auc_score( np.array(all_labels), np.array(all_preds), average=None)
        self.log_auc_scores(self.auc_scores)

        return loss_meter.avg, acc_meter.avg, self.auc_scores.mean()

    def log_epoch_stats(self, phase, batch_id, num_steps, avg_loss, avg_acc, mean_auc, avg_data_time, avg_batch_time):
        self.logger.info(f'{phase} Epoch: {self.current_epoch} Step: {batch_id}/{num_steps} Loss: {avg_loss:.4f} Accuracy: {avg_acc:.4f} AUC: {mean_auc:.4f} Data Time: {avg_data_time:.4f} Batch Time: {avg_batch_time:.4f}')

    def log_auc_scores(self, auc_scores):
        if isinstance(auc_scores, np.ndarray):
            for i, score in enumerate(auc_scores):
                self.logger.info(f'AUC Score {i}: {score:.4f}')
        else:
            self.logger.info(f'AUC Score: {auc_scores:.4f}')

    def save_model(self, save_path):
        torch.save(self.model.state_dict(), save_path)

    def train(self):
        for epoch in range(self.current_epoch, self.args.num_epochs):
            self.current_epoch = epoch
            self.logger.info(f'Starting Epoch: {epoch + 1}')
            train_loss, train_acc, train_auc = self.train_or_val('train')
            val_loss, val_acc, val_auc = self.train_or_val('val')

            if val_loss < self.best_loss:
                self.best_loss = val_loss
                self.best_model = copy.deepcopy(self.model)
                self.best_epoch = epoch + 1
                self.logger.info(f'New best model at epoch: {epoch + 1}')

                save_path = os.path.join( self.args.record_dir, self.args.save_name + '_best.pt')
                self.save_model(save_path)

            save_path = os.path.join( self.args.record_dir, self.args.save_name + '.pt')
            self.save_model(save_path)

# %%
dataloaders = get_dataloader( args )

# %%
trainer = Trainer(LogisticRegression(), 
                  globules_net , milia_net, negative_net, pigment_net, streaks_net,
                  dataloaders, 
                  args,
                 )
# Out:
# 2024-06-25 16:11:24,798 - INFO - seed is: 1111
# 2024-06-25 16:11:24,800 - INFO - args: Namespace(report_freq=1, tune_mode='fine-tune', backbone='resnet50', cls_type='single', hidden_dim=512, record_root_dir='./record-data', exp='default_exp', batch_size=120, num_workers=0, num_classes=1, num_epochs=100, num_steps=-1, learn_rate=0.0001, weight_decay=0.0001, resume=False, input_dir='../h5py/', save_name='Resnet50', device='cuda:0', gpu_ids=[0], seed=1111, root='/scratch/rs37890/CARC/Explainable-NN-model', sub_root='/Fold1_Bio-Unet-stage1', checkpoint_root='/F(CLR) + F(Res) + F(Seg)', shallow_network_folder='/Mel-detection', csv_h5_dir='/scratch/rs37890/CARC/Explainable-NN-model/Data', record_dir='/scratch/rs37890/CARC/Explainable-NN-model/Fold1_Bio-Unet-stage1/Mel-detection/record_dir')

# %%
trainer.train()
# Out:
# 2024-06-25 16:11:24,805 - INFO - Starting Epoch: 1
# /home/rs37890/.conda/envs/UDA/lib/python3.9/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1712608885084/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:84.)
#   return F.conv2d(input, weight, bias, self.stride,
# 2024-06-25 16:11:27,475 - INFO - TRAIN Epoch: 0 Step: 0/18 Loss: 0.6948 Accuracy: 0.5167 AUC: 0.0000 Data Time: 1.5099 Batch Time: 2.6681
# 2024-06-25 16:11:29,709 - INFO - TRAIN Epoch: 0 Step: 1/18 Loss: 1.0731 Accuracy: 0.6167 AUC: 0.0000 Data Time: 1.3760 Batch Time: 2.4508
# 2024-06-25 16:11:32,431 - INFO - TRAIN Epoch: 0 Step: 2/18 Loss: 1.0893 Accuracy: 0.6528 AUC: 0.0000 Data Time: 1.4428 Batch Time: 2.5407
# 2024-06-25 16:11:35,022 - INFO - TRAIN Epoch: 0 Step: 3/18 Loss: 0.9492 Accuracy: 0.6917 AUC: 0.0000 Data Time: 1.4262 Batch Time: 2.5530
# 2024-06-25 16:11:37,487 - INFO - TRAIN Epoch: 0 Step: 4/18 Loss: 0.8848 Accuracy: 0.6967 AUC: 0.0000 Data Time: 1.4331 Batch Time: 2.5351
# 2024-06-25 16:11:40,355 - INFO - TRAIN Epoch: 0 Step: 5/18 Loss: 0.8550 Accuracy: 0.6569 AUC: 0.0000 Data Time: 1.5001 Batch Time: 2.5904
# 2024-06-25 16:11:43,283 - INFO - TRAIN Epoch: 0 Step: 6/18 Loss: 0.8120 Accuracy: 0.6750 AUC: 0.0000 Data Time: 1.5497 Batch Time: 2.6383
# 2024-06-25 16:11:45,935 - INFO - TRAIN Epoch: 0 Step: 7/18 Loss: 0.7606 Accuracy: 0.6969 AUC: 0.0000 Data Time: 1.5609 Batch Time: 2.6399
# 2024-06-25 16:11:49,544 - INFO - TRAIN Epoch: 0 Step: 8/18 Loss: 0.7357 Accuracy: 0.7093 AUC: 0.0000 Data Time: 1.6732 Batch Time: 2.7475
# 2024-06-25 16:11:52,630 - INFO - TRAIN Epoch: 0 Step: 9/18 Loss: 0.7264 Accuracy: 0.7167 AUC: 0.0000 Data Time: 1.7049 Batch Time: 2.7811
# 2024-06-25 16:11:56,555 - INFO - TRAIN Epoch: 0 Step: 10/18 Loss: 0.7157 Accuracy: 0.7235 AUC: 0.0000 Data Time: 1.8062 Batch Time: 2.8850
# 2024-06-25 16:11:59,538 - INFO - TRAIN Epoch: 0 Step: 11/18 Loss: 0.6903 Accuracy: 0.7340 AUC: 0.0000 Data Time: 1.8149 Batch Time: 2.8930
# 2024-06-25 16:12:02,759 - INFO - TRAIN Epoch: 0 Step: 12/18 Loss: 0.6717 Accuracy: 0.7404 AUC: 0.0000 Data Time: 1.8412 Batch Time: 2.9181
# 2024-06-25 16:12:06,281 - INFO - TRAIN Epoch: 0 Step: 13/18 Loss: 0.6602 Accuracy: 0.7429 AUC: 0.0000 Data Time: 1.8896 Batch Time: 2.9612
# 2024-06-25 16:12:09,912 - INFO - TRAIN Epoch: 0 Step: 14/18 Loss: 0.6454 Accuracy: 0.7483 AUC: 0.0000 Data Time: 1.9382 Batch Time: 3.0058
# 2024-06-25 16:12:12,813 - INFO - TRAIN Epoch: 0 Step: 15/18 Loss: 0.6347 Accuracy: 0.7526 AUC: 0.0000 Data Time: 1.9330 Batch Time: 2.9991
# 2024-06-25 16:12:15,736 - INFO - TRAIN Epoch: 0 Step: 16/18 Loss: 0.6266 Accuracy: 0.7559 AUC: 0.0000 Data Time: 1.9312 Batch Time: 2.9946
# 2024-06-25 16:12:16,838 - INFO - TRAIN Epoch: 0 Step: 17/18 Loss: 0.6239 Accuracy: 0.7565 AUC: 0.0000 Data Time: 1.8668 Batch Time: 2.8893
# 2024-06-25 16:12:16,841 - INFO - AUC Score: 0.5110
# 2024-06-25 16:12:19,183 - INFO - VAL Epoch: 0 Step: 0/5 Loss: 0.4791 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.3218 Batch Time: 2.3408
# 2024-06-25 16:12:21,712 - INFO - VAL Epoch: 0 Step: 1/5 Loss: 0.4526 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.4174 Batch Time: 2.4345
# 2024-06-25 16:12:24,175 - INFO - VAL Epoch: 0 Step: 2/5 Loss: 0.4583 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.4339 Batch Time: 2.4435
# 2024-06-25 16:12:26,425 - INFO - VAL Epoch: 0 Step: 3/5 Loss: 0.4713 Accuracy: 0.8125 AUC: 0.0000 Data Time: 1.3846 Batch Time: 2.3948
# 2024-06-25 16:12:27,211 - INFO - VAL Epoch: 0 Step: 4/5 Loss: 0.4832 Accuracy: 0.8035 AUC: 0.0000 Data Time: 1.1973 Batch Time: 2.0727
# 2024-06-25 16:12:27,214 - INFO - AUC Score: 0.6889
# 2024-06-25 16:12:27,215 - INFO - New best model at epoch: 1
# 2024-06-25 16:12:27,397 - INFO - Starting Epoch: 2
# 2024-06-25 16:12:30,797 - INFO - TRAIN Epoch: 1 Step: 0/18 Loss: 0.4689 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.3847 Batch Time: 3.3984
# 2024-06-25 16:12:34,002 - INFO - TRAIN Epoch: 1 Step: 1/18 Loss: 0.4825 Accuracy: 0.7958 AUC: 0.0000 Data Time: 2.2747 Batch Time: 3.3010
# 2024-06-25 16:12:37,079 - INFO - TRAIN Epoch: 1 Step: 2/18 Loss: 0.5046 Accuracy: 0.7667 AUC: 0.0000 Data Time: 2.1950 Batch Time: 3.2256
# 2024-06-25 16:12:40,685 - INFO - TRAIN Epoch: 1 Step: 3/18 Loss: 0.4655 Accuracy: 0.7937 AUC: 0.0000 Data Time: 2.2801 Batch Time: 3.3205
# 2024-06-25 16:12:44,334 - INFO - TRAIN Epoch: 1 Step: 4/18 Loss: 0.4659 Accuracy: 0.7917 AUC: 0.0000 Data Time: 2.3493 Batch Time: 3.3860
# 2024-06-25 16:12:47,708 - INFO - TRAIN Epoch: 1 Step: 5/18 Loss: 0.4589 Accuracy: 0.7944 AUC: 0.0000 Data Time: 2.3428 Batch Time: 3.3838
# 2024-06-25 16:12:51,927 - INFO - TRAIN Epoch: 1 Step: 6/18 Loss: 0.4495 Accuracy: 0.8000 AUC: 0.0000 Data Time: 2.4513 Batch Time: 3.5029
# 2024-06-25 16:12:55,706 - INFO - TRAIN Epoch: 1 Step: 7/18 Loss: 0.4546 Accuracy: 0.7979 AUC: 0.0000 Data Time: 2.4886 Batch Time: 3.5373
# 2024-06-25 16:12:59,235 - INFO - TRAIN Epoch: 1 Step: 8/18 Loss: 0.4565 Accuracy: 0.7944 AUC: 0.0000 Data Time: 2.4819 Batch Time: 3.5363
# 2024-06-25 16:13:02,527 - INFO - TRAIN Epoch: 1 Step: 9/18 Loss: 0.4539 Accuracy: 0.7958 AUC: 0.0000 Data Time: 2.4448 Batch Time: 3.5118
# 2024-06-25 16:13:06,414 - INFO - TRAIN Epoch: 1 Step: 10/18 Loss: 0.4502 Accuracy: 0.7977 AUC: 0.0000 Data Time: 2.4783 Batch Time: 3.5458
# 2024-06-25 16:13:10,129 - INFO - TRAIN Epoch: 1 Step: 11/18 Loss: 0.4494 Accuracy: 0.8014 AUC: 0.0000 Data Time: 2.4967 Batch Time: 3.5599
# 2024-06-25 16:13:13,787 - INFO - TRAIN Epoch: 1 Step: 12/18 Loss: 0.4516 Accuracy: 0.8019 AUC: 0.0000 Data Time: 2.5076 Batch Time: 3.5674
# 2024-06-25 16:13:18,097 - INFO - TRAIN Epoch: 1 Step: 13/18 Loss: 0.4550 Accuracy: 0.8024 AUC: 0.0000 Data Time: 2.5637 Batch Time: 3.6203
# 2024-06-25 16:13:22,175 - INFO - TRAIN Epoch: 1 Step: 14/18 Loss: 0.4546 Accuracy: 0.8028 AUC: 0.0000 Data Time: 2.5978 Batch Time: 3.6508
# 2024-06-25 16:13:25,885 - INFO - TRAIN Epoch: 1 Step: 15/18 Loss: 0.4494 Accuracy: 0.8063 AUC: 0.0000 Data Time: 2.6029 Batch Time: 3.6544
# 2024-06-25 16:13:30,354 - INFO - TRAIN Epoch: 1 Step: 16/18 Loss: 0.4476 Accuracy: 0.8059 AUC: 0.0000 Data Time: 2.6498 Batch Time: 3.7022
# 2024-06-25 16:13:31,879 - INFO - TRAIN Epoch: 1 Step: 17/18 Loss: 0.4451 Accuracy: 0.8076 AUC: 0.0000 Data Time: 2.5704 Batch Time: 3.5811
# 2024-06-25 16:13:31,883 - INFO - AUC Score: 0.7322
# 2024-06-25 16:13:34,202 - INFO - VAL Epoch: 1 Step: 0/5 Loss: 0.4964 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.3137 Batch Time: 2.3167
# 2024-06-25 16:13:36,844 - INFO - VAL Epoch: 1 Step: 1/5 Loss: 0.4372 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.4463 Batch Time: 2.4786
# 2024-06-25 16:13:39,335 - INFO - VAL Epoch: 1 Step: 2/5 Loss: 0.4508 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.4593 Batch Time: 2.4821
# 2024-06-25 16:13:41,819 - INFO - VAL Epoch: 1 Step: 3/5 Loss: 0.4868 Accuracy: 0.8125 AUC: 0.0000 Data Time: 1.4565 Batch Time: 2.4822
# 2024-06-25 16:13:42,401 - INFO - VAL Epoch: 1 Step: 4/5 Loss: 0.5184 Accuracy: 0.8035 AUC: 0.0000 Data Time: 1.2152 Batch Time: 2.1020
# 2024-06-25 16:13:42,404 - INFO - AUC Score: 0.7091
# 2024-06-25 16:13:42,490 - INFO - Starting Epoch: 3
# 2024-06-25 16:13:45,217 - INFO - TRAIN Epoch: 2 Step: 0/18 Loss: 0.4073 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.7027 Batch Time: 2.7258
# 2024-06-25 16:13:48,012 - INFO - TRAIN Epoch: 2 Step: 1/18 Loss: 0.4401 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.7339 Batch Time: 2.7598
# 2024-06-25 16:13:51,205 - INFO - TRAIN Epoch: 2 Step: 2/18 Loss: 0.4258 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.8416 Batch Time: 2.9040
# 2024-06-25 16:13:54,378 - INFO - TRAIN Epoch: 2 Step: 3/18 Loss: 0.4439 Accuracy: 0.8146 AUC: 0.0000 Data Time: 1.9122 Batch Time: 2.9708
# 2024-06-25 16:13:56,975 - INFO - TRAIN Epoch: 2 Step: 4/18 Loss: 0.4390 Accuracy: 0.8100 AUC: 0.0000 Data Time: 1.8391 Batch Time: 2.8943
# 2024-06-25 16:13:59,458 - INFO - TRAIN Epoch: 2 Step: 5/18 Loss: 0.4224 Accuracy: 0.8222 AUC: 0.0000 Data Time: 1.7686 Batch Time: 2.8255
# 2024-06-25 16:14:02,449 - INFO - TRAIN Epoch: 2 Step: 6/18 Loss: 0.4285 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.7949 Batch Time: 2.8490
# 2024-06-25 16:14:04,847 - INFO - TRAIN Epoch: 2 Step: 7/18 Loss: 0.4320 Accuracy: 0.8146 AUC: 0.0000 Data Time: 1.7406 Batch Time: 2.7925
# 2024-06-25 16:14:07,848 - INFO - TRAIN Epoch: 2 Step: 8/18 Loss: 0.4342 Accuracy: 0.8176 AUC: 0.0000 Data Time: 1.7646 Batch Time: 2.8156
# 2024-06-25 16:14:10,346 - INFO - TRAIN Epoch: 2 Step: 9/18 Loss: 0.4337 Accuracy: 0.8183 AUC: 0.0000 Data Time: 1.7334 Batch Time: 2.7836
# 2024-06-25 16:14:12,881 - INFO - TRAIN Epoch: 2 Step: 10/18 Loss: 0.4385 Accuracy: 0.8136 AUC: 0.0000 Data Time: 1.7125 Batch Time: 2.7610
# 2024-06-25 16:14:15,312 - INFO - TRAIN Epoch: 2 Step: 11/18 Loss: 0.4398 Accuracy: 0.8118 AUC: 0.0000 Data Time: 1.6867 Batch Time: 2.7334
# 2024-06-25 16:14:18,172 - INFO - TRAIN Epoch: 2 Step: 12/18 Loss: 0.4363 Accuracy: 0.8147 AUC: 0.0000 Data Time: 1.6961 Batch Time: 2.7430
# 2024-06-25 16:14:20,901 - INFO - TRAIN Epoch: 2 Step: 13/18 Loss: 0.4472 Accuracy: 0.8089 AUC: 0.0000 Data Time: 1.6953 Batch Time: 2.7420
# 2024-06-25 16:14:23,973 - INFO - TRAIN Epoch: 2 Step: 14/18 Loss: 0.4501 Accuracy: 0.8078 AUC: 0.0000 Data Time: 1.7172 Batch Time: 2.7639
# 2024-06-25 16:14:26,864 - INFO - TRAIN Epoch: 2 Step: 15/18 Loss: 0.4407 Accuracy: 0.8130 AUC: 0.0000 Data Time: 1.7224 Batch Time: 2.7717
# 2024-06-25 16:14:30,152 - INFO - TRAIN Epoch: 2 Step: 16/18 Loss: 0.4346 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.7539 Batch Time: 2.8019
# 2024-06-25 16:14:30,935 - INFO - TRAIN Epoch: 2 Step: 17/18 Loss: 0.4347 Accuracy: 0.8158 AUC: 0.0000 Data Time: 1.6830 Batch Time: 2.6897
# 2024-06-25 16:14:30,938 - INFO - AUC Score: 0.7455
# 2024-06-25 16:14:33,184 - INFO - VAL Epoch: 2 Step: 0/5 Loss: 0.4307 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.2161 Batch Time: 2.2428
# 2024-06-25 16:14:35,605 - INFO - VAL Epoch: 2 Step: 1/5 Loss: 0.3924 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.3072 Batch Time: 2.3312
# 2024-06-25 16:14:37,745 - INFO - VAL Epoch: 2 Step: 2/5 Loss: 0.4016 Accuracy: 0.8278 AUC: 0.0000 Data Time: 1.2367 Batch Time: 2.2668
# 2024-06-25 16:14:40,249 - INFO - VAL Epoch: 2 Step: 3/5 Loss: 0.4146 Accuracy: 0.8229 AUC: 0.0000 Data Time: 1.3035 Batch Time: 2.3259
# 2024-06-25 16:14:41,037 - INFO - VAL Epoch: 2 Step: 4/5 Loss: 0.4316 Accuracy: 0.8150 AUC: 0.0000 Data Time: 1.1318 Batch Time: 2.0181
# 2024-06-25 16:14:41,039 - INFO - AUC Score: 0.7583
# 2024-06-25 16:14:41,040 - INFO - New best model at epoch: 3
# 2024-06-25 16:14:41,212 - INFO - Starting Epoch: 4
# 2024-06-25 16:14:43,655 - INFO - TRAIN Epoch: 3 Step: 0/18 Loss: 0.4382 Accuracy: 0.8417 AUC: 0.0000 Data Time: 1.3810 Batch Time: 2.4413
# 2024-06-25 16:14:46,576 - INFO - TRAIN Epoch: 3 Step: 1/18 Loss: 0.4232 Accuracy: 0.8375 AUC: 0.0000 Data Time: 1.6177 Batch Time: 2.6804
# 2024-06-25 16:14:48,893 - INFO - TRAIN Epoch: 3 Step: 2/18 Loss: 0.4244 Accuracy: 0.8361 AUC: 0.0000 Data Time: 1.5064 Batch Time: 2.5589
# 2024-06-25 16:14:51,462 - INFO - TRAIN Epoch: 3 Step: 3/18 Loss: 0.4241 Accuracy: 0.8396 AUC: 0.0000 Data Time: 1.5178 Batch Time: 2.5612
# 2024-06-25 16:14:53,876 - INFO - TRAIN Epoch: 3 Step: 4/18 Loss: 0.4209 Accuracy: 0.8367 AUC: 0.0000 Data Time: 1.4900 Batch Time: 2.5315
# 2024-06-25 16:14:56,746 - INFO - TRAIN Epoch: 3 Step: 5/18 Loss: 0.4250 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.5479 Batch Time: 2.5876
# 2024-06-25 16:14:59,721 - INFO - TRAIN Epoch: 3 Step: 6/18 Loss: 0.4157 Accuracy: 0.8357 AUC: 0.0000 Data Time: 1.6023 Batch Time: 2.6428
# 2024-06-25 16:15:03,776 - INFO - TRAIN Epoch: 3 Step: 7/18 Loss: 0.4240 Accuracy: 0.8271 AUC: 0.0000 Data Time: 1.7755 Batch Time: 2.8192
# 2024-06-25 16:15:07,578 - INFO - TRAIN Epoch: 3 Step: 8/18 Loss: 0.4112 Accuracy: 0.8306 AUC: 0.0000 Data Time: 1.8775 Batch Time: 2.9282
# 2024-06-25 16:15:10,347 - INFO - TRAIN Epoch: 3 Step: 9/18 Loss: 0.4096 Accuracy: 0.8300 AUC: 0.0000 Data Time: 1.8629 Batch Time: 2.9120
# 2024-06-25 16:15:13,381 - INFO - TRAIN Epoch: 3 Step: 10/18 Loss: 0.4053 Accuracy: 0.8364 AUC: 0.0000 Data Time: 1.8786 Batch Time: 2.9229
# 2024-06-25 16:15:16,414 - INFO - TRAIN Epoch: 3 Step: 11/18 Loss: 0.3998 Accuracy: 0.8382 AUC: 0.0000 Data Time: 1.8909 Batch Time: 2.9320
# 2024-06-25 16:15:19,347 - INFO - TRAIN Epoch: 3 Step: 12/18 Loss: 0.3985 Accuracy: 0.8378 AUC: 0.0000 Data Time: 1.8922 Batch Time: 2.9320
# 2024-06-25 16:15:22,374 - INFO - TRAIN Epoch: 3 Step: 13/18 Loss: 0.3961 Accuracy: 0.8363 AUC: 0.0000 Data Time: 1.9009 Batch Time: 2.9385
# 2024-06-25 16:15:24,971 - INFO - TRAIN Epoch: 3 Step: 14/18 Loss: 0.3951 Accuracy: 0.8361 AUC: 0.0000 Data Time: 1.8774 Batch Time: 2.9156
# 2024-06-25 16:15:27,718 - INFO - TRAIN Epoch: 3 Step: 15/18 Loss: 0.3992 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.8671 Batch Time: 2.9049
# 2024-06-25 16:15:31,065 - INFO - TRAIN Epoch: 3 Step: 16/18 Loss: 0.4011 Accuracy: 0.8324 AUC: 0.0000 Data Time: 1.8907 Batch Time: 2.9308
# 2024-06-25 16:15:32,050 - INFO - TRAIN Epoch: 3 Step: 17/18 Loss: 0.4002 Accuracy: 0.8327 AUC: 0.0000 Data Time: 1.8239 Batch Time: 2.8226
# 2024-06-25 16:15:32,055 - INFO - AUC Score: 0.7970
# 2024-06-25 16:15:34,534 - INFO - VAL Epoch: 3 Step: 0/5 Loss: 0.4220 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.4862 Batch Time: 2.4739
# 2024-06-25 16:15:36,830 - INFO - VAL Epoch: 3 Step: 1/5 Loss: 0.3711 Accuracy: 0.8417 AUC: 0.0000 Data Time: 1.3923 Batch Time: 2.3845
# 2024-06-25 16:15:39,448 - INFO - VAL Epoch: 3 Step: 2/5 Loss: 0.3811 Accuracy: 0.8306 AUC: 0.0000 Data Time: 1.4508 Batch Time: 2.4607
# 2024-06-25 16:15:41,980 - INFO - VAL Epoch: 3 Step: 3/5 Loss: 0.3958 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.4665 Batch Time: 2.4778
# 2024-06-25 16:15:42,967 - INFO - VAL Epoch: 3 Step: 4/5 Loss: 0.4157 Accuracy: 0.8170 AUC: 0.0000 Data Time: 1.3034 Batch Time: 2.1791
# 2024-06-25 16:15:42,973 - INFO - AUC Score: 0.7788
# 2024-06-25 16:15:42,978 - INFO - New best model at epoch: 4
# 2024-06-25 16:15:43,247 - INFO - Starting Epoch: 5
# 2024-06-25 16:15:46,074 - INFO - TRAIN Epoch: 4 Step: 0/18 Loss: 0.4712 Accuracy: 0.7417 AUC: 0.0000 Data Time: 1.7931 Batch Time: 2.8254
# 2024-06-25 16:15:48,716 - INFO - TRAIN Epoch: 4 Step: 1/18 Loss: 0.3988 Accuracy: 0.7958 AUC: 0.0000 Data Time: 1.7180 Batch Time: 2.7330
# 2024-06-25 16:15:51,321 - INFO - TRAIN Epoch: 4 Step: 2/18 Loss: 0.4345 Accuracy: 0.7861 AUC: 0.0000 Data Time: 1.6494 Batch Time: 2.6897
# 2024-06-25 16:15:53,800 - INFO - TRAIN Epoch: 4 Step: 3/18 Loss: 0.4185 Accuracy: 0.7979 AUC: 0.0000 Data Time: 1.5995 Batch Time: 2.6369
# 2024-06-25 16:15:56,502 - INFO - TRAIN Epoch: 4 Step: 4/18 Loss: 0.4022 Accuracy: 0.8050 AUC: 0.0000 Data Time: 1.6148 Batch Time: 2.6497
# 2024-06-25 16:15:59,202 - INFO - TRAIN Epoch: 4 Step: 5/18 Loss: 0.4034 Accuracy: 0.8111 AUC: 0.0000 Data Time: 1.6280 Batch Time: 2.6578
# 2024-06-25 16:16:01,966 - INFO - TRAIN Epoch: 4 Step: 6/18 Loss: 0.3984 Accuracy: 0.8202 AUC: 0.0000 Data Time: 1.6487 Batch Time: 2.6728
# 2024-06-25 16:16:05,126 - INFO - TRAIN Epoch: 4 Step: 7/18 Loss: 0.3929 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.7085 Batch Time: 2.7336
# 2024-06-25 16:16:08,238 - INFO - TRAIN Epoch: 4 Step: 8/18 Loss: 0.3835 Accuracy: 0.8306 AUC: 0.0000 Data Time: 1.7424 Batch Time: 2.7751
# 2024-06-25 16:16:10,558 - INFO - TRAIN Epoch: 4 Step: 9/18 Loss: 0.3845 Accuracy: 0.8317 AUC: 0.0000 Data Time: 1.6955 Batch Time: 2.7295
# 2024-06-25 16:16:13,094 - INFO - TRAIN Epoch: 4 Step: 10/18 Loss: 0.3856 Accuracy: 0.8326 AUC: 0.0000 Data Time: 1.6727 Batch Time: 2.7116
# 2024-06-25 16:16:16,126 - INFO - TRAIN Epoch: 4 Step: 11/18 Loss: 0.3840 Accuracy: 0.8347 AUC: 0.0000 Data Time: 1.6986 Batch Time: 2.7380
# 2024-06-25 16:16:19,225 - INFO - TRAIN Epoch: 4 Step: 12/18 Loss: 0.3906 Accuracy: 0.8321 AUC: 0.0000 Data Time: 1.7242 Batch Time: 2.7657
# 2024-06-25 16:16:21,856 - INFO - TRAIN Epoch: 4 Step: 13/18 Loss: 0.3865 Accuracy: 0.8351 AUC: 0.0000 Data Time: 1.7162 Batch Time: 2.7560
# 2024-06-25 16:16:24,741 - INFO - TRAIN Epoch: 4 Step: 14/18 Loss: 0.3822 Accuracy: 0.8367 AUC: 0.0000 Data Time: 1.7248 Batch Time: 2.7645
# 2024-06-25 16:16:27,487 - INFO - TRAIN Epoch: 4 Step: 15/18 Loss: 0.3863 Accuracy: 0.8354 AUC: 0.0000 Data Time: 1.7219 Batch Time: 2.7632
# 2024-06-25 16:16:30,599 - INFO - TRAIN Epoch: 4 Step: 16/18 Loss: 0.3833 Accuracy: 0.8363 AUC: 0.0000 Data Time: 1.7439 Batch Time: 2.7836
# 2024-06-25 16:16:31,335 - INFO - TRAIN Epoch: 4 Step: 17/18 Loss: 0.3850 Accuracy: 0.8346 AUC: 0.0000 Data Time: 1.6709 Batch Time: 2.6698
# 2024-06-25 16:16:31,337 - INFO - AUC Score: 0.8153
# 2024-06-25 16:16:33,649 - INFO - VAL Epoch: 4 Step: 0/5 Loss: 0.4096 Accuracy: 0.8417 AUC: 0.0000 Data Time: 1.2991 Batch Time: 2.3099
# 2024-06-25 16:16:35,364 - INFO - VAL Epoch: 4 Step: 1/5 Loss: 0.3640 Accuracy: 0.8500 AUC: 0.0000 Data Time: 1.0105 Batch Time: 2.0121
# 2024-06-25 16:16:37,799 - INFO - VAL Epoch: 4 Step: 2/5 Loss: 0.3744 Accuracy: 0.8361 AUC: 0.0000 Data Time: 1.1243 Batch Time: 2.1528
# 2024-06-25 16:16:40,026 - INFO - VAL Epoch: 4 Step: 3/5 Loss: 0.3857 Accuracy: 0.8229 AUC: 0.0000 Data Time: 1.1465 Batch Time: 2.1709
# 2024-06-25 16:16:40,810 - INFO - VAL Epoch: 4 Step: 4/5 Loss: 0.4022 Accuracy: 0.8150 AUC: 0.0000 Data Time: 1.0061 Batch Time: 1.8935
# 2024-06-25 16:16:40,814 - INFO - AUC Score: 0.8003
# 2024-06-25 16:16:40,815 - INFO - New best model at epoch: 5
# 2024-06-25 16:16:40,987 - INFO - Starting Epoch: 6
# 2024-06-25 16:16:43,357 - INFO - TRAIN Epoch: 5 Step: 0/18 Loss: 0.5052 Accuracy: 0.7500 AUC: 0.0000 Data Time: 1.3562 Batch Time: 2.3695
# 2024-06-25 16:16:45,588 - INFO - TRAIN Epoch: 5 Step: 1/18 Loss: 0.4431 Accuracy: 0.7792 AUC: 0.0000 Data Time: 1.2865 Batch Time: 2.2994
# 2024-06-25 16:16:47,794 - INFO - TRAIN Epoch: 5 Step: 2/18 Loss: 0.4295 Accuracy: 0.8028 AUC: 0.0000 Data Time: 1.2533 Batch Time: 2.2680
# 2024-06-25 16:16:50,313 - INFO - TRAIN Epoch: 5 Step: 3/18 Loss: 0.4173 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.3119 Batch Time: 2.3307
# 2024-06-25 16:16:52,907 - INFO - TRAIN Epoch: 5 Step: 4/18 Loss: 0.4112 Accuracy: 0.8183 AUC: 0.0000 Data Time: 1.3493 Batch Time: 2.3829
# 2024-06-25 16:16:55,540 - INFO - TRAIN Epoch: 5 Step: 5/18 Loss: 0.4131 Accuracy: 0.8194 AUC: 0.0000 Data Time: 1.3938 Batch Time: 2.4245
# 2024-06-25 16:16:58,022 - INFO - TRAIN Epoch: 5 Step: 6/18 Loss: 0.3965 Accuracy: 0.8286 AUC: 0.0000 Data Time: 1.4043 Batch Time: 2.4326
# 2024-06-25 16:17:00,533 - INFO - TRAIN Epoch: 5 Step: 7/18 Loss: 0.3927 Accuracy: 0.8313 AUC: 0.0000 Data Time: 1.4158 Batch Time: 2.4422
# 2024-06-25 16:17:02,880 - INFO - TRAIN Epoch: 5 Step: 8/18 Loss: 0.3996 Accuracy: 0.8306 AUC: 0.0000 Data Time: 1.4066 Batch Time: 2.4315
# 2024-06-25 16:17:05,347 - INFO - TRAIN Epoch: 5 Step: 9/18 Loss: 0.3970 Accuracy: 0.8342 AUC: 0.0000 Data Time: 1.4109 Batch Time: 2.4350
# 2024-06-25 16:17:07,801 - INFO - TRAIN Epoch: 5 Step: 10/18 Loss: 0.3962 Accuracy: 0.8318 AUC: 0.0000 Data Time: 1.4125 Batch Time: 2.4367
# 2024-06-25 16:17:10,156 - INFO - TRAIN Epoch: 5 Step: 11/18 Loss: 0.3925 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.4066 Batch Time: 2.4298
# 2024-06-25 16:17:12,615 - INFO - TRAIN Epoch: 5 Step: 12/18 Loss: 0.3862 Accuracy: 0.8340 AUC: 0.0000 Data Time: 1.4096 Batch Time: 2.4320
# 2024-06-25 16:17:14,943 - INFO - TRAIN Epoch: 5 Step: 13/18 Loss: 0.3870 Accuracy: 0.8315 AUC: 0.0000 Data Time: 1.4025 Batch Time: 2.4244
# 2024-06-25 16:17:17,408 - INFO - TRAIN Epoch: 5 Step: 14/18 Loss: 0.3864 Accuracy: 0.8328 AUC: 0.0000 Data Time: 1.4058 Batch Time: 2.4271
# 2024-06-25 16:17:19,884 - INFO - TRAIN Epoch: 5 Step: 15/18 Loss: 0.3869 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.4024 Batch Time: 2.4301
# 2024-06-25 16:17:22,292 - INFO - TRAIN Epoch: 5 Step: 16/18 Loss: 0.3900 Accuracy: 0.8319 AUC: 0.0000 Data Time: 1.4019 Batch Time: 2.4287
# 2024-06-25 16:17:23,038 - INFO - TRAIN Epoch: 5 Step: 17/18 Loss: 0.3924 Accuracy: 0.8298 AUC: 0.0000 Data Time: 1.3486 Batch Time: 2.3352
# 2024-06-25 16:17:23,040 - INFO - AUC Score: 0.8114
# 2024-06-25 16:17:25,265 - INFO - VAL Epoch: 5 Step: 0/5 Loss: 0.4155 Accuracy: 0.8583 AUC: 0.0000 Data Time: 1.2195 Batch Time: 2.2230
# 2024-06-25 16:17:27,508 - INFO - VAL Epoch: 5 Step: 1/5 Loss: 0.3636 Accuracy: 0.8667 AUC: 0.0000 Data Time: 1.2224 Batch Time: 2.2326
# 2024-06-25 16:17:29,734 - INFO - VAL Epoch: 5 Step: 2/5 Loss: 0.3749 Accuracy: 0.8472 AUC: 0.0000 Data Time: 1.2188 Batch Time: 2.2302
# 2024-06-25 16:17:32,062 - INFO - VAL Epoch: 5 Step: 3/5 Loss: 0.3858 Accuracy: 0.8354 AUC: 0.0000 Data Time: 1.2122 Batch Time: 2.2541
# 2024-06-25 16:17:32,633 - INFO - VAL Epoch: 5 Step: 4/5 Loss: 0.4051 Accuracy: 0.8266 AUC: 0.0000 Data Time: 1.0170 Batch Time: 1.9169
# 2024-06-25 16:17:32,637 - INFO - AUC Score: 0.7903
# 2024-06-25 16:17:32,724 - INFO - Starting Epoch: 7
# 2024-06-25 16:17:35,010 - INFO - TRAIN Epoch: 6 Step: 0/18 Loss: 0.4333 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.2579 Batch Time: 2.2837
# 2024-06-25 16:17:37,300 - INFO - TRAIN Epoch: 6 Step: 1/18 Loss: 0.4170 Accuracy: 0.8000 AUC: 0.0000 Data Time: 1.2631 Batch Time: 2.2852
# 2024-06-25 16:17:39,643 - INFO - TRAIN Epoch: 6 Step: 2/18 Loss: 0.4114 Accuracy: 0.8111 AUC: 0.0000 Data Time: 1.2446 Batch Time: 2.3037
# 2024-06-25 16:17:41,907 - INFO - TRAIN Epoch: 6 Step: 3/18 Loss: 0.4003 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.2453 Batch Time: 2.2930
# 2024-06-25 16:17:44,321 - INFO - TRAIN Epoch: 6 Step: 4/18 Loss: 0.3920 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.2762 Batch Time: 2.3168
# 2024-06-25 16:17:46,615 - INFO - TRAIN Epoch: 6 Step: 5/18 Loss: 0.4000 Accuracy: 0.8194 AUC: 0.0000 Data Time: 1.2736 Batch Time: 2.3129
# 2024-06-25 16:17:48,965 - INFO - TRAIN Epoch: 6 Step: 6/18 Loss: 0.3938 Accuracy: 0.8274 AUC: 0.0000 Data Time: 1.2800 Batch Time: 2.3181
# 2024-06-25 16:17:51,525 - INFO - TRAIN Epoch: 6 Step: 7/18 Loss: 0.3898 Accuracy: 0.8271 AUC: 0.0000 Data Time: 1.2951 Batch Time: 2.3482
# 2024-06-25 16:17:53,938 - INFO - TRAIN Epoch: 6 Step: 8/18 Loss: 0.3897 Accuracy: 0.8296 AUC: 0.0000 Data Time: 1.3059 Batch Time: 2.3552
# 2024-06-25 16:17:56,536 - INFO - TRAIN Epoch: 6 Step: 9/18 Loss: 0.4039 Accuracy: 0.8225 AUC: 0.0000 Data Time: 1.3335 Batch Time: 2.3794
# 2024-06-25 16:17:58,842 - INFO - TRAIN Epoch: 6 Step: 10/18 Loss: 0.3955 Accuracy: 0.8273 AUC: 0.0000 Data Time: 1.3287 Batch Time: 2.3726
# 2024-06-25 16:18:01,327 - INFO - TRAIN Epoch: 6 Step: 11/18 Loss: 0.3935 Accuracy: 0.8278 AUC: 0.0000 Data Time: 1.3406 Batch Time: 2.3819
# 2024-06-25 16:18:03,710 - INFO - TRAIN Epoch: 6 Step: 12/18 Loss: 0.3866 Accuracy: 0.8321 AUC: 0.0000 Data Time: 1.3427 Batch Time: 2.3818
# 2024-06-25 16:18:06,053 - INFO - TRAIN Epoch: 6 Step: 13/18 Loss: 0.3851 Accuracy: 0.8345 AUC: 0.0000 Data Time: 1.3412 Batch Time: 2.3789
# 2024-06-25 16:18:08,413 - INFO - TRAIN Epoch: 6 Step: 14/18 Loss: 0.3837 Accuracy: 0.8372 AUC: 0.0000 Data Time: 1.3411 Batch Time: 2.3776
# 2024-06-25 16:18:10,809 - INFO - TRAIN Epoch: 6 Step: 15/18 Loss: 0.3787 Accuracy: 0.8401 AUC: 0.0000 Data Time: 1.3431 Batch Time: 2.3787
# 2024-06-25 16:18:13,153 - INFO - TRAIN Epoch: 6 Step: 16/18 Loss: 0.3749 Accuracy: 0.8426 AUC: 0.0000 Data Time: 1.3422 Batch Time: 2.3765
# 2024-06-25 16:18:13,935 - INFO - TRAIN Epoch: 6 Step: 17/18 Loss: 0.3767 Accuracy: 0.8419 AUC: 0.0000 Data Time: 1.2947 Batch Time: 2.2878
# 2024-06-25 16:18:13,940 - INFO - AUC Score: 0.8270
# 2024-06-25 16:18:16,249 - INFO - VAL Epoch: 6 Step: 0/5 Loss: 0.3901 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.2411 Batch Time: 2.3068
# 2024-06-25 16:18:18,464 - INFO - VAL Epoch: 6 Step: 1/5 Loss: 0.3477 Accuracy: 0.8625 AUC: 0.0000 Data Time: 1.2179 Batch Time: 2.2591
# 2024-06-25 16:18:20,644 - INFO - VAL Epoch: 6 Step: 2/5 Loss: 0.3577 Accuracy: 0.8528 AUC: 0.0000 Data Time: 1.1987 Batch Time: 2.2317
# 2024-06-25 16:18:22,907 - INFO - VAL Epoch: 6 Step: 3/5 Loss: 0.3811 Accuracy: 0.8354 AUC: 0.0000 Data Time: 1.2104 Batch Time: 2.2394
# 2024-06-25 16:18:23,644 - INFO - VAL Epoch: 6 Step: 4/5 Loss: 0.4047 Accuracy: 0.8247 AUC: 0.0000 Data Time: 1.0474 Batch Time: 1.9387
# 2024-06-25 16:18:23,648 - INFO - AUC Score: 0.8038
# 2024-06-25 16:18:23,733 - INFO - Starting Epoch: 8
# 2024-06-25 16:18:26,050 - INFO - TRAIN Epoch: 7 Step: 0/18 Loss: 0.2427 Accuracy: 0.9167 AUC: 0.0000 Data Time: 1.2794 Batch Time: 2.3145
# 2024-06-25 16:18:28,388 - INFO - TRAIN Epoch: 7 Step: 1/18 Loss: 0.3108 Accuracy: 0.8875 AUC: 0.0000 Data Time: 1.2959 Batch Time: 2.3256
# 2024-06-25 16:18:30,730 - INFO - TRAIN Epoch: 7 Step: 2/18 Loss: 0.3438 Accuracy: 0.8722 AUC: 0.0000 Data Time: 1.3043 Batch Time: 2.3302
# 2024-06-25 16:18:33,019 - INFO - TRAIN Epoch: 7 Step: 3/18 Loss: 0.3448 Accuracy: 0.8688 AUC: 0.0000 Data Time: 1.2924 Batch Time: 2.3192
# 2024-06-25 16:18:35,250 - INFO - TRAIN Epoch: 7 Step: 4/18 Loss: 0.3572 Accuracy: 0.8567 AUC: 0.0000 Data Time: 1.2771 Batch Time: 2.3011
# 2024-06-25 16:18:37,597 - INFO - TRAIN Epoch: 7 Step: 5/18 Loss: 0.3539 Accuracy: 0.8597 AUC: 0.0000 Data Time: 1.2780 Batch Time: 2.3083
# 2024-06-25 16:18:40,003 - INFO - TRAIN Epoch: 7 Step: 6/18 Loss: 0.3482 Accuracy: 0.8619 AUC: 0.0000 Data Time: 1.2911 Batch Time: 2.3217
# 2024-06-25 16:18:43,570 - INFO - TRAIN Epoch: 7 Step: 7/18 Loss: 0.3462 Accuracy: 0.8625 AUC: 0.0000 Data Time: 1.4477 Batch Time: 2.4772
# 2024-06-25 16:18:45,908 - INFO - TRAIN Epoch: 7 Step: 8/18 Loss: 0.3544 Accuracy: 0.8583 AUC: 0.0000 Data Time: 1.4340 Batch Time: 2.4616
# 2024-06-25 16:18:48,282 - INFO - TRAIN Epoch: 7 Step: 9/18 Loss: 0.3525 Accuracy: 0.8558 AUC: 0.0000 Data Time: 1.4263 Batch Time: 2.4528
# 2024-06-25 16:18:50,910 - INFO - TRAIN Epoch: 7 Step: 10/18 Loss: 0.3609 Accuracy: 0.8485 AUC: 0.0000 Data Time: 1.4449 Batch Time: 2.4686
# 2024-06-25 16:18:54,767 - INFO - TRAIN Epoch: 7 Step: 11/18 Loss: 0.3562 Accuracy: 0.8507 AUC: 0.0000 Data Time: 1.5621 Batch Time: 2.5842
# 2024-06-25 16:18:57,031 - INFO - TRAIN Epoch: 7 Step: 12/18 Loss: 0.3558 Accuracy: 0.8487 AUC: 0.0000 Data Time: 1.5398 Batch Time: 2.5595
# 2024-06-25 16:18:59,758 - INFO - TRAIN Epoch: 7 Step: 13/18 Loss: 0.3540 Accuracy: 0.8494 AUC: 0.0000 Data Time: 1.5511 Batch Time: 2.5714
# 2024-06-25 16:19:03,034 - INFO - TRAIN Epoch: 7 Step: 14/18 Loss: 0.3632 Accuracy: 0.8444 AUC: 0.0000 Data Time: 1.5956 Batch Time: 2.6183
# 2024-06-25 16:19:05,397 - INFO - TRAIN Epoch: 7 Step: 15/18 Loss: 0.3645 Accuracy: 0.8422 AUC: 0.0000 Data Time: 1.5787 Batch Time: 2.6023
# 2024-06-25 16:19:08,321 - INFO - TRAIN Epoch: 7 Step: 16/18 Loss: 0.3684 Accuracy: 0.8412 AUC: 0.0000 Data Time: 1.5978 Batch Time: 2.6212
# 2024-06-25 16:19:09,111 - INFO - TRAIN Epoch: 7 Step: 17/18 Loss: 0.3671 Accuracy: 0.8423 AUC: 0.0000 Data Time: 1.5365 Batch Time: 2.5193
# 2024-06-25 16:19:09,115 - INFO - AUC Score: 0.8379
# 2024-06-25 16:19:12,009 - INFO - VAL Epoch: 7 Step: 0/5 Loss: 0.3999 Accuracy: 0.8417 AUC: 0.0000 Data Time: 1.6845 Batch Time: 2.8913
# 2024-06-25 16:19:14,896 - INFO - VAL Epoch: 7 Step: 1/5 Loss: 0.3537 Accuracy: 0.8583 AUC: 0.0000 Data Time: 1.6406 Batch Time: 2.8888
# 2024-06-25 16:19:17,640 - INFO - VAL Epoch: 7 Step: 2/5 Loss: 0.3649 Accuracy: 0.8417 AUC: 0.0000 Data Time: 1.6174 Batch Time: 2.8398
# 2024-06-25 16:19:20,017 - INFO - VAL Epoch: 7 Step: 3/5 Loss: 0.3797 Accuracy: 0.8313 AUC: 0.0000 Data Time: 1.5197 Batch Time: 2.7238
# 2024-06-25 16:19:21,098 - INFO - VAL Epoch: 7 Step: 4/5 Loss: 0.4004 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.3595 Batch Time: 2.3928
# 2024-06-25 16:19:21,106 - INFO - AUC Score: 0.8009
# 2024-06-25 16:19:21,109 - INFO - New best model at epoch: 8
# 2024-06-25 16:19:21,515 - INFO - Starting Epoch: 9
# 2024-06-25 16:19:26,309 - INFO - TRAIN Epoch: 8 Step: 0/18 Loss: 0.3889 Accuracy: 0.8583 AUC: 0.0000 Data Time: 2.6088 Batch Time: 4.7845
# 2024-06-25 16:19:30,742 - INFO - TRAIN Epoch: 8 Step: 1/18 Loss: 0.4172 Accuracy: 0.8167 AUC: 0.0000 Data Time: 2.8815 Batch Time: 4.6079
# 2024-06-25 16:19:34,956 - INFO - TRAIN Epoch: 8 Step: 2/18 Loss: 0.4347 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.9642 Batch Time: 4.4738
# 2024-06-25 16:19:38,154 - INFO - TRAIN Epoch: 8 Step: 3/18 Loss: 0.4109 Accuracy: 0.8250 AUC: 0.0000 Data Time: 2.7554 Batch Time: 4.1545
# 2024-06-25 16:19:41,566 - INFO - TRAIN Epoch: 8 Step: 4/18 Loss: 0.4139 Accuracy: 0.8217 AUC: 0.0000 Data Time: 2.6683 Batch Time: 4.0044
# 2024-06-25 16:19:45,034 - INFO - TRAIN Epoch: 8 Step: 5/18 Loss: 0.4071 Accuracy: 0.8208 AUC: 0.0000 Data Time: 2.6269 Batch Time: 3.9149
# 2024-06-25 16:19:47,681 - INFO - TRAIN Epoch: 8 Step: 6/18 Loss: 0.4035 Accuracy: 0.8214 AUC: 0.0000 Data Time: 2.4788 Batch Time: 3.7328
# 2024-06-25 16:19:50,326 - INFO - TRAIN Epoch: 8 Step: 7/18 Loss: 0.4028 Accuracy: 0.8208 AUC: 0.0000 Data Time: 2.3622 Batch Time: 3.5964
# 2024-06-25 16:19:53,487 - INFO - TRAIN Epoch: 8 Step: 8/18 Loss: 0.3977 Accuracy: 0.8250 AUC: 0.0000 Data Time: 2.3384 Batch Time: 3.5477
# 2024-06-25 16:19:56,011 - INFO - TRAIN Epoch: 8 Step: 9/18 Loss: 0.3928 Accuracy: 0.8317 AUC: 0.0000 Data Time: 2.2578 Batch Time: 3.4452
# 2024-06-25 16:19:58,562 - INFO - TRAIN Epoch: 8 Step: 10/18 Loss: 0.3889 Accuracy: 0.8318 AUC: 0.0000 Data Time: 2.1942 Batch Time: 3.3638
# 2024-06-25 16:20:01,339 - INFO - TRAIN Epoch: 8 Step: 11/18 Loss: 0.3889 Accuracy: 0.8306 AUC: 0.0000 Data Time: 2.1595 Batch Time: 3.3148
# 2024-06-25 16:20:04,089 - INFO - TRAIN Epoch: 8 Step: 12/18 Loss: 0.3854 Accuracy: 0.8321 AUC: 0.0000 Data Time: 2.1257 Batch Time: 3.2712
# 2024-06-25 16:20:06,898 - INFO - TRAIN Epoch: 8 Step: 13/18 Loss: 0.3809 Accuracy: 0.8369 AUC: 0.0000 Data Time: 2.0994 Batch Time: 3.2380
# 2024-06-25 16:20:09,580 - INFO - TRAIN Epoch: 8 Step: 14/18 Loss: 0.3761 Accuracy: 0.8383 AUC: 0.0000 Data Time: 2.0658 Batch Time: 3.2009
# 2024-06-25 16:20:12,245 - INFO - TRAIN Epoch: 8 Step: 15/18 Loss: 0.3781 Accuracy: 0.8385 AUC: 0.0000 Data Time: 2.0386 Batch Time: 3.1673
# 2024-06-25 16:20:15,482 - INFO - TRAIN Epoch: 8 Step: 16/18 Loss: 0.3770 Accuracy: 0.8397 AUC: 0.0000 Data Time: 2.0456 Batch Time: 3.1713
# 2024-06-25 16:20:16,275 - INFO - TRAIN Epoch: 8 Step: 17/18 Loss: 0.3767 Accuracy: 0.8404 AUC: 0.0000 Data Time: 1.9586 Batch Time: 3.0391
# 2024-06-25 16:20:16,279 - INFO - AUC Score: 0.8274
# 2024-06-25 16:20:19,735 - INFO - VAL Epoch: 8 Step: 0/5 Loss: 0.3859 Accuracy: 0.8583 AUC: 0.0000 Data Time: 2.3200 Batch Time: 3.4544
# 2024-06-25 16:20:22,433 - INFO - VAL Epoch: 8 Step: 1/5 Loss: 0.3417 Accuracy: 0.8708 AUC: 0.0000 Data Time: 2.0020 Batch Time: 3.0750
# 2024-06-25 16:20:25,409 - INFO - VAL Epoch: 8 Step: 2/5 Loss: 0.3539 Accuracy: 0.8528 AUC: 0.0000 Data Time: 1.9609 Batch Time: 3.0414
# 2024-06-25 16:20:27,949 - INFO - VAL Epoch: 8 Step: 3/5 Loss: 0.3723 Accuracy: 0.8396 AUC: 0.0000 Data Time: 1.8455 Batch Time: 2.9157
# 2024-06-25 16:20:28,835 - INFO - VAL Epoch: 8 Step: 4/5 Loss: 0.3929 Accuracy: 0.8285 AUC: 0.0000 Data Time: 1.5805 Batch Time: 2.5094
# 2024-06-25 16:20:28,840 - INFO - AUC Score: 0.8146
# 2024-06-25 16:20:28,842 - INFO - New best model at epoch: 9
# 2024-06-25 16:20:29,014 - INFO - Starting Epoch: 10
# 2024-06-25 16:20:31,749 - INFO - TRAIN Epoch: 9 Step: 0/18 Loss: 0.3718 Accuracy: 0.8500 AUC: 0.0000 Data Time: 1.7353 Batch Time: 2.7314
# 2024-06-25 16:20:34,501 - INFO - TRAIN Epoch: 9 Step: 1/18 Loss: 0.3812 Accuracy: 0.8458 AUC: 0.0000 Data Time: 1.7188 Batch Time: 2.7405
# 2024-06-25 16:20:37,250 - INFO - TRAIN Epoch: 9 Step: 2/18 Loss: 0.3521 Accuracy: 0.8667 AUC: 0.0000 Data Time: 1.7046 Batch Time: 2.7430
# 2024-06-25 16:20:39,802 - INFO - TRAIN Epoch: 9 Step: 3/18 Loss: 0.3687 Accuracy: 0.8458 AUC: 0.0000 Data Time: 1.6436 Batch Time: 2.6949
# 2024-06-25 16:20:42,432 - INFO - TRAIN Epoch: 9 Step: 4/18 Loss: 0.3587 Accuracy: 0.8600 AUC: 0.0000 Data Time: 1.6379 Batch Time: 2.6813
# 2024-06-25 16:20:44,838 - INFO - TRAIN Epoch: 9 Step: 5/18 Loss: 0.3603 Accuracy: 0.8514 AUC: 0.0000 Data Time: 1.5963 Batch Time: 2.6350
# 2024-06-25 16:20:47,232 - INFO - TRAIN Epoch: 9 Step: 6/18 Loss: 0.3505 Accuracy: 0.8595 AUC: 0.0000 Data Time: 1.5649 Batch Time: 2.6005
# 2024-06-25 16:20:50,085 - INFO - TRAIN Epoch: 9 Step: 7/18 Loss: 0.3543 Accuracy: 0.8562 AUC: 0.0000 Data Time: 1.5988 Batch Time: 2.6313
# 2024-06-25 16:20:52,832 - INFO - TRAIN Epoch: 9 Step: 8/18 Loss: 0.3601 Accuracy: 0.8537 AUC: 0.0000 Data Time: 1.6162 Batch Time: 2.6440
# 2024-06-25 16:20:55,527 - INFO - TRAIN Epoch: 9 Step: 9/18 Loss: 0.3574 Accuracy: 0.8525 AUC: 0.0000 Data Time: 1.6245 Batch Time: 2.6491
# 2024-06-25 16:20:58,249 - INFO - TRAIN Epoch: 9 Step: 10/18 Loss: 0.3528 Accuracy: 0.8538 AUC: 0.0000 Data Time: 1.6343 Batch Time: 2.6556
# 2024-06-25 16:21:01,047 - INFO - TRAIN Epoch: 9 Step: 11/18 Loss: 0.3567 Accuracy: 0.8514 AUC: 0.0000 Data Time: 1.6455 Batch Time: 2.6672
# 2024-06-25 16:21:04,384 - INFO - TRAIN Epoch: 9 Step: 12/18 Loss: 0.3531 Accuracy: 0.8532 AUC: 0.0000 Data Time: 1.6924 Batch Time: 2.7187
# 2024-06-25 16:21:07,436 - INFO - TRAIN Epoch: 9 Step: 13/18 Loss: 0.3507 Accuracy: 0.8554 AUC: 0.0000 Data Time: 1.7187 Batch Time: 2.7424
# 2024-06-25 16:21:10,480 - INFO - TRAIN Epoch: 9 Step: 14/18 Loss: 0.3537 Accuracy: 0.8544 AUC: 0.0000 Data Time: 1.7388 Batch Time: 2.7623
# 2024-06-25 16:21:13,257 - INFO - TRAIN Epoch: 9 Step: 15/18 Loss: 0.3554 Accuracy: 0.8542 AUC: 0.0000 Data Time: 1.7399 Batch Time: 2.7631
# 2024-06-25 16:21:16,489 - INFO - TRAIN Epoch: 9 Step: 16/18 Loss: 0.3579 Accuracy: 0.8534 AUC: 0.0000 Data Time: 1.7519 Batch Time: 2.7906
# 2024-06-25 16:21:17,427 - INFO - TRAIN Epoch: 9 Step: 17/18 Loss: 0.3577 Accuracy: 0.8539 AUC: 0.0000 Data Time: 1.6896 Batch Time: 2.6875
# 2024-06-25 16:21:17,431 - INFO - AUC Score: 0.8488
# 2024-06-25 16:21:20,704 - INFO - VAL Epoch: 9 Step: 0/5 Loss: 0.3752 Accuracy: 0.8750 AUC: 0.0000 Data Time: 2.1916 Batch Time: 3.2698
# 2024-06-25 16:21:23,808 - INFO - VAL Epoch: 9 Step: 1/5 Loss: 0.3383 Accuracy: 0.8792 AUC: 0.0000 Data Time: 2.1188 Batch Time: 3.1857
# 2024-06-25 16:21:27,189 - INFO - VAL Epoch: 9 Step: 2/5 Loss: 0.3485 Accuracy: 0.8611 AUC: 0.0000 Data Time: 2.1825 Batch Time: 3.2505
# 2024-06-25 16:21:30,917 - INFO - VAL Epoch: 9 Step: 3/5 Loss: 0.3715 Accuracy: 0.8458 AUC: 0.0000 Data Time: 2.3019 Batch Time: 3.3692
# 2024-06-25 16:21:31,917 - INFO - VAL Epoch: 9 Step: 4/5 Loss: 0.3935 Accuracy: 0.8324 AUC: 0.0000 Data Time: 1.9614 Batch Time: 2.8951
# 2024-06-25 16:21:31,921 - INFO - AUC Score: 0.8191
# 2024-06-25 16:21:32,009 - INFO - Starting Epoch: 11
# 2024-06-25 16:21:34,456 - INFO - TRAIN Epoch: 10 Step: 0/18 Loss: 0.3933 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.4430 Batch Time: 2.4452
# 2024-06-25 16:21:38,015 - INFO - TRAIN Epoch: 10 Step: 1/18 Loss: 0.3898 Accuracy: 0.8458 AUC: 0.0000 Data Time: 1.7494 Batch Time: 3.0008
# 2024-06-25 16:21:40,649 - INFO - TRAIN Epoch: 10 Step: 2/18 Loss: 0.3565 Accuracy: 0.8528 AUC: 0.0000 Data Time: 1.7061 Batch Time: 2.8777
# 2024-06-25 16:21:43,017 - INFO - TRAIN Epoch: 10 Step: 3/18 Loss: 0.3712 Accuracy: 0.8458 AUC: 0.0000 Data Time: 1.6181 Batch Time: 2.7500
# 2024-06-25 16:21:45,626 - INFO - TRAIN Epoch: 10 Step: 4/18 Loss: 0.3658 Accuracy: 0.8483 AUC: 0.0000 Data Time: 1.6099 Batch Time: 2.7215
# 2024-06-25 16:21:48,305 - INFO - TRAIN Epoch: 10 Step: 5/18 Loss: 0.3492 Accuracy: 0.8597 AUC: 0.0000 Data Time: 1.6185 Batch Time: 2.7142
# 2024-06-25 16:21:50,995 - INFO - TRAIN Epoch: 10 Step: 6/18 Loss: 0.3536 Accuracy: 0.8536 AUC: 0.0000 Data Time: 1.6285 Batch Time: 2.7106
# 2024-06-25 16:21:53,708 - INFO - TRAIN Epoch: 10 Step: 7/18 Loss: 0.3483 Accuracy: 0.8583 AUC: 0.0000 Data Time: 1.6354 Batch Time: 2.7107
# 2024-06-25 16:21:58,510 - INFO - TRAIN Epoch: 10 Step: 8/18 Loss: 0.3514 Accuracy: 0.8611 AUC: 0.0000 Data Time: 1.7230 Batch Time: 2.9430
# 2024-06-25 16:22:03,355 - INFO - TRAIN Epoch: 10 Step: 9/18 Loss: 0.3542 Accuracy: 0.8600 AUC: 0.0000 Data Time: 1.8188 Batch Time: 3.1330
# 2024-06-25 16:22:07,566 - INFO - TRAIN Epoch: 10 Step: 10/18 Loss: 0.3521 Accuracy: 0.8583 AUC: 0.0000 Data Time: 1.8789 Batch Time: 3.2308
# 2024-06-25 16:22:12,001 - INFO - TRAIN Epoch: 10 Step: 11/18 Loss: 0.3496 Accuracy: 0.8590 AUC: 0.0000 Data Time: 1.9523 Batch Time: 3.3309
# 2024-06-25 16:22:15,039 - INFO - TRAIN Epoch: 10 Step: 12/18 Loss: 0.3484 Accuracy: 0.8583 AUC: 0.0000 Data Time: 1.9582 Batch Time: 3.3076
# 2024-06-25 16:22:18,037 - INFO - TRAIN Epoch: 10 Step: 13/18 Loss: 0.3461 Accuracy: 0.8589 AUC: 0.0000 Data Time: 1.9608 Batch Time: 3.2854
# 2024-06-25 16:22:20,834 - INFO - TRAIN Epoch: 10 Step: 14/18 Loss: 0.3461 Accuracy: 0.8589 AUC: 0.0000 Data Time: 1.9507 Batch Time: 3.2528
# 2024-06-25 16:22:23,665 - INFO - TRAIN Epoch: 10 Step: 15/18 Loss: 0.3547 Accuracy: 0.8526 AUC: 0.0000 Data Time: 1.9413 Batch Time: 3.2264
# 2024-06-25 16:22:26,256 - INFO - TRAIN Epoch: 10 Step: 16/18 Loss: 0.3548 Accuracy: 0.8520 AUC: 0.0000 Data Time: 1.9216 Batch Time: 3.1889
# 2024-06-25 16:22:26,996 - INFO - TRAIN Epoch: 10 Step: 17/18 Loss: 0.3557 Accuracy: 0.8505 AUC: 0.0000 Data Time: 1.8395 Batch Time: 3.0528
# 2024-06-25 16:22:27,001 - INFO - AUC Score: 0.8514
# 2024-06-25 16:22:28,932 - INFO - VAL Epoch: 10 Step: 0/5 Loss: 0.4192 Accuracy: 0.8333 AUC: 0.0000 Data Time: 0.9469 Batch Time: 1.9290
# 2024-06-25 16:22:31,243 - INFO - VAL Epoch: 10 Step: 1/5 Loss: 0.3648 Accuracy: 0.8583 AUC: 0.0000 Data Time: 1.1202 Batch Time: 2.1193
# 2024-06-25 16:22:33,516 - INFO - VAL Epoch: 10 Step: 2/5 Loss: 0.3824 Accuracy: 0.8389 AUC: 0.0000 Data Time: 1.1695 Batch Time: 2.1700
# 2024-06-25 16:22:35,580 - INFO - VAL Epoch: 10 Step: 3/5 Loss: 0.3914 Accuracy: 0.8292 AUC: 0.0000 Data Time: 1.1463 Batch Time: 2.1431
# 2024-06-25 16:22:36,166 - INFO - VAL Epoch: 10 Step: 4/5 Loss: 0.4101 Accuracy: 0.8227 AUC: 0.0000 Data Time: 0.9678 Batch Time: 1.8315
# 2024-06-25 16:22:36,172 - INFO - AUC Score: 0.8120
# 2024-06-25 16:22:36,261 - INFO - Starting Epoch: 12
# 2024-06-25 16:22:38,844 - INFO - TRAIN Epoch: 11 Step: 0/18 Loss: 0.4220 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.5926 Batch Time: 2.5815
# 2024-06-25 16:22:41,082 - INFO - TRAIN Epoch: 11 Step: 1/18 Loss: 0.3842 Accuracy: 0.8458 AUC: 0.0000 Data Time: 1.4056 Batch Time: 2.4091
# 2024-06-25 16:22:43,362 - INFO - TRAIN Epoch: 11 Step: 2/18 Loss: 0.3777 Accuracy: 0.8417 AUC: 0.0000 Data Time: 1.3493 Batch Time: 2.3656
# 2024-06-25 16:22:46,067 - INFO - TRAIN Epoch: 11 Step: 3/18 Loss: 0.3731 Accuracy: 0.8458 AUC: 0.0000 Data Time: 1.4407 Batch Time: 2.4500
# 2024-06-25 16:22:48,221 - INFO - TRAIN Epoch: 11 Step: 4/18 Loss: 0.3640 Accuracy: 0.8500 AUC: 0.0000 Data Time: 1.3852 Batch Time: 2.3905
# 2024-06-25 16:22:50,828 - INFO - TRAIN Epoch: 11 Step: 5/18 Loss: 0.3678 Accuracy: 0.8486 AUC: 0.0000 Data Time: 1.4240 Batch Time: 2.4264
# 2024-06-25 16:22:53,043 - INFO - TRAIN Epoch: 11 Step: 6/18 Loss: 0.3692 Accuracy: 0.8464 AUC: 0.0000 Data Time: 1.3845 Batch Time: 2.3959
# 2024-06-25 16:22:55,186 - INFO - TRAIN Epoch: 11 Step: 7/18 Loss: 0.3595 Accuracy: 0.8531 AUC: 0.0000 Data Time: 1.3528 Batch Time: 2.3641
# 2024-06-25 16:22:57,564 - INFO - TRAIN Epoch: 11 Step: 8/18 Loss: 0.3589 Accuracy: 0.8491 AUC: 0.0000 Data Time: 1.3536 Batch Time: 2.3655
# 2024-06-25 16:22:59,912 - INFO - TRAIN Epoch: 11 Step: 9/18 Loss: 0.3583 Accuracy: 0.8467 AUC: 0.0000 Data Time: 1.3518 Batch Time: 2.3636
# 2024-06-25 16:23:02,403 - INFO - TRAIN Epoch: 11 Step: 10/18 Loss: 0.3554 Accuracy: 0.8470 AUC: 0.0000 Data Time: 1.3603 Batch Time: 2.3751
# 2024-06-25 16:23:04,600 - INFO - TRAIN Epoch: 11 Step: 11/18 Loss: 0.3510 Accuracy: 0.8493 AUC: 0.0000 Data Time: 1.3480 Batch Time: 2.3601
# 2024-06-25 16:23:06,755 - INFO - TRAIN Epoch: 11 Step: 12/18 Loss: 0.3556 Accuracy: 0.8468 AUC: 0.0000 Data Time: 1.3344 Batch Time: 2.3442
# 2024-06-25 16:23:08,985 - INFO - TRAIN Epoch: 11 Step: 13/18 Loss: 0.3540 Accuracy: 0.8488 AUC: 0.0000 Data Time: 1.3282 Batch Time: 2.3360
# 2024-06-25 16:23:11,648 - INFO - TRAIN Epoch: 11 Step: 14/18 Loss: 0.3567 Accuracy: 0.8483 AUC: 0.0000 Data Time: 1.3495 Batch Time: 2.3577
# 2024-06-25 16:23:14,035 - INFO - TRAIN Epoch: 11 Step: 15/18 Loss: 0.3560 Accuracy: 0.8479 AUC: 0.0000 Data Time: 1.3525 Batch Time: 2.3594
# 2024-06-25 16:23:16,430 - INFO - TRAIN Epoch: 11 Step: 16/18 Loss: 0.3550 Accuracy: 0.8485 AUC: 0.0000 Data Time: 1.3560 Batch Time: 2.3614
# 2024-06-25 16:23:17,226 - INFO - TRAIN Epoch: 11 Step: 17/18 Loss: 0.3521 Accuracy: 0.8500 AUC: 0.0000 Data Time: 1.3055 Batch Time: 2.2743
# 2024-06-25 16:23:17,230 - INFO - AUC Score: 0.8523
# 2024-06-25 16:23:19,423 - INFO - VAL Epoch: 11 Step: 0/5 Loss: 0.5482 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.2117 Batch Time: 2.1920
# 2024-06-25 16:23:21,696 - INFO - VAL Epoch: 11 Step: 1/5 Loss: 0.4977 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.2392 Batch Time: 2.2314
# 2024-06-25 16:23:23,811 - INFO - VAL Epoch: 11 Step: 2/5 Loss: 0.5019 Accuracy: 0.8333 AUC: 0.0000 Data Time: 1.1937 Batch Time: 2.1921
# 2024-06-25 16:23:25,847 - INFO - VAL Epoch: 11 Step: 3/5 Loss: 0.5599 Accuracy: 0.8187 AUC: 0.0000 Data Time: 1.1486 Batch Time: 2.1529
# 2024-06-25 16:23:26,650 - INFO - VAL Epoch: 11 Step: 4/5 Loss: 0.5993 Accuracy: 0.8092 AUC: 0.0000 Data Time: 1.0110 Batch Time: 1.8827
# 2024-06-25 16:23:26,656 - INFO - AUC Score: 0.7953
# 2024-06-25 16:23:26,749 - INFO - Starting Epoch: 13
# 2024-06-25 16:23:29,680 - INFO - TRAIN Epoch: 12 Step: 0/18 Loss: 0.6367 Accuracy: 0.7667 AUC: 0.0000 Data Time: 1.9185 Batch Time: 2.9275
# 2024-06-25 16:23:32,573 - INFO - TRAIN Epoch: 12 Step: 1/18 Loss: 0.4900 Accuracy: 0.8083 AUC: 0.0000 Data Time: 1.8966 Batch Time: 2.9092
# 2024-06-25 16:23:34,900 - INFO - TRAIN Epoch: 12 Step: 2/18 Loss: 0.4219 Accuracy: 0.8306 AUC: 0.0000 Data Time: 1.7043 Batch Time: 2.7145
# 2024-06-25 16:23:37,153 - INFO - TRAIN Epoch: 12 Step: 3/18 Loss: 0.4088 Accuracy: 0.8292 AUC: 0.0000 Data Time: 1.5654 Batch Time: 2.5988
# 2024-06-25 16:23:39,411 - INFO - TRAIN Epoch: 12 Step: 4/18 Loss: 0.4213 Accuracy: 0.8150 AUC: 0.0000 Data Time: 1.4820 Batch Time: 2.5306
# 2024-06-25 16:23:41,667 - INFO - TRAIN Epoch: 12 Step: 5/18 Loss: 0.4200 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.4460 Batch Time: 2.4846
# 2024-06-25 16:23:43,932 - INFO - TRAIN Epoch: 12 Step: 6/18 Loss: 0.4086 Accuracy: 0.8226 AUC: 0.0000 Data Time: 1.4146 Batch Time: 2.4530
# 2024-06-25 16:23:46,043 - INFO - TRAIN Epoch: 12 Step: 7/18 Loss: 0.4091 Accuracy: 0.8208 AUC: 0.0000 Data Time: 1.3780 Batch Time: 2.4101
# 2024-06-25 16:23:48,608 - INFO - TRAIN Epoch: 12 Step: 8/18 Loss: 0.4241 Accuracy: 0.8102 AUC: 0.0000 Data Time: 1.4001 Batch Time: 2.4272
# 2024-06-25 16:23:51,351 - INFO - TRAIN Epoch: 12 Step: 9/18 Loss: 0.4168 Accuracy: 0.8125 AUC: 0.0000 Data Time: 1.4311 Batch Time: 2.4586
# 2024-06-25 16:23:54,148 - INFO - TRAIN Epoch: 12 Step: 10/18 Loss: 0.4152 Accuracy: 0.8136 AUC: 0.0000 Data Time: 1.4617 Batch Time: 2.4892
# 2024-06-25 16:23:56,987 - INFO - TRAIN Epoch: 12 Step: 11/18 Loss: 0.4132 Accuracy: 0.8118 AUC: 0.0000 Data Time: 1.4881 Batch Time: 2.5183
# 2024-06-25 16:23:59,511 - INFO - TRAIN Epoch: 12 Step: 12/18 Loss: 0.4126 Accuracy: 0.8122 AUC: 0.0000 Data Time: 1.4877 Batch Time: 2.5186
# 2024-06-25 16:24:03,008 - INFO - TRAIN Epoch: 12 Step: 13/18 Loss: 0.4094 Accuracy: 0.8137 AUC: 0.0000 Data Time: 1.5564 Batch Time: 2.5884
# 2024-06-25 16:24:05,731 - INFO - TRAIN Epoch: 12 Step: 14/18 Loss: 0.4030 Accuracy: 0.8178 AUC: 0.0000 Data Time: 1.5679 Batch Time: 2.5971
# 2024-06-25 16:24:08,200 - INFO - TRAIN Epoch: 12 Step: 15/18 Loss: 0.4009 Accuracy: 0.8193 AUC: 0.0000 Data Time: 1.5617 Batch Time: 2.5890
# 2024-06-25 16:24:11,639 - INFO - TRAIN Epoch: 12 Step: 16/18 Loss: 0.4007 Accuracy: 0.8186 AUC: 0.0000 Data Time: 1.6075 Batch Time: 2.6389
# 2024-06-25 16:24:12,427 - INFO - TRAIN Epoch: 12 Step: 17/18 Loss: 0.4004 Accuracy: 0.8182 AUC: 0.0000 Data Time: 1.5450 Batch Time: 2.5360
# 2024-06-25 16:24:12,432 - INFO - AUC Score: 0.8051
# 2024-06-25 16:24:14,954 - INFO - VAL Epoch: 12 Step: 0/5 Loss: 0.3879 Accuracy: 0.8500 AUC: 0.0000 Data Time: 1.3961 Batch Time: 2.5193
# 2024-06-25 16:24:17,491 - INFO - VAL Epoch: 12 Step: 1/5 Loss: 0.3488 Accuracy: 0.8667 AUC: 0.0000 Data Time: 1.3694 Batch Time: 2.5274
# 2024-06-25 16:24:20,464 - INFO - VAL Epoch: 12 Step: 2/5 Loss: 0.3599 Accuracy: 0.8528 AUC: 0.0000 Data Time: 1.5718 Batch Time: 2.6755
# 2024-06-25 16:24:24,205 - INFO - VAL Epoch: 12 Step: 3/5 Loss: 0.3800 Accuracy: 0.8354 AUC: 0.0000 Data Time: 1.6302 Batch Time: 2.9413
# 2024-06-25 16:24:25,049 - INFO - VAL Epoch: 12 Step: 4/5 Loss: 0.4007 Accuracy: 0.8247 AUC: 0.0000 Data Time: 1.4046 Batch Time: 2.5216
# 2024-06-25 16:24:25,053 - INFO - AUC Score: 0.7979
# 2024-06-25 16:24:25,145 - INFO - Starting Epoch: 14
# 2024-06-25 16:24:28,796 - INFO - TRAIN Epoch: 13 Step: 0/18 Loss: 0.3689 Accuracy: 0.8500 AUC: 0.0000 Data Time: 1.5420 Batch Time: 3.6484
# 2024-06-25 16:24:31,232 - INFO - TRAIN Epoch: 13 Step: 1/18 Loss: 0.3459 Accuracy: 0.8667 AUC: 0.0000 Data Time: 1.4817 Batch Time: 3.0406
# 2024-06-25 16:24:33,885 - INFO - TRAIN Epoch: 13 Step: 2/18 Loss: 0.3621 Accuracy: 0.8667 AUC: 0.0000 Data Time: 1.5324 Batch Time: 2.9111
# 2024-06-25 16:24:37,707 - INFO - TRAIN Epoch: 13 Step: 3/18 Loss: 0.3613 Accuracy: 0.8604 AUC: 0.0000 Data Time: 1.7686 Batch Time: 3.1382
# 2024-06-25 16:24:40,491 - INFO - TRAIN Epoch: 13 Step: 4/18 Loss: 0.3697 Accuracy: 0.8517 AUC: 0.0000 Data Time: 1.7704 Batch Time: 3.0664
# 2024-06-25 16:24:42,962 - INFO - TRAIN Epoch: 13 Step: 5/18 Loss: 0.3717 Accuracy: 0.8514 AUC: 0.0000 Data Time: 1.7200 Batch Time: 2.9664
# 2024-06-25 16:24:45,428 - INFO - TRAIN Epoch: 13 Step: 6/18 Loss: 0.3572 Accuracy: 0.8595 AUC: 0.0000 Data Time: 1.6816 Batch Time: 2.8947
# 2024-06-25 16:24:47,882 - INFO - TRAIN Epoch: 13 Step: 7/18 Loss: 0.3766 Accuracy: 0.8458 AUC: 0.0000 Data Time: 1.6532 Batch Time: 2.8395
# 2024-06-25 16:24:50,366 - INFO - TRAIN Epoch: 13 Step: 8/18 Loss: 0.3731 Accuracy: 0.8491 AUC: 0.0000 Data Time: 1.6347 Batch Time: 2.7998
# 2024-06-25 16:24:52,848 - INFO - TRAIN Epoch: 13 Step: 9/18 Loss: 0.3750 Accuracy: 0.8500 AUC: 0.0000 Data Time: 1.6181 Batch Time: 2.7678
# 2024-06-25 16:24:55,214 - INFO - TRAIN Epoch: 13 Step: 10/18 Loss: 0.3807 Accuracy: 0.8477 AUC: 0.0000 Data Time: 1.5953 Batch Time: 2.7311
# 2024-06-25 16:24:57,704 - INFO - TRAIN Epoch: 13 Step: 11/18 Loss: 0.3759 Accuracy: 0.8493 AUC: 0.0000 Data Time: 1.5863 Batch Time: 2.7108
# 2024-06-25 16:25:00,423 - INFO - TRAIN Epoch: 13 Step: 12/18 Loss: 0.3755 Accuracy: 0.8481 AUC: 0.0000 Data Time: 1.5957 Batch Time: 2.7114
# 2024-06-25 16:25:02,929 - INFO - TRAIN Epoch: 13 Step: 13/18 Loss: 0.3745 Accuracy: 0.8464 AUC: 0.0000 Data Time: 1.5884 Batch Time: 2.6966
# 2024-06-25 16:25:05,507 - INFO - TRAIN Epoch: 13 Step: 14/18 Loss: 0.3726 Accuracy: 0.8472 AUC: 0.0000 Data Time: 1.5859 Batch Time: 2.6886
# 2024-06-25 16:25:08,296 - INFO - TRAIN Epoch: 13 Step: 15/18 Loss: 0.3686 Accuracy: 0.8490 AUC: 0.0000 Data Time: 1.5949 Batch Time: 2.6947
# 2024-06-25 16:25:11,295 - INFO - TRAIN Epoch: 13 Step: 16/18 Loss: 0.3662 Accuracy: 0.8500 AUC: 0.0000 Data Time: 1.6163 Batch Time: 2.7125
# 2024-06-25 16:25:11,928 - INFO - TRAIN Epoch: 13 Step: 17/18 Loss: 0.3627 Accuracy: 0.8515 AUC: 0.0000 Data Time: 1.5450 Batch Time: 2.5969
# 2024-06-25 16:25:11,936 - INFO - AUC Score: 0.8422
# 2024-06-25 16:25:14,903 - INFO - VAL Epoch: 13 Step: 0/5 Loss: 0.4069 Accuracy: 0.8417 AUC: 0.0000 Data Time: 1.9596 Batch Time: 2.9635
# 2024-06-25 16:25:18,004 - INFO - VAL Epoch: 13 Step: 1/5 Loss: 0.3644 Accuracy: 0.8667 AUC: 0.0000 Data Time: 2.0223 Batch Time: 3.0301
# 2024-06-25 16:25:20,656 - INFO - VAL Epoch: 13 Step: 2/5 Loss: 0.3765 Accuracy: 0.8639 AUC: 0.0000 Data Time: 1.8888 Batch Time: 2.9028
# 2024-06-25 16:25:23,110 - INFO - VAL Epoch: 13 Step: 3/5 Loss: 0.4084 Accuracy: 0.8438 AUC: 0.0000 Data Time: 1.7760 Batch Time: 2.7898
# 2024-06-25 16:25:23,897 - INFO - VAL Epoch: 13 Step: 4/5 Loss: 0.4361 Accuracy: 0.8324 AUC: 0.0000 Data Time: 1.5097 Batch Time: 2.3888
# 2024-06-25 16:25:23,901 - INFO - AUC Score: 0.8099
# 2024-06-25 16:25:23,987 - INFO - Starting Epoch: 15
# 2024-06-25 16:25:26,404 - INFO - TRAIN Epoch: 14 Step: 0/18 Loss: 0.3776 Accuracy: 0.8500 AUC: 0.0000 Data Time: 1.4138 Batch Time: 2.4140
# 2024-06-25 16:25:28,812 - INFO - TRAIN Epoch: 14 Step: 1/18 Loss: 0.3855 Accuracy: 0.8375 AUC: 0.0000 Data Time: 1.4093 Batch Time: 2.4090
# 2024-06-25 16:25:31,294 - INFO - TRAIN Epoch: 14 Step: 2/18 Loss: 0.3565 Accuracy: 0.8472 AUC: 0.0000 Data Time: 1.4275 Batch Time: 2.4325
# 2024-06-25 16:25:33,538 - INFO - TRAIN Epoch: 14 Step: 3/18 Loss: 0.3648 Accuracy: 0.8479 AUC: 0.0000 Data Time: 1.3789 Batch Time: 2.3849
# ...
# 2024-06-25 16:49:55,341 - INFO - TRAIN Epoch: 39 Step: 3/18 Loss: 0.3169 Accuracy: 0.8667 AUC: 0.0000 Data Time: 3.5170 Batch Time: 5.5258
# 2024-06-25 16:50:00,540 - INFO - TRAIN Epoch: 39 Step: 4/18 Loss: 0.3115 Accuracy: 0.8683 AUC: 0.0000 Data Time: 3.5918 Batch Time: 5.4594
# 2024-06-25 16:50:08,281 - INFO - TRAIN Epoch: 39 Step: 5/18 Loss: 0.2955 Accuracy: 0.8736 AUC: 0.0000 Data Time: 3.7501 Batch Time: 5.8363
# 2024-06-25 16:50:14,977 - INFO - TRAIN Epoch: 39 Step: 6/18 Loss: 0.2881 Accuracy: 0.8798 AUC: 0.0000 Data Time: 3.9881 Batch Time: 5.9586
# 2024-06-25 16:50:21,287 - INFO - TRAIN Epoch: 39 Step: 7/18 Loss: 0.2912 Accuracy: 0.8792 AUC: 0.0000 Data Time: 4.1068 Batch Time: 6.0024
# 2024-06-25 16:50:27,397 - INFO - TRAIN Epoch: 39 Step: 8/18 Loss: 0.2895 Accuracy: 0.8796 AUC: 0.0000 Data Time: 4.1643 Batch Time: 6.0140
# 2024-06-25 16:50:33,403 - INFO - TRAIN Epoch: 39 Step: 9/18 Loss: 0.2949 Accuracy: 0.8717 AUC: 0.0000 Data Time: 4.1704 Batch Time: 6.0124
# 2024-06-25 16:50:39,552 - INFO - TRAIN Epoch: 39 Step: 10/18 Loss: 0.2928 Accuracy: 0.8742 AUC: 0.0000 Data Time: 4.0986 Batch Time: 6.0245
# 2024-06-25 16:50:45,142 - INFO - TRAIN Epoch: 39 Step: 11/18 Loss: 0.2907 Accuracy: 0.8764 AUC: 0.0000 Data Time: 4.1284 Batch Time: 5.9874
# 2024-06-25 16:50:51,237 - INFO - TRAIN Epoch: 39 Step: 12/18 Loss: 0.2883 Accuracy: 0.8769 AUC: 0.0000 Data Time: 4.1806 Batch Time: 5.9941
# 2024-06-25 16:50:59,369 - INFO - TRAIN Epoch: 39 Step: 13/18 Loss: 0.2907 Accuracy: 0.8768 AUC: 0.0000 Data Time: 4.2622 Batch Time: 6.1465
# 2024-06-25 16:51:07,166 - INFO - TRAIN Epoch: 39 Step: 14/18 Loss: 0.2878 Accuracy: 0.8778 AUC: 0.0000 Data Time: 4.4026 Batch Time: 6.2557
# 2024-06-25 16:51:12,324 - INFO - TRAIN Epoch: 39 Step: 15/18 Loss: 0.2877 Accuracy: 0.8776 AUC: 0.0000 Data Time: 4.3786 Batch Time: 6.1866
# 2024-06-25 16:51:17,875 - INFO - TRAIN Epoch: 39 Step: 16/18 Loss: 0.2828 Accuracy: 0.8804 AUC: 0.0000 Data Time: 4.2967 Batch Time: 6.1490
# 2024-06-25 16:51:19,370 - INFO - TRAIN Epoch: 39 Step: 17/18 Loss: 0.2831 Accuracy: 0.8799 AUC: 0.0000 Data Time: 4.1158 Batch Time: 5.8900
# 2024-06-25 16:51:19,375 - INFO - AUC Score: 0.9124
# 2024-06-25 16:51:25,928 - INFO - VAL Epoch: 39 Step: 0/5 Loss: 0.4308 Accuracy: 0.8500 AUC: 0.0000 Data Time: 4.3151 Batch Time: 6.5492
# 2024-06-25 16:51:31,100 - INFO - VAL Epoch: 39 Step: 1/5 Loss: 0.3921 Accuracy: 0.8625 AUC: 0.0000 Data Time: 4.1600 Batch Time: 5.8590
# 2024-06-25 16:51:36,236 - INFO - VAL Epoch: 39 Step: 2/5 Loss: 0.4024 Accuracy: 0.8583 AUC: 0.0000 Data Time: 3.7589 Batch Time: 5.6161
# 2024-06-25 16:51:44,920 - INFO - VAL Epoch: 39 Step: 3/5 Loss: 0.4520 Accuracy: 0.8375 AUC: 0.0000 Data Time: 4.1221 Batch Time: 6.3816
# 2024-06-25 16:51:46,477 - INFO - VAL Epoch: 39 Step: 4/5 Loss: 0.4863 Accuracy: 0.8285 AUC: 0.0000 Data Time: 3.5251 Batch Time: 5.4158
# 2024-06-25 16:51:46,487 - INFO - AUC Score: 0.8162
# 2024-06-25 16:51:46,655 - INFO - Starting Epoch: 41
# 2024-06-25 16:51:51,740 - INFO - TRAIN Epoch: 40 Step: 0/18 Loss: 0.4364 Accuracy: 0.7833 AUC: 0.0000 Data Time: 3.0921 Batch Time: 5.0766
# 2024-06-25 16:51:55,809 - INFO - TRAIN Epoch: 40 Step: 1/18 Loss: 0.3939 Accuracy: 0.8083 AUC: 0.0000 Data Time: 2.8812 Batch Time: 4.5717
# 2024-06-25 16:52:03,472 - INFO - TRAIN Epoch: 40 Step: 2/18 Loss: 0.3882 Accuracy: 0.8083 AUC: 0.0000 Data Time: 3.2192 Batch Time: 5.6010
# 2024-06-25 16:52:11,193 - INFO - TRAIN Epoch: 40 Step: 3/18 Loss: 0.3926 Accuracy: 0.8063 AUC: 0.0000 Data Time: 3.4404 Batch Time: 6.1287
# 2024-06-25 16:52:19,375 - INFO - TRAIN Epoch: 40 Step: 4/18 Loss: 0.3680 Accuracy: 0.8300 AUC: 0.0000 Data Time: 3.7358 Batch Time: 6.5388
# 2024-06-25 16:52:26,869 - INFO - TRAIN Epoch: 40 Step: 5/18 Loss: 0.3857 Accuracy: 0.8250 AUC: 0.0000 Data Time: 3.8605 Batch Time: 6.6976
# 2024-06-25 16:52:34,236 - INFO - TRAIN Epoch: 40 Step: 6/18 Loss: 0.3748 Accuracy: 0.8298 AUC: 0.0000 Data Time: 3.8136 Batch Time: 6.7929
# 2024-06-25 16:52:39,691 - INFO - TRAIN Epoch: 40 Step: 7/18 Loss: 0.3636 Accuracy: 0.8344 AUC: 0.0000 Data Time: 3.7026 Batch Time: 6.6255
# 2024-06-25 16:52:44,093 - INFO - TRAIN Epoch: 40 Step: 8/18 Loss: 0.3516 Accuracy: 0.8398 AUC: 0.0000 Data Time: 3.6383 Batch Time: 6.3782
# 2024-06-25 16:52:49,462 - INFO - TRAIN Epoch: 40 Step: 9/18 Loss: 0.3503 Accuracy: 0.8392 AUC: 0.0000 Data Time: 3.6692 Batch Time: 6.2768
# 2024-06-25 16:52:55,194 - INFO - TRAIN Epoch: 40 Step: 10/18 Loss: 0.3516 Accuracy: 0.8394 AUC: 0.0000 Data Time: 3.7355 Batch Time: 6.2269
# 2024-06-25 16:53:01,721 - INFO - TRAIN Epoch: 40 Step: 11/18 Loss: 0.3470 Accuracy: 0.8410 AUC: 0.0000 Data Time: 3.8197 Batch Time: 6.2515
# 2024-06-25 16:53:07,653 - INFO - TRAIN Epoch: 40 Step: 12/18 Loss: 0.3436 Accuracy: 0.8442 AUC: 0.0000 Data Time: 3.7762 Batch Time: 6.2267
# 2024-06-25 16:53:12,409 - INFO - TRAIN Epoch: 40 Step: 13/18 Loss: 0.3446 Accuracy: 0.8440 AUC: 0.0000 Data Time: 3.7282 Batch Time: 6.1214
# 2024-06-25 16:53:16,625 - INFO - TRAIN Epoch: 40 Step: 14/18 Loss: 0.3447 Accuracy: 0.8433 AUC: 0.0000 Data Time: 3.6842 Batch Time: 5.9942
# 2024-06-25 16:53:19,236 - INFO - TRAIN Epoch: 40 Step: 15/18 Loss: 0.3436 Accuracy: 0.8427 AUC: 0.0000 Data Time: 3.5523 Batch Time: 5.7827
# 2024-06-25 16:53:22,239 - INFO - TRAIN Epoch: 40 Step: 16/18 Loss: 0.3401 Accuracy: 0.8461 AUC: 0.0000 Data Time: 3.4575 Batch Time: 5.6191
# 2024-06-25 16:53:23,082 - INFO - TRAIN Epoch: 40 Step: 17/18 Loss: 0.3406 Accuracy: 0.8462 AUC: 0.0000 Data Time: 3.2928 Batch Time: 5.3536
# 2024-06-25 16:53:23,088 - INFO - AUC Score: 0.8706
# 2024-06-25 16:53:25,831 - INFO - VAL Epoch: 40 Step: 0/5 Loss: 0.4320 Accuracy: 0.8167 AUC: 0.0000 Data Time: 1.7480 Batch Time: 2.7391
# 2024-06-25 16:53:28,856 - INFO - VAL Epoch: 40 Step: 1/5 Loss: 0.3829 Accuracy: 0.8375 AUC: 0.0000 Data Time: 1.8792 Batch Time: 2.8788
# 2024-06-25 16:53:31,771 - INFO - VAL Epoch: 40 Step: 2/5 Loss: 0.3973 Accuracy: 0.8278 AUC: 0.0000 Data Time: 1.8588 Batch Time: 2.8905
# 2024-06-25 16:53:34,943 - INFO - VAL Epoch: 40 Step: 3/5 Loss: 0.4028 Accuracy: 0.8250 AUC: 0.0000 Data Time: 1.9186 Batch Time: 2.9605
# 2024-06-25 16:53:35,638 - INFO - VAL Epoch: 40 Step: 4/5 Loss: 0.4173 Accuracy: 0.8170 AUC: 0.0000 Data Time: 1.6072 Batch Time: 2.5070
# 2024-06-25 16:53:35,648 - INFO - AUC Score: 0.8342
# 2024-06-25 16:53:35,835 - INFO - Starting Epoch: 42
# 2024-06-25 16:53:38,309 - INFO - TRAIN Epoch: 41 Step: 0/18 Loss: 0.2956 Accuracy: 0.8833 AUC: 0.0000 Data Time: 1.3961 Batch Time: 2.4715
# 2024-06-25 16:53:41,778 - INFO - TRAIN Epoch: 41 Step: 1/18 Loss: 0.2738 Accuracy: 0.8917 AUC: 0.0000 Data Time: 1.8811 Batch Time: 2.9665
# 2024-06-25 16:53:44,846 - INFO - TRAIN Epoch: 41 Step: 2/18 Loss: 0.2785 Accuracy: 0.8778 AUC: 0.0000 Data Time: 1.9303 Batch Time: 3.0000
# 2024-06-25 16:53:47,951 - INFO - TRAIN Epoch: 41 Step: 3/18 Loss: 0.2861 Accuracy: 0.8708 AUC: 0.0000 Data Time: 1.9640 Batch Time: 3.0258
# 2024-06-25 16:53:51,102 - INFO - TRAIN Epoch: 41 Step: 4/18 Loss: 0.3026 Accuracy: 0.8650 AUC: 0.0000 Data Time: 1.9922 Batch Time: 3.0506
# 2024-06-25 16:53:54,425 - INFO - TRAIN Epoch: 41 Step: 5/18 Loss: 0.3062 Accuracy: 0.8639 AUC: 0.0000 Data Time: 2.0389 Batch Time: 3.0957
# 2024-06-25 16:53:57,407 - INFO - TRAIN Epoch: 41 Step: 6/18 Loss: 0.3021 Accuracy: 0.8667 AUC: 0.0000 Data Time: 2.0247 Batch Time: 3.0793
# 2024-06-25 16:54:00,194 - INFO - TRAIN Epoch: 41 Step: 7/18 Loss: 0.3028 Accuracy: 0.8677 AUC: 0.0000 Data Time: 1.9912 Batch Time: 3.0427
# 2024-06-25 16:54:02,905 - INFO - TRAIN Epoch: 41 Step: 8/18 Loss: 0.3006 Accuracy: 0.8685 AUC: 0.0000 Data Time: 1.9551 Batch Time: 3.0056
# 2024-06-25 16:54:06,113 - INFO - TRAIN Epoch: 41 Step: 9/18 Loss: 0.2963 Accuracy: 0.8700 AUC: 0.0000 Data Time: 1.9754 Batch Time: 3.0259
# 2024-06-25 16:54:09,135 - INFO - TRAIN Epoch: 41 Step: 10/18 Loss: 0.2969 Accuracy: 0.8674 AUC: 0.0000 Data Time: 1.9751 Batch Time: 3.0254
# 2024-06-25 16:54:12,483 - INFO - TRAIN Epoch: 41 Step: 11/18 Loss: 0.3009 Accuracy: 0.8660 AUC: 0.0000 Data Time: 1.9982 Batch Time: 3.0522
# 2024-06-25 16:54:15,734 - INFO - TRAIN Epoch: 41 Step: 12/18 Loss: 0.3025 Accuracy: 0.8660 AUC: 0.0000 Data Time: 2.0100 Batch Time: 3.0671
# 2024-06-25 16:54:19,112 - INFO - TRAIN Epoch: 41 Step: 13/18 Loss: 0.3012 Accuracy: 0.8685 AUC: 0.0000 Data Time: 2.0332 Batch Time: 3.0887
# 2024-06-25 16:54:21,965 - INFO - TRAIN Epoch: 41 Step: 14/18 Loss: 0.2951 Accuracy: 0.8717 AUC: 0.0000 Data Time: 2.0215 Batch Time: 3.0729
# 2024-06-25 16:54:25,213 - INFO - TRAIN Epoch: 41 Step: 15/18 Loss: 0.2964 Accuracy: 0.8693 AUC: 0.0000 Data Time: 2.0342 Batch Time: 3.0832
# 2024-06-25 16:54:27,924 - INFO - TRAIN Epoch: 41 Step: 16/18 Loss: 0.2956 Accuracy: 0.8686 AUC: 0.0000 Data Time: 2.0126 Batch Time: 3.0612
# 2024-06-25 16:54:28,655 - INFO - TRAIN Epoch: 41 Step: 17/18 Loss: 0.2940 Accuracy: 0.8693 AUC: 0.0000 Data Time: 1.9242 Batch Time: 2.9317
# 2024-06-25 16:54:28,658 - INFO - AUC Score: 0.9065
# 2024-06-25 16:54:31,465 - INFO - VAL Epoch: 41 Step: 0/5 Loss: 0.3570 Accuracy: 0.8417 AUC: 0.0000 Data Time: 1.8068 Batch Time: 2.8044
# 2024-06-25 16:54:34,441 - INFO - VAL Epoch: 41 Step: 1/5 Loss: 0.3228 Accuracy: 0.8542 AUC: 0.0000 Data Time: 1.8660 Batch Time: 2.8895
# 2024-06-25 16:54:37,141 - INFO - VAL Epoch: 41 Step: 2/5 Loss: 0.3341 Accuracy: 0.8528 AUC: 0.0000 Data Time: 1.8115 Batch Time: 2.8256
# 2024-06-25 16:54:39,730 - INFO - VAL Epoch: 41 Step: 3/5 Loss: 0.3628 Accuracy: 0.8396 AUC: 0.0000 Data Time: 1.7443 Batch Time: 2.7660
# 2024-06-25 16:54:40,685 - INFO - VAL Epoch: 41 Step: 4/5 Loss: 0.3836 Accuracy: 0.8304 AUC: 0.0000 Data Time: 1.5151 Batch Time: 2.4036
# 2024-06-25 16:54:40,689 - INFO - AUC Score: 0.8330
# 2024-06-25 16:54:40,778 - INFO - Starting Epoch: 43
# 2024-06-25 16:54:42,960 - INFO - TRAIN Epoch: 42 Step: 0/18 Loss: 0.3296 Accuracy: 0.8667 AUC: 0.0000 Data Time: 1.1901 Batch Time: 2.1795
# 2024-06-25 16:54:45,780 - INFO - TRAIN Epoch: 42 Step: 1/18 Loss: 0.2863 Accuracy: 0.8917 AUC: 0.0000 Data Time: 1.5031 Batch Time: 2.4990
# 2024-06-25 16:54:48,191 - INFO - TRAIN Epoch: 42 Step: 2/18 Loss: 0.2701 Accuracy: 0.8917 AUC: 0.0000 Data Time: 1.4680 Batch Time: 2.4690
# 2024-06-25 16:54:50,803 - INFO - TRAIN Epoch: 42 Step: 3/18 Loss: 0.2747 Accuracy: 0.8896 AUC: 0.0000 Data Time: 1.4760 Batch Time: 2.5045
# 2024-06-25 16:54:53,617 - INFO - TRAIN Epoch: 42 Step: 4/18 Loss: 0.2943 Accuracy: 0.8850 AUC: 0.0000 Data Time: 1.5295 Batch Time: 2.5659
# 2024-06-25 16:54:56,365 - INFO - TRAIN Epoch: 42 Step: 5/18 Loss: 0.2943 Accuracy: 0.8847 AUC: 0.0000 Data Time: 1.5499 Batch Time: 2.5960
# 2024-06-25 16:54:59,401 - INFO - TRAIN Epoch: 42 Step: 6/18 Loss: 0.2912 Accuracy: 0.8821 AUC: 0.0000 Data Time: 1.6089 Batch Time: 2.6588
# 2024-06-25 16:55:03,254 - INFO - TRAIN Epoch: 42 Step: 7/18 Loss: 0.2929 Accuracy: 0.8750 AUC: 0.0000 Data Time: 1.7497 Batch Time: 2.8077
# 2024-06-25 16:55:06,245 - INFO - TRAIN Epoch: 42 Step: 8/18 Loss: 0.2795 Accuracy: 0.8852 AUC: 0.0000 Data Time: 1.7591 Batch Time: 2.8279
# 2024-06-25 16:55:09,225 - INFO - TRAIN Epoch: 42 Step: 9/18 Loss: 0.2775 Accuracy: 0.8883 AUC: 0.0000 Data Time: 1.7750 Batch Time: 2.8430
# 2024-06-25 16:55:12,071 - INFO - TRAIN Epoch: 42 Step: 10/18 Loss: 0.2749 Accuracy: 0.8909 AUC: 0.0000 Data Time: 1.7729 Batch Time: 2.8431
# 2024-06-25 16:55:14,923 - INFO - TRAIN Epoch: 42 Step: 11/18 Loss: 0.2755 Accuracy: 0.8910 AUC: 0.0000 Data Time: 1.7729 Batch Time: 2.8436
# 2024-06-25 16:55:18,139 - INFO - TRAIN Epoch: 42 Step: 12/18 Loss: 0.2748 Accuracy: 0.8904 AUC: 0.0000 Data Time: 1.7983 Batch Time: 2.8722
# 2024-06-25 16:55:21,509 - INFO - TRAIN Epoch: 42 Step: 13/18 Loss: 0.2760 Accuracy: 0.8899 AUC: 0.0000 Data Time: 1.8337 Batch Time: 2.9076
# 2024-06-25 16:55:25,858 - INFO - TRAIN Epoch: 42 Step: 14/18 Loss: 0.2793 Accuracy: 0.8867 AUC: 0.0000 Data Time: 1.9266 Batch Time: 3.0036
# 2024-06-25 16:55:28,560 - INFO - TRAIN Epoch: 42 Step: 15/18 Loss: 0.2810 Accuracy: 0.8839 AUC: 0.0000 Data Time: 1.9090 Batch Time: 2.9847
# 2024-06-25 16:55:31,369 - INFO - TRAIN Epoch: 42 Step: 16/18 Loss: 0.2835 Accuracy: 0.8824 AUC: 0.0000 Data Time: 1.9009 Batch Time: 2.9743
# 2024-06-25 16:55:32,014 - INFO - TRAIN Epoch: 42 Step: 17/18 Loss: 0.2861 Accuracy: 0.8809 AUC: 0.0000 Data Time: 1.8148 Batch Time: 2.8448
# 2024-06-25 16:55:32,018 - INFO - AUC Score: 0.9105
# 2024-06-25 16:55:34,524 - INFO - VAL Epoch: 42 Step: 0/5 Loss: 0.3757 Accuracy: 0.8583 AUC: 0.0000 Data Time: 1.4662 Batch Time: 2.5044
# 2024-06-25 16:55:38,336 - INFO - VAL Epoch: 42 Step: 1/5 Loss: 0.3404 Accuracy: 0.8583 AUC: 0.0000 Data Time: 2.1092 Batch Time: 3.1576
# 2024-06-25 16:55:42,372 - INFO - VAL Epoch: 42 Step: 2/5 Loss: 0.3578 Accuracy: 0.8500 AUC: 0.0000 Data Time: 2.3406 Batch Time: 3.4495
# 2024-06-25 16:55:45,054 - INFO - VAL Epoch: 42 Step: 3/5 Loss: 0.3762 Accuracy: 0.8396 AUC: 0.0000 Data Time: 2.1759 Batch Time: 3.2563
# 2024-06-25 16:55:46,241 - INFO - VAL Epoch: 42 Step: 4/5 Loss: 0.3931 Accuracy: 0.8343 AUC: 0.0000 Data Time: 1.9018 Batch Time: 2.8420
# 2024-06-25 16:55:46,244 - INFO - AUC Score: 0.8373
# 2024-06-25 16:55:46,329 - INFO - Starting Epoch: 44
# 2024-06-25 16:55:48,675 - INFO - TRAIN Epoch: 43 Step: 0/18 Loss: 0.2814 Accuracy: 0.8750 AUC: 0.0000 Data Time: 1.3279 Batch Time: 2.3439
# 2024-06-25 16:55:51,557 - INFO - TRAIN Epoch: 43 Step: 1/18 Loss: 0.2778 Accuracy: 0.8792 AUC: 0.0000 Data Time: 1.5295 Batch Time: 2.6127
# 2024-06-25 16:55:54,833 - INFO - TRAIN Epoch: 43 Step: 2/18 Loss: 0.2839 Accuracy: 0.8833 AUC: 0.0000 Data Time: 1.7576 Batch Time: 2.8329
# 2024-06-25 16:55:57,129 - INFO - TRAIN Epoch: 43 Step: 3/18 Loss: 0.2911 Accuracy: 0.8771 AUC: 0.0000 Data Time: 1.6427 Batch Time: 2.6982
# 2024-06-25 16:55:59,804 - INFO - TRAIN Epoch: 43 Step: 4/18 Loss: 0.3235 Accuracy: 0.8617 AUC: 0.0000 Data Time: 1.6375 Batch Time: 2.6932
# 2024-06-25 16:56:02,427 - INFO - TRAIN Epoch: 43 Step: 5/18 Loss: 0.3234 Accuracy: 0.8611 AUC: 0.0000 Data Time: 1.6339 Batch Time: 2.6814
# 2024-06-25 16:56:05,301 - INFO - TRAIN Epoch: 43 Step: 6/18 Loss: 0.3283 Accuracy: 0.8631 AUC: 0.0000 Data Time: 1.6491 Batch Time: 2.7088
# 2024-06-25 16:56:08,111 - INFO - TRAIN Epoch: 43 Step: 7/18 Loss: 0.3232 Accuracy: 0.8646 AUC: 0.0000 Data Time: 1.6647 Batch Time: 2.7213
# 2024-06-25 16:56:10,565 - INFO - TRAIN Epoch: 43 Step: 8/18 Loss: 0.3226 Accuracy: 0.8620 AUC: 0.0000 Data Time: 1.6374 Batch Time: 2.6915
# 2024-06-25 16:56:13,493 - INFO - TRAIN Epoch: 43 Step: 9/18 Loss: 0.3199 Accuracy: 0.8583 AUC: 0.0000 Data Time: 1.6616 Batch Time: 2.7150
# 2024-06-25 16:56:15,911 - INFO - TRAIN Epoch: 43 Step: 10/18 Loss: 0.3132 Accuracy: 0.8629 AUC: 0.0000 Data Time: 1.6337 Batch Time: 2.6880
# 2024-06-25 16:56:18,342 - INFO - TRAIN Epoch: 43 Step: 11/18 Loss: 0.3101 Accuracy: 0.8653 AUC: 0.0000 Data Time: 1.6140 Batch Time: 2.6664
# 2024-06-25 16:56:21,582 - INFO - TRAIN Epoch: 43 Step: 12/18 Loss: 0.3067 Accuracy: 0.8692 AUC: 0.0000 Data Time: 1.6597 Batch Time: 2.7104
# 2024-06-25 16:56:24,656 - INFO - TRAIN Epoch: 43 Step: 13/18 Loss: 0.2982 Accuracy: 0.8750 AUC: 0.0000 Data Time: 1.6847 Batch Time: 2.7363
# 2024-06-25 16:56:28,007 - INFO - TRAIN Epoch: 43 Step: 14/18 Loss: 0.2992 Accuracy: 0.8744 AUC: 0.0000 Data Time: 1.7245 Batch Time: 2.7769
# 2024-06-25 16:56:30,880 - INFO - TRAIN Epoch: 43 Step: 15/18 Loss: 0.2966 Accuracy: 0.8750 AUC: 0.0000 Data Time: 1.7271 Batch Time: 2.7828
# 2024-06-25 16:56:35,607 - INFO - TRAIN Epoch: 43 Step: 16/18 Loss: 0.2983 Accuracy: 0.8750 AUC: 0.0000 Data Time: 1.8305 Batch Time: 2.8971
# 2024-06-25 16:56:36,929 - INFO - TRAIN Epoch: 43 Step: 17/18 Loss: 0.2961 Accuracy: 0.8766 AUC: 0.0000 Data Time: 1.7821 Batch Time: 2.8094
# 2024-06-25 16:56:36,943 - INFO - AUC Score: 0.9040
# 2024-06-25 16:56:40,709 - INFO - VAL Epoch: 43 Step: 0/5 Loss: 0.4151 Accuracy: 0.8500 AUC: 0.0000 Data Time: 2.6506 Batch Time: 3.7640
# 2024-06-25 16:56:46,688 - INFO - VAL Epoch: 43 Step: 1/5 Loss: 0.3655 Accuracy: 0.8667 AUC: 0.0000 Data Time: 3.5768 Batch Time: 4.8696
# 2024-06-25 16:56:53,126 - INFO - VAL Epoch: 43 Step: 2/5 Loss: 0.3773 Accuracy: 0.8639 AUC: 0.0000 Data Time: 4.0085 Batch Time: 5.3916

# %%
trainer.auc_scores
